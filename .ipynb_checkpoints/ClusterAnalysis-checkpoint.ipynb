# %%
import pandas as pd

errorlogs_30100 = pd.read_pickle('errlogs.pkl') # from 30K to 100K
errorlogs_100end = pd.read_csv('errlogs-100000-end.csv') # from 100K to end 
errorlogs = pd.concat([errorlogs_30100, errorlogs_100end])
del errorlogs_30100
del errorlogs_100end
# found thanks to clustering! 
suspicious_cids = [70715, 70716, 74459, 74460, 74461, 74463, 74464]
suspicious_cids.append(88301) # very interesting case (as a data analyst: removing an outlier can dramatically ease your job!)
for cid in suspicious_cids:
    errorlogs = errorlogs[errorlogs.cid != cid]

# %%
# errorlogs = pd.read_csv('errlogs-25000-30000.csv') # from 100K to end

# %%
len(errorlogs)
# Out:
# 3644

# %%
errorlogs.loc[3]['error_message']
# Out:
# 3    make[4]: flex: Command not found\nmake[4]: ***...
# 3    drivers/gpu/drm/amd/amdgpu/amdgpu_object.c: In...
# Name: error_message, dtype: object

# %%
from enum import Enum, auto
class ErrorLog(Enum):
    BLACKLIGHT = auto(),
    BLACKLIGHT2 = auto(),
    CONFIG_NLS_DEFAULT = auto(),
    CRC32_CLUSTER = auto(),
    V4L2 = auto(), 
    OVERFLOW2 = auto(), 
    ULPI = auto(), 
    PCM = auto(),
    TTM = auto(), 
    AS68K = auto(), 
    GEN = auto(), 
    AICDB = auto(), 
    AIC7XXX = auto(),
    DRM_BRIDGE_CLUSTER = auto(),
    PINCTRL_CLUSTER = auto(), 
    BTBCM = auto(),
    BPFFANCY = auto(), 
    DEVM = auto(), 
    DEVM2 = auto(), 
    I2C_CLUSTER = auto() 
    


    

patterns = { ErrorLog.BLACKLIGHT : "undefined reference to `backlight_device",
            ErrorLog.BLACKLIGHT2: 'error: ‘intel_backlight_device_register’', # 'intel_backlight_device_register', # cid 87044 does not match BACKLIGHT 
            ErrorLog.CONFIG_NLS_DEFAULT : "CONFIG_NLS_DEFAULT",
            ErrorLog.CRC32_CLUSTER : 'undefined reference to `crc32', 
            ErrorLog.V4L2 : 'undefined reference to `v4l2',
            ErrorLog.OVERFLOW2 : '__read_overflow2',
            ErrorLog.ULPI : 'undefined reference to `ulpi', # 100-126K dataset
            ErrorLog.PCM : 'undefined reference to `atmel_pcm_dma_platform', # 100-126K dataset
            ErrorLog.TTM : 'undefined reference to `ttm', 
            ErrorLog.AS68K: 'as68k: not found',
            ErrorLog.GEN : 'undefined reference to `gen_pool', 
            ErrorLog.AIC7XXX: '[drivers/scsi/aic7xxx/aicasm/aicasm] Error 2', #'drivers/scsi/aic7xxx',
            ErrorLog.AICDB : 'aicdb.h: No such file or directory', 
            ErrorLog.DRM_BRIDGE_CLUSTER : 'undefined reference to `drm_panel_bridge_add', 
            ErrorLog.PINCTRL_CLUSTER : '[drivers/pinctrl/pinctrl-mcp23s08.o] Error', #'pinctrl-mcp23s08', # loosely pattern (too general?)
            ErrorLog.BTBCM : 'undefined reference to `btbcm_set_bdaddr', 
            ErrorLog.BPFFANCY : 'bpf-fancy', # loosely pattern (too general?)
            ErrorLog.DEVM : 'undefined reference to `__devm_regmap',
            ErrorLog.I2C_CLUSTER: 'error: implicit declaration of function ‘i2c_get_adapter’', #'i2c_get_adapter',
            ErrorLog.DEVM2 : 'undefined reference to `devm_of_led'
           }

pattern_name = [name for name, member in ErrorLog.__members__.items()]
# TODO: instead of having True/False values for each pattern column name, 
# let's have a single column with cluster(s) values
error_pattern = pd.DataFrame(columns=pattern_name, index=errorlogs['cid'])
error_pattern.fillna(False, inplace=True)

for i, errorlog in errorlogs.iterrows():
    error = errorlog['error_message']
    cid = errorlog['cid']
    for k, p in patterns.items():
        if (p in error):
            error_pattern.loc[cid][k.name] = True
            # TODO: error_pattern.loc[cid]['cluster_error'] = k.name
            #print (k.name, "found in configuration", cid)

# %%
# same, except we use the first error message (and only it)
# it mimics basic Linux build process
# see discussion here: https://github.com/TuxML/compilation-analysis/issues/1#issuecomment-488711237

pattern_name = [name for name, member in ErrorLog.__members__.items()]
error_patternfirst = pd.DataFrame(columns=pattern_name, index=errorlogs['cid'])
error_patternfirst.fillna(False, inplace=True)

for i, errorlog in errorlogs.iterrows():
    error = errorlog['error_message']
    cid = errorlog['cid']
    #print(cid)
    for err in error.splitlines():
        found = False
        for k, p in patterns.items():
            if found:
                break
            if (p in err):
                error_patternfirst.loc[cid][k.name] = True
                found = True
                #print (k, "found")
        if found:
            break
    #for k, p in patterns.items():
    #    if (p in error):
    #        error_patternfirst.loc[cid][k.name] = True
            #print (k.name, "found in configuration", cid)

# %%
error_patternfirst
# Out:
#         BLACKLIGHT  BLACKLIGHT2  CONFIG_NLS_DEFAULT  CRC32_CLUSTER   V4L2  \
# cid
# 30699        False        False               False          False  False
# 30700        False        False               False          False  False
# 30704        False        False               False          False  False
# 30717        False        False               False          False  False
# 30718        False        False               False          False  False
# 30722        False        False               False          False  False
# 30726        False        False               False          False  False
# 30730        False        False               False          False  False
# 30731        False        False               False          False  False
# 30737        False        False               False          False  False
# 30806        False        False               False          False  False
# 30811        False        False               False          False  False
# 30821        False        False               False          False  False
# 30837        False        False               False          False  False
# 30849        False        False               False          False  False
# 30879        False        False               False          False  False
# 30886        False        False               False          False  False
# 30891        False        False               False          False  False
# 30901        False        False               False          False  False
# 30904        False        False               False          False  False
# 30917        False        False               False          False  False
# 30927        False        False               False          False  False
# 30959        False        False               False          False  False
# 30961        False        False               False          False  False
# 30962        False        False               False          False  False
# 30964        False        False               False          False  False
# 30971        False        False               False          False  False
# 30989        False        False               False          False  False
# 31012        False        False               False          False  False
# 31025        False        False               False          False  False
# ...            ...          ...                 ...            ...    ...
# 118808       False        False               False          False  False
# 118947       False        False               False          False  False
# 119021       False        False               False          False   True
# 119060       False        False               False          False   True
# 119109       False        False               False          False  False
# 119590       False        False               False          False  False
# 119806       False        False               False          False  False
# 119828       False        False               False          False  False
# 120205       False        False               False          False  False
# 120411       False        False               False          False  False
# 120603       False        False               False          False  False
# 121270       False        False               False          False  False
# 121405       False        False                True          False  False
# 122676       False        False               False          False   True
# 123103       False        False               False          False  False
# 123346       False        False               False          False  False
# 123348       False        False               False          False  False
# 123387       False        False               False          False  False
# 123536       False        False               False          False  False
# 124344       False        False               False          False  False
# 124690       False        False               False          False  False
# 124965       False        False               False          False   True
# 125121       False        False               False          False  False
# 125230       False        False               False          False  False
# 125374       False        False               False          False  False
# 125567       False        False               False          False  False
# 125969       False        False               False          False  False
# 126432       False        False               False          False  False
# 126652        True        False               False          False  False
# 126719       False        False               False          False  False
#
#         OVERFLOW2   ULPI    PCM    TTM  AS68K    GEN  AICDB  AIC7XXX  \
# cid
# 30699       False  False  False  False   True  False  False    False
# 30700       False  False  False  False   True  False  False    False
# 30704       False  False  False  False  False  False  False     True
# 30717       False  False  False  False  False  False  False     True
# 30718       False  False  False  False  False  False  False     True
# 30722       False  False  False  False  False  False  False     True
# 30726       False  False  False  False  False  False  False     True
# 30730        True  False  False  False  False  False  False    False
# 30731       False  False  False  False  False  False  False     True
# 30737       False  False  False  False  False  False  False     True
# 30806       False  False  False  False  False  False  False     True
# 30811       False  False  False  False  False  False  False     True
# 30821       False  False  False  False  False   True  False    False
# 30837        True  False  False  False  False  False  False    False
# 30849       False  False  False  False  False  False  False     True
# 30879       False  False  False  False  False  False  False     True
# 30886       False  False  False  False  False  False  False     True
# 30891       False  False  False  False  False  False  False     True
# 30901       False  False  False  False  False  False  False     True
# 30904       False  False  False  False  False  False  False     True
# 30917       False  False  False  False  False  False  False     True
# 30927       False  False  False  False  False  False  False     True
# 30959       False  False  False  False  False  False  False     True
# 30961       False  False  False  False   True  False  False    False
# 30962       False  False  False  False   True  False  False    False
# 30964       False  False  False  False  False  False  False     True
# 30971       False  False  False  False  False  False  False     True
# 30989       False  False  False  False   True  False  False    False
# 31012       False  False  False  False  False  False  False     True
# 31025       False  False  False  False   True  False  False    False
# ...           ...    ...    ...    ...    ...    ...    ...      ...
# 118808      False  False  False  False  False   True  False    False
# 118947      False  False  False  False  False   True  False    False
# 119021      False  False  False  False  False  False  False    False
# 119060      False  False  False  False  False  False  False    False
# 119109      False  False  False  False  False   True  False    False
# 119590      False  False  False  False  False   True  False    False
# 119806      False  False  False  False  False   True  False    False
# 119828      False  False  False  False  False   True  False    False
# 120205      False  False  False  False  False   True  False    False
# 120411      False  False  False  False  False   True  False    False
# 120603      False  False  False  False  False   True  False    False
# 121270      False  False  False  False  False   True  False    False
# 121405      False  False  False  False  False  False  False    False
# 122676      False  False  False  False  False  False  False    False
# 123103      False  False  False  False  False   True  False    False
# 123346      False  False  False  False  False   True  False    False
# 123348      False  False  False  False  False   True  False    False
# 123387      False  False  False  False  False   True  False    False
# 123536      False  False  False  False  False   True  False    False
# 124344      False  False  False  False  False   True  False    False
# 124690      False  False  False  False  False   True  False    False
# 124965      False  False  False  False  False  False  False    False
# 125121      False  False  False  False  False   True  False    False
# 125230      False  False  False  False  False   True  False    False
# 125374      False  False  False  False  False   True  False    False
# 125567      False  False  False  False  False   True  False    False
# 125969      False  False  False  False  False   True  False    False
# 126432      False  False  False  False  False   True  False    False
# 126652      False  False  False  False  False  False  False    False
# 126719      False  False  False  False   True  False  False    False
#
#         DRM_BRIDGE_CLUSTER  PINCTRL_CLUSTER  BTBCM  BPFFANCY   DEVM  DEVM2  \
# cid
# 30699                False            False  False     False  False  False
# 30700                False            False  False     False  False  False
# 30704                False            False  False     False  False  False
# 30717                False            False  False     False  False  False
# 30718                False            False  False     False  False  False
# 30722                False            False  False     False  False  False
# 30726                False            False  False     False  False  False
# 30730                False            False  False     False  False  False
# 30731                False            False  False     False  False  False
# 30737                False            False  False     False  False  False
# 30806                False            False  False     False  False  False
# 30811                False            False  False     False  False  False
# 30821                False            False  False     False  False  False
# 30837                False            False  False     False  False  False
# 30849                False            False  False     False  False  False
# 30879                False            False  False     False  False  False
# 30886                False            False  False     False  False  False
# 30891                False            False  False     False  False  False
# 30901                False            False  False     False  False  False
# 30904                False            False  False     False  False  False
# 30917                False            False  False     False  False  False
# 30927                False            False  False     False  False  False
# 30959                False            False  False     False  False  False
# 30961                False            False  False     False  False  False
# 30962                False            False  False     False  False  False
# 30964                False            False  False     False  False  False
# 30971                False            False  False     False  False  False
# 30989                False            False  False     False  False  False
# 31012                False            False  False     False  False  False
# 31025                False            False  False     False  False  False
# ...                    ...              ...    ...       ...    ...    ...
# 118808               False            False  False     False  False  False
# 118947               False            False  False     False  False  False
# 119021               False            False  False     False  False  False
# 119060               False            False  False     False  False  False
# 119109               False            False  False     False  False  False
# 119590               False            False  False     False  False  False
# 119806               False            False  False     False  False  False
# 119828               False            False  False     False  False  False
# 120205               False            False  False     False  False  False
# 120411               False            False  False     False  False  False
# 120603               False            False  False     False  False  False
# 121270               False            False  False     False  False  False
# 121405               False            False  False     False  False  False
# 122676               False            False  False     False  False  False
# 123103               False            False  False     False  False  False
# 123346               False            False  False     False  False  False
# 123348               False            False  False     False  False  False
# 123387               False            False  False     False  False  False
# 123536               False            False  False     False  False  False
# 124344               False            False  False     False  False  False
# 124690               False            False  False     False  False  False
# 124965               False            False  False     False  False  False
# 125121               False            False  False     False  False  False
# 125230               False            False  False     False  False  False
# 125374               False            False  False     False  False  False
# 125567               False            False  False     False  False  False
# 125969               False            False  False     False  False  False
# 126432               False            False  False     False  False  False
# 126652               False            False  False     False  False  False
# 126719               False            False  False     False  False  False
#
#         I2C_CLUSTER
# cid
# 30699         False
# 30700         False
# 30704         False
# 30717         False
# 30718         False
# 30722         False
# 30726         False
# 30730         False
# 30731         False
# 30737         False
# 30806         False
# 30811         False
# 30821         False
# 30837         False
# 30849         False
# 30879         False
# 30886         False
# 30891         False
# 30901         False
# 30904         False
# 30917         False
# 30927         False
# 30959         False
# 30961         False
# 30962         False
# 30964         False
# 30971         False
# 30989         False
# 31012         False
# 31025         False
# ...             ...
# 118808        False
# 118947        False
# 119021        False
# 119060        False
# 119109        False
# 119590        False
# 119806        False
# 119828        False
# 120205        False
# 120411        False
# 120603        False
# 121270        False
# 121405        False
# 122676        False
# 123103        False
# 123346        False
# 123348        False
# 123387        False
# 123536        False
# 124344        False
# 124690        False
# 124965        False
# 125121        False
# 125230        False
# 125374        False
# 125567        False
# 125969        False
# 126432        False
# 126652        False
# 126719        False
#
# [3644 rows x 20 columns]

# %%
#error_pattern.loc[99949]['BLACKLIGHT'] = True
error_pattern['CONFIG_NLS_DEFAULT'].value_counts()
#error_pattern.hist()
# Out:
# False    3638
# True        6
# Name: CONFIG_NLS_DEFAULT, dtype: int64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline  

def nb_patterns(row):
    return sum(row == True)                    
error_pattern['nb_patterns'] = error_pattern.apply(nb_patterns, axis=1)
pattern_frequencies = error_pattern[pattern_name].apply(nb_patterns, axis=0)
pattern_frequencies.plot(kind='bar')
pattern_frequencies
# Out:
# BLACKLIGHT              15
# BLACKLIGHT2              1
# CONFIG_NLS_DEFAULT       6
# CRC32_CLUSTER            2
# V4L2                    19
# OVERFLOW2               86
# ULPI                     1
# PCM                      1
# TTM                     13
# AS68K                  551
# GEN                    371
# AICDB                 2514
# AIC7XXX               2681
# DRM_BRIDGE_CLUSTER       3
# PINCTRL_CLUSTER          3
# BTBCM                    2
# BPFFANCY                 2
# DEVM                     2
# DEVM2                    1
# I2C_CLUSTER              1
# dtype: int64

# %%
import numpy as np 
# error_patternfirst['nb_patterns'] = error_patternfirst.apply(nb_patterns, axis=1)
patternfirst_frequencies = error_patternfirst[pattern_name].apply(nb_patterns, axis=0)
patternfirst_frequencies.plot(kind='bar')
patternfirst_frequencies
# np.unique(error_patternfirst['nb_patterns'].values)
# Out:
# BLACKLIGHT              15
# BLACKLIGHT2              1
# CONFIG_NLS_DEFAULT       6
# CRC32_CLUSTER            2
# V4L2                    19
# OVERFLOW2               86
# ULPI                     1
# PCM                      1
# TTM                     13
# AS68K                  479
# GEN                    369
# AICDB                 2476
# AIC7XXX                162
# DRM_BRIDGE_CLUSTER       3
# PINCTRL_CLUSTER          3
# BTBCM                    2
# BPFFANCY                 2
# DEVM                     2
# DEVM2                    1
# I2C_CLUSTER              1
# dtype: int64

# %%
error_pattern['nb_patterns'].hist()
error_pattern.query("AIC7XXX == False")['nb_patterns'].hist()

# %%
error_pattern.sort_values(by='nb_patterns', ascending=False)[:20]
# Out:
#        BLACKLIGHT  BLACKLIGHT2  CONFIG_NLS_DEFAULT  CRC32_CLUSTER   V4L2  \
# cid
# 83619       False        False               False          False  False
# 51532       False        False               False          False  False
# 73258       False        False               False          False  False
# 40041       False        False               False          False  False
# 45350       False        False               False          False  False
# 86309       False        False               False          False  False
# 77193       False        False               False          False  False
# 39669       False        False               False          False  False
# 84325       False        False               False          False  False
# 61148       False        False               False          False  False
# 67022       False        False               False          False  False
# 72724       False        False               False          False  False
# 72676       False        False               False          False  False
# 77339       False        False               False          False  False
# 72482       False        False               False          False  False
# 77373       False        False               False          False  False
# 60569       False        False               False          False  False
# 57646       False        False               False          False  False
# 34546       False        False               False          False  False
# 56765       False        False               False          False  False
#
#        OVERFLOW2   ULPI    PCM    TTM  AS68K     ...       AICDB  AIC7XXX  \
# cid                                              ...
# 83619      False  False  False  False   True     ...        True     True
# 51532      False  False  False  False   True     ...        True     True
# 73258      False  False  False  False   True     ...        True     True
# 40041      False  False  False  False   True     ...        True     True
# 45350      False  False  False  False   True     ...        True     True
# 86309      False  False  False  False   True     ...        True     True
# 77193      False  False  False  False   True     ...        True     True
# 39669      False  False  False  False   True     ...        True     True
# 84325      False  False  False  False   True     ...        True     True
# 61148      False  False  False  False   True     ...        True     True
# 67022      False  False  False  False   True     ...        True     True
# 72724      False  False  False  False   True     ...        True     True
# 72676      False  False  False  False   True     ...        True     True
# 77339      False  False  False  False   True     ...        True     True
# 72482      False  False  False  False   True     ...        True     True
# 77373      False  False  False  False   True     ...        True     True
# 60569      False  False  False  False   True     ...        True     True
# 57646      False  False  False  False   True     ...        True     True
# 34546      False  False  False  False   True     ...        True     True
# 56765      False  False  False  False   True     ...        True     True
#
#        DRM_BRIDGE_CLUSTER  PINCTRL_CLUSTER  BTBCM  BPFFANCY   DEVM  DEVM2  \
# cid
# 83619               False            False  False     False  False  False
# 51532               False            False  False     False  False  False
# 73258               False            False  False     False  False  False
# 40041               False            False  False     False  False  False
# 45350               False            False  False     False  False  False
# 86309               False            False  False     False  False  False
# 77193               False            False  False     False  False  False
# 39669               False            False  False     False  False  False
# 84325               False            False  False     False  False  False
# 61148               False            False  False     False  False  False
# 67022               False            False  False     False  False  False
# 72724               False            False  False     False  False  False
# 72676               False            False  False     False  False  False
# 77339               False            False  False     False  False  False
# 72482               False            False  False     False  False  False
# 77373               False            False  False     False  False  False
# 60569               False            False  False     False  False  False
# 57646               False            False  False     False  False  False
# 34546               False            False  False     False  False  False
# 56765               False            False  False     False  False  False
#
#        I2C_CLUSTER  nb_patterns
# cid
# 83619        False            3
# 51532        False            3
# 73258        False            3
# 40041        False            3
# 45350        False            3
# 86309        False            3
# 77193        False            3
# 39669        False            3
# 84325        False            3
# 61148        False            3
# 67022        False            3
# 72724        False            3
# 72676        False            3
# 77339        False            3
# 72482        False            3
# 77373        False            3
# 60569        False            3
# 57646        False            3
# 34546        False            3
# 56765        False            3
#
# [20 rows x 21 columns]

# %%
#error_pattern['CONFIG_NLS_DEFAULT'].value_counts().plot(kind='bar')
error_pattern.query('nb_patterns == 0')
# Out:
# Empty DataFrame
# Columns: [BLACKLIGHT, BLACKLIGHT2, CONFIG_NLS_DEFAULT, CRC32_CLUSTER, V4L2, OVERFLOW2, ULPI, PCM, TTM, AS68K, GEN, AICDB, AIC7XXX, DRM_BRIDGE_CLUSTER, PINCTRL_CLUSTER, BTBCM, BPFFANCY, DEVM, DEVM2, I2C_CLUSTER, nb_patterns]
# Index: []
#
# [0 rows x 21 columns]

# %%
error_pattern.query('nb_patterns == 0').shape
# Out:
# (0, 21)

# %%
for cid in error_pattern.query('nb_patterns == 0').index:
    print ("configuration cid", cid)
    #if cid in suspicious_cids:
    #    print("false positive failure")
    #    continue
    
    error_message = errorlogs.query("cid == " + str(cid))['error_message'].values
    for err in error_message[0].splitlines():
        if "Cyclomatic" not in err:
            print (err)
    print()
    print()
    print()
    
# 74459, 74460, 74461, 74463, 74464

# %%
error_pattern.query('nb_patterns >= 2 & (AS68K == True & AIC7XXX == False)').sort_values(by='nb_patterns', ascending=False)
# Out:
# Empty DataFrame
# Columns: [BLACKLIGHT, BLACKLIGHT2, CONFIG_NLS_DEFAULT, CRC32_CLUSTER, V4L2, OVERFLOW2, ULPI, PCM, TTM, AS68K, GEN, AICDB, AIC7XXX, DRM_BRIDGE_CLUSTER, PINCTRL_CLUSTER, BTBCM, BPFFANCY, DEVM, DEVM2, I2C_CLUSTER, nb_patterns]
# Index: []
#
# [0 rows x 21 columns]

# %%
error_pattern.query('nb_patterns >= 2 & (AS68K == False & AIC7XXX == False & AICDB == True)').sort_values(by='nb_patterns', ascending=False)
# Out:
# Empty DataFrame
# Columns: [BLACKLIGHT, BLACKLIGHT2, CONFIG_NLS_DEFAULT, CRC32_CLUSTER, V4L2, OVERFLOW2, ULPI, PCM, TTM, AS68K, GEN, AICDB, AIC7XXX, DRM_BRIDGE_CLUSTER, PINCTRL_CLUSTER, BTBCM, BPFFANCY, DEVM, DEVM2, I2C_CLUSTER, nb_patterns]
# Index: []
#
# [0 rows x 21 columns]

# %%
#error_pattern.query('nb_patterns == 2 & (as68k == False & AIC7XXX == True)').sort_values(by='nb_patterns', ascending=False)
error_pattern.query('nb_patterns >= 2 & (AS68K == False & AICDB == False & AIC7XXX == True)').sort_values(by='nb_patterns', ascending=False)
# Out:
# Empty DataFrame
# Columns: [BLACKLIGHT, BLACKLIGHT2, CONFIG_NLS_DEFAULT, CRC32_CLUSTER, V4L2, OVERFLOW2, ULPI, PCM, TTM, AS68K, GEN, AICDB, AIC7XXX, DRM_BRIDGE_CLUSTER, PINCTRL_CLUSTER, BTBCM, BPFFANCY, DEVM, DEVM2, I2C_CLUSTER, nb_patterns]
# Index: []
#
# [0 rows x 21 columns]

# %%
error_pattern.query('nb_patterns >= 2 & (AS68K == False & AIC7XXX == False)').sort_values(by='nb_patterns', ascending=False)
# Out:
#        BLACKLIGHT  BLACKLIGHT2  CONFIG_NLS_DEFAULT  CRC32_CLUSTER   V4L2  \
# cid
# 60939       False        False               False          False  False
# 78770       False        False               False          False  False
#
#        OVERFLOW2   ULPI    PCM   TTM  AS68K     ...       AICDB  AIC7XXX  \
# cid                                             ...
# 60939      False  False  False  True  False     ...       False    False
# 78770      False  False  False  True  False     ...       False    False
#
#        DRM_BRIDGE_CLUSTER  PINCTRL_CLUSTER  BTBCM  BPFFANCY   DEVM  DEVM2  \
# cid
# 60939               False            False  False     False  False  False
# 78770               False            False  False     False  False  False
#
#        I2C_CLUSTER  nb_patterns
# cid
# 60939        False            2
# 78770        False            2
#
# [2 rows x 21 columns]

# %%
# masking effect
error_pattern.query('nb_patterns >= 2 & CONFIG_NLS_DEFAULT == True').sort_values(by='nb_patterns', ascending=False)
error_pattern.query('CONFIG_NLS_DEFAULT == True').sort_values(by='nb_patterns', ascending=False)
# Out:
#         BLACKLIGHT  BLACKLIGHT2  CONFIG_NLS_DEFAULT  CRC32_CLUSTER   V4L2  \
# cid
# 44596        False        False                True          False  False
# 52277        False        False                True          False  False
# 60391        False        False                True          False  False
# 62743        False        False                True          False  False
# 99949        False        False                True          False  False
# 121405       False        False                True          False  False
#
#         OVERFLOW2   ULPI    PCM    TTM  AS68K     ...       AICDB  AIC7XXX  \
# cid                                               ...
# 44596       False  False  False  False  False     ...       False    False
# 52277       False  False  False  False  False     ...       False    False
# 60391       False  False  False  False  False     ...       False    False
# 62743       False  False  False  False  False     ...       False    False
# 99949       False  False  False  False  False     ...       False    False
# 121405      False  False  False  False  False     ...       False    False
#
#         DRM_BRIDGE_CLUSTER  PINCTRL_CLUSTER  BTBCM  BPFFANCY   DEVM  DEVM2  \
# cid
# 44596                False            False  False     False  False  False
# 52277                False            False  False     False  False  False
# 60391                False            False  False     False  False  False
# 62743                False            False  False     False  False  False
# 99949                False            False  False     False  False  False
# 121405               False            False  False     False  False  False
#
#         I2C_CLUSTER  nb_patterns
# cid
# 44596         False            1
# 52277         False            1
# 60391         False            1
# 62743         False            1
# 99949         False            1
# 121405        False            1
#
# [6 rows x 21 columns]

# %%
# masking effect
error_pattern.query('GEN == True').sort_values(by='nb_patterns', ascending=False)
# Out:
#         BLACKLIGHT  BLACKLIGHT2  CONFIG_NLS_DEFAULT  CRC32_CLUSTER   V4L2  \
# cid
# 60939        False        False               False          False  False
# 78770        False        False               False          False  False
# 91189        False        False               False          False  False
# 93969        False        False               False          False  False
# 93724        False        False               False          False  False
# 93416        False        False               False          False  False
# 93271        False        False               False          False  False
# 92838        False        False               False          False  False
# 92120        False        False               False          False  False
# 91742        False        False               False          False  False
# 91633        False        False               False          False  False
# 91291        False        False               False          False  False
# 91054        False        False               False          False  False
# 94536        False        False               False          False  False
# 90975        False        False               False          False  False
# 90710        False        False               False          False  False
# 90506        False        False               False          False  False
# 89757        False        False               False          False  False
# 89701        False        False               False          False  False
# 89577        False        False               False          False  False
# 88748        False        False               False          False  False
# 88252        False        False               False          False  False
# 88140        False        False               False          False  False
# 94391        False        False               False          False  False
# 30821        False        False               False          False  False
# 87566        False        False               False          False  False
# 95092        False        False               False          False  False
# 99203        False        False               False          False  False
# 98920        False        False               False          False  False
# 98902        False        False               False          False  False
# ...            ...          ...                 ...            ...    ...
# 58039        False        False               False          False  False
# 57953        False        False               False          False  False
# 57837        False        False               False          False  False
# 57479        False        False               False          False  False
# 57388        False        False               False          False  False
# 57008        False        False               False          False  False
# 60735        False        False               False          False  False
# 61238        False        False               False          False  False
# 66445        False        False               False          False  False
# 61554        False        False               False          False  False
# 65748        False        False               False          False  False
# 65543        False        False               False          False  False
# 65140        False        False               False          False  False
# 64884        False        False               False          False  False
# 64564        False        False               False          False  False
# 64179        False        False               False          False  False
# 63967        False        False               False          False  False
# 63879        False        False               False          False  False
# 63677        False        False               False          False  False
# 63365        False        False               False          False  False
# 63112        False        False               False          False  False
# 62809        False        False               False          False  False
# 62501        False        False               False          False  False
# 62070        False        False               False          False  False
# 61990        False        False               False          False  False
# 61856        False        False               False          False  False
# 61696        False        False               False          False  False
# 61649        False        False               False          False  False
# 61556        False        False               False          False  False
# 126432       False        False               False          False  False
#
#         OVERFLOW2   ULPI    PCM    TTM  AS68K     ...       AICDB  AIC7XXX  \
# cid                                               ...
# 60939       False  False  False   True  False     ...       False    False
# 78770       False  False  False   True  False     ...       False    False
# 91189       False  False  False  False  False     ...       False    False
# 93969       False  False  False  False  False     ...       False    False
# 93724       False  False  False  False  False     ...       False    False
# 93416       False  False  False  False  False     ...       False    False
# 93271       False  False  False  False  False     ...       False    False
# 92838       False  False  False  False  False     ...       False    False
# 92120       False  False  False  False  False     ...       False    False
# 91742       False  False  False  False  False     ...       False    False
# 91633       False  False  False  False  False     ...       False    False
# 91291       False  False  False  False  False     ...       False    False
# 91054       False  False  False  False  False     ...       False    False
# 94536       False  False  False  False  False     ...       False    False
# 90975       False  False  False  False  False     ...       False    False
# 90710       False  False  False  False  False     ...       False    False
# 90506       False  False  False  False  False     ...       False    False
# 89757       False  False  False  False  False     ...       False    False
# 89701       False  False  False  False  False     ...       False    False
# 89577       False  False  False  False  False     ...       False    False
# 88748       False  False  False  False  False     ...       False    False
# 88252       False  False  False  False  False     ...       False    False
# 88140       False  False  False  False  False     ...       False    False
# 94391       False  False  False  False  False     ...       False    False
# 30821       False  False  False  False  False     ...       False    False
# 87566       False  False  False  False  False     ...       False    False
# 95092       False  False  False  False  False     ...       False    False
# 99203       False  False  False  False  False     ...       False    False
# 98920       False  False  False  False  False     ...       False    False
# 98902       False  False  False  False  False     ...       False    False
# ...           ...    ...    ...    ...    ...     ...         ...      ...
# 58039       False  False  False  False  False     ...       False    False
# 57953       False  False  False  False  False     ...       False    False
# 57837       False  False  False  False  False     ...       False    False
# 57479       False  False  False  False  False     ...       False    False
# 57388       False  False  False  False  False     ...       False    False
# 57008       False  False  False  False  False     ...       False    False
# 60735       False  False  False  False  False     ...       False    False
# 61238       False  False  False  False  False     ...       False    False
# 66445       False  False  False  False  False     ...       False    False
# 61554       False  False  False  False  False     ...       False    False
# 65748       False  False  False  False  False     ...       False    False
# 65543       False  False  False  False  False     ...       False    False
# 65140       False  False  False  False  False     ...       False    False
# 64884       False  False  False  False  False     ...       False    False
# 64564       False  False  False  False  False     ...       False    False
# 64179       False  False  False  False  False     ...       False    False
# 63967       False  False  False  False  False     ...       False    False
# 63879       False  False  False  False  False     ...       False    False
# 63677       False  False  False  False  False     ...       False    False
# 63365       False  False  False  False  False     ...       False    False
# 63112       False  False  False  False  False     ...       False    False
# 62809       False  False  False  False  False     ...       False    False
# 62501       False  False  False  False  False     ...       False    False
# 62070       False  False  False  False  False     ...       False    False
# 61990       False  False  False  False  False     ...       False    False
# 61856       False  False  False  False  False     ...       False    False
# 61696       False  False  False  False  False     ...       False    False
# 61649       False  False  False  False  False     ...       False    False
# 61556       False  False  False  False  False     ...       False    False
# 126432      False  False  False  False  False     ...       False    False
#
#         DRM_BRIDGE_CLUSTER  PINCTRL_CLUSTER  BTBCM  BPFFANCY   DEVM  DEVM2  \
# cid
# 60939                False            False  False     False  False  False
# 78770                False            False  False     False  False  False
# 91189                False            False  False     False  False  False
# 93969                False            False  False     False  False  False
# 93724                False            False  False     False  False  False
# 93416                False            False  False     False  False  False
# 93271                False            False  False     False  False  False
# 92838                False            False  False     False  False  False
# 92120                False            False  False     False  False  False
# 91742                False            False  False     False  False  False
# 91633                False            False  False     False  False  False
# 91291                False            False  False     False  False  False
# 91054                False            False  False     False  False  False
# 94536                False            False  False     False  False  False
# 90975                False            False  False     False  False  False
# 90710                False            False  False     False  False  False
# 90506                False            False  False     False  False  False
# 89757                False            False  False     False  False  False
# 89701                False            False  False     False  False  False
# 89577                False            False  False     False  False  False
# 88748                False            False  False     False  False  False
# 88252                False            False  False     False  False  False
# 88140                False            False  False     False  False  False
# 94391                False            False  False     False  False  False
# 30821                False            False  False     False  False  False
# 87566                False            False  False     False  False  False
# 95092                False            False  False     False  False  False
# 99203                False            False  False     False  False  False
# 98920                False            False  False     False  False  False
# 98902                False            False  False     False  False  False
# ...                    ...              ...    ...       ...    ...    ...
# 58039                False            False  False     False  False  False
# 57953                False            False  False     False  False  False
# 57837                False            False  False     False  False  False
# 57479                False            False  False     False  False  False
# 57388                False            False  False     False  False  False
# 57008                False            False  False     False  False  False
# 60735                False            False  False     False  False  False
# 61238                False            False  False     False  False  False
# 66445                False            False  False     False  False  False
# 61554                False            False  False     False  False  False
# 65748                False            False  False     False  False  False
# 65543                False            False  False     False  False  False
# 65140                False            False  False     False  False  False
# 64884                False            False  False     False  False  False
# 64564                False            False  False     False  False  False
# 64179                False            False  False     False  False  False
# 63967                False            False  False     False  False  False
# 63879                False            False  False     False  False  False
# 63677                False            False  False     False  False  False
# 63365                False            False  False     False  False  False
# 63112                False            False  False     False  False  False
# 62809                False            False  False     False  False  False
# 62501                False            False  False     False  False  False
# 62070                False            False  False     False  False  False
# 61990                False            False  False     False  False  False
# 61856                False            False  False     False  False  False
# 61696                False            False  False     False  False  False
# 61649                False            False  False     False  False  False
# 61556                False            False  False     False  False  False
# 126432               False            False  False     False  False  False
#
#         I2C_CLUSTER  nb_patterns
# cid
# 60939         False            2
# 78770         False            2
# 91189         False            1
# 93969         False            1
# 93724         False            1
# 93416         False            1
# 93271         False            1
# 92838         False            1
# 92120         False            1
# 91742         False            1
# 91633         False            1
# 91291         False            1
# 91054         False            1
# 94536         False            1
# 90975         False            1
# 90710         False            1
# 90506         False            1
# 89757         False            1
# 89701         False            1
# 89577         False            1
# 88748         False            1
# 88252         False            1
# 88140         False            1
# 94391         False            1
# 30821         False            1
# 87566         False            1
# 95092         False            1
# 99203         False            1
# 98920         False            1
# 98902         False            1
# ...             ...          ...
# 58039         False            1
# 57953         False            1
# 57837         False            1
# 57479         False            1
# 57388         False            1
# 57008         False            1
# 60735         False            1
# 61238         False            1
# 66445         False            1
# 61554         False            1
# 65748         False            1
# 65543         False            1
# 65140         False            1
# 64884         False            1
# 64564         False            1
# 64179         False            1
# 63967         False            1
# 63879         False            1
# 63677         False            1
# 63365         False            1
# 63112         False            1
# 62809         False            1
# 62501         False            1
# 62070         False            1
# 61990         False            1
# 61856         False            1
# 61696         False            1
# 61649         False            1
# 61556         False            1
# 126432        False            1
#
# [371 rows x 21 columns]

# %%
error_pattern.query('BLACKLIGHT == True').sort_values(by='nb_patterns', ascending=False)
# Out:
#         BLACKLIGHT  BLACKLIGHT2  CONFIG_NLS_DEFAULT  CRC32_CLUSTER   V4L2  \
# cid
# 59503         True        False               False          False  False
# 64086         True        False               False          False  False
# 65670         True        False               False          False  False
# 66938         True        False               False          False  False
# 67750         True        False               False          False  False
# 75145         True        False               False          False  False
# 81720         True        False               False          False  False
# 89618         True        False               False          False  False
# 93674         True        False               False          False  False
# 98215         True        False               False          False  False
# 100734        True        False               False          False  False
# 101561        True        False               False          False  False
# 109530        True        False               False          False  False
# 113286        True        False               False          False  False
# 126652        True        False               False          False  False
#
#         OVERFLOW2   ULPI    PCM    TTM  AS68K     ...       AICDB  AIC7XXX  \
# cid                                               ...
# 59503       False  False  False  False  False     ...       False    False
# 64086       False  False  False  False  False     ...       False    False
# 65670       False  False  False  False  False     ...       False    False
# 66938       False  False  False  False  False     ...       False    False
# 67750       False  False  False  False  False     ...       False    False
# 75145       False  False  False  False  False     ...       False    False
# 81720       False  False  False  False  False     ...       False    False
# 89618       False  False  False  False  False     ...       False    False
# 93674       False  False  False  False  False     ...       False    False
# 98215       False  False  False  False  False     ...       False    False
# 100734      False  False  False  False  False     ...       False    False
# 101561      False  False  False  False  False     ...       False    False
# 109530      False  False  False  False  False     ...       False    False
# 113286      False  False  False  False  False     ...       False    False
# 126652      False  False  False  False  False     ...       False    False
#
#         DRM_BRIDGE_CLUSTER  PINCTRL_CLUSTER  BTBCM  BPFFANCY   DEVM  DEVM2  \
# cid
# 59503                False            False  False     False  False  False
# 64086                False            False  False     False  False  False
# 65670                False            False  False     False  False  False
# 66938                False            False  False     False  False  False
# 67750                False            False  False     False  False  False
# 75145                False            False  False     False  False  False
# 81720                False            False  False     False  False  False
# 89618                False            False  False     False  False  False
# 93674                False            False  False     False  False  False
# 98215                False            False  False     False  False  False
# 100734               False            False  False     False  False  False
# 101561               False            False  False     False  False  False
# 109530               False            False  False     False  False  False
# 113286               False            False  False     False  False  False
# 126652               False            False  False     False  False  False
#
#         I2C_CLUSTER  nb_patterns
# cid
# 59503         False            1
# 64086         False            1
# 65670         False            1
# 66938         False            1
# 67750         False            1
# 75145         False            1
# 81720         False            1
# 89618         False            1
# 93674         False            1
# 98215         False            1
# 100734        False            1
# 101561        False            1
# 109530        False            1
# 113286        False            1
# 126652        False            1
#
# [15 rows x 21 columns]

# %%
# nice masking effect!
error_pattern.query('PINCTRL_CLUSTER == True & (AS68K == False & AIC7XXX == False)').sort_values(by='nb_patterns', ascending=False)
# Out:
#        BLACKLIGHT  BLACKLIGHT2  CONFIG_NLS_DEFAULT  CRC32_CLUSTER   V4L2  \
# cid
# 37227       False        False               False          False  False
# 89854       False        False               False          False  False
# 98605       False        False               False          False  False
#
#        OVERFLOW2   ULPI    PCM    TTM  AS68K     ...       AICDB  AIC7XXX  \
# cid                                              ...
# 37227      False  False  False  False  False     ...       False    False
# 89854      False  False  False  False  False     ...       False    False
# 98605      False  False  False  False  False     ...       False    False
#
#        DRM_BRIDGE_CLUSTER  PINCTRL_CLUSTER  BTBCM  BPFFANCY   DEVM  DEVM2  \
# cid
# 37227               False             True  False     False  False  False
# 89854               False             True  False     False  False  False
# 98605               False             True  False     False  False  False
#
#        I2C_CLUSTER  nb_patterns
# cid
# 37227        False            1
# 89854        False            1
# 98605        False            1
#
# [3 rows x 21 columns]

# %%
# nice masking effect!
error_pattern.query('I2C_CLUSTER == True & (PINCTRL_CLUSTER == False & AS68K == False & AIC7XXX == False)').sort_values(by='nb_patterns', ascending=False)
# Out:
#        BLACKLIGHT  BLACKLIGHT2  CONFIG_NLS_DEFAULT  CRC32_CLUSTER   V4L2  \
# cid
# 96730       False        False               False          False  False
#
#        OVERFLOW2   ULPI    PCM    TTM  AS68K     ...       AICDB  AIC7XXX  \
# cid                                              ...
# 96730      False  False  False  False  False     ...       False    False
#
#        DRM_BRIDGE_CLUSTER  PINCTRL_CLUSTER  BTBCM  BPFFANCY   DEVM  DEVM2  \
# cid
# 96730               False            False  False     False  False  False
#
#        I2C_CLUSTER  nb_patterns
# cid
# 96730         True            1
#
# [1 rows x 21 columns]

# %%
import json
# see Hugo notebook here!
with open("option_columns.json","r") as f:
    option_columns = json.load(f)

# %%
import pandas as pd 
rawtuxdata = pd.read_csv("dataset_encoded.csv", dtype={k:"int8" for k in option_columns})
# rawtuxdata = pd.read_csv("dataset_after_encoding.csv", dtype={k:"int8" for k in option_columns})
rawtuxdata.query("cid >= 30000", inplace=True)
rawtuxdata.info(memory_usage='deep')
rawtuxdata.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 96096 entries, 14758 to 110853
# Columns: 12638 entries, 104_QUAD_8 to compile_success
# dtypes: float64(3), int64(24), int8(12611)
# memory usage: 1.1 GB
# (96096, 12638)

# %%
for cid in suspicious_cids:
    rawtuxdata.query("cid != " + str(cid), inplace=True)
    # rawtuxdata = rawtuxdata[rawtuxdata.cid != cid]

# %%
rawtuxdata[['cid', 'X86_64', 'TRACING', 'FSI', 'DRM_VBOXVIDEO', 'GENERIC_ALLOCATOR', 'compile_success']][:10]
# Out:
#          cid  X86_64  TRACING  FSI  DRM_VBOXVIDEO  GENERIC_ALLOCATOR  \
# 14758  30000       0        1    2              1                  1
# 14759  30001       0        0    1              1                  1
# 14760  30002       0        1    2              1                  0
# 14761  30003       0        0    2              1                  1
# 14762  30004       0        0    2              1                  1
# 14763  30005       0        0    2              1                  1
# 14764  30006       0        1    2              1                  1
# 14765  30007       0        0    1              1                  1
# 14766  30008       0        1    2              1                  1
# 14767  30009       0        0    2              1                  1
#
#        compile_success
# 14758                1
# 14759                1
# 14760                1
# 14761                1
# 14762                1
# 14763                1
# 14764                1
# 14765                1
# 14766                1
# 14767                1

# %%
len(rawtuxdata.query("compile_success != 1").index)
# Out:
# 3621

# %%
set(errorlogs['cid']) - set(rawtuxdata['cid'])
# Out:
# {33833,
#  33836,
#  33837,
#  54125,
#  54126,
#  54127,
#  54128,
#  54129,
#  56432,
#  56558,
#  57249,
#  70614,
#  70665,
#  70709,
#  70710,
#  74227,
#  74233,
#  78892,
#  79033,
#  79141,
#  88152,
#  88817,
#  88909}

# %%
set(rawtuxdata['cid']) - set(errorlogs['cid'])
# Out:
# {30000,
#  30001,
#  30002,
#  30003,
#  30004,
#  30005,
#  30006,
#  30007,
#  30008,
#  30009,
#  30010,
#  30011,
#  30012,
#  30013,
#  30014,
#  30015,
#  30016,
#  30017,
#  30018,
#  30019,
#  30020,
#  30021,
#  30022,
#  30023,
#  30024,
#  30025,
#  30026,
#  30027,
#  30028,
#  30029,
#  30030,
#  30031,
#  30032,
#  30033,
#  30034,
#  30035,
#  30036,
#  30037,
#  30038,
#  30039,
#  30040,
#  30041,
#  30042,
#  30043,
#  30044,
#  30045,
#  30046,
#  30047,
#  30048,
#  30049,
#  30050,
#  30051,
#  30052,
#  30053,
#  30054,
#  30055,
#  30056,
#  30057,
#  30058,
#  30059,
#  30060,
#  30061,
#  30062,
#  30063,
#  30064,
#  30065,
#  30066,
#  30067,
#  30068,
#  30069,
#  30070,
#  30071,
#  30072,
#  30073,
#  30074,
#  30075,
#  30076,
#  30077,
#  30078,
#  30079,
#  30080,
#  30081,
#  30082,
#  30083,
#  30084,
#  30085,
#  30086,
#  30087,
#  30088,
#  30089,
#  30090,
#  30091,
#  30092,
#  30093,
#  30094,
#  30095,
#  30096,
#  30097,
#  30098,
#  30099,
#  30100,
#  30101,
#  30102,
#  30103,
#  30104,
#  30105,
#  30106,
#  30107,
#  30108,
#  30109,
#  30110,
#  30111,
#  30112,
#  30113,
#  30114,
#  30115,
#  30116,
#  30117,
#  30118,
#  30119,
#  30120,
#  30121,
#  30122,
#  30123,
#  30124,
#  30125,
#  30126,
#  30127,
#  30128,
#  30129,
#  30130,
#  30131,
#  30132,
#  30133,
#  30134,
#  30135,
#  30136,
#  30137,
#  30138,
#  30139,
#  30140,
#  30141,
#  30142,
#  30143,
#  30144,
#  30145,
#  30146,
#  30147,
#  30148,
#  30149,
#  30150,
#  30151,
#  30152,
#  30153,
#  30154,
#  30155,
#  30156,
#  30157,
#  30158,
#  30159,
#  30160,
#  30161,
#  30162,
#  30163,
#  30164,
#  30165,
#  30166,
#  30167,
#  30168,
#  30169,
#  30170,
#  30171,
#  30172,
#  30173,
#  30174,
#  30175,
#  30176,
#  30177,
#  30178,
#  30179,
#  30180,
#  30181,
#  30182,
#  30183,
#  30184,
#  30185,
#  30186,
#  30187,
#  30188,
#  30189,
#  30190,
#  30191,
#  30192,
#  30193,
#  30194,
#  30195,
#  30196,
#  30197,
#  30198,
#  30199,
#  30200,
#  30201,
#  30202,
#  30203,
#  30204,
#  30205,
#  30206,
#  30207,
#  30208,
#  30209,
#  30210,
#  30211,
#  30212,
#  30213,
#  30214,
#  30215,
#  30216,
#  30217,
#  30218,
#  30219,
#  30220,
#  30221,
#  30222,
#  30223,
#  30224,
#  30225,
#  30226,
#  30227,
#  30228,
#  30229,
#  30230,
#  30231,
#  30232,
#  30233,
#  30234,
#  30235,
#  30236,
#  30237,
#  30238,
#  30239,
#  30240,
#  30241,
#  30242,
#  30243,
#  30244,
#  30245,
#  30246,
#  30247,
#  30248,
#  30249,
#  30250,
#  30251,
#  30252,
#  30253,
#  30254,
#  30255,
#  30256,
#  30257,
#  30258,
#  30259,
#  30260,
#  30261,
#  30262,
#  30263,
#  30264,
#  30265,
#  30266,
#  30267,
#  30268,
#  30269,
#  30270,
#  30271,
#  30272,
#  30273,
#  30274,
#  30275,
#  30276,
#  30277,
#  30278,
#  30279,
#  30280,
#  30281,
#  30282,
#  30283,
#  30284,
#  30285,
#  30286,
#  30287,
#  30288,
#  30289,
#  30290,
#  30291,
#  30292,
#  30293,
#  30294,
#  30295,
#  30296,
#  30297,
#  30298,
#  30299,
#  30300,
#  30301,
#  30302,
#  30303,
#  30304,
#  30305,
#  30306,
#  30307,
#  30308,
#  30309,
#  30310,
#  30311,
#  30312,
#  30313,
#  30314,
#  30315,
#  30316,
#  30317,
#  30318,
#  30319,
#  30320,
#  30321,
#  30322,
#  30323,
#  30324,
#  30325,
#  30326,
#  30327,
#  30328,
#  30329,
#  30330,
#  30331,
#  30332,
#  30333,
#  30334,
#  30335,
#  30336,
#  30337,
#  30338,
#  30339,
#  30340,
#  30341,
#  30342,
#  30343,
#  30344,
#  30345,
#  30346,
#  30347,
#  30348,
#  30349,
#  30350,
#  30351,
#  30352,
#  30353,
#  30354,
#  30355,
#  30356,
#  30357,
#  30358,
#  30359,
#  30360,
#  30361,
#  30362,
#  30363,
#  30364,
#  30365,
#  30366,
#  30367,
#  30368,
#  30369,
#  30370,
#  30371,
#  30372,
#  30373,
#  30374,
#  30375,
#  30376,
#  30377,
#  30378,
#  30379,
#  30380,
#  30381,
#  30382,
#  30383,
#  30384,
#  30385,
#  30386,
#  30387,
#  30388,
#  30389,
#  30390,
#  30391,
#  30392,
#  30393,
#  30394,
#  30395,
#  30396,
#  30397,
#  30398,
#  30399,
#  30400,
#  30401,
#  30402,
#  30403,
#  30404,
#  30405,
#  30406,
#  30407,
#  30408,
#  30409,
#  30410,
#  30411,
#  30412,
#  30413,
#  30414,
#  30415,
#  30416,
#  30417,
#  30418,
#  30419,
#  30420,
#  30421,
#  30422,
#  30423,
#  30424,
#  30425,
#  30426,
#  30427,
#  30428,
#  30429,
#  30430,
#  30431,
#  30432,
#  30433,
#  30434,
#  30435,
#  30436,
#  30437,
#  30438,
#  30439,
#  30440,
#  30441,
#  30442,
#  30443,
#  30444,
#  30445,
#  30446,
#  30447,
#  30448,
#  30449,
#  30450,
#  30451,
#  30452,
#  30453,
#  30454,
#  30455,
#  30456,
#  30457,
#  30458,
#  30459,
#  30460,
#  30461,
#  30462,
#  30463,
#  30464,
#  30465,
#  30466,
#  30467,
#  30468,
#  30469,
#  30470,
#  30471,
#  30472,
#  30473,
#  30474,
#  30475,
#  30476,
#  30477,
#  30478,
#  30479,
#  30480,
#  30481,
#  30482,
#  30483,
#  30484,
#  30485,
#  30486,
#  30487,
#  30488,
#  30489,
#  30490,
#  30491,
#  30492,
#  30493,
#  30494,
#  30495,
#  30496,
#  30497,
#  30498,
#  30499,
#  30500,
#  30501,
#  30502,
#  30503,
#  30504,
#  30505,
#  30506,
#  30507,
#  30508,
#  30509,
#  30510,
#  30511,
#  30512,
#  30513,
#  30514,
#  30515,
#  30516,
#  30517,
#  30518,
#  30519,
#  30520,
#  30521,
#  30522,
#  30523,
#  30524,
#  30525,
#  30526,
#  30527,
#  30528,
#  30529,
#  30530,
#  30531,
#  30532,
#  30533,
#  30534,
#  30535,
#  30536,
#  30537,
#  30538,
#  30539,
#  30540,
#  30541,
#  30542,
#  30543,
#  30544,
#  30545,
#  30546,
#  30547,
#  30548,
#  30549,
#  30550,
#  30551,
#  30552,
#  30553,
#  30554,
#  30555,
#  30556,
#  30557,
#  30558,
#  30559,
#  30560,
#  30561,
#  30562,
#  30563,
#  30564,
#  30565,
#  30566,
#  30567,
#  30568,
#  30569,
#  30570,
#  30571,
#  30572,
#  30573,
#  30574,
#  30575,
#  30576,
#  30577,
#  30578,
#  30579,
#  30580,
#  30581,
#  30582,
#  30583,
#  30584,
#  30585,
#  30586,
#  30587,
#  30588,
#  30589,
#  30590,
#  30591,
#  30592,
#  30593,
#  30594,
#  30595,
#  30596,
#  30597,
#  30598,
#  30599,
#  30600,
#  30601,
#  30602,
#  30603,
#  30604,
#  30605,
#  30606,
#  30607,
#  30608,
#  30609,
#  30610,
#  30611,
#  30612,
#  30613,
#  30614,
#  30615,
#  30616,
#  30617,
#  30618,
#  30619,
#  30620,
#  30621,
#  30622,
#  30623,
#  30624,
#  30625,
#  30626,
#  30627,
#  30628,
#  30629,
#  30630,
#  30631,
#  30632,
#  30633,
#  30634,
#  30635,
#  30636,
#  30637,
#  30638,
#  30639,
#  30640,
#  30641,
#  30642,
#  30643,
#  30644,
#  30645,
#  30646,
#  30647,
#  30648,
#  30649,
#  30650,
#  30651,
#  30652,
#  30653,
#  30654,
#  30655,
#  30656,
#  30657,
#  30658,
#  30659,
#  30660,
#  30661,
#  30662,
#  30663,
#  30664,
#  30665,
#  30666,
#  30667,
#  30668,
#  30669,
#  30670,
#  30671,
#  30672,
#  30673,
#  30674,
#  30675,
#  30676,
#  30677,
#  30678,
#  30679,
#  30680,
#  30681,
#  30682,
#  30683,
#  30684,
#  30685,
#  30686,
#  30687,
#  30688,
#  30689,
#  30690,
#  30691,
#  30692,
#  30693,
#  30694,
#  30695,
#  30696,
#  30697,
#  30701,
#  30702,
#  30703,
#  30705,
#  30706,
#  30707,
#  30708,
#  30709,
#  30710,
#  30711,
#  30712,
#  30713,
#  30714,
#  30715,
#  30716,
#  30719,
#  30720,
#  30721,
#  30723,
#  30724,
#  30725,
#  30727,
#  30728,
#  30729,
#  30732,
#  30733,
#  30734,
#  30735,
#  30736,
#  30738,
#  30739,
#  30740,
#  30741,
#  30742,
#  30743,
#  30744,
#  30745,
#  30746,
#  30747,
#  30748,
#  30749,
#  30750,
#  30751,
#  30752,
#  30753,
#  30754,
#  30755,
#  30756,
#  30757,
#  30758,
#  30759,
#  30760,
#  30761,
#  30762,
#  30763,
#  30764,
#  30765,
#  30766,
#  30767,
#  30768,
#  30769,
#  30770,
#  30771,
#  30772,
#  30773,
#  30774,
#  30775,
#  30776,
#  30777,
#  30778,
#  30779,
#  30780,
#  30781,
#  30782,
#  30783,
#  30784,
#  30785,
#  30786,
#  30787,
#  30788,
#  30789,
#  30790,
#  30791,
#  30792,
#  30793,
#  30794,
#  30795,
#  30796,
#  30797,
#  30798,
#  30799,
#  30800,
#  30801,
#  30802,
#  30803,
#  30804,
#  30805,
#  30807,
#  30808,
#  30809,
#  30810,
#  30812,
#  30813,
#  30814,
#  30815,
#  30816,
#  30817,
#  30818,
#  30819,
#  30820,
#  30822,
#  30823,
#  30824,
#  30825,
#  30826,
#  30827,
#  30828,
#  30829,
#  30830,
#  30831,
#  30832,
#  30833,
#  30834,
#  30835,
#  30836,
#  30838,
#  30839,
#  30840,
#  30841,
#  30842,
#  30843,
#  30844,
#  30846,
#  30847,
#  30848,
#  30850,
#  30851,
#  30852,
#  30853,
#  30854,
#  30855,
#  30856,
#  30857,
#  30858,
#  30859,
#  30860,
#  30861,
#  30862,
#  30863,
#  30864,
#  30865,
#  30866,
#  30867,
#  30868,
#  30869,
#  30870,
#  30871,
#  30872,
#  30873,
#  30874,
#  30875,
#  30876,
#  30877,
#  30878,
#  30880,
#  30881,
#  30882,
#  30883,
#  30884,
#  30885,
#  30887,
#  30888,
#  30889,
#  30890,
#  30892,
#  30893,
#  30894,
#  30895,
#  30896,
#  30897,
#  30898,
#  30899,
#  30900,
#  30902,
#  30903,
#  30905,
#  30906,
#  30907,
#  30908,
#  30909,
#  30910,
#  30911,
#  30912,
#  30913,
#  30914,
#  30915,
#  30916,
#  30918,
#  30919,
#  30920,
#  30921,
#  30922,
#  30923,
#  30924,
#  30925,
#  30926,
#  30928,
#  30929,
#  30930,
#  30931,
#  30932,
#  30933,
#  30934,
#  30935,
#  30936,
#  30937,
#  30938,
#  30939,
#  30940,
#  30941,
#  30942,
#  30943,
#  30944,
#  30945,
#  30946,
#  30947,
#  30948,
#  30950,
#  30951,
#  30952,
#  30953,
#  30954,
#  30955,
#  30956,
#  30957,
#  30958,
#  30960,
#  30963,
#  30965,
#  30966,
#  30967,
#  30968,
#  30969,
#  30970,
#  30972,
#  30973,
#  30974,
#  30975,
#  30976,
#  30977,
#  30978,
#  30979,
#  30980,
#  30981,
#  30982,
#  30983,
#  30984,
#  30985,
#  30986,
#  30987,
#  30988,
#  30990,
#  30991,
#  30992,
#  30993,
#  30994,
#  30995,
#  30996,
#  30997,
#  30998,
#  30999,
#  31000,
#  31001,
#  31002,
#  31003,
#  31004,
#  31005,
#  31006,
#  31007,
#  31008,
#  31009,
#  31010,
#  31011,
#  31013,
#  31014,
#  31015,
#  31016,
#  31017,
#  31018,
#  31019,
#  31020,
#  31021,
#  31022,
#  31023,
#  31024,
#  31026,
#  31027,
#  31028,
#  31029,
#  31030,
#  31031,
#  31032,
#  ...}

# %%
basic_head = ["cid", "time", "date"] # "compile"
compilation_status_column_name = 'compile_success'
size_methods = ["vmlinux", "GZIP-bzImage", "GZIP-vmlinux", "GZIP", "BZIP2-bzImage", 
              "BZIP2-vmlinux", "BZIP2", "LZMA-bzImage", "LZMA-vmlinux", "LZMA", "XZ-bzImage", "XZ-vmlinux", "XZ", 
              "LZO-bzImage", "LZO-vmlinux", "LZO", "LZ4-bzImage", "LZ4-vmlinux", "LZ4"]

# %%
print(str(len(rawtuxdata)) + " before the removal of some entries (those with same configurations)")
# tuxdata.drop_duplicates(subset=tuxdata.columns.difference(['vmlinux']), inplace=True)
# rawtuxdata.drop_duplicates(subset=rawtuxdata.columns.difference(size_methods).difference(basic_head), inplace=True)
rawtuxdata.drop_duplicates(subset=rawtuxdata.columns.difference(basic_head).difference([compilation_status_column_name]), inplace=True)
print(str(len(rawtuxdata)) + " after the removal of some entries (those with same configurations)")
# Out:
# 96094 before the removal of some entries (those with same configurations)
# 96094 after the removal of some entries (those with same configurations)

# %%
#rawtuxdata.columns

# %%
rawtuxdata[:10][['cid']]
# rawtuxdata.query("cid >= 30000", inplace=True)
# Out:
#          cid
# 14758  30000
# 14759  30001
# 14760  30002
# 14761  30003
# 14762  30004
# 14763  30005
# 14764  30006
# 14765  30007
# 14766  30008
# 14767  30009

# %%
import pandas as pd
from tabulate import tabulate

def pandas_df_to_markdown_table(df):
    # Dependent upon ipython
    # shamelessly stolen from https://stackoverflow.com/questions/33181846/programmatically-convert-pandas-dataframe-to-markdown-table
    from IPython.display import Markdown, display
    fmt = ['---' for i in range(len(df.columns))]
    df_fmt = pd.DataFrame([fmt], columns=df.columns)
    df_formatted = pd.concat([df_fmt, df])
    #display(Markdown(df_formatted.to_csv(sep="|", index=False)))
    return Markdown(df_formatted.to_csv(sep="|", index=False))
#     return df_formatted

def df_to_markdown(df, y_index=False):
    blob = tabulate(df, headers='keys', tablefmt='pipe')
    if not y_index:
        # Remove the index with some creative splicing and iteration
        return '\n'.join(['| {}'.format(row.split('|', 2)[-1]) for row in blob.split('\n')])
    return blob


generic_mask = rawtuxdata.query("cid >= 30000 & GENERIC_ALLOCATOR == 0 & DRM_VBOXVIDEO == 2 & (AIC7XXX_BUILD_FIRMWARE == 1 | AIC79XX_BUILD_FIRMWARE == 1)")[['cid', compilation_status_column_name, 'AIC7XXX_BUILD_FIRMWARE', 'AIC79XX_BUILD_FIRMWARE', 'GENERIC_ALLOCATOR', 'DRM_VBOXVIDEO']]
#print(df_to_markdown(generic_mask))

for cid in generic_mask['cid'].values:
    print(error_patternfirst.query("cid == " + str(cid))[['AICDB', 'AS68K', 'AIC7XXX']])
# Out:
#        AICDB  AS68K  AIC7XXX
# cid
# 30901  False  False     True
#        AICDB  AS68K  AIC7XXX
# cid
# 37341   True  False    False
#        AICDB  AS68K  AIC7XXX
# cid
# 40757   True  False    False
#        AICDB  AS68K  AIC7XXX
# cid
# 48193   True  False    False
#        AICDB  AS68K  AIC7XXX
# cid
# 50359   True  False    False
#        AICDB  AS68K  AIC7XXX
# cid
# 55986   True  False    False
#        AICDB  AS68K  AIC7XXX
# cid
# 59253   True  False    False
#        AICDB  AS68K  AIC7XXX
# cid
# 61758   True  False    False
#        AICDB  AS68K  AIC7XXX
# cid
# 67576   True  False    False
#        AICDB  AS68K  AIC7XXX
# cid
# 79099   True  False    False
#        AICDB  AS68K  AIC7XXX
# cid
# 84168   True  False    False

# %%
errorlogs.query("cid == 40757")['error_message'].values
# Out:
# array(['drivers/gpu/drm/radeon/radeon_object.c: In function \'radeon_bo_create\':\ndrivers/gpu/drm/radeon/radeon_object.c:242:2: warning: #warning Please enable CONFIG_MTRR and CONFIG_X86_PAT for better performance thanks to write-combining [-Wcpp]\n #warning Please enable CONFIG_MTRR and CONFIG_X86_PAT for better performance \\\n  ^~~~~~~\ndrivers/gpu/drm/radeon/radeon_object.c:242:2: warning: #warning Please enable CONFIG_MTRR and CONFIG_X86_PAT for better performance thanks to write-combining [-Wcpp]\n #warning Please enable CONFIG_MTRR and CONFIG_X86_PAT for better performance \\\n  ^~~~~~~\naicasm_symbol.c:48:19: fatal error: aicdb.h: No such file or directory\n #include "aicdb.h"\n                   ^\ncompilation terminated.\naicasm_gram.tab.c: In function \'yyparse\':\naicasm_gram.tab.c:1628:16: warning: implicit declaration of function \'yylex\' [-Wimplicit-function-declaration]\naicasm_macro_gram.tab.c: In function \'mmparse\':\n/TuxML/linux-4.13.3/drivers/scsi/aic7xxx/aicasm//aicasm_macro_gram.c:64:25: warning: implicit declaration of function \'mmlex\' [-Wimplicit-function-declaration]\n #define yylex           mmlex\n                         ^\naicasm_macro_gram.tab.c:1199:16: note: in expansion of macro \'yylex\'\naicasm_scan.l: In function \'yylex\':\naicasm_scan.l:420:6: warning: implicit declaration of function \'mm_switch_to_buffer\' [-Wimplicit-function-declaration]\n      yy_switch_to_buffer(temp_state);\n      ^~~~~~~~~~~~~~~~~~~\naicasm_scan.l:421:6: warning: implicit declaration of function \'mmparse\' [-Wimplicit-function-declaration]\n      mm_switch_to_buffer(old_state);\n      ^~~~~~~\naicasm_scan.l:424:6: warning: implicit declaration of function \'mm_delete_buffer\' [-Wimplicit-function-declaration]\n      yy_switch_to_buffer(old_state);\n      ^~~~~~~~~~~~~~~~\nmake[4]: *** [aicasm] Error 1\nmake[3]: *** [drivers/scsi/aic7xxx/aicasm/aicasm] Error 2\nmake[2]: *** [drivers/scsi/aic7xxx] Error 2\nmake[2]: *** Waiting for unfinished jobs....\nmake[1]: *** [drivers/scsi] Error 2\nmake[1]: *** Waiting for unfinished jobs....\nmake: *** [drivers] Error 2\n'],
#       dtype=object)

# %%
cid_errors_not_in_configdata = set(errorlogs['cid']) - set(rawtuxdata['cid'])
for cid in cid_errors_not_in_configdata:
    error_message = errorlogs.query("cid == " + str(cid))['error_message'].values
    for err in error_message[0].splitlines():
        if "Cyclomatic" not in err:
            print (err)
# Out:
# aicasm_symbol.c:48:19: fatal error: aicdb.h: No such file or directory
#  #include "aicdb.h"
#                    ^
# compilation terminated.
# aicasm_gram.tab.c: In function 'yyparse':
# aicasm_gram.tab.c:1628:16: warning: implicit declaration of function 'yylex' [-Wimplicit-function-declaration]
# aicasm_macro_gram.tab.c: In function 'mmparse':
# /TuxML/linux-4.13.3/drivers/scsi/aic7xxx/aicasm//aicasm_macro_gram.c:64:25: warning: implicit declaration of function 'mmlex' [-Wimplicit-function-declaration]
#  #define yylex           mmlex
#                          ^
# aicasm_macro_gram.tab.c:1199:16: note: in expansion of macro 'yylex'
# aicasm_scan.l: In function 'yylex':
# aicasm_scan.l:420:6: warning: implicit declaration of function 'mm_switch_to_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(temp_state);
#       ^~~~~~~~~~~~~~~~~~~
# aicasm_scan.l:421:6: warning: implicit declaration of function 'mmparse' [-Wimplicit-function-declaration]
#       mm_switch_to_buffer(old_state);
#       ^~~~~~~
# aicasm_scan.l:424:6: warning: implicit declaration of function 'mm_delete_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(old_state);
#       ^~~~~~~~~~~~~~~~
# make[4]: *** [aicasm] Error 1
# make[3]: *** [drivers/scsi/aic7xxx/aicasm/aicasm] Error 2
# make[2]: *** [drivers/scsi/aic7xxx] Error 2
# make[2]: *** Waiting for unfinished jobs....
# make[1]: *** [drivers/scsi] Error 2
# make[1]: *** Waiting for unfinished jobs....
# make: *** [drivers] Error 2
# aicasm_symbol.c:48:19: fatal error: aicdb.h: No such file or directory
#  #include "aicdb.h"
#                    ^
# compilation terminated.
# aicasm_gram.tab.c: In function 'yyparse':
# aicasm_gram.tab.c:1628:16: warning: implicit declaration of function 'yylex' [-Wimplicit-function-declaration]
# aicasm_macro_gram.tab.c: In function 'mmparse':
# /TuxML/linux-4.13.3/drivers/scsi/aic7xxx/aicasm//aicasm_macro_gram.c:64:25: warning: implicit declaration of function 'mmlex' [-Wimplicit-function-declaration]
#  #define yylex           mmlex
#                          ^
# aicasm_macro_gram.tab.c:1199:16: note: in expansion of macro 'yylex'
# aicasm_scan.l: In function 'yylex':
# aicasm_scan.l:420:6: warning: implicit declaration of function 'mm_switch_to_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(temp_state);
#       ^~~~~~~~~~~~~~~~~~~
# aicasm_scan.l:421:6: warning: implicit declaration of function 'mmparse' [-Wimplicit-function-declaration]
#       mm_switch_to_buffer(old_state);
#       ^~~~~~~
# aicasm_scan.l:424:6: warning: implicit declaration of function 'mm_delete_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(old_state);
#       ^~~~~~~~~~~~~~~~
# make[4]: *** [aicasm] Error 1
# make[3]: *** [drivers/scsi/aic7xxx/aicasm/aicasm] Error 2
# make[2]: *** [drivers/scsi/aic7xxx] Error 2
# make[1]: *** [drivers/scsi] Error 2
# make[1]: *** Waiting for unfinished jobs....
# make: *** [drivers] Error 2
# warning: (X86_INTEL_LPSS && INTEL_SOC_DTS_IOSF_CORE && SND_SST_IPC_ACPI && MMC_SDHCI_ACPI) selects IOSF_MBI which has unmet direct dependencies (PCI)
# warning: (X86_INTEL_LPSS && INTEL_SOC_DTS_IOSF_CORE && SND_SST_IPC_ACPI && MMC_SDHCI_ACPI) selects IOSF_MBI which has unmet direct dependencies (PCI)
# aicasm_symbol.c:48:19: fatal error: aicdb.h: No such file or directory
#  #include "aicdb.h"
#                    ^
# compilation terminated.
# aicasm_gram.tab.c: In function ‘yyparse’:
# aicasm_gram.tab.c:1628:16: warning: implicit declaration of function ‘yylex’ [-Wimplicit-function-declaration]
# aicasm_macro_gram.tab.c: In function ‘mmparse’:
# /TuxML/linux-4.13.3/drivers/scsi/aic7xxx/aicasm//aicasm_macro_gram.c:64:25: warning: implicit declaration of function ‘mmlex’ [-Wimplicit-function-declaration]
#  #define yylex           mmlex
#                          ^
# aicasm_macro_gram.tab.c:1199:16: note: in expansion of macro ‘yylex’
# aicasm_scan.l: In function ‘yylex’:
# aicasm_scan.l:420:6: warning: implicit declaration of function ‘mm_switch_to_buffer’ [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(temp_state);
#       ^~~~~~~~~~~~~~~~~~~
# aicasm_scan.l:421:6: warning: implicit declaration of function ‘mmparse’ [-Wimplicit-function-declaration]
#       mm_switch_to_buffer(old_state);
#       ^~~~~~~
# aicasm_scan.l:424:6: warning: implicit declaration of function ‘mm_delete_buffer’ [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(old_state);
#       ^~~~~~~~~~~~~~~~
# make[4]: *** [aicasm] Error 1
# make[3]: *** [drivers/scsi/aic7xxx/aicasm/aicasm] Error 2
# make[2]: *** [drivers/scsi/aic7xxx] Error 2
# make[1]: *** [drivers/scsi] Error 2
# make[1]: *** Waiting for unfinished jobs....
# make: *** [drivers] Error 2
# make[4]: flex: Command not found
# make[4]: *** [/TuxML/linux-4.13.3/drivers/scsi/aic7xxx/aicasm//aicasm_scan.c] Error 127
# make[3]: *** [drivers/scsi/aic7xxx/aicasm/aicasm] Error 2
# make[2]: *** [drivers/scsi/aic7xxx] Error 2
# make[1]: *** [drivers/scsi] Error 2
# make[1]: *** Waiting for unfinished jobs....
# In file included from ./include/linux/mtd/spi-nor.h:14:0,
#                  from drivers/spi/spi-bcm-qspi.c:28:
# ./include/linux/mtd/cfi.h:76:2: warning: #warning No CONFIG_MTD_CFI_Ix selected. No NOR chip support can work. [-Wcpp]
#  #warning No CONFIG_MTD_CFI_Ix selected. No NOR chip support can work.
#   ^~~~~~~
# In file included from ./include/linux/mtd/spi-nor.h:14:0,
#                  from drivers/spi/spi-bcm-qspi.c:28:
# ./include/linux/mtd/cfi.h:76:2: warning: #warning No CONFIG_MTD_CFI_Ix selected. No NOR chip support can work. [-Wcpp]
#  #warning No CONFIG_MTD_CFI_Ix selected. No NOR chip support can work.
#   ^~~~~~~
# make: *** [drivers] Error 2
# aicasm_symbol.c:48:19: fatal error: aicdb.h: No such file or directory
#  #include "aicdb.h"
#                    ^
# compilation terminated.
# aicasm_gram.tab.c: In function 'yyparse':
# aicasm_gram.tab.c:1628:16: warning: implicit declaration of function 'yylex' [-Wimplicit-function-declaration]
# aicasm_macro_gram.tab.c: In function 'mmparse':
# /TuxML/linux-4.13.3/drivers/scsi/aic7xxx/aicasm//aicasm_macro_gram.c:64:25: warning: implicit declaration of function 'mmlex' [-Wimplicit-function-declaration]
#  #define yylex           mmlex
#                          ^
# aicasm_macro_gram.tab.c:1199:16: note: in expansion of macro 'yylex'
# aicasm_scan.l: In function 'yylex':
# aicasm_scan.l:420:6: warning: implicit declaration of function 'mm_switch_to_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(temp_state);
#       ^~~~~~~~~~~~~~~~~~~
# aicasm_scan.l:421:6: warning: implicit declaration of function 'mmparse' [-Wimplicit-function-declaration]
#       mm_switch_to_buffer(old_state);
#       ^~~~~~~
# aicasm_scan.l:424:6: warning: implicit declaration of function 'mm_delete_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(old_state);
#       ^~~~~~~~~~~~~~~~
# make[4]: *** [aicasm] Error 1
# make[3]: *** [drivers/scsi/aic7xxx/aicasm/aicasm] Error 2
# make[2]: *** [drivers/scsi/aic7xxx] Error 2
# make[1]: *** [drivers/scsi] Error 2
# make[1]: *** Waiting for unfinished jobs....
# make: *** [drivers] Error 2
# aicasm_symbol.c:48:19: fatal error: aicdb.h: No such file or directory
#  #include "aicdb.h"
#                    ^
# compilation terminated.
# aicasm_gram.tab.c: In function 'yyparse':
# aicasm_gram.tab.c:1628:16: warning: implicit declaration of function 'yylex' [-Wimplicit-function-declaration]
# aicasm_macro_gram.tab.c: In function 'mmparse':
# /TuxML/linux-4.13.3/drivers/scsi/aic7xxx/aicasm//aicasm_macro_gram.c:64:25: warning: implicit declaration of function 'mmlex' [-Wimplicit-function-declaration]
#  #define yylex           mmlex
#                          ^
# aicasm_macro_gram.tab.c:1199:16: note: in expansion of macro 'yylex'
# aicasm_scan.l: In function 'yylex':
# aicasm_scan.l:420:6: warning: implicit declaration of function 'mm_switch_to_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(temp_state);
#       ^~~~~~~~~~~~~~~~~~~
# aicasm_scan.l:421:6: warning: implicit declaration of function 'mmparse' [-Wimplicit-function-declaration]
#       mm_switch_to_buffer(old_state);
#       ^~~~~~~
# aicasm_scan.l:424:6: warning: implicit declaration of function 'mm_delete_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(old_state);
#       ^~~~~~~~~~~~~~~~
# make[4]: *** [aicasm] Error 1
# make[3]: *** [drivers/scsi/aic7xxx/aicasm/aicasm] Error 2
# make[2]: *** [drivers/scsi/aic7xxx] Error 2
# make[1]: *** [drivers/scsi] Error 2
# make[1]: *** Waiting for unfinished jobs....
# make: *** [drivers] Error 2
# In file included from /usr/include/linux/filter.h:9:0,
#                  from samples/seccomp/bpf-fancy.c:12:
# /usr/include/linux/types.h:4:23: fatal error: asm/types.h: No such file or directory
#  #include <asm/types.h>
#                        ^
# compilation terminated.
# make[2]: *** [samples/seccomp/bpf-fancy.o] Error 1
# make[1]: *** [samples/seccomp] Error 2
# make: *** [samples] Error 2
# make: *** Waiting for unfinished jobs....
# aicasm_symbol.c:48:19: fatal error: aicdb.h: No such file or directory
#  #include "aicdb.h"
#                    ^
# compilation terminated.
# aicasm_gram.tab.c: In function 'yyparse':
# aicasm_gram.tab.c:1628:16: warning: implicit declaration of function 'yylex' [-Wimplicit-function-declaration]
# aicasm_macro_gram.tab.c: In function 'mmparse':
# /TuxML/linux-4.13.3/drivers/scsi/aic7xxx/aicasm//aicasm_macro_gram.c:64:25: warning: implicit declaration of function 'mmlex' [-Wimplicit-function-declaration]
#  #define yylex           mmlex
#                          ^
# aicasm_macro_gram.tab.c:1199:16: note: in expansion of macro 'yylex'
# aicasm_scan.l: In function 'yylex':
# aicasm_scan.l:420:6: warning: implicit declaration of function 'mm_switch_to_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(temp_state);
#       ^~~~~~~~~~~~~~~~~~~
# aicasm_scan.l:421:6: warning: implicit declaration of function 'mmparse' [-Wimplicit-function-declaration]
#       mm_switch_to_buffer(old_state);
#       ^~~~~~~
# aicasm_scan.l:424:6: warning: implicit declaration of function 'mm_delete_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(old_state);
#       ^~~~~~~~~~~~~~~~
# make[4]: *** [aicasm] Error 1
# make[3]: *** [drivers/scsi/aic7xxx/aicasm/aicasm] Error 2
# make[2]: *** [drivers/scsi/aic7xxx] Error 2
# make[2]: *** Waiting for unfinished jobs....
# make[1]: *** [drivers/scsi] Error 2
# make[1]: *** Waiting for unfinished jobs....
# make: *** [drivers] Error 2
# aicasm_symbol.c:48:19: fatal error: aicdb.h: No such file or directory
#  #include "aicdb.h"
#                    ^
# compilation terminated.
# aicasm_gram.tab.c: In function 'yyparse':
# aicasm_gram.tab.c:1628:16: warning: implicit declaration of function 'yylex' [-Wimplicit-function-declaration]
# aicasm_macro_gram.tab.c: In function 'mmparse':
# /TuxML/linux-4.13.3/drivers/scsi/aic7xxx/aicasm//aicasm_macro_gram.c:64:25: warning: implicit declaration of function 'mmlex' [-Wimplicit-function-declaration]
#  #define yylex           mmlex
#                          ^
# aicasm_macro_gram.tab.c:1199:16: note: in expansion of macro 'yylex'
# aicasm_scan.l: In function 'yylex':
# aicasm_scan.l:420:6: warning: implicit declaration of function 'mm_switch_to_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(temp_state);
#       ^~~~~~~~~~~~~~~~~~~
# aicasm_scan.l:421:6: warning: implicit declaration of function 'mmparse' [-Wimplicit-function-declaration]
#       mm_switch_to_buffer(old_state);
#       ^~~~~~~
# aicasm_scan.l:424:6: warning: implicit declaration of function 'mm_delete_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(old_state);
#       ^~~~~~~~~~~~~~~~
# make[4]: *** [aicasm] Error 1
# make[3]: *** [drivers/scsi/aic7xxx/aicasm/aicasm] Error 2
# make[2]: *** [drivers/scsi/aic7xxx] Error 2
# make[2]: *** Waiting for unfinished jobs....
# make[1]: *** [drivers/scsi] Error 2
# make[1]: *** Waiting for unfinished jobs....
# make: *** [drivers] Error 2
# In file included from /usr/include/stdio.h:27:0,
#                  from samples/seccomp/bpf-fancy.c:15:
# /usr/include/features.h:364:25: fatal error: sys/cdefs.h: No such file or directory
#  #  include <sys/cdefs.h>
#                          ^
# compilation terminated.
# make[2]: *** [samples/seccomp/bpf-fancy.o] Error 1
# make[1]: *** [samples/seccomp] Error 2
# make: *** [samples] Error 2
# make: *** Waiting for unfinished jobs....
# lib/ubsan.o: warning: objtool: val_to_string.constprop.4()+0xaf: leave instruction with modified stack frame
# /bin/sh: 1: as68k: not found
# make[3]: *** [drivers/net/wan/wanxlfw.inc] Error 127
# make[2]: *** [drivers/net/wan] Error 2
# make[2]: *** Waiting for unfinished jobs....
# make[1]: *** [drivers/net] Error 2
# make[1]: *** Waiting for unfinished jobs....
# make: *** [drivers] Error 2
# aicasm_symbol.c:48:19: fatal error: aicdb.h: No such file or directory
#  #include "aicdb.h"
#                    ^
# compilation terminated.
# aicasm_gram.tab.c: In function 'yyparse':
# aicasm_gram.tab.c:1628:16: warning: implicit declaration of function 'yylex' [-Wimplicit-function-declaration]
# aicasm_macro_gram.tab.c: In function 'mmparse':
# /TuxML/linux-4.13.3/drivers/scsi/aic7xxx/aicasm//aicasm_macro_gram.c:64:25: warning: implicit declaration of function 'mmlex' [-Wimplicit-function-declaration]
#  #define yylex           mmlex
#                          ^
# aicasm_macro_gram.tab.c:1199:16: note: in expansion of macro 'yylex'
# aicasm_scan.l: In function 'yylex':
# aicasm_scan.l:420:6: warning: implicit declaration of function 'mm_switch_to_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(temp_state);
#       ^~~~~~~~~~~~~~~~~~~
# aicasm_scan.l:421:6: warning: implicit declaration of function 'mmparse' [-Wimplicit-function-declaration]
#       mm_switch_to_buffer(old_state);
#       ^~~~~~~
# aicasm_scan.l:424:6: warning: implicit declaration of function 'mm_delete_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(old_state);
#       ^~~~~~~~~~~~~~~~
# make[4]: *** [aicasm] Error 1
# make[3]: *** [drivers/scsi/aic7xxx/aicasm/aicasm] Error 2
# make[2]: *** [drivers/scsi/aic7xxx] Error 2
# make[2]: *** Waiting for unfinished jobs....
# make[1]: *** [drivers/scsi] Error 2
# make[1]: *** Waiting for unfinished jobs....
# make: *** [drivers] Error 2
# crypto/twofish_common.c: In function '__twofish_setkey':
# crypto/twofish_common.c:700:1: warning: the frame size of 4992 bytes is larger than 2048 bytes [-Wframe-larger-than=]
#  }
#  ^
# aicasm_symbol.c:48:19: fatal error: aicdb.h: No such file or directory
#  #include "aicdb.h"
#                    ^
# compilation terminated.
# aicasm_gram.tab.c: In function 'yyparse':
# aicasm_gram.tab.c:1628:16: warning: implicit declaration of function 'yylex' [-Wimplicit-function-declaration]
# aicasm_macro_gram.tab.c: In function 'mmparse':
# /TuxML/linux-4.13.3/drivers/scsi/aic7xxx/aicasm//aicasm_macro_gram.c:64:25: warning: implicit declaration of function 'mmlex' [-Wimplicit-function-declaration]
#  #define yylex           mmlex
#                          ^
# aicasm_macro_gram.tab.c:1199:16: note: in expansion of macro 'yylex'
# aicasm_scan.l: In function 'yylex':
# aicasm_scan.l:420:6: warning: implicit declaration of function 'mm_switch_to_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(temp_state);
#       ^~~~~~~~~~~~~~~~~~~
# aicasm_scan.l:421:6: warning: implicit declaration of function 'mmparse' [-Wimplicit-function-declaration]
#       mm_switch_to_buffer(old_state);
#       ^~~~~~~
# aicasm_scan.l:424:6: warning: implicit declaration of function 'mm_delete_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(old_state);
#       ^~~~~~~~~~~~~~~~
# make[4]: *** [aicasm] Error 1
# make[3]: *** [drivers/scsi/aic7xxx/aicasm/aicasm] Error 2
# make[2]: *** [drivers/scsi/aic7xxx] Error 2
# make[2]: *** Waiting for unfinished jobs....
# make[1]: *** [drivers/scsi] Error 2
# make[1]: *** Waiting for unfinished jobs....
# make: *** [drivers] Error 2
# In file included from ./include/linux/bitmap.h:8:0,
#                  from ./include/linux/cpumask.h:11,
#                  from ./arch/x86/include/asm/cpumask.h:4,
#                  from ./arch/x86/include/asm/msr.h:10,
#                  from ./arch/x86/include/asm/processor.h:20,
#                  from ./arch/x86/include/asm/cpufeature.h:4,
#                  from ./arch/x86/include/asm/thread_info.h:52,
#                  from ./include/linux/thread_info.h:37,
#                  from ./arch/x86/include/asm/preempt.h:6,
#                  from ./include/linux/preempt.h:80,
#                  from ./include/linux/spinlock.h:50,
#                  from drivers/infiniband/core/core_priv.h:37,
#                  from drivers/infiniband/core/roce_gid_mgmt.c:33:
# In function 'memcpy',
#     inlined from 'rdma_ip2gid' at ./include/rdma/ib_addr.h:175:3,
#     inlined from 'addr_event.isra.0.constprop' at drivers/infiniband/core/roce_gid_mgmt.c:691:2,
#     inlined from 'inetaddr_event' at drivers/infiniband/core/roce_gid_mgmt.c:714:9:
# ./include/linux/string.h:305:4: error: call to '__read_overflow2' declared with attribute error: detected read beyond size of object passed as 2nd parameter
#     __read_overflow2();
#     ^~~~~~~~~~~~~~~~~~
# make[3]: *** [drivers/infiniband/core/roce_gid_mgmt.o] Error 1
# make[2]: *** [drivers/infiniband/core] Error 2
# make[1]: *** [drivers/infiniband] Error 2
# make[1]: *** Waiting for unfinished jobs....
# make: *** [drivers] Error 2
# In file included from ./include/linux/bitmap.h:8:0,
#                  from ./include/linux/cpumask.h:11,
#                  from ./arch/x86/include/asm/cpumask.h:4,
#                  from ./arch/x86/include/asm/msr.h:10,
#                  from ./arch/x86/include/asm/processor.h:20,
#                  from ./arch/x86/include/asm/cpufeature.h:4,
#                  from ./arch/x86/include/asm/thread_info.h:52,
#                  from ./include/linux/thread_info.h:37,
#                  from ./arch/x86/include/asm/preempt.h:6,
#                  from ./include/linux/preempt.h:80,
#                  from ./include/linux/spinlock.h:50,
#                  from drivers/infiniband/core/core_priv.h:37,
#                  from drivers/infiniband/core/roce_gid_mgmt.c:33:
# In function 'memcpy',
#     inlined from 'rdma_ip2gid' at ./include/rdma/ib_addr.h:175:3,
#     inlined from 'addr_event.isra.0.constprop' at drivers/infiniband/core/roce_gid_mgmt.c:691:2,
#     inlined from 'inetaddr_event' at drivers/infiniband/core/roce_gid_mgmt.c:714:9:
# ./include/linux/string.h:305:4: error: call to '__read_overflow2' declared with attribute error: detected read beyond size of object passed as 2nd parameter
#     __read_overflow2();
#     ^~~~~~~~~~~~~~~~~~
# make[3]: *** [drivers/infiniband/core/roce_gid_mgmt.o] Error 1
# make[2]: *** [drivers/infiniband/core] Error 2
# make[1]: *** [drivers/infiniband] Error 2
# make[1]: *** Waiting for unfinished jobs....
# make: *** [drivers] Error 2
# In file included from ./include/linux/uaccess.h:13:0,
#                  from ./include/linux/highmem.h:8,
#                  from fs/binfmt_elf.c:28:
# fs/binfmt_elf.c: In function 'create_elf_tables':
# ./arch/x86/include/asm/uaccess_64.h:143:20: warning: array subscript is above array bounds [-Warray-bounds]
#     __put_user_asm(4[(u16 *)src], 4 + (u16 __user *)dst,
#                     ^
# ./arch/x86/include/asm/uaccess.h:468:16: note: in definition of macro '__put_user_asm'
#         : ltype(x), "m" (__m(addr)), "i" (errret), "0" (err))
#                 ^
# ./arch/x86/include/asm/uaccess_64.h:143:20: warning: array subscript is above array bounds [-Warray-bounds]
#     __put_user_asm(4[(u16 *)src], 4 + (u16 __user *)dst,
#                     ^
# ./arch/x86/include/asm/uaccess.h:468:16: note: in definition of macro '__put_user_asm'
#         : ltype(x), "m" (__m(addr)), "i" (errret), "0" (err))
#                 ^
# ./arch/x86/include/asm/uaccess_64.h:154:20: warning: array subscript is above array bounds [-Warray-bounds]
#     __put_user_asm(1[(u64 *)src], 1 + (u64 __user *)dst,
#                     ^
# ./arch/x86/include/asm/uaccess.h:468:16: note: in definition of macro '__put_user_asm'
#         : ltype(x), "m" (__m(addr)), "i" (errret), "0" (err))
#                 ^
# ./arch/x86/include/asm/uaccess_64.h:154:20: warning: array subscript is above array bounds [-Warray-bounds]
#     __put_user_asm(1[(u64 *)src], 1 + (u64 __user *)dst,
#                     ^
# ./arch/x86/include/asm/uaccess.h:468:16: note: in definition of macro '__put_user_asm'
#         : ltype(x), "m" (__m(addr)), "i" (errret), "0" (err))
#                 ^
# In file included from ./include/linux/uaccess.h:13:0,
#                  from ./include/linux/highmem.h:8,
#                  from fs/binfmt_elf.c:28,
#                  from fs/compat_binfmt_elf.c:131:
# fs/binfmt_elf.c: In function 'create_elf_tables':
# ./arch/x86/include/asm/uaccess_64.h:143:20: warning: array subscript is above array bounds [-Warray-bounds]
#     __put_user_asm(4[(u16 *)src], 4 + (u16 __user *)dst,
#                     ^
# ./arch/x86/include/asm/uaccess.h:468:16: note: in definition of macro '__put_user_asm'
#         : ltype(x), "m" (__m(addr)), "i" (errret), "0" (err))
#                 ^
# ./arch/x86/include/asm/uaccess_64.h:143:20: warning: array subscript is above array bounds [-Warray-bounds]
#     __put_user_asm(4[(u16 *)src], 4 + (u16 __user *)dst,
#                     ^
# ./arch/x86/include/asm/uaccess.h:468:16: note: in definition of macro '__put_user_asm'
#         : ltype(x), "m" (__m(addr)), "i" (errret), "0" (err))
#                 ^
# ./arch/x86/include/asm/uaccess_64.h:154:20: warning: array subscript is above array bounds [-Warray-bounds]
#     __put_user_asm(1[(u64 *)src], 1 + (u64 __user *)dst,
#                     ^
# ./arch/x86/include/asm/uaccess.h:468:16: note: in definition of macro '__put_user_asm'
#         : ltype(x), "m" (__m(addr)), "i" (errret), "0" (err))
#                 ^
# ./arch/x86/include/asm/uaccess_64.h:154:20: warning: array subscript is above array bounds [-Warray-bounds]
#     __put_user_asm(1[(u64 *)src], 1 + (u64 __user *)dst,
#                     ^
# ./arch/x86/include/asm/uaccess.h:468:16: note: in definition of macro '__put_user_asm'
#         : ltype(x), "m" (__m(addr)), "i" (errret), "0" (err))
#                 ^
# aicasm_symbol.c:48:19: fatal error: aicdb.h: No such file or directory
#  #include "aicdb.h"
#                    ^
# compilation terminated.
# aicasm_gram.tab.c: In function 'yyparse':
# aicasm_gram.tab.c:1628:16: warning: implicit declaration of function 'yylex' [-Wimplicit-function-declaration]
# aicasm_macro_gram.tab.c: In function 'mmparse':
# /TuxML/linux-4.13.3/drivers/scsi/aic7xxx/aicasm//aicasm_macro_gram.c:64:25: warning: implicit declaration of function 'mmlex' [-Wimplicit-function-declaration]
#  #define yylex           mmlex
#                          ^
# aicasm_macro_gram.tab.c:1199:16: note: in expansion of macro 'yylex'
# aicasm_scan.l: In function 'yylex':
# aicasm_scan.l:420:6: warning: implicit declaration of function 'mm_switch_to_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(temp_state);
#       ^~~~~~~~~~~~~~~~~~~
# aicasm_scan.l:421:6: warning: implicit declaration of function 'mmparse' [-Wimplicit-function-declaration]
#       mm_switch_to_buffer(old_state);
#       ^~~~~~~
# aicasm_scan.l:424:6: warning: implicit declaration of function 'mm_delete_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(old_state);
#       ^~~~~~~~~~~~~~~~
# make[4]: *** [aicasm] Error 1
# make[3]: *** [drivers/scsi/aic7xxx/aicasm/aicasm] Error 2
# make[2]: *** [drivers/scsi/aic7xxx] Error 2
# make[1]: *** [drivers/scsi] Error 2
# make[1]: *** Waiting for unfinished jobs....
# make: *** [drivers] Error 2
# /bin/sh: 1: as68k: not found
# make[3]: *** [drivers/net/wan/wanxlfw.inc] Error 127
# make[2]: *** [drivers/net/wan] Error 2
# make[1]: *** [drivers/net] Error 2
# make[1]: *** Waiting for unfinished jobs....
# make: *** [drivers] Error 2
# In file included from ./include/linux/bitmap.h:8:0,
#                  from ./include/linux/cpumask.h:11,
#                  from ./arch/x86/include/asm/cpumask.h:4,
#                  from ./arch/x86/include/asm/msr.h:10,
#                  from ./arch/x86/include/asm/processor.h:20,
#                  from ./arch/x86/include/asm/cpufeature.h:4,
#                  from ./arch/x86/include/asm/thread_info.h:52,
#                  from ./include/linux/thread_info.h:37,
#                  from ./arch/x86/include/asm/preempt.h:6,
#                  from ./include/linux/preempt.h:80,
#                  from ./include/linux/spinlock.h:50,
#                  from drivers/infiniband/core/core_priv.h:37,
#                  from drivers/infiniband/core/roce_gid_mgmt.c:33:
# In function 'memcpy',
#     inlined from 'rdma_ip2gid' at ./include/rdma/ib_addr.h:175:3,
#     inlined from 'addr_event.isra.0.constprop' at drivers/infiniband/core/roce_gid_mgmt.c:691:2,
#     inlined from 'inetaddr_event' at drivers/infiniband/core/roce_gid_mgmt.c:714:9:
# ./include/linux/string.h:305:4: error: call to '__read_overflow2' declared with attribute error: detected read beyond size of object passed as 2nd parameter
#     __read_overflow2();
#     ^~~~~~~~~~~~~~~~~~
# make[3]: *** [drivers/infiniband/core/roce_gid_mgmt.o] Error 1
# make[2]: *** [drivers/infiniband/core] Error 2
# make[1]: *** [drivers/infiniband] Error 2
# make[1]: *** Waiting for unfinished jobs....
# make: *** [drivers] Error 2
# lib/ubsan.o: warning: objtool: val_to_string.constprop.4()+0xaf: leave instruction with modified stack frame
# /bin/sh: 1: as68k: not found
# make[3]: *** [drivers/net/wan/wanxlfw.inc] Error 127
# make[3]: *** Waiting for unfinished jobs....
# make[2]: *** [drivers/net/wan] Error 2
# make[2]: *** Waiting for unfinished jobs....
# aicasm_symbol.c: In function 'aic_print_reg_dump_end':
# aicasm_symbol.c:397:13: warning: implicit declaration of function 'tolower' [-Wimplicit-function-declaration]
#    *letter = tolower(*letter);
#              ^~~~~~~
# aicasm_gram.tab.c: In function 'yyparse':
# aicasm_gram.tab.c:1628:16: warning: implicit declaration of function 'yylex' [-Wimplicit-function-declaration]
# aicasm_macro_gram.tab.c: In function 'mmparse':
# /TuxML/linux-4.13.3/drivers/scsi/aic7xxx/aicasm//aicasm_macro_gram.c:64:25: warning: implicit declaration of function 'mmlex' [-Wimplicit-function-declaration]
#  #define yylex           mmlex
#                          ^
# aicasm_macro_gram.tab.c:1199:16: note: in expansion of macro 'yylex'
# aicasm_scan.l: In function 'yylex':
# aicasm_scan.l:420:6: warning: implicit declaration of function 'mm_switch_to_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(temp_state);
#       ^~~~~~~~~~~~~~~~~~~
# aicasm_scan.l:421:6: warning: implicit declaration of function 'mmparse' [-Wimplicit-function-declaration]
#       mm_switch_to_buffer(old_state);
#       ^~~~~~~
# aicasm_scan.l:424:6: warning: implicit declaration of function 'mm_delete_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(old_state);
#       ^~~~~~~~~~~~~~~~
# drivers/scsi/aic7xxx/aicasm/aicasm: 880 instructions used
# drivers/scsi/aic7xxx/aicasm/aicasm: 25 of 37 register definitions used
# make[1]: *** [drivers/net] Error 2
# make[1]: *** Waiting for unfinished jobs....
# make: *** [drivers] Error 2
# drivers/gpu/drm/radeon/radeon_object.c: In function 'radeon_bo_create':
# drivers/gpu/drm/radeon/radeon_object.c:242:2: warning: #warning Please enable CONFIG_MTRR and CONFIG_X86_PAT for better performance thanks to write-combining [-Wcpp]
#  #warning Please enable CONFIG_MTRR and CONFIG_X86_PAT for better performance \
#   ^~~~~~~
# aicasm_symbol.c:48:19: fatal error: aicdb.h: No such file or directory
#  #include "aicdb.h"
#                    ^
# compilation terminated.
# aicasm_gram.tab.c: In function 'yyparse':
# aicasm_gram.tab.c:1628:16: warning: implicit declaration of function 'yylex' [-Wimplicit-function-declaration]
# aicasm_macro_gram.tab.c: In function 'mmparse':
# /TuxML/linux-4.13.3/drivers/scsi/aic7xxx/aicasm//aicasm_macro_gram.c:64:25: warning: implicit declaration of function 'mmlex' [-Wimplicit-function-declaration]
#  #define yylex           mmlex
#                          ^
# aicasm_macro_gram.tab.c:1199:16: note: in expansion of macro 'yylex'
# aicasm_scan.l: In function 'yylex':
# aicasm_scan.l:420:6: warning: implicit declaration of function 'mm_switch_to_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(temp_state);
#       ^~~~~~~~~~~~~~~~~~~
# aicasm_scan.l:421:6: warning: implicit declaration of function 'mmparse' [-Wimplicit-function-declaration]
#       mm_switch_to_buffer(old_state);
#       ^~~~~~~
# aicasm_scan.l:424:6: warning: implicit declaration of function 'mm_delete_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(old_state);
#       ^~~~~~~~~~~~~~~~
# make[4]: *** [aicasm] Error 1
# make[3]: *** [drivers/scsi/aic7xxx/aicasm/aicasm] Error 2
# make[2]: *** [drivers/scsi/aic7xxx] Error 2
# make[1]: *** [drivers/scsi] Error 2
# make[1]: *** Waiting for unfinished jobs....
# make: *** [drivers] Error 2
# drivers/gpu/drm/amd/amdgpu/amdgpu_object.c: In function 'amdgpu_bo_create_restricted':
# drivers/gpu/drm/amd/amdgpu/amdgpu_object.c:378:2: warning: #warning Please enable CONFIG_MTRR and CONFIG_X86_PAT for better performance thanks to write-combining [-Wcpp]
#  #warning Please enable CONFIG_MTRR and CONFIG_X86_PAT for better performance \
#   ^~~~~~~
# drivers/staging/vboxvideo/vbox_hgsmi.o: In function `hgsmi_buffer_alloc':
# /TuxML/linux-4.13.3/drivers/staging/vboxvideo/vbox_hgsmi.c:76: undefined reference to `gen_pool_dma_alloc'
# drivers/staging/vboxvideo/vbox_hgsmi.o: In function `hgsmi_buffer_free':
# /TuxML/linux-4.13.3/drivers/staging/vboxvideo/vbox_hgsmi.c:101: undefined reference to `gen_pool_free'
# drivers/staging/vboxvideo/vbox_hgsmi.o: In function `hgsmi_buffer_submit':
# /TuxML/linux-4.13.3/drivers/staging/vboxvideo/vbox_hgsmi.c:108: undefined reference to `gen_pool_virt_to_phys'
# drivers/staging/vboxvideo/vbox_main.o: In function `vbox_hw_fini':
# /TuxML/linux-4.13.3/drivers/staging/vboxvideo/vbox_main.c:348: undefined reference to `gen_pool_destroy'
# drivers/staging/vboxvideo/vbox_main.o: In function `vbox_driver_load':
# /TuxML/linux-4.13.3/drivers/staging/vboxvideo/vbox_main.c:295: undefined reference to `gen_pool_create'
# /TuxML/linux-4.13.3/drivers/staging/vboxvideo/vbox_main.c:299: undefined reference to `gen_pool_add_virt'
# /TuxML/linux-4.13.3/drivers/staging/vboxvideo/vbox_main.c:339: undefined reference to `gen_pool_destroy'
# make: *** [vmlinux] Error 1
# drivers/gpu/drm/radeon/radeon_object.c: In function 'radeon_bo_create':
# drivers/gpu/drm/radeon/radeon_object.c:242:2: warning: #warning Please enable CONFIG_MTRR and CONFIG_X86_PAT for better performance thanks to write-combining [-Wcpp]
#  #warning Please enable CONFIG_MTRR and CONFIG_X86_PAT for better performance \
#   ^~~~~~~
# drivers/staging/vboxvideo/vbox_hgsmi.o: In function `hgsmi_buffer_alloc':
# /TuxML/linux-4.13.3/drivers/staging/vboxvideo/vbox_hgsmi.c:76: undefined reference to `gen_pool_dma_alloc'
# drivers/staging/vboxvideo/vbox_hgsmi.o: In function `hgsmi_buffer_free':
# /TuxML/linux-4.13.3/drivers/staging/vboxvideo/vbox_hgsmi.c:101: undefined reference to `gen_pool_free'
# drivers/staging/vboxvideo/vbox_hgsmi.o: In function `hgsmi_buffer_submit':
# /TuxML/linux-4.13.3/drivers/staging/vboxvideo/vbox_hgsmi.c:108: undefined reference to `gen_pool_virt_to_phys'
# drivers/staging/vboxvideo/vbox_main.o: In function `vbox_hw_fini':
# /TuxML/linux-4.13.3/drivers/staging/vboxvideo/vbox_main.c:348: undefined reference to `gen_pool_destroy'
# drivers/staging/vboxvideo/vbox_main.o: In function `vbox_driver_load':
# /TuxML/linux-4.13.3/drivers/staging/vboxvideo/vbox_main.c:295: undefined reference to `gen_pool_create'
# /TuxML/linux-4.13.3/drivers/staging/vboxvideo/vbox_main.c:299: undefined reference to `gen_pool_add_virt'
# /TuxML/linux-4.13.3/drivers/staging/vboxvideo/vbox_main.c:339: undefined reference to `gen_pool_destroy'
# make: *** [vmlinux] Error 1
# drivers/gpu/drm/radeon/radeon_object.c: In function 'radeon_bo_create':
# drivers/gpu/drm/radeon/radeon_object.c:242:2: warning: #warning Please enable CONFIG_MTRR and CONFIG_X86_PAT for better performance thanks to write-combining [-Wcpp]
#  #warning Please enable CONFIG_MTRR and CONFIG_X86_PAT for better performance \
#   ^~~~~~~
# aicasm_symbol.c:48:19: fatal error: aicdb.h: No such file or directory
#  #include "aicdb.h"
#                    ^
# compilation terminated.
# aicasm_gram.tab.c: In function 'yyparse':
# aicasm_gram.tab.c:1628:16: warning: implicit declaration of function 'yylex' [-Wimplicit-function-declaration]
# aicasm_macro_gram.tab.c: In function 'mmparse':
# /TuxML/linux-4.13.3/drivers/scsi/aic7xxx/aicasm//aicasm_macro_gram.c:64:25: warning: implicit declaration of function 'mmlex' [-Wimplicit-function-declaration]
#  #define yylex           mmlex
#                          ^
# aicasm_macro_gram.tab.c:1199:16: note: in expansion of macro 'yylex'
# aicasm_scan.l: In function 'yylex':
# aicasm_scan.l:420:6: warning: implicit declaration of function 'mm_switch_to_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(temp_state);
#       ^~~~~~~~~~~~~~~~~~~
# aicasm_scan.l:421:6: warning: implicit declaration of function 'mmparse' [-Wimplicit-function-declaration]
#       mm_switch_to_buffer(old_state);
#       ^~~~~~~
# aicasm_scan.l:424:6: warning: implicit declaration of function 'mm_delete_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(old_state);
#       ^~~~~~~~~~~~~~~~
# make[4]: *** [aicasm] Error 1
# make[3]: *** [drivers/scsi/aic7xxx/aicasm/aicasm] Error 2
# make[2]: *** [drivers/scsi/aic7xxx] Error 2
# make[2]: *** Waiting for unfinished jobs....
# make[1]: *** [drivers/scsi] Error 2
# make[1]: *** Waiting for unfinished jobs....
# make: *** [drivers] Error 2

# %%
# TODO: workaround 
# see issue here: https://github.com/TuxML/compilation-analysis/issues/7
for cid in cid_errors_not_in_configdata:
    errorlogs = errorlogs[errorlogs.cid != cid]
    error_patternfirst = error_patternfirst[error_patternfirst.index != cid]
    error_pattern = error_pattern[error_pattern.index != cid]

errorlogs.shape, error_patternfirst.shape, error_pattern.shape
# Out:
# ((3621, 2), (3621, 20), (3621, 21))

# %%
patternfirst_frequencies = error_patternfirst[pattern_name].apply(nb_patterns, axis=0)
patternfirst_frequencies.plot(kind='bar')
patternfirst_frequencies
# Out:
# BLACKLIGHT              15
# BLACKLIGHT2              1
# CONFIG_NLS_DEFAULT       6
# CRC32_CLUSTER            2
# V4L2                    19
# OVERFLOW2               83
# ULPI                     1
# PCM                      1
# TTM                     13
# AS68K                  476
# GEN                    367
# AICDB                 2464
# AIC7XXX                161
# DRM_BRIDGE_CLUSTER       3
# PINCTRL_CLUSTER          3
# BTBCM                    2
# BPFFANCY                 0
# DEVM                     2
# DEVM2                    1
# I2C_CLUSTER              1
# dtype: int64

# %%
rawtuxdata.fillna(-1, inplace=True)

# %%
from sklearn.model_selection import train_test_split
from sklearn import tree


TESTING_SIZE= 0.001 #0.99 # 0.001 # 0.9
X_train, X_test, y_train, y_test = train_test_split(
    rawtuxdata
    .drop(columns=["cid"])
    # .drop(columns=size_methods)
    .drop(columns=compilation_status_column_name), 
    rawtuxdata[compilation_status_column_name], test_size=TESTING_SIZE, random_state=0)  
clf = tree.DecisionTreeClassifier() #GradientBoostingClassifier(n_estimators=100) #RandomForestRegressor(n_estimators=100) #   #GradientBoostingRegressor(n_estimators=100)  
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, balanced_accuracy_score

y_pred = clf.predict(X_test)

acc = accuracy_score (y_test, y_pred)
prec = precision_score (y_test, y_pred)
reca = recall_score (y_test, y_pred)
f1 = f1_score (y_test, y_pred)
balance_acc = balanced_accuracy_score (y_test, y_pred)
print("Accuracy score:", acc)
print("Precision score:", prec)
print("Recall score:", reca)
print("F1 score:", f1)
print("Balanced accuracy score:", balance_acc)
# Out:
# Accuracy score: 1.0
# Precision score: 1.0
# Recall score: 1.0
# F1 score: 1.0
# Balance accuracy score: 1.0

# %%
del X_train
del X_test 
del y_train 
del y_test

# %%
import graphviz 

def printTree(clf, feature_names):
    dot_data = tree.export_graphviz(clf, out_file=None, 
                         feature_names=feature_names,  
                         filled=True, rounded=True,
                         special_characters=True)  
    graph = graphviz.Source(dot_data)  
    graph.render("TUXML_compilation_failures")
    
# printTree(clf, rawtuxdata.drop(columns=["cid"]).drop(columns=size_methods).drop(columns=compilation_status_column_name).columns)
printTree(clf, rawtuxdata.drop(columns=["cid"]).drop(columns=compilation_status_column_name).columns)

# %%
rawtuxdata.query("AIC79XX_BUILD_FIRMWARE == 1 & VIDEO_SAA7134_GO7007 == 2 & VFIO_PCI_INTX == 1")[[compilation_status_column_name, 'INITRAMFS_SOURCE']]

rawtuxdata.query("AIC79XX_BUILD_FIRMWARE == 1 & " + compilation_status_column_name + " == 1")[[compilation_status_column_name, 'INITRAMFS_SOURCE', 'cid']]
# Out:
# Empty DataFrame
# Columns: [compile_success, INITRAMFS_SOURCE, cid]
# Index: []

# %%
from sklearn.tree import _tree

def tree_to_rules(tree, feature_names):
    tree_ = tree.tree_
    feature_name = [
        feature_names[i] if i != _tree.TREE_UNDEFINED else "undefined!"
        for i in tree_.feature
    ]
    #print ("def tree({}):".format(", ".join(feature_names)))

    def recurse(node, previous_rules):
        if tree_.feature[node] != _tree.TREE_UNDEFINED:
            name = feature_name[node]
            threshold = tree_.threshold[node]
            #print ("{}if {} <= {}:".format(indent, name, threshold))
            recurse(tree_.children_left[node], previous_rules+[name + " <= " + str(threshold)])
            #print ("{}else:  # if {} > {}".format(indent, name, threshold))
            recurse(tree_.children_right[node], previous_rules+[name + " > " + str(threshold)])
        else:
            print(" & ".join(previous_rules) + " ---> " + str(tree_.value[node]))

    recurse(0, [])
    
#tree_to_rules(clf, rawtuxdata.drop(columns=["cid"]).drop(columns=size_methods).drop(columns=compilation_status_column_name).columns)
tree_to_rules(clf, rawtuxdata.drop(columns=["cid"]).drop(columns=compilation_status_column_name).columns)
# Out:
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR <= 0.5 & DRM_VBOXVIDEO <= 1.5 & HFI1_VERBS_31BIT_PSN <= 0.5 & WIL6210_TRACING <= 0.5 & ISDN_DRV_AVMB1_T1PCI <= 0.5 & SCLP_ASYNC_ID <= 4360.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR <= 0.5 & DRM_VBOXVIDEO <= 1.5 & HFI1_VERBS_31BIT_PSN <= 0.5 & WIL6210_TRACING <= 0.5 & ISDN_DRV_AVMB1_T1PCI <= 0.5 & SCLP_ASYNC_ID > 4360.5 ---> [[0. 7.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR <= 0.5 & DRM_VBOXVIDEO <= 1.5 & HFI1_VERBS_31BIT_PSN <= 0.5 & WIL6210_TRACING <= 0.5 & ISDN_DRV_AVMB1_T1PCI > 0.5 & INFINIBAND_ISERT <= 1.5 & SPI_SH_MSIOF <= 0.5 & BACKLIGHT_LP8788 <= 0.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR <= 0.5 & DRM_VBOXVIDEO <= 1.5 & HFI1_VERBS_31BIT_PSN <= 0.5 & WIL6210_TRACING <= 0.5 & ISDN_DRV_AVMB1_T1PCI > 0.5 & INFINIBAND_ISERT <= 1.5 & SPI_SH_MSIOF <= 0.5 & BACKLIGHT_LP8788 > 0.5 ---> [[ 0. 28.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR <= 0.5 & DRM_VBOXVIDEO <= 1.5 & HFI1_VERBS_31BIT_PSN <= 0.5 & WIL6210_TRACING <= 0.5 & ISDN_DRV_AVMB1_T1PCI > 0.5 & INFINIBAND_ISERT <= 1.5 & SPI_SH_MSIOF > 0.5 & RT_MUTEXES <= 0.5 & USB_HACKRF <= 0.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR <= 0.5 & DRM_VBOXVIDEO <= 1.5 & HFI1_VERBS_31BIT_PSN <= 0.5 & WIL6210_TRACING <= 0.5 & ISDN_DRV_AVMB1_T1PCI > 0.5 & INFINIBAND_ISERT <= 1.5 & SPI_SH_MSIOF > 0.5 & RT_MUTEXES <= 0.5 & USB_HACKRF > 0.5 ---> [[ 0. 51.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR <= 0.5 & DRM_VBOXVIDEO <= 1.5 & HFI1_VERBS_31BIT_PSN <= 0.5 & WIL6210_TRACING <= 0.5 & ISDN_DRV_AVMB1_T1PCI > 0.5 & INFINIBAND_ISERT <= 1.5 & SPI_SH_MSIOF > 0.5 & RT_MUTEXES > 0.5 ---> [[   0. 4719.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR <= 0.5 & DRM_VBOXVIDEO <= 1.5 & HFI1_VERBS_31BIT_PSN <= 0.5 & WIL6210_TRACING <= 0.5 & ISDN_DRV_AVMB1_T1PCI > 0.5 & INFINIBAND_ISERT > 1.5 & FPGA_MGR_ICE40_SPI <= 1.5 ---> [[ 0. 10.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR <= 0.5 & DRM_VBOXVIDEO <= 1.5 & HFI1_VERBS_31BIT_PSN <= 0.5 & WIL6210_TRACING <= 0.5 & ISDN_DRV_AVMB1_T1PCI > 0.5 & INFINIBAND_ISERT > 1.5 & FPGA_MGR_ICE40_SPI > 1.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR <= 0.5 & DRM_VBOXVIDEO <= 1.5 & HFI1_VERBS_31BIT_PSN <= 0.5 & WIL6210_TRACING > 0.5 & NF_CONNTRACK_PPTP <= 1.5 ---> [[0. 7.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR <= 0.5 & DRM_VBOXVIDEO <= 1.5 & HFI1_VERBS_31BIT_PSN <= 0.5 & WIL6210_TRACING > 0.5 & NF_CONNTRACK_PPTP > 1.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR <= 0.5 & DRM_VBOXVIDEO <= 1.5 & HFI1_VERBS_31BIT_PSN > 0.5 & TEST_SYSCTL <= 0.5 & NET_IPIP <= 1.0 ---> [[0. 1.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR <= 0.5 & DRM_VBOXVIDEO <= 1.5 & HFI1_VERBS_31BIT_PSN > 0.5 & TEST_SYSCTL <= 0.5 & NET_IPIP > 1.0 ---> [[2. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR <= 0.5 & DRM_VBOXVIDEO <= 1.5 & HFI1_VERBS_31BIT_PSN > 0.5 & TEST_SYSCTL > 0.5 & VIDEO_AD5820 <= 1.5 ---> [[ 0. 44.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR <= 0.5 & DRM_VBOXVIDEO <= 1.5 & HFI1_VERBS_31BIT_PSN > 0.5 & TEST_SYSCTL > 0.5 & VIDEO_AD5820 > 1.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR <= 0.5 & DRM_VBOXVIDEO > 1.5 ---> [[369.   0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC <= 0.5 & VIDEO_MUX <= 1.5 & SND_AT91_SOC_SAM9G20_WM8731 <= 1.5 ---> [[  0. 360.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC <= 0.5 & VIDEO_MUX <= 1.5 & SND_AT91_SOC_SAM9G20_WM8731 > 1.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC <= 0.5 & VIDEO_MUX > 1.5 & REGMAP_I2C <= 0.5 ---> [[13.  0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC <= 0.5 & VIDEO_MUX > 1.5 & REGMAP_I2C > 0.5 ---> [[ 0. 59.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 <= 0.5 & MAX1363 <= 1.5 ---> [[ 0. 36.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 <= 0.5 & MAX1363 > 1.5 ---> [[2. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS <= 0.5 & DVB_DUMMY_FE <= 1.5 ---> [[ 0. 43.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS <= 0.5 & DVB_DUMMY_FE > 1.5 ---> [[2. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN <= 0.5 & USB_STORAGE_SDDR09 <= 1.5 & COMEDI_DAS08_ISA <= 1.5 ---> [[ 0. 87.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN <= 0.5 & USB_STORAGE_SDDR09 <= 1.5 & COMEDI_DAS08_ISA > 1.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN <= 0.5 & USB_STORAGE_SDDR09 > 1.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND <= 0.5 & SND_SOC_IMX_WM8962 <= 1.5 & BRIDGE_EBT_ARPREPLY <= 1.5 & CAN_PEAK_USB <= 1.5 & VIDEO_STI_DELTA_DRIVER <= 1.5 & DRM_R128 <= 1.5 ---> [[   0. 1222.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND <= 0.5 & SND_SOC_IMX_WM8962 <= 1.5 & BRIDGE_EBT_ARPREPLY <= 1.5 & CAN_PEAK_USB <= 1.5 & VIDEO_STI_DELTA_DRIVER <= 1.5 & DRM_R128 > 1.5 & BLK_DEV_NULL_BLK <= 0.5 & SND_SEQ_MIDI_EMUL <= 0.5 ---> [[0. 1.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND <= 0.5 & SND_SOC_IMX_WM8962 <= 1.5 & BRIDGE_EBT_ARPREPLY <= 1.5 & CAN_PEAK_USB <= 1.5 & VIDEO_STI_DELTA_DRIVER <= 1.5 & DRM_R128 > 1.5 & BLK_DEV_NULL_BLK <= 0.5 & SND_SEQ_MIDI_EMUL > 0.5 ---> [[2. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND <= 0.5 & SND_SOC_IMX_WM8962 <= 1.5 & BRIDGE_EBT_ARPREPLY <= 1.5 & CAN_PEAK_USB <= 1.5 & VIDEO_STI_DELTA_DRIVER <= 1.5 & DRM_R128 > 1.5 & BLK_DEV_NULL_BLK > 0.5 ---> [[ 0. 43.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND <= 0.5 & SND_SOC_IMX_WM8962 <= 1.5 & BRIDGE_EBT_ARPREPLY <= 1.5 & CAN_PEAK_USB <= 1.5 & VIDEO_STI_DELTA_DRIVER > 1.5 & SND_VERBOSE_PRINTK <= 0.5 ---> [[0. 4.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND <= 0.5 & SND_SOC_IMX_WM8962 <= 1.5 & BRIDGE_EBT_ARPREPLY <= 1.5 & CAN_PEAK_USB <= 1.5 & VIDEO_STI_DELTA_DRIVER > 1.5 & SND_VERBOSE_PRINTK > 0.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND <= 0.5 & SND_SOC_IMX_WM8962 <= 1.5 & BRIDGE_EBT_ARPREPLY <= 1.5 & CAN_PEAK_USB > 1.5 & SERIAL_8250_LPSS <= 0.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND <= 0.5 & SND_SOC_IMX_WM8962 <= 1.5 & BRIDGE_EBT_ARPREPLY <= 1.5 & CAN_PEAK_USB > 1.5 & SERIAL_8250_LPSS > 0.5 ---> [[0. 3.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND <= 0.5 & SND_SOC_IMX_WM8962 <= 1.5 & BRIDGE_EBT_ARPREPLY > 1.5 & GPIO_PCI_IDIO_16 <= 0.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND <= 0.5 & SND_SOC_IMX_WM8962 <= 1.5 & BRIDGE_EBT_ARPREPLY > 1.5 & GPIO_PCI_IDIO_16 > 0.5 ---> [[0. 1.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND <= 0.5 & SND_SOC_IMX_WM8962 > 1.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 <= 0.5 & PWRSEQ_SD8787 <= 1.5 & VIDEO_MUX <= 1.5 & TYPEC_WCOVE <= 1.5 & GPIOLIB <= 0.5 & DRM_I2C_NXP_TDA998X <= 1.5 & USB_STORAGE_ONETOUCH <= 1.5 ---> [[  0. 120.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 <= 0.5 & PWRSEQ_SD8787 <= 1.5 & VIDEO_MUX <= 1.5 & TYPEC_WCOVE <= 1.5 & GPIOLIB <= 0.5 & DRM_I2C_NXP_TDA998X <= 1.5 & USB_STORAGE_ONETOUCH > 1.5 & EFI_FAKE_MEMMAP <= 0.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 <= 0.5 & PWRSEQ_SD8787 <= 1.5 & VIDEO_MUX <= 1.5 & TYPEC_WCOVE <= 1.5 & GPIOLIB <= 0.5 & DRM_I2C_NXP_TDA998X <= 1.5 & USB_STORAGE_ONETOUCH > 1.5 & EFI_FAKE_MEMMAP > 0.5 ---> [[0. 1.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 <= 0.5 & PWRSEQ_SD8787 <= 1.5 & VIDEO_MUX <= 1.5 & TYPEC_WCOVE <= 1.5 & GPIOLIB <= 0.5 & DRM_I2C_NXP_TDA998X > 1.5 & EXTRA_FIRMWARE_DIR <= 12181.0 ---> [[0. 4.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 <= 0.5 & PWRSEQ_SD8787 <= 1.5 & VIDEO_MUX <= 1.5 & TYPEC_WCOVE <= 1.5 & GPIOLIB <= 0.5 & DRM_I2C_NXP_TDA998X > 1.5 & EXTRA_FIRMWARE_DIR > 12181.0 ---> [[3. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 <= 0.5 & PWRSEQ_SD8787 <= 1.5 & VIDEO_MUX <= 1.5 & TYPEC_WCOVE <= 1.5 & GPIOLIB > 0.5 & SND_SOC_INTEL_KBL_RT5663_RT5514_MAX98927_MACH <= 1.5 & MMC_SDHCI_PXAV2 <= 1.5 & MTD_SBC_GXX <= 1.5 ---> [[   0. 3629.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 <= 0.5 & PWRSEQ_SD8787 <= 1.5 & VIDEO_MUX <= 1.5 & TYPEC_WCOVE <= 1.5 & GPIOLIB > 0.5 & SND_SOC_INTEL_KBL_RT5663_RT5514_MAX98927_MACH <= 1.5 & MMC_SDHCI_PXAV2 <= 1.5 & MTD_SBC_GXX > 1.5 & GPIO_PISOSR <= 0.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 <= 0.5 & PWRSEQ_SD8787 <= 1.5 & VIDEO_MUX <= 1.5 & TYPEC_WCOVE <= 1.5 & GPIOLIB > 0.5 & SND_SOC_INTEL_KBL_RT5663_RT5514_MAX98927_MACH <= 1.5 & MMC_SDHCI_PXAV2 <= 1.5 & MTD_SBC_GXX > 1.5 & GPIO_PISOSR > 0.5 ---> [[ 0. 31.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 <= 0.5 & PWRSEQ_SD8787 <= 1.5 & VIDEO_MUX <= 1.5 & TYPEC_WCOVE <= 1.5 & GPIOLIB > 0.5 & SND_SOC_INTEL_KBL_RT5663_RT5514_MAX98927_MACH <= 1.5 & MMC_SDHCI_PXAV2 > 1.5 & CHARGER_TWL4030 <= 1.5 ---> [[ 0. 18.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 <= 0.5 & PWRSEQ_SD8787 <= 1.5 & VIDEO_MUX <= 1.5 & TYPEC_WCOVE <= 1.5 & GPIOLIB > 0.5 & SND_SOC_INTEL_KBL_RT5663_RT5514_MAX98927_MACH <= 1.5 & MMC_SDHCI_PXAV2 > 1.5 & CHARGER_TWL4030 > 1.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 <= 0.5 & PWRSEQ_SD8787 <= 1.5 & VIDEO_MUX <= 1.5 & TYPEC_WCOVE <= 1.5 & GPIOLIB > 0.5 & SND_SOC_INTEL_KBL_RT5663_RT5514_MAX98927_MACH > 1.5 & HWMON_VID <= 0.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 <= 0.5 & PWRSEQ_SD8787 <= 1.5 & VIDEO_MUX <= 1.5 & TYPEC_WCOVE <= 1.5 & GPIOLIB > 0.5 & SND_SOC_INTEL_KBL_RT5663_RT5514_MAX98927_MACH > 1.5 & HWMON_VID > 0.5 ---> [[0. 9.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 <= 0.5 & PWRSEQ_SD8787 <= 1.5 & VIDEO_MUX <= 1.5 & TYPEC_WCOVE > 1.5 & PHY_BRCM_SATA <= 0.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 <= 0.5 & PWRSEQ_SD8787 <= 1.5 & VIDEO_MUX <= 1.5 & TYPEC_WCOVE > 1.5 & PHY_BRCM_SATA > 0.5 ---> [[0. 6.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 <= 0.5 & PWRSEQ_SD8787 <= 1.5 & VIDEO_MUX > 1.5 & DRM_PANEL <= 0.5 ---> [[0. 3.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 <= 0.5 & PWRSEQ_SD8787 <= 1.5 & VIDEO_MUX > 1.5 & DRM_PANEL > 0.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 <= 0.5 & PWRSEQ_SD8787 > 1.5 & CORDIC <= 0.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 <= 0.5 & PWRSEQ_SD8787 > 1.5 & CORDIC > 0.5 ---> [[0. 1.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS <= 1.5 & PARIDE_EPIA <= 1.5 & TCM_USER2 <= 1.5 & SCSI_AIC94XX <= 1.5 & BLK_DEV_RBD <= 0.5 & SPI_JCORE <= 0.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS <= 1.5 & PARIDE_EPIA <= 1.5 & TCM_USER2 <= 1.5 & SCSI_AIC94XX <= 1.5 & BLK_DEV_RBD <= 0.5 & SPI_JCORE > 0.5 ---> [[0. 7.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS <= 1.5 & PARIDE_EPIA <= 1.5 & TCM_USER2 <= 1.5 & SCSI_AIC94XX <= 1.5 & BLK_DEV_RBD > 0.5 ---> [[   0. 2480.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS <= 1.5 & PARIDE_EPIA <= 1.5 & TCM_USER2 <= 1.5 & SCSI_AIC94XX > 1.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS <= 1.5 & PARIDE_EPIA <= 1.5 & TCM_USER2 > 1.5 & RANDOMIZE_BASE <= 0.5 ---> [[2. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS <= 1.5 & PARIDE_EPIA <= 1.5 & TCM_USER2 > 1.5 & RANDOMIZE_BASE > 0.5 ---> [[0. 1.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS <= 1.5 & PARIDE_EPIA > 1.5 ---> [[2. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC <= 0.5 & SND_PDAUDIOCF <= 1.5 & PTP_1588_CLOCK_GIANFAR <= 0.5 & TCG_VTPM_PROXY <= 1.5 ---> [[0. 3.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC <= 0.5 & SND_PDAUDIOCF <= 1.5 & PTP_1588_CLOCK_GIANFAR <= 0.5 & TCG_VTPM_PROXY > 1.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC <= 0.5 & SND_PDAUDIOCF <= 1.5 & PTP_1588_CLOCK_GIANFAR > 0.5 & CAN_PEAK_PCIEFD <= 1.5 ---> [[  0. 688.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC <= 0.5 & SND_PDAUDIOCF <= 1.5 & PTP_1588_CLOCK_GIANFAR > 0.5 & CAN_PEAK_PCIEFD > 1.5 & TCS3414 <= 0.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC <= 0.5 & SND_PDAUDIOCF <= 1.5 & PTP_1588_CLOCK_GIANFAR > 0.5 & CAN_PEAK_PCIEFD > 1.5 & TCS3414 > 0.5 ---> [[0. 8.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC <= 0.5 & SND_PDAUDIOCF > 1.5 & MOST <= 0.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC <= 0.5 & SND_PDAUDIOCF > 1.5 & MOST > 0.5 ---> [[0. 2.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC > 0.5 & REGMAP_MMIO <= 0.5 & SND_SOC_GTM601 <= 1.5 & PINCTRL_AS3722 <= 1.5 ---> [[  0. 786.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC > 0.5 & REGMAP_MMIO <= 0.5 & SND_SOC_GTM601 <= 1.5 & PINCTRL_AS3722 > 1.5 & HID_APPLE <= 0.5 ---> [[0. 1.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC > 0.5 & REGMAP_MMIO <= 0.5 & SND_SOC_GTM601 <= 1.5 & PINCTRL_AS3722 > 1.5 & HID_APPLE > 0.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC > 0.5 & REGMAP_MMIO <= 0.5 & SND_SOC_GTM601 > 1.5 ---> [[2. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC > 0.5 & REGMAP_MMIO > 0.5 & FUSION_LAN <= 0.5 & SND_SYNTH_EMUX <= 1.5 ---> [[  0. 115.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC > 0.5 & REGMAP_MMIO > 0.5 & FUSION_LAN <= 0.5 & SND_SYNTH_EMUX > 1.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC > 0.5 & REGMAP_MMIO > 0.5 & FUSION_LAN > 0.5 & USB_F_TCM <= 0.5 & VIDEO_SOLO6X10 <= 1.5 & USB_CHIPIDEA_PCI <= 1.5 & VIDEO_LM3646 <= 1.5 ---> [[   0. 1140.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC > 0.5 & REGMAP_MMIO > 0.5 & FUSION_LAN > 0.5 & USB_F_TCM <= 0.5 & VIDEO_SOLO6X10 <= 1.5 & USB_CHIPIDEA_PCI <= 1.5 & VIDEO_LM3646 > 1.5 & SND_SOC_ROCKCHIP <= 0.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC > 0.5 & REGMAP_MMIO > 0.5 & FUSION_LAN > 0.5 & USB_F_TCM <= 0.5 & VIDEO_SOLO6X10 <= 1.5 & USB_CHIPIDEA_PCI <= 1.5 & VIDEO_LM3646 > 1.5 & SND_SOC_ROCKCHIP > 0.5 ---> [[ 0. 18.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC > 0.5 & REGMAP_MMIO > 0.5 & FUSION_LAN > 0.5 & USB_F_TCM <= 0.5 & VIDEO_SOLO6X10 <= 1.5 & USB_CHIPIDEA_PCI > 1.5 & BCM_KONA_USB2_PHY <= 1.5 ---> [[ 0. 10.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC > 0.5 & REGMAP_MMIO > 0.5 & FUSION_LAN > 0.5 & USB_F_TCM <= 0.5 & VIDEO_SOLO6X10 <= 1.5 & USB_CHIPIDEA_PCI > 1.5 & BCM_KONA_USB2_PHY > 1.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC > 0.5 & REGMAP_MMIO > 0.5 & FUSION_LAN > 0.5 & USB_F_TCM <= 0.5 & VIDEO_SOLO6X10 > 1.5 & COMPAT_32 <= 0.5 ---> [[0. 1.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC > 0.5 & REGMAP_MMIO > 0.5 & FUSION_LAN > 0.5 & USB_F_TCM <= 0.5 & VIDEO_SOLO6X10 > 1.5 & COMPAT_32 > 0.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC > 0.5 & REGMAP_MMIO > 0.5 & FUSION_LAN > 0.5 & USB_F_TCM > 0.5 & EDAC_PND2 <= 0.5 & USB_MUSB_GADGET <= 0.5 & VIPERBOARD_ADC <= 1.5 ---> [[   0. 1146.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC > 0.5 & REGMAP_MMIO > 0.5 & FUSION_LAN > 0.5 & USB_F_TCM > 0.5 & EDAC_PND2 <= 0.5 & USB_MUSB_GADGET <= 0.5 & VIPERBOARD_ADC > 1.5 & MPILIB <= 0.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC > 0.5 & REGMAP_MMIO > 0.5 & FUSION_LAN > 0.5 & USB_F_TCM > 0.5 & EDAC_PND2 <= 0.5 & USB_MUSB_GADGET <= 0.5 & VIPERBOARD_ADC > 1.5 & MPILIB > 0.5 ---> [[ 0. 12.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC > 0.5 & REGMAP_MMIO > 0.5 & FUSION_LAN > 0.5 & USB_F_TCM > 0.5 & EDAC_PND2 <= 0.5 & USB_MUSB_GADGET > 0.5 & AD2S90 <= 1.5 ---> [[ 0. 24.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC > 0.5 & REGMAP_MMIO > 0.5 & FUSION_LAN > 0.5 & USB_F_TCM > 0.5 & EDAC_PND2 <= 0.5 & USB_MUSB_GADGET > 0.5 & AD2S90 > 1.5 ---> [[2. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC > 0.5 & REGMAP_MMIO > 0.5 & FUSION_LAN > 0.5 & USB_F_TCM > 0.5 & EDAC_PND2 > 0.5 & NET_ACT_CONNMARK <= 1.5 & I2C_EG20T <= 0.5 & SND_AT73C213 <= 1.5 & USB_SL811_CS <= 1.5 & CHARGER_AXP20X <= 1.5 & DVB_BUDGET <= 1.5 ---> [[   0. 3449.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC > 0.5 & REGMAP_MMIO > 0.5 & FUSION_LAN > 0.5 & USB_F_TCM > 0.5 & EDAC_PND2 > 0.5 & NET_ACT_CONNMARK <= 1.5 & I2C_EG20T <= 0.5 & SND_AT73C213 <= 1.5 & USB_SL811_CS <= 1.5 & CHARGER_AXP20X <= 1.5 & DVB_BUDGET > 1.5 & COMEDI_AMPLC_PC263_PCI <= 1.5 ---> [[ 0. 26.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC > 0.5 & REGMAP_MMIO > 0.5 & FUSION_LAN > 0.5 & USB_F_TCM > 0.5 & EDAC_PND2 > 0.5 & NET_ACT_CONNMARK <= 1.5 & I2C_EG20T <= 0.5 & SND_AT73C213 <= 1.5 & USB_SL811_CS <= 1.5 & CHARGER_AXP20X <= 1.5 & DVB_BUDGET > 1.5 & COMEDI_AMPLC_PC263_PCI > 1.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC > 0.5 & REGMAP_MMIO > 0.5 & FUSION_LAN > 0.5 & USB_F_TCM > 0.5 & EDAC_PND2 > 0.5 & NET_ACT_CONNMARK <= 1.5 & I2C_EG20T <= 0.5 & SND_AT73C213 <= 1.5 & USB_SL811_CS <= 1.5 & CHARGER_AXP20X > 1.5 & SATA_SIL <= 1.5 ---> [[ 0. 25.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC > 0.5 & REGMAP_MMIO > 0.5 & FUSION_LAN > 0.5 & USB_F_TCM > 0.5 & EDAC_PND2 > 0.5 & NET_ACT_CONNMARK <= 1.5 & I2C_EG20T <= 0.5 & SND_AT73C213 <= 1.5 & USB_SL811_CS <= 1.5 & CHARGER_AXP20X > 1.5 & SATA_SIL > 1.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC > 0.5 & REGMAP_MMIO > 0.5 & FUSION_LAN > 0.5 & USB_F_TCM > 0.5 & EDAC_PND2 > 0.5 & NET_ACT_CONNMARK <= 1.5 & I2C_EG20T <= 0.5 & SND_AT73C213 <= 1.5 & USB_SL811_CS > 1.5 & GENERIC_IRQ_CHIP <= 0.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC > 0.5 & REGMAP_MMIO > 0.5 & FUSION_LAN > 0.5 & USB_F_TCM > 0.5 & EDAC_PND2 > 0.5 & NET_ACT_CONNMARK <= 1.5 & I2C_EG20T <= 0.5 & SND_AT73C213 <= 1.5 & USB_SL811_CS > 1.5 & GENERIC_IRQ_CHIP > 0.5 ---> [[ 0. 21.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC > 0.5 & REGMAP_MMIO > 0.5 & FUSION_LAN > 0.5 & USB_F_TCM > 0.5 & EDAC_PND2 > 0.5 & NET_ACT_CONNMARK <= 1.5 & I2C_EG20T <= 0.5 & SND_AT73C213 > 1.5 & VIDEO_CS5345 <= 1.5 ---> [[0. 9.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC > 0.5 & REGMAP_MMIO > 0.5 & FUSION_LAN > 0.5 & USB_F_TCM > 0.5 & EDAC_PND2 > 0.5 & NET_ACT_CONNMARK <= 1.5 & I2C_EG20T <= 0.5 & SND_AT73C213 > 1.5 & VIDEO_CS5345 > 1.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC > 0.5 & REGMAP_MMIO > 0.5 & FUSION_LAN > 0.5 & USB_F_TCM > 0.5 & EDAC_PND2 > 0.5 & NET_ACT_CONNMARK <= 1.5 & I2C_EG20T > 0.5 & INFINIBAND_QEDR <= 1.5 & SND_AT73C213 <= 0.5 & IMA_READ_POLICY <= 0.5 ---> [[  0. 578.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC > 0.5 & REGMAP_MMIO > 0.5 & FUSION_LAN > 0.5 & USB_F_TCM > 0.5 & EDAC_PND2 > 0.5 & NET_ACT_CONNMARK <= 1.5 & I2C_EG20T > 0.5 & INFINIBAND_QEDR <= 1.5 & SND_AT73C213 <= 0.5 & IMA_READ_POLICY > 0.5 & DVB_CX24123 <= 1.5 ---> [[0. 9.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC > 0.5 & REGMAP_MMIO > 0.5 & FUSION_LAN > 0.5 & USB_F_TCM > 0.5 & EDAC_PND2 > 0.5 & NET_ACT_CONNMARK <= 1.5 & I2C_EG20T > 0.5 & INFINIBAND_QEDR <= 1.5 & SND_AT73C213 <= 0.5 & IMA_READ_POLICY > 0.5 & DVB_CX24123 > 1.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC > 0.5 & REGMAP_MMIO > 0.5 & FUSION_LAN > 0.5 & USB_F_TCM > 0.5 & EDAC_PND2 > 0.5 & NET_ACT_CONNMARK <= 1.5 & I2C_EG20T > 0.5 & INFINIBAND_QEDR <= 1.5 & SND_AT73C213 > 0.5 & VIDEO_SOLO6X10 <= 1.5 ---> [[    0. 64638.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC > 0.5 & REGMAP_MMIO > 0.5 & FUSION_LAN > 0.5 & USB_F_TCM > 0.5 & EDAC_PND2 > 0.5 & NET_ACT_CONNMARK <= 1.5 & I2C_EG20T > 0.5 & INFINIBAND_QEDR <= 1.5 & SND_AT73C213 > 0.5 & VIDEO_SOLO6X10 > 1.5 & MEMCG_SWAP_ENABLED <= 0.5 ---> [[   0. 1156.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC > 0.5 & REGMAP_MMIO > 0.5 & FUSION_LAN > 0.5 & USB_F_TCM > 0.5 & EDAC_PND2 > 0.5 & NET_ACT_CONNMARK <= 1.5 & I2C_EG20T > 0.5 & INFINIBAND_QEDR <= 1.5 & SND_AT73C213 > 0.5 & VIDEO_SOLO6X10 > 1.5 & MEMCG_SWAP_ENABLED > 0.5 & NFC_NCI_SPI <= 1.5 ---> [[ 0. 28.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC > 0.5 & REGMAP_MMIO > 0.5 & FUSION_LAN > 0.5 & USB_F_TCM > 0.5 & EDAC_PND2 > 0.5 & NET_ACT_CONNMARK <= 1.5 & I2C_EG20T > 0.5 & INFINIBAND_QEDR <= 1.5 & SND_AT73C213 > 0.5 & VIDEO_SOLO6X10 > 1.5 & MEMCG_SWAP_ENABLED > 0.5 & NFC_NCI_SPI > 1.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC > 0.5 & REGMAP_MMIO > 0.5 & FUSION_LAN > 0.5 & USB_F_TCM > 0.5 & EDAC_PND2 > 0.5 & NET_ACT_CONNMARK <= 1.5 & I2C_EG20T > 0.5 & INFINIBAND_QEDR > 1.5 & GPIOLIB <= 0.5 & QCOM_HIDMA_MGMT <= 1.5 ---> [[0. 4.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC > 0.5 & REGMAP_MMIO > 0.5 & FUSION_LAN > 0.5 & USB_F_TCM > 0.5 & EDAC_PND2 > 0.5 & NET_ACT_CONNMARK <= 1.5 & I2C_EG20T > 0.5 & INFINIBAND_QEDR > 1.5 & GPIOLIB <= 0.5 & QCOM_HIDMA_MGMT > 1.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC > 0.5 & REGMAP_MMIO > 0.5 & FUSION_LAN > 0.5 & USB_F_TCM > 0.5 & EDAC_PND2 > 0.5 & NET_ACT_CONNMARK <= 1.5 & I2C_EG20T > 0.5 & INFINIBAND_QEDR > 1.5 & GPIOLIB > 0.5 ---> [[  0. 250.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC > 0.5 & REGMAP_MMIO > 0.5 & FUSION_LAN > 0.5 & USB_F_TCM > 0.5 & EDAC_PND2 > 0.5 & NET_ACT_CONNMARK > 1.5 & USB_GSPCA_OV534 <= 1.5 ---> [[  0. 180.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC > 0.5 & REGMAP_MMIO > 0.5 & FUSION_LAN > 0.5 & USB_F_TCM > 0.5 & EDAC_PND2 > 0.5 & NET_ACT_CONNMARK > 1.5 & USB_GSPCA_OV534 > 1.5 & INITRAMFS_COMPRESSION <= 21273.5 ---> [[0. 4.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC > 0.5 & REGMAP_MMIO > 0.5 & FUSION_LAN > 0.5 & USB_F_TCM > 0.5 & EDAC_PND2 > 0.5 & NET_ACT_CONNMARK > 1.5 & USB_GSPCA_OV534 > 1.5 & INITRAMFS_COMPRESSION > 21273.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL > 0.5 & INFINIBAND_ADDR_TRANS <= 0.5 & I40EVF <= 0.5 & SND_HDA_EXT_CORE <= 0.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL > 0.5 & INFINIBAND_ADDR_TRANS <= 0.5 & I40EVF <= 0.5 & SND_HDA_EXT_CORE > 0.5 ---> [[0. 9.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL > 0.5 & INFINIBAND_ADDR_TRANS <= 0.5 & I40EVF > 0.5 & VIDEO_XILINX_TPG <= 0.5 & SCR24X <= 1.5 ---> [[ 0. 16.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL > 0.5 & INFINIBAND_ADDR_TRANS <= 0.5 & I40EVF > 0.5 & VIDEO_XILINX_TPG <= 0.5 & SCR24X > 1.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL > 0.5 & INFINIBAND_ADDR_TRANS <= 0.5 & I40EVF > 0.5 & VIDEO_XILINX_TPG > 0.5 ---> [[   0. 4579.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL > 0.5 & INFINIBAND_ADDR_TRANS > 0.5 & FORTIFY_SOURCE <= 0.5 ---> [[  0. 231.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL > 0.5 & INFINIBAND_ADDR_TRANS > 0.5 & FORTIFY_SOURCE > 0.5 & IPV6 <= 1.5 & IPV6 <= 0.5 ---> [[ 0. 36.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL > 0.5 & INFINIBAND_ADDR_TRANS > 0.5 & FORTIFY_SOURCE > 0.5 & IPV6 <= 1.5 & IPV6 > 0.5 & UBSAN_NULL <= 0.5 & UBSAN_ALIGNMENT <= 0.5 ---> [[ 0. 22.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL > 0.5 & INFINIBAND_ADDR_TRANS > 0.5 & FORTIFY_SOURCE > 0.5 & IPV6 <= 1.5 & IPV6 > 0.5 & UBSAN_NULL <= 0.5 & UBSAN_ALIGNMENT > 0.5 ---> [[24.  0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL > 0.5 & INFINIBAND_ADDR_TRANS > 0.5 & FORTIFY_SOURCE > 0.5 & IPV6 <= 1.5 & IPV6 > 0.5 & UBSAN_NULL > 0.5 ---> [[46.  0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL > 0.5 & INFINIBAND_ADDR_TRANS > 0.5 & FORTIFY_SOURCE > 0.5 & IPV6 > 1.5 & NEW_LEDS <= 0.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL > 0.5 & INFINIBAND_ADDR_TRANS > 0.5 & FORTIFY_SOURCE > 0.5 & IPV6 > 1.5 & NEW_LEDS > 0.5 ---> [[  0. 118.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE > 0.5 ---> [[421.   0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE > 0.5 ---> [[1073.    0.]]
# AIC79XX_BUILD_FIRMWARE > 0.5 ---> [[1612.    0.]]

# %%
def tree_to_failure_rules(tree, feature_names):
    tree_ = tree.tree_
    feature_name = [
        feature_names[i] if i != _tree.TREE_UNDEFINED else "undefined!"
        for i in tree_.feature
    ]
    #print ("def tree({}):".format(", ".join(feature_names)))

    def recurse(node, previous_rules, acc):
        if tree_.feature[node] != _tree.TREE_UNDEFINED:
            name = feature_name[node]
            threshold = tree_.threshold[node]
            #print ("{}if {} <= {}:".format(indent, name, threshold))
            recurse(tree_.children_left[node], previous_rules+[name + " <= " + str(threshold)], acc)
            #print ("{}else:  # if {} > {}".format(indent, name, threshold))
            recurse(tree_.children_right[node], previous_rules+[name + " > " + str(threshold)], acc)
        else:
            if tree_.value[node][0][0] > tree_.value[node][0][1]:
                #print(" & ".join(previous_rules) + " ---> " + str(tree_.value[node]))
                acc.append(" & ".join(previous_rules))

    acc = []
    recurse(0, [], acc)
    return acc
    
# all_paths = tree_to_failure_rules(clf, rawtuxdata.drop(columns=["cid"]).drop(columns=size_methods).drop(columns=compilation_status_column_name).columns)
all_paths = tree_to_failure_rules(clf, rawtuxdata.drop(columns=["cid"]).drop(columns=compilation_status_column_name).columns)

# %%
    
def find_rule_for_configuration(tree, feature_names, configuration):
    tree_ = tree.tree_
    feature_name = [
        feature_names[i] if i != _tree.TREE_UNDEFINED else "undefined!"
        for i in tree_.feature
    ]
    
    def recurse(node, previous_rules, configuration):
        if tree_.feature[node] != _tree.TREE_UNDEFINED:
            name = feature_name[node]
            threshold = tree_.threshold[node]
            #print ("{}if {} <= {}:".format(indent, name, threshold))
            if configuration[name] <= threshold:
                return recurse(tree_.children_left[node], previous_rules+[name + " <= " + str(threshold)], configuration)
            #print ("{}else:  # if {} > {}".format(indent, name, threshold))
            else:
                return recurse(tree_.children_right[node], previous_rules+[name + " > " + str(threshold)], configuration)
        else:
            #if tree_.value[node][0][0] > tree_.value[node][0][1]:
            #print(" & ".join(previous_rules))
            return " & ".join(previous_rules)
       
    return recurse(0, [], configuration)
    
def find_rule_for_configuration_id(cid):
    # return find_rule_for_configuration(clf, rawtuxdata.drop(columns=["cid"]).drop(columns=size_methods).drop(columns=compilation_status_column_name).columns, rawtuxdata.query("cid == " + str(cid)).iloc[0]) 
    return find_rule_for_configuration(clf, rawtuxdata.drop(columns=["cid"]).drop(columns=compilation_status_column_name).columns, rawtuxdata.query("cid == " + str(cid)).iloc[0]) 

find_rule_for_configuration_id(92072)
# Out:
# 'AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC > 0.5 & REGMAP_MMIO <= 0.5 & SND_SOC_GTM601 > 1.5'

# %%
rawtuxdata.query("AIC7XXX_BUILD_FIRMWARE == 1 | AIC79XX_BUILD_FIRMWARE == 1 | WANXL_BUILD_FIRMWARE == 1").shape
# Out:
# (3108, 12638)

# %%
rawtuxdata.query("(AIC7XXX_BUILD_FIRMWARE == 0 & AIC79XX_BUILD_FIRMWARE == 0) & WANXL_BUILD_FIRMWARE == 1")['compile_success'].unique()
# Out:
# array([0])

# %%
rawtuxdata.query("AIC7XXX_BUILD_FIRMWARE == 0 & AIC79XX_BUILD_FIRMWARE == 0 & WANXL_BUILD_FIRMWARE == 0 & compile_success == False").shape
# Out:
# (513, 12638)

# %%
'''
basic conclusion: bug GENERIC_ALLOCATOR + DRM_VBOXVIDEO is always masked by firmwares-like failures
'''
generic_allocator_mask_firmwares = rawtuxdata.query("GENERIC_ALLOCATOR == 0 & DRM_VBOXVIDEO == 2 & (AIC7XXX_BUILD_FIRMWARE == 1 | AIC79XX_BUILD_FIRMWARE == 1 | WANXL_BUILD_FIRMWARE == 1)  & compile_success == False")
print("generic allocator bug with firmwares' failures", generic_allocator_mask_firmwares.shape)
print()
print()
for cid in generic_allocator_mask_firmwares['cid']:
    print ("###### configuration id", cid)
    err_pattern = error_pattern.query("cid == " + str(cid)).iloc[0]
    for err in ErrorLog:
        if (err_pattern[err.name]):
            print(err)
    error_messages = errorlogs.query("cid == " + str(cid)).iloc[0]['error_message'].splitlines()
    for error in error_messages:
        if "Cyclomatic " not in error:
            print(error)
    print()
    print()
# Out:
# generic allocator bug with firmwares' failures (13, 12638)
#
#
# ###### configuration id 30901
# ErrorLog.AIC7XXX
# make[4]: flex: Command not found
# make[4]: *** [/TuxML/linux-4.13.3/drivers/scsi/aic7xxx/aicasm//aicasm_scan.c] Error 127
# make[3]: *** [drivers/scsi/aic7xxx/aicasm/aicasm] Error 2
# make[2]: *** [drivers/scsi/aic7xxx] Error 2
# make[1]: *** [drivers/scsi] Error 2
# make[1]: *** Waiting for unfinished jobs....
# make: *** [drivers] Error 2
#
#
# ###### configuration id 36364
# ErrorLog.AS68K
# In file included from ./include/linux/uaccess.h:13:0,
#                  from ./include/linux/highmem.h:8,
#                  from fs/binfmt_elf.c:28:
# fs/binfmt_elf.c: In function 'create_elf_tables':
# ./arch/x86/include/asm/uaccess_64.h:143:20: warning: array subscript is above array bounds [-Warray-bounds]
#     __put_user_asm(4[(u16 *)src], 4 + (u16 __user *)dst,
#                     ^
# ./arch/x86/include/asm/uaccess.h:468:16: note: in definition of macro '__put_user_asm'
#         : ltype(x), "m" (__m(addr)), "i" (errret), "0" (err))
#                 ^
# ./arch/x86/include/asm/uaccess_64.h:143:20: warning: array subscript is above array bounds [-Warray-bounds]
#     __put_user_asm(4[(u16 *)src], 4 + (u16 __user *)dst,
#                     ^
# ./arch/x86/include/asm/uaccess.h:468:16: note: in definition of macro '__put_user_asm'
#         : ltype(x), "m" (__m(addr)), "i" (errret), "0" (err))
#                 ^
# ./arch/x86/include/asm/uaccess_64.h:154:20: warning: array subscript is above array bounds [-Warray-bounds]
#     __put_user_asm(1[(u64 *)src], 1 + (u64 __user *)dst,
#                     ^
# ./arch/x86/include/asm/uaccess.h:468:16: note: in definition of macro '__put_user_asm'
#         : ltype(x), "m" (__m(addr)), "i" (errret), "0" (err))
#                 ^
# ./arch/x86/include/asm/uaccess_64.h:154:20: warning: array subscript is above array bounds [-Warray-bounds]
#     __put_user_asm(1[(u64 *)src], 1 + (u64 __user *)dst,
#                     ^
# ./arch/x86/include/asm/uaccess.h:468:16: note: in definition of macro '__put_user_asm'
#         : ltype(x), "m" (__m(addr)), "i" (errret), "0" (err))
#                 ^
# drivers/gpu/drm/radeon/radeon_object.c: In function 'radeon_bo_create':
# drivers/gpu/drm/radeon/radeon_object.c:242:2: warning: #warning Please enable CONFIG_MTRR and CONFIG_X86_PAT for better performance thanks to write-combining [-Wcpp]
#  #warning Please enable CONFIG_MTRR and CONFIG_X86_PAT for better performance \
#   ^~~~~~~
# /bin/sh: 1: as68k: not found
# make[3]: *** [drivers/net/wan/wanxlfw.inc] Error 127
# make[2]: *** [drivers/net/wan] Error 2
# make[2]: *** Waiting for unfinished jobs....
# make[1]: *** [drivers/net] Error 2
# make[1]: *** Waiting for unfinished jobs....
# make: *** [drivers] Error 2
#
#
# ###### configuration id 37341
# ErrorLog.AICDB
# ErrorLog.AIC7XXX
# aicasm_symbol.c:48:19: fatal error: aicdb.h: No such file or directory
#  #include "aicdb.h"
#                    ^
# compilation terminated.
# aicasm_gram.tab.c: In function 'yyparse':
# aicasm_gram.tab.c:1628:16: warning: implicit declaration of function 'yylex' [-Wimplicit-function-declaration]
# aicasm_macro_gram.tab.c: In function 'mmparse':
# /TuxML/linux-4.13.3/drivers/scsi/aic7xxx/aicasm//aicasm_macro_gram.c:64:25: warning: implicit declaration of function 'mmlex' [-Wimplicit-function-declaration]
#  #define yylex           mmlex
#                          ^
# aicasm_macro_gram.tab.c:1199:16: note: in expansion of macro 'yylex'
# aicasm_scan.l: In function 'yylex':
# aicasm_scan.l:420:6: warning: implicit declaration of function 'mm_switch_to_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(temp_state);
#       ^~~~~~~~~~~~~~~~~~~
# aicasm_scan.l:421:6: warning: implicit declaration of function 'mmparse' [-Wimplicit-function-declaration]
#       mm_switch_to_buffer(old_state);
#       ^~~~~~~
# aicasm_scan.l:424:6: warning: implicit declaration of function 'mm_delete_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(old_state);
#       ^~~~~~~~~~~~~~~~
# make[4]: *** [aicasm] Error 1
# make[3]: *** [drivers/scsi/aic7xxx/aicasm/aicasm] Error 2
# make[2]: *** [drivers/scsi/aic7xxx] Error 2
# make[1]: *** [drivers/scsi] Error 2
# make[1]: *** Waiting for unfinished jobs....
# make: *** [drivers] Error 2
#
#
# ###### configuration id 40757
# ErrorLog.AICDB
# ErrorLog.AIC7XXX
# drivers/gpu/drm/radeon/radeon_object.c: In function 'radeon_bo_create':
# drivers/gpu/drm/radeon/radeon_object.c:242:2: warning: #warning Please enable CONFIG_MTRR and CONFIG_X86_PAT for better performance thanks to write-combining [-Wcpp]
#  #warning Please enable CONFIG_MTRR and CONFIG_X86_PAT for better performance \
#   ^~~~~~~
# drivers/gpu/drm/radeon/radeon_object.c:242:2: warning: #warning Please enable CONFIG_MTRR and CONFIG_X86_PAT for better performance thanks to write-combining [-Wcpp]
#  #warning Please enable CONFIG_MTRR and CONFIG_X86_PAT for better performance \
#   ^~~~~~~
# aicasm_symbol.c:48:19: fatal error: aicdb.h: No such file or directory
#  #include "aicdb.h"
#                    ^
# compilation terminated.
# aicasm_gram.tab.c: In function 'yyparse':
# aicasm_gram.tab.c:1628:16: warning: implicit declaration of function 'yylex' [-Wimplicit-function-declaration]
# aicasm_macro_gram.tab.c: In function 'mmparse':
# /TuxML/linux-4.13.3/drivers/scsi/aic7xxx/aicasm//aicasm_macro_gram.c:64:25: warning: implicit declaration of function 'mmlex' [-Wimplicit-function-declaration]
#  #define yylex           mmlex
#                          ^
# aicasm_macro_gram.tab.c:1199:16: note: in expansion of macro 'yylex'
# aicasm_scan.l: In function 'yylex':
# aicasm_scan.l:420:6: warning: implicit declaration of function 'mm_switch_to_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(temp_state);
#       ^~~~~~~~~~~~~~~~~~~
# aicasm_scan.l:421:6: warning: implicit declaration of function 'mmparse' [-Wimplicit-function-declaration]
#       mm_switch_to_buffer(old_state);
#       ^~~~~~~
# aicasm_scan.l:424:6: warning: implicit declaration of function 'mm_delete_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(old_state);
#       ^~~~~~~~~~~~~~~~
# make[4]: *** [aicasm] Error 1
# make[3]: *** [drivers/scsi/aic7xxx/aicasm/aicasm] Error 2
# make[2]: *** [drivers/scsi/aic7xxx] Error 2
# make[2]: *** Waiting for unfinished jobs....
# make[1]: *** [drivers/scsi] Error 2
# make[1]: *** Waiting for unfinished jobs....
# make: *** [drivers] Error 2
#
#
# ###### configuration id 48193
# ErrorLog.AICDB
# ErrorLog.AIC7XXX
# kernel/sysctl_binary.c: In function 'SYSC_sysctl':
# kernel/sysctl_binary.c:1413:23: note: userspace variable will be forcibly initialized
#   struct __sysctl_args tmp;
#                        ^~~
# kernel/ptrace.c: In function 'ptrace_peek_siginfo':
# kernel/ptrace.c:712:13: note: userspace variable will be forcibly initialized
#    siginfo_t info;
#              ^~~~
# kernel/ptrace.c: In function 'ptrace_request':
# kernel/ptrace.c:1076:16: note: userspace variable will be forcibly initialized
#    struct iovec kiov;
#                 ^~~~
# kernel/ptrace.c:890:12: note: userspace variable will be forcibly initialized
#   siginfo_t siginfo, *si;
#             ^~~~~~~
# kernel/signal.c: In function 'SYSC_sigaltstack':
# kernel/signal.c:3209:15: note: userspace variable will be forcibly initialized
#   stack_t new, old;
#                ^~~
# kernel/signal.c:3209:10: note: userspace variable will be forcibly initialized
#   stack_t new, old;
#           ^~~
# kernel/signal.c: In function 'do_notify_parent_cldstop':
# kernel/signal.c:1706:17: note: userspace variable will be forcibly initialized
#   struct siginfo info;
#                  ^~~~
# kernel/signal.c: In function 'ptrace_do_notify':
# kernel/signal.c:1929:12: note: userspace variable will be forcibly initialized
#   siginfo_t info;
#             ^~~~
# kernel/signal.c: In function 'SYSC_rt_tgsigqueueinfo':
# kernel/signal.c:3071:12: note: userspace variable will be forcibly initialized
#   siginfo_t info;
#             ^~~~
# kernel/signal.c: In function 'SYSC_kill':
# kernel/signal.c:2917:17: note: userspace variable will be forcibly initialized
#   struct siginfo info;
#                  ^~~~
# kernel/signal.c: In function 'SYSC_rt_sigqueueinfo':
# kernel/signal.c:3030:12: note: userspace variable will be forcibly initialized
#   siginfo_t info;
#             ^~~~
# kernel/signal.c: In function 'do_notify_parent':
# kernel/signal.c:1602:17: note: userspace variable will be forcibly initialized
#   struct siginfo info;
#                  ^~~~
# In file included from arch/x86/entry/common.c:17:0:
# arch/x86/entry/common.c: In function 'tracehook_report_syscall_exit':
# ./include/linux/tracehook.h:126:13: note: userspace variable will be forcibly initialized
#    siginfo_t info;
#              ^~~~
# kernel/signal.c: In function 'SYSC_rt_sigtimedwait':
# kernel/signal.c:2851:12: note: userspace variable will be forcibly initialized
#   siginfo_t info;
#             ^~~~
# kernel/signal.c: In function 'restore_altstack':
# kernel/signal.c:3222:10: note: userspace variable will be forcibly initialized
#   stack_t new;
#           ^~~
# arch/x86/entry/vsyscall/vsyscall_64.c: In function 'write_ok_or_segv':
# arch/x86/entry/vsyscall/vsyscall_64.c:105:13: note: userspace variable will be forcibly initialized
#    siginfo_t info;
#              ^~~~
# arch/x86/kernel/signal.c: In function 'do_signal':
# arch/x86/kernel/signal.c:806:17: note: userspace variable will be forcibly initialized
#   struct ksignal ksig;
#                  ^~~~
# arch/x86/kernel/traps.c: In function 'math_error':
# arch/x86/kernel/traps.c:827:12: note: userspace variable will be forcibly initialized
#   siginfo_t info;
#             ^~~~
# arch/x86/kernel/traps.c: In function 'do_error_trap':
# arch/x86/kernel/traps.c:303:12: note: userspace variable will be forcibly initialized
#   siginfo_t info;
#             ^~~~
# arch/x86/mm/fault.c: In function 'force_sig_info_fault':
# arch/x86/mm/fault.c:231:12: note: userspace variable will be forcibly initialized
#   siginfo_t info;
#             ^~~~
# In file included from fs/read_write.c:12:0:
# fs/read_write.c: In function 'iov_iter_iovec':
# ./include/linux/uio.h:69:9: note: userspace variable will be forcibly initialized
#   return (struct iovec) {
#          ^
# fs/read_write.c: In function 'new_sync_read':
# fs/read_write.c:391:15: note: userspace variable will be forcibly initialized
#   struct iovec iov = { .iov_base = buf, .iov_len = len };
#                ^~~
# fs/read_write.c: In function 'new_sync_write':
# fs/read_write.c:448:15: note: userspace variable will be forcibly initialized
#   struct iovec iov = { .iov_base = (void __user *)buf, .iov_len = len };
#                ^~~
# In file included from fs/read_write.c:12:0:
# fs/read_write.c: In function 'do_loop_readv_writev':
# ./include/linux/uio.h:69:9: note: userspace variable will be forcibly initialized
#   return (struct iovec) {
#          ^
# fs/read_write.c:666:16: note: userspace variable will be forcibly initialized
#    struct iovec iovec = iov_iter_iovec(iter);
#                 ^~~~~
# fs/exec.c: In function 'count':
# fs/exec.c:465:12: note: userspace variable will be forcibly initialized
#  static int count(struct user_arg_ptr argv, int max)
#             ^~~~~
# fs/exec.c: In function 'copy_strings':
# fs/exec.c:496:12: note: userspace variable will be forcibly initialized
#  static int copy_strings(int argc, struct user_arg_ptr argv,
#             ^~~~~~~~~~~~
# fs/exec.c: In function 'copy_strings_kernel':
# fs/exec.c:592:22: note: userspace variable will be forcibly initialized
#   struct user_arg_ptr argv = {
#                       ^~~~
# fs/exec.c: In function 'do_execveat_common':
# fs/exec.c:592:22: note: userspace variable will be forcibly initialized
# fs/exec.c: In function 'do_execve':
# fs/exec.c:1833:22: note: userspace variable will be forcibly initialized
#   struct user_arg_ptr envp = { .ptr.native = __envp };
#                       ^~~~
# fs/exec.c:1832:22: note: userspace variable will be forcibly initialized
#   struct user_arg_ptr argv = { .ptr.native = __argv };
#                       ^~~~
# fs/exec.c: In function 'SYSC_execve':
# fs/exec.c:1832:22: note: userspace variable will be forcibly initialized
# fs/exec.c:1833:22: note: userspace variable will be forcibly initialized
#   struct user_arg_ptr envp = { .ptr.native = __envp };
#                       ^~~~
# fs/exec.c: In function 'do_execveat':
# fs/exec.c:1843:22: note: userspace variable will be forcibly initialized
#   struct user_arg_ptr envp = { .ptr.native = __envp };
#                       ^~~~
# fs/exec.c:1842:22: note: userspace variable will be forcibly initialized
#   struct user_arg_ptr argv = { .ptr.native = __argv };
#                       ^~~~
# fs/exec.c: In function 'SYSC_execveat':
# fs/exec.c:1842:22: note: userspace variable will be forcibly initialized
# fs/exec.c:1843:22: note: userspace variable will be forcibly initialized
#   struct user_arg_ptr envp = { .ptr.native = __envp };
#                       ^~~~
# fs/fcntl.c: In function 'send_sigio_to_task':
# fs/fcntl.c:733:13: note: userspace variable will be forcibly initialized
#    siginfo_t si;
#              ^~
# fs/splice.c: In function 'vmsplice_to_user':
# fs/splice.c:1265:21: note: userspace variable will be forcibly initialized
#   struct splice_desc sd;
#                      ^~
# arch/x86/kernel/ptrace.c: In function 'send_sigtrap':
# arch/x86/kernel/ptrace.c:1396:17: note: userspace variable will be forcibly initialized
#   struct siginfo info;
#                  ^~~~
# arch/x86/kernel/stacktrace.c: In function '__save_stack_trace_user':
# arch/x86/kernel/stacktrace.c:207:27: note: userspace variable will be forcibly initialized
#    struct stack_frame_user frame;
#                            ^~~~~
# kernel/time/posix-timers.c: In function 'SYSC_timer_create':
# kernel/time/posix-timers.c:577:14: note: userspace variable will be forcibly initialized
#    sigevent_t event;
#               ^~~~~
# security/keys/keyring.c: In function 'keyring_read':
# security/keys/keyring.c:461:39: note: userspace variable will be forcibly initialized
#   struct keyring_read_iterator_context ctx;
#                                        ^~~
# security/keys/keyctl.c: In function 'keyctl_instantiate_key':
# security/keys/keyctl.c:1122:16: note: userspace variable will be forcibly initialized
#    struct iovec iov;
#                 ^~~
# In file included from block/bio.c:22:0:
# block/bio.c: In function 'iov_iter_iovec':
# ./include/linux/uio.h:69:9: note: userspace variable will be forcibly initialized
#   return (struct iovec) {
#          ^
# block/bio.c: In function 'bio_map_user_iov':
# ./include/linux/uio.h:69:9: note: userspace variable will be forcibly initialized
# ./include/linux/uio.h:69:9: note: userspace variable will be forcibly initialized
# block/bio.c:1329:15: note: userspace variable will be forcibly initialized
#   struct iovec iov;
#                ^~~
# block/blk-map.c: In function 'blk_rq_map_user':
# block/blk-map.c:160:15: note: userspace variable will be forcibly initialized
#   struct iovec iov;
#                ^~~
# block/ioctl.c: In function 'blkpg_ioctl':
# block/ioctl.c:18:25: note: userspace variable will be forcibly initialized
#   struct blkpg_ioctl_arg a;
#                          ^
# block/scsi_ioctl.c: In function 'scsi_cmd_ioctl':
# block/scsi_ioctl.c:612:21: note: userspace variable will be forcibly initialized
#     struct sg_io_hdr hdr;
#                      ^~~
# block/scsi_ioctl.c:611:33: note: userspace variable will be forcibly initialized
#     struct cdrom_generic_command cgc;
#                                  ^~~
# block/scsi_ioctl.c:597:21: note: userspace variable will be forcibly initialized
#     struct sg_io_hdr hdr;
#                      ^~~
# sound/core/control.c: In function 'snd_ctl_elem_list':
# sound/core/control.c:750:27: note: userspace variable will be forcibly initialized
#   struct snd_ctl_elem_list list;
#                            ^~~~
# sound/core/hwdep.c: In function 'snd_hwdep_dsp_load':
# sound/core/hwdep.c:223:29: note: userspace variable will be forcibly initialized
#   struct snd_hwdep_dsp_image info;
#                              ^~~~
# sound/core/pcm_native.c: In function 'snd_pcm_capture_ioctl1':
# sound/core/pcm_native.c:2971:20: note: userspace variable will be forcibly initialized
#    struct snd_xfern xfern;
#                     ^~~~~
# sound/core/pcm_native.c:2955:20: note: userspace variable will be forcibly initialized
#    struct snd_xferi xferi;
#                     ^~~~~
# sound/core/pcm_native.c: In function 'snd_pcm_playback_ioctl1':
# sound/core/pcm_native.c:2891:20: note: userspace variable will be forcibly initialized
#    struct snd_xfern xfern;
#                     ^~~~~
# sound/core/pcm_native.c:2875:20: note: userspace variable will be forcibly initialized
#    struct snd_xferi xferi;
#                     ^~~~~
# lib/iov_iter.c: In function 'iov_iter_fault_in_readable':
# lib/iov_iter.c:418:15: note: userspace variable will be forcibly initialized
#   struct iovec v;
#                ^
# lib/iov_iter.c: In function '_copy_to_iter':
# lib/iov_iter.c:565:32: note: userspace variable will be forcibly initialized
#   iterate_and_advance(i, bytes, v,
#                                 ^
# lib/iov_iter.c:119:17: note: in definition of macro 'iterate_and_advance'
#     struct iovec v;    \
#                  ^
# lib/iov_iter.c: In function '_copy_from_iter':
# lib/iov_iter.c:585:32: note: userspace variable will be forcibly initialized
#   iterate_and_advance(i, bytes, v,
#                                 ^
# lib/iov_iter.c:119:17: note: in definition of macro 'iterate_and_advance'
#     struct iovec v;    \
#                  ^
# lib/iov_iter.c: In function '_copy_from_iter_nocache':
# lib/iov_iter.c:630:32: note: userspace variable will be forcibly initialized
#   iterate_and_advance(i, bytes, v,
#                                 ^
# lib/iov_iter.c:119:17: note: in definition of macro 'iterate_and_advance'
#     struct iovec v;    \
#                  ^
# lib/iov_iter.c: In function '_copy_from_iter_flushcache':
# lib/iov_iter.c:650:32: note: userspace variable will be forcibly initialized
#   iterate_and_advance(i, bytes, v,
#                                 ^
# lib/iov_iter.c:119:17: note: in definition of macro 'iterate_and_advance'
#     struct iovec v;    \
#                  ^
# lib/iov_iter.c: In function 'iov_iter_zero':
# lib/iov_iter.c:761:32: note: userspace variable will be forcibly initialized
#   iterate_and_advance(i, bytes, v,
#                                 ^
# lib/iov_iter.c:119:17: note: in definition of macro 'iterate_and_advance'
#     struct iovec v;    \
#                  ^
# lib/iov_iter.c: In function 'iov_iter_copy_from_user_atomic':
# lib/iov_iter.c:784:30: note: userspace variable will be forcibly initialized
#   iterate_all_kinds(i, bytes, v,
#                               ^
# lib/iov_iter.c:88:17: note: in definition of macro 'iterate_all_kinds'
#     struct iovec v;    \
#                  ^
# lib/iov_iter.c: In function 'iov_iter_advance':
# lib/iov_iter.c:847:31: note: userspace variable will be forcibly initialized
#   iterate_and_advance(i, size, v, 0, 0, 0)
#                                ^
# lib/iov_iter.c:119:17: note: in definition of macro 'iterate_and_advance'
#     struct iovec v;    \
#                  ^
# lib/iov_iter.c: In function '_copy_from_iter_full':
# lib/iov_iter.c:608:30: note: userspace variable will be forcibly initialized
#   iterate_all_kinds(i, bytes, v, ({
#                               ^
# lib/iov_iter.c:88:17: note: in definition of macro 'iterate_all_kinds'
#     struct iovec v;    \
#                  ^
# lib/iov_iter.c: In function '_copy_from_iter_full_nocache':
# lib/iov_iter.c:673:30: note: userspace variable will be forcibly initialized
#   iterate_all_kinds(i, bytes, v, ({
#                               ^
# lib/iov_iter.c:88:17: note: in definition of macro 'iterate_all_kinds'
#     struct iovec v;    \
#                  ^
# lib/iov_iter.c: In function 'iov_iter_alignment':
# lib/iov_iter.c:982:29: note: userspace variable will be forcibly initialized
#   iterate_all_kinds(i, size, v,
#                              ^
# lib/iov_iter.c:88:17: note: in definition of macro 'iterate_all_kinds'
#     struct iovec v;    \
#                  ^
# lib/iov_iter.c: In function 'iov_iter_gap_alignment':
# lib/iov_iter.c:1001:29: note: userspace variable will be forcibly initialized
#   iterate_all_kinds(i, size, v,
#                              ^
# lib/iov_iter.c:88:17: note: in definition of macro 'iterate_all_kinds'
#     struct iovec v;    \
#                  ^
# lib/iov_iter.c: In function 'iov_iter_get_pages':
# lib/iov_iter.c:1066:32: note: userspace variable will be forcibly initialized
#   iterate_all_kinds(i, maxsize, v, ({
#                                 ^
# lib/iov_iter.c:88:17: note: in definition of macro 'iterate_all_kinds'
#     struct iovec v;    \
#                  ^
# lib/iov_iter.c: In function 'iov_iter_get_pages_alloc':
# lib/iov_iter.c:1143:32: note: userspace variable will be forcibly initialized
#   iterate_all_kinds(i, maxsize, v, ({
#                                 ^
# lib/iov_iter.c:88:17: note: in definition of macro 'iterate_all_kinds'
#     struct iovec v;    \
#                  ^
# lib/iov_iter.c: In function 'csum_and_copy_from_iter':
# lib/iov_iter.c:1188:32: note: userspace variable will be forcibly initialized
#   iterate_and_advance(i, bytes, v, ({
#                                 ^
# lib/iov_iter.c:119:17: note: in definition of macro 'iterate_and_advance'
#     struct iovec v;    \
#                  ^
# lib/iov_iter.c: In function 'csum_and_copy_from_iter_full':
# lib/iov_iter.c:1232:30: note: userspace variable will be forcibly initialized
#   iterate_all_kinds(i, bytes, v, ({
#                               ^
# lib/iov_iter.c:88:17: note: in definition of macro 'iterate_all_kinds'
#     struct iovec v;    \
#                  ^
# lib/iov_iter.c: In function 'csum_and_copy_to_iter':
# lib/iov_iter.c:1275:32: note: userspace variable will be forcibly initialized
#   iterate_and_advance(i, bytes, v, ({
#                                 ^
# lib/iov_iter.c:119:17: note: in definition of macro 'iterate_and_advance'
#     struct iovec v;    \
#                  ^
# lib/iov_iter.c: In function 'iov_iter_npages':
# lib/iov_iter.c:1327:36: note: userspace variable will be forcibly initialized
#   } else iterate_all_kinds(i, size, v, ({
#                                     ^
# lib/iov_iter.c:88:17: note: in definition of macro 'iterate_all_kinds'
#     struct iovec v;    \
#                  ^
# drivers/block/floppy.c: In function 'raw_cmd_copyout':
# drivers/block/floppy.c:3073:25: note: userspace variable will be forcibly initialized
#    struct floppy_raw_cmd cmd = *ptr;
#                          ^~~
# drivers/block/DAC960.c: In function 'DAC960_gam_ioctl':
# drivers/block/DAC960.c:7007:30: note: userspace variable will be forcibly initialized
#   DAC960_V2_GetHealthStatus_T GetHealthStatus;
#                               ^~~~~~~~~~~~~~~
# drivers/block/DAC960.c:6843:26: note: userspace variable will be forcibly initialized
#   DAC960_V2_UserCommand_T UserCommand;
#                           ^~~~~~~~~~~
# drivers/block/DAC960.c:6676:26: note: userspace variable will be forcibly initialized
#   DAC960_V1_UserCommand_T UserCommand;
#                           ^~~~~~~~~~~
# drivers/block/skd_main.c: In function 'skd_sg_io_copy_buffer':
# drivers/block/skd_main.c:1595:18: note: userspace variable will be forcibly initialized
#   struct sg_iovec curiov;
#                   ^~~~~~
# drivers/block/skd_main.c: In function 'skd_ioctl_sg_io':
# drivers/block/skd_main.c:1247:19: note: userspace variable will be forcibly initialized
#   struct skd_sg_io sksgio;
#                    ^~~~~~
# In file included from fs/jffs2/background.c:19:0:
# fs/jffs2/background.c: In function 'kernel_dequeue_signal':
# ./include/linux/sched/signal.h:268:12: note: userspace variable will be forcibly initialized
#   siginfo_t __info;
#             ^~~~~~
# drivers/cdrom/cdrom.c: In function 'mmc_ioctl_cdrom_read_audio':
# drivers/cdrom/cdrom.c:3006:26: note: userspace variable will be forcibly initialized
#   struct cdrom_read_audio ra;
#                           ^~
# drivers/char/mwave/mwavedd.c: In function 'mwave_ioctl':
# drivers/char/mwave/mwavedd.c:259:17: note: userspace variable will be forcibly initialized
#     MW_READWRITE rWriteData;
#                  ^~~~~~~~~~
# drivers/char/mwave/mwavedd.c:236:17: note: userspace variable will be forcibly initialized
#     MW_READWRITE rWriteData;
#                  ^~~~~~~~~~
# drivers/char/mwave/mwavedd.c:213:17: note: userspace variable will be forcibly initialized
#     MW_READWRITE rReadData;
#                  ^~~~~~~~~
# drivers/char/mwave/mwavedd.c:190:17: note: userspace variable will be forcibly initialized
#     MW_READWRITE rReadData;
#                  ^~~~~~~~~
# fs/eventpoll.c: In function 'ep_send_events':
# fs/eventpoll.c:1718:29: note: userspace variable will be forcibly initialized
#   struct ep_send_events_data esed;
#                              ^~~~
# fs/eventpoll.c: In function 'ep_poll':
# fs/eventpoll.c:1718:29: note: userspace variable will be forcibly initialized
# fs/signalfd.c: In function 'signalfd_read':
# fs/signalfd.c:211:12: note: userspace variable will be forcibly initialized
#   siginfo_t info;
#             ^~~~
# drivers/hid/uhid.c: In function 'uhid_dev_create':
# drivers/hid/uhid.c:535:25: note: userspace variable will be forcibly initialized
#   struct uhid_create_req orig;
#                          ^~~~
# drivers/i2c/i2c-dev.c: In function 'i2cdev_ioctl_rdwr':
# drivers/i2c/i2c-dev.c:243:29: note: userspace variable will be forcibly initialized
#   struct i2c_rdwr_ioctl_data rdwr_arg;
#                              ^~~~~~~~
# drivers/i2c/i2c-dev.c: In function 'i2cdev_ioctl_smbus':
# drivers/i2c/i2c-dev.c:333:30: note: userspace variable will be forcibly initialized
#   struct i2c_smbus_ioctl_data data_arg;
#                               ^~~~~~~~
# drivers/input/ff-memless.c: In function 'ml_play_effects':
# drivers/input/ff-memless.c:404:19: note: userspace variable will be forcibly initialized
#   struct ff_effect effect;
#                    ^~~~~~
# drivers/input/evdev.c: In function 'evdev_do_ioctl':
# drivers/input/evdev.c:1067:19: note: userspace variable will be forcibly initialized
#   struct ff_effect effect;
#                    ^~~~~~
# drivers/input/misc/uinput.c: In function 'uinput_ioctl_handler':
# drivers/input/misc/uinput.c:792:26: note: userspace variable will be forcibly initialized
#   struct uinput_ff_upload ff_up;
#                           ^~~~~
# drivers/mtd/mtdchar.c: In function 'mtdchar_ioctl':
# drivers/mtd/mtdchar.c:1035:26: note: userspace variable will be forcibly initialized
#    struct blkpg_ioctl_arg a;
#                           ^
# drivers/mtd/mtdchar.c:806:22: note: userspace variable will be forcibly initialized
#    struct mtd_oob_buf buf;
#                       ^~~
# drivers/mtd/mtdchar.c:792:22: note: userspace variable will be forcibly initialized
#    struct mtd_oob_buf buf;
#                       ^~~
# drivers/gpu/drm/qxl/qxl_ioctl.c: In function 'qxl_execbuffer_ioctl':
# drivers/gpu/drm/qxl/qxl_ioctl.c:279:25: note: userspace variable will be forcibly initialized
#   struct drm_qxl_command user_cmd;
#                          ^~~~~~~~
# aicasm_symbol.c:48:19: fatal error: aicdb.h: No such file or directory
#  #include "aicdb.h"
#                    ^
# compilation terminated.
# aicasm_gram.tab.c: In function 'yyparse':
# aicasm_gram.tab.c:1628:16: warning: implicit declaration of function 'yylex' [-Wimplicit-function-declaration]
# aicasm_macro_gram.tab.c: In function 'mmparse':
# /TuxML/linux-4.13.3/drivers/scsi/aic7xxx/aicasm//aicasm_macro_gram.c:64:25: warning: implicit declaration of function 'mmlex' [-Wimplicit-function-declaration]
#  #define yylex           mmlex
#                          ^
# aicasm_macro_gram.tab.c:1199:16: note: in expansion of macro 'yylex'
# aicasm_scan.l: In function 'yylex':
# aicasm_scan.l:420:6: warning: implicit declaration of function 'mm_switch_to_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(temp_state);
#       ^~~~~~~~~~~~~~~~~~~
# aicasm_scan.l:421:6: warning: implicit declaration of function 'mmparse' [-Wimplicit-function-declaration]
#       mm_switch_to_buffer(old_state);
#       ^~~~~~~
# aicasm_scan.l:424:6: warning: implicit declaration of function 'mm_delete_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(old_state);
#       ^~~~~~~~~~~~~~~~
# make[4]: *** [aicasm] Error 1
# make[3]: *** [drivers/scsi/aic7xxx/aicasm/aicasm] Error 2
# make[2]: *** [drivers/scsi/aic7xxx] Error 2
# make[1]: *** [drivers/scsi] Error 2
# make[1]: *** Waiting for unfinished jobs....
# make: *** [drivers] Error 2
#
#
# ###### configuration id 50359
# ErrorLog.AICDB
# ErrorLog.AIC7XXX
# aicasm_symbol.c:48:19: fatal error: aicdb.h: No such file or directory
#  #include "aicdb.h"
#                    ^
# compilation terminated.
# aicasm_gram.tab.c: In function 'yyparse':
# aicasm_gram.tab.c:1628:16: warning: implicit declaration of function 'yylex' [-Wimplicit-function-declaration]
# aicasm_macro_gram.tab.c: In function 'mmparse':
# /TuxML/linux-4.13.3/drivers/scsi/aic7xxx/aicasm//aicasm_macro_gram.c:64:25: warning: implicit declaration of function 'mmlex' [-Wimplicit-function-declaration]
#  #define yylex           mmlex
#                          ^
# aicasm_macro_gram.tab.c:1199:16: note: in expansion of macro 'yylex'
# aicasm_scan.l: In function 'yylex':
# aicasm_scan.l:420:6: warning: implicit declaration of function 'mm_switch_to_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(temp_state);
#       ^~~~~~~~~~~~~~~~~~~
# aicasm_scan.l:421:6: warning: implicit declaration of function 'mmparse' [-Wimplicit-function-declaration]
#       mm_switch_to_buffer(old_state);
#       ^~~~~~~
# aicasm_scan.l:424:6: warning: implicit declaration of function 'mm_delete_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(old_state);
#       ^~~~~~~~~~~~~~~~
# make[4]: *** [aicasm] Error 1
# make[3]: *** [drivers/scsi/aic7xxx/aicasm/aicasm] Error 2
# make[2]: *** [drivers/scsi/aic7xxx] Error 2
# make[1]: *** [drivers/scsi] Error 2
# make[1]: *** Waiting for unfinished jobs....
# make: *** [drivers] Error 2
#
#
# ###### configuration id 53234
# ErrorLog.AS68K
# /bin/sh: 1: as68k: not found
# make[3]: *** [drivers/net/wan/wanxlfw.inc] Error 127
# make[3]: *** Waiting for unfinished jobs....
# make[2]: *** [drivers/net/wan] Error 2
# make[2]: *** Waiting for unfinished jobs....
# make[1]: *** [drivers/net] Error 2
# make: *** [drivers] Error 2
#
#
# ###### configuration id 55986
# ErrorLog.AICDB
# ErrorLog.AIC7XXX
# aicasm_symbol.c:48:19: fatal error: aicdb.h: No such file or directory
#  #include "aicdb.h"
#                    ^
# compilation terminated.
# aicasm_gram.tab.c: In function 'yyparse':
# aicasm_gram.tab.c:1628:16: warning: implicit declaration of function 'yylex' [-Wimplicit-function-declaration]
# aicasm_macro_gram.tab.c: In function 'mmparse':
# /TuxML/linux-4.13.3/drivers/scsi/aic7xxx/aicasm//aicasm_macro_gram.c:64:25: warning: implicit declaration of function 'mmlex' [-Wimplicit-function-declaration]
#  #define yylex           mmlex
#                          ^
# aicasm_macro_gram.tab.c:1199:16: note: in expansion of macro 'yylex'
# aicasm_scan.l: In function 'yylex':
# aicasm_scan.l:420:6: warning: implicit declaration of function 'mm_switch_to_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(temp_state);
#       ^~~~~~~~~~~~~~~~~~~
# aicasm_scan.l:421:6: warning: implicit declaration of function 'mmparse' [-Wimplicit-function-declaration]
#       mm_switch_to_buffer(old_state);
#       ^~~~~~~
# aicasm_scan.l:424:6: warning: implicit declaration of function 'mm_delete_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(old_state);
#       ^~~~~~~~~~~~~~~~
# make[4]: *** [aicasm] Error 1
# make[3]: *** [drivers/scsi/aic7xxx/aicasm/aicasm] Error 2
# make[2]: *** [drivers/scsi/aic7xxx] Error 2
# make[1]: *** [drivers/scsi] Error 2
# make[1]: *** Waiting for unfinished jobs....
# make: *** [drivers] Error 2
#
#
# ###### configuration id 59253
# ErrorLog.AICDB
# ErrorLog.AIC7XXX
# aicasm_symbol.c:48:19: fatal error: aicdb.h: No such file or directory
#  #include "aicdb.h"
#                    ^
# compilation terminated.
# aicasm_gram.tab.c: In function 'yyparse':
# aicasm_gram.tab.c:1628:16: warning: implicit declaration of function 'yylex' [-Wimplicit-function-declaration]
# aicasm_macro_gram.tab.c: In function 'mmparse':
# /TuxML/linux-4.13.3/drivers/scsi/aic7xxx/aicasm//aicasm_macro_gram.c:64:25: warning: implicit declaration of function 'mmlex' [-Wimplicit-function-declaration]
#  #define yylex           mmlex
#                          ^
# aicasm_macro_gram.tab.c:1199:16: note: in expansion of macro 'yylex'
# aicasm_scan.l: In function 'yylex':
# aicasm_scan.l:420:6: warning: implicit declaration of function 'mm_switch_to_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(temp_state);
#       ^~~~~~~~~~~~~~~~~~~
# aicasm_scan.l:421:6: warning: implicit declaration of function 'mmparse' [-Wimplicit-function-declaration]
#       mm_switch_to_buffer(old_state);
#       ^~~~~~~
# aicasm_scan.l:424:6: warning: implicit declaration of function 'mm_delete_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(old_state);
#       ^~~~~~~~~~~~~~~~
# make[4]: *** [aicasm] Error 1
# make[3]: *** [drivers/scsi/aic7xxx/aicasm/aicasm] Error 2
# make[2]: *** [drivers/scsi/aic7xxx] Error 2
# make[1]: *** [drivers/scsi] Error 2
# make[1]: *** Waiting for unfinished jobs....
# make: *** [drivers] Error 2
#
#
# ###### configuration id 61758
# ErrorLog.AICDB
# ErrorLog.AIC7XXX
# drivers/gpu/drm/radeon/radeon_object.c: In function 'radeon_bo_create':
# drivers/gpu/drm/radeon/radeon_object.c:242:2: warning: #warning Please enable CONFIG_MTRR and CONFIG_X86_PAT for better performance thanks to write-combining [-Wcpp]
#  #warning Please enable CONFIG_MTRR and CONFIG_X86_PAT for better performance \
#   ^~~~~~~
# aicasm_symbol.c:48:19: fatal error: aicdb.h: No such file or directory
#  #include "aicdb.h"
#                    ^
# compilation terminated.
# aicasm_gram.tab.c: In function 'yyparse':
# aicasm_gram.tab.c:1628:16: warning: implicit declaration of function 'yylex' [-Wimplicit-function-declaration]
# aicasm_macro_gram.tab.c: In function 'mmparse':
# /TuxML/linux-4.13.3/drivers/scsi/aic7xxx/aicasm//aicasm_macro_gram.c:64:25: warning: implicit declaration of function 'mmlex' [-Wimplicit-function-declaration]
#  #define yylex           mmlex
#                          ^
# aicasm_macro_gram.tab.c:1199:16: note: in expansion of macro 'yylex'
# aicasm_scan.l: In function 'yylex':
# aicasm_scan.l:420:6: warning: implicit declaration of function 'mm_switch_to_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(temp_state);
#       ^~~~~~~~~~~~~~~~~~~
# aicasm_scan.l:421:6: warning: implicit declaration of function 'mmparse' [-Wimplicit-function-declaration]
#       mm_switch_to_buffer(old_state);
#       ^~~~~~~
# aicasm_scan.l:424:6: warning: implicit declaration of function 'mm_delete_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(old_state);
#       ^~~~~~~~~~~~~~~~
# make[4]: *** [aicasm] Error 1
# make[3]: *** [drivers/scsi/aic7xxx/aicasm/aicasm] Error 2
# make[2]: *** [drivers/scsi/aic7xxx] Error 2
# make[1]: *** [drivers/scsi] Error 2
# make[1]: *** Waiting for unfinished jobs....
# make: *** [drivers] Error 2
#
#
# ###### configuration id 67576
# ErrorLog.AICDB
# ErrorLog.AIC7XXX
# aicasm_symbol.c:48:19: fatal error: aicdb.h: No such file or directory
#  #include "aicdb.h"
#                    ^
# compilation terminated.
# aicasm_gram.tab.c: In function 'yyparse':
# aicasm_gram.tab.c:1628:16: warning: implicit declaration of function 'yylex' [-Wimplicit-function-declaration]
# aicasm_macro_gram.tab.c: In function 'mmparse':
# /TuxML/linux-4.13.3/drivers/scsi/aic7xxx/aicasm//aicasm_macro_gram.c:64:25: warning: implicit declaration of function 'mmlex' [-Wimplicit-function-declaration]
#  #define yylex           mmlex
#                          ^
# aicasm_macro_gram.tab.c:1199:16: note: in expansion of macro 'yylex'
# aicasm_scan.l: In function 'yylex':
# aicasm_scan.l:420:6: warning: implicit declaration of function 'mm_switch_to_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(temp_state);
#       ^~~~~~~~~~~~~~~~~~~
# aicasm_scan.l:421:6: warning: implicit declaration of function 'mmparse' [-Wimplicit-function-declaration]
#       mm_switch_to_buffer(old_state);
#       ^~~~~~~
# aicasm_scan.l:424:6: warning: implicit declaration of function 'mm_delete_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(old_state);
#       ^~~~~~~~~~~~~~~~
# make[4]: *** [aicasm] Error 1
# make[3]: *** [drivers/scsi/aic7xxx/aicasm/aicasm] Error 2
# make[2]: *** [drivers/scsi/aic7xxx] Error 2
# make[1]: *** [drivers/scsi] Error 2
# make[1]: *** Waiting for unfinished jobs....
# drivers/gpu/drm/radeon/radeon_object.c: In function 'radeon_bo_create':
# drivers/gpu/drm/radeon/radeon_object.c:242:2: warning: #warning Please enable CONFIG_MTRR and CONFIG_X86_PAT for better performance thanks to write-combining [-Wcpp]
#  #warning Please enable CONFIG_MTRR and CONFIG_X86_PAT for better performance \
#   ^~~~~~~
# make: *** [drivers] Error 2
#
#
# ###### configuration id 79099
# ErrorLog.AICDB
# ErrorLog.AIC7XXX
# aicasm_symbol.c:48:19: fatal error: aicdb.h: No such file or directory
#  #include "aicdb.h"
#                    ^
# compilation terminated.
# aicasm_gram.tab.c: In function ‘yyparse’:
# aicasm_gram.tab.c:1628:16: warning: implicit declaration of function ‘yylex’ [-Wimplicit-function-declaration]
# aicasm_macro_gram.tab.c: In function ‘mmparse’:
# /TuxML/linux-4.13.3/drivers/scsi/aic7xxx/aicasm//aicasm_macro_gram.c:64:25: warning: implicit declaration of function ‘mmlex’ [-Wimplicit-function-declaration]
#  #define yylex           mmlex
#                          ^
# aicasm_macro_gram.tab.c:1199:16: note: in expansion of macro ‘yylex’
# aicasm_scan.l: In function ‘yylex’:
# aicasm_scan.l:420:6: warning: implicit declaration of function ‘mm_switch_to_buffer’ [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(temp_state);
#       ^~~~~~~~~~~~~~~~~~~
# aicasm_scan.l:421:6: warning: implicit declaration of function ‘mmparse’ [-Wimplicit-function-declaration]
#       mm_switch_to_buffer(old_state);
#       ^~~~~~~
# aicasm_scan.l:424:6: warning: implicit declaration of function ‘mm_delete_buffer’ [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(old_state);
#       ^~~~~~~~~~~~~~~~
# make[4]: *** [aicasm] Error 1
# make[3]: *** [drivers/scsi/aic7xxx/aicasm/aicasm] Error 2
# make[2]: *** [drivers/scsi/aic7xxx] Error 2
# make[2]: *** Waiting for unfinished jobs....
# make[1]: *** [drivers/scsi] Error 2
# make[1]: *** Waiting for unfinished jobs....
# make: *** [drivers] Error 2
#
#
# ###### configuration id 84168
# ErrorLog.AICDB
# ErrorLog.AIC7XXX
# drivers/gpu/drm/amd/amdgpu/amdgpu_object.c: In function ‘amdgpu_bo_create_restricted’:
# drivers/gpu/drm/amd/amdgpu/amdgpu_object.c:378:2: warning: #warning Please enable CONFIG_MTRR and CONFIG_X86_PAT for better performance thanks to write-combining [-Wcpp]
#  #warning Please enable CONFIG_MTRR and CONFIG_X86_PAT for better performance \
#   ^~~~~~~
# aicasm_symbol.c:48:19: fatal error: aicdb.h: No such file or directory
#  #include "aicdb.h"
#                    ^
# compilation terminated.
# aicasm_gram.tab.c: In function ‘yyparse’:
# aicasm_gram.tab.c:1628:16: warning: implicit declaration of function ‘yylex’ [-Wimplicit-function-declaration]
# aicasm_macro_gram.tab.c: In function ‘mmparse’:
# /TuxML/linux-4.13.3/drivers/scsi/aic7xxx/aicasm//aicasm_macro_gram.c:64:25: warning: implicit declaration of function ‘mmlex’ [-Wimplicit-function-declaration]
#  #define yylex           mmlex
#                          ^
# aicasm_macro_gram.tab.c:1199:16: note: in expansion of macro ‘yylex’
# aicasm_scan.l: In function ‘yylex’:
# aicasm_scan.l:420:6: warning: implicit declaration of function ‘mm_switch_to_buffer’ [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(temp_state);
#       ^~~~~~~~~~~~~~~~~~~
# aicasm_scan.l:421:6: warning: implicit declaration of function ‘mmparse’ [-Wimplicit-function-declaration]
#       mm_switch_to_buffer(old_state);
#       ^~~~~~~
# aicasm_scan.l:424:6: warning: implicit declaration of function ‘mm_delete_buffer’ [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(old_state);
#       ^~~~~~~~~~~~~~~~
# make[4]: *** [aicasm] Error 1
# make[3]: *** [drivers/scsi/aic7xxx/aicasm/aicasm] Error 2
# make[2]: *** [drivers/scsi/aic7xxx] Error 2
# make[1]: *** [drivers/scsi] Error 2
# make[1]: *** Waiting for unfinished jobs....
# make: *** [drivers] Error 2

# %%
'''
basic conclusion: bug GENERIC_ALLOCATOR + DRM_VBOXVIDEO is not dominated by other bugs than firmware
'''

generic_allocator_mask_notfirmware = rawtuxdata.query("GENERIC_ALLOCATOR == 0 & DRM_VBOXVIDEO == 2 & ~(AIC7XXX_BUILD_FIRMWARE == 1 | AIC79XX_BUILD_FIRMWARE == 1 | WANXL_BUILD_FIRMWARE == 1)  & compile_success == 0")


print("generic allocator bug *without* firmwares' failures", generic_allocator_mask_notfirmware.shape)
print()
print()
for cid in generic_allocator_mask_notfirmware['cid']:
    err_pattern = error_pattern.query("cid == " + str(cid)).iloc[0]
    if not (err_pattern[ErrorLog.GEN.name]):
        print ("###### configuration id", cid)
        print("GENERIC allocator NOT found")
    #else:
    #    for err in ErrorLog:
    #        if (err_pattern[err.name]):
    #            print(err)
# Out:
# generic allocator bug *without* firmwares' failures (369, 12638)

# %%
# ~(AIC7XXX_BUILD_FIRMWARE == 1 | AIC79XX_BUILD_FIRMWARE == 1 | WANXL_BUILD_FIRMWARE == 1)  &
# Mathieu: I'm deactivating it, it's time-consuming and error-prone 
if False:
    for path1 in all_paths[::-1]:
        # collect all cids related to a path
        path_cids = rawtuxdata.query(path1 + " & compile_success == False")['cid'].values
        spath_cids = set(path_cids)
        print (path1)
        for path2 in all_paths[::-1]:
            if (path1 != path2):                
                for cid in path_cids:
                    # report whether an alternate path/rule can match the cid 
                    #print (cid)
                    overlap = rawtuxdata.query(path2 + " & compile_success == False & cid == " + str(cid)) #['cid'].values
                    #overlap = list(spath_cids & set(path_cids2)) 
                    if len(overlap) > 0:
                        print(path1, "also hold with\n", path2, "=> #", overlap)
                        print()
    
       
#    for path2 in all_paths:
#        if (path1 != path2):
#            overlap = len(rawtuxdata.query(path1 + " | ~(" + path2 + ") & compile_success == False").index)
#            if  overlap > 0:
#                print(path1, "also hold with\n", path2, "=> #", overlap)
#                print()
        
        
#

# %%
# TODO: classification on clusters!
rawtuxdata = pd.merge(rawtuxdata, error_patternfirst, on='cid', how='outer')

# %%
rawtuxdata.shape, error_patternfirst.shape
# Out:
# ((96094, 12658), (3621, 20))

# %%
rawtuxdata.query(ErrorLog.AICDB.name + " == True").shape
# rawtuxdata['cid']
# configwithclusters['cid']
# Out:
# (2464, 12658)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.utils.multiclass import unique_labels


def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if not title:
        if normalize:
            title = 'Normalized confusion matrix'
        else:
            title = 'Confusion matrix, without normalization'

    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    # Only use the labels that appear in the data
    classes = classes[unique_labels(y_true, y_pred)]
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        #print("Normalized confusion matrix")
    else:
        #print('Confusion matrix, without normalization')
        pass

    #print(cm)

    fig, ax = plt.subplots(figsize=(15, 15))
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=classes, yticklabels=classes,
           title=title,
           ylabel='True label',
           xlabel='Predicted label')

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return ax

# %%
for err in ErrorLog:
    rawtuxdata[err.name] = rawtuxdata[err.name].fillna(False)

# %%
'''
create a column with the first kind/cluster of error message that pops out
it will be a label
allows multi-class classification (instead of simply binary classification)
TODO: applies to error_patternfirst and error_pattern
'''

from sklearn.preprocessing import LabelEncoder
# FIXE: enum auto() does not work
def which_pattern(row):
    for err in ErrorLog:
        if (row[err.name]):
            return err.name
    return "NO_FAILURE"
cluster_errorfirst = rawtuxdata.apply(which_pattern, axis=1)
cluster_errorfirst.unique()
# Out:
# array(['NO_FAILURE', 'AS68K', 'AIC7XXX', 'OVERFLOW2', 'GEN', 'V4L2',
#        'DRM_BRIDGE_CLUSTER', 'AICDB', 'PINCTRL_CLUSTER',
#        'CONFIG_NLS_DEFAULT', 'TTM', 'CRC32_CLUSTER', 'BTBCM',
#        'BLACKLIGHT', 'DEVM2', 'DEVM', 'BLACKLIGHT2', 'I2C_CLUSTER', 'PCM',
#        'ULPI'], dtype=object)

# %%
# encoding strings as labels
le_cluster = LabelEncoder()
rawtuxdata['cluster_errorfirst'] = le_cluster.fit_transform(cluster_errorfirst)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import matthews_corrcoef
from sklearn import tree
from sklearn.metrics import classification_report
import graphviz 

'''
1. when cluster_of_interest == 'cluster_errorfirst' it is a multiclass classification (multi-class is all clusters' errors)
2. when cluster_of_interest is the name of a cluster, it is a per class classification 
(ie we aim to recognize a specific failure and the rest is either other failure or NO failure)
3. for simple failure/no failure, see elsewhere
4. (TODO) it is also possible to have a look at a subset of clusters (not all), but not generalized here (I've made some experiments though)
'''
def mk_decisiontree_overcluster(cluster_of_interest, print_cfmatrix=True):

    TESTING_SIZE_CLUSTER= 0.1 #0.99 # 0.001 # 0.9
    X_train_cluster, X_test_cluster, y_train_cluster, y_test_cluster = train_test_split(
        rawtuxdata
        .drop(columns=["cid"])
        .drop(columns=['cluster_errorfirst'])
       # .drop(columns=["nb_patterns"])
        .drop(columns=pattern_name)
       # .drop(columns=size_methods)
        .drop(columns=compilation_status_column_name), 
        rawtuxdata[cluster_of_interest], ### can be 'cluster_errorfirst' column ie all clusters are of interest!
        test_size=TESTING_SIZE_CLUSTER, random_state=0)  

    clf_cluster = tree.DecisionTreeClassifier() #GradientBoostingClassifier(n_estimators=100) #RandomForestRegressor(n_estimators=100) #   #GradientBoostingRegressor(n_estimators=100)  
    clf_cluster.fit(X_train_cluster, y_train_cluster)
        
    ######## eval_decisiontree
    y_pred_cluster = clf_cluster.predict(X_test_cluster)

    acc_cl = accuracy_score (y_test_cluster, y_pred_cluster)
    if (cluster_of_interest == 'cluster_errorfirst'):
        #### multi-class
        average_method_cl = 'micro'
        prec_cl = precision_score (y_test_cluster, y_pred_cluster, average=average_method_cl)
        reca_cl = recall_score (y_test_cluster, y_pred_cluster, average=average_method_cl)
        f1_cl = f1_score (y_test_cluster, y_pred_cluster, average=average_method_cl)
    else:
        prec_cl = precision_score (y_test_cluster, y_pred_cluster)
        reca_cl = recall_score (y_test_cluster, y_pred_cluster)
        f1_cl = f1_score (y_test_cluster, y_pred_cluster)
        
    balance_acc_cl = balanced_accuracy_score (y_test_cluster, y_pred_cluster)
    matt_cl = matthews_corrcoef(y_test_cluster, y_pred_cluster) 


    print("Accuracy score:", acc_cl)
    print("Precision score:", prec_cl)
    print("Recall score:", reca_cl)
    print("F1 score:", f1_cl)
    print("Balanced accuracy score:", balance_acc_cl)

    print("Matthews corr score:", matt_cl)
    
    ######### plot decision tree
    # ft_names =  rawtuxdata.drop(columns=["cid", 'cluster_errorfirst']).drop(columns=pattern_name).drop(columns=size_methods).drop(columns=compilation_status_column_name).columns
    ft_names =  rawtuxdata.drop(columns=["cid", 'cluster_errorfirst']).drop(columns=pattern_name).drop(columns=compilation_status_column_name).columns
    #
    # TODO: 
    if (cluster_of_interest == 'cluster_errorfirst'):
        cl_names = [list(le_cluster.classes_)[i] for i in clf_cluster.classes_] # list(le_cluster.classes_) 
    else:
        cl_names = [] 
        cl_names.append('NOFAILURE_WITH_' + cluster_of_interest)
        cl_names.append(cluster_of_interest)
    dot_data = tree.export_graphviz(clf_cluster, out_file=None, 
                             feature_names=ft_names,
                             class_names = cl_names,
                             filled=True, rounded=True,
                             special_characters=True)  
    graph = graphviz.Source(dot_data)  
    graph.render("TUXML_compilation_failures_clusters_" + cluster_of_interest)
    
    ######## confusion matrix
    
    #np.set_printoptions(precision=2)
    # Plot non-normalized confusion matrix
    if print_cfmatrix:
        plot_confusion_matrix(y_test_cluster, y_pred_cluster, classes=np.array(cl_names),
                              title='Confusion matrix, without normalization')

        # Plot normalized confusion matrix
        plot_confusion_matrix(y_test_cluster, y_pred_cluster, classes=np.array(cl_names), normalize=True,
                              title='Normalized confusion matrix')

        plt.show() 
    
    
    ###### classification report 
    print(classification_report(y_test_cluster, y_pred_cluster)) # labels=np.array(cl_names)
        

# mk_decisiontree_overcluster('cluster_errorfirst')

for cl in ErrorLog:
    mk_decisiontree_overcluster(cl.name, print_cfmatrix=False)
    
    # ErrorLog.GEN.name # ErrorLog.OVERFLOW2.name ErrorLog.CONFIG_NLS_DEFAULT.name #
# Out:
# Accuracy score: 0.9998959417273673
# Precision score: 0.6666666666666666
# Recall score: 1.0
# F1 score: 0.8
# Balanced accuracy score: 0.9999479600333057
# Matthews corr score: 0.81645408936719
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00      9608
#         True       0.67      1.00      0.80         2
#
#    micro avg       1.00      1.00      1.00      9610
#    macro avg       0.83      1.00      0.90      9610
# weighted avg       1.00      1.00      1.00      9610
# /usr/local/lib/python3.7/site-packages/sklearn/metrics/classification.py:543: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# Accuracy score: 1.0
# Precision score: 0.0
# Recall score: 0.0
# F1 score: 0.0
# Balanced accuracy score: 1.0
# Matthews corr score: 0.0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-87-b6be28abd112> in <module>
#      96
#      97 for cl in ErrorLog:
# ---> 98     mk_decisiontree_overcluster(cl.name)
#      99
#     100     # ErrorLog.GEN.name # ErrorLog.OVERFLOW2.name ErrorLog.CONFIG_NLS_DEFAULT.name #
#
# <ipython-input-87-b6be28abd112> in mk_decisiontree_overcluster(cluster_of_interest)
#      80     # Plot non-normalized confusion matrix
#      81     plot_confusion_matrix(y_test_cluster, y_pred_cluster, classes=np.array(cl_names),
# ---> 82                           title='Confusion matrix, without normalization')
#      83
#      84     # Plot normalized confusion matrix
#
# <ipython-input-78-fc128aefd2e7> in plot_confusion_matrix(y_true, y_pred, classes, normalize, title, cmap)
#      20     cm = confusion_matrix(y_true, y_pred)
#      21     # Only use the labels that appear in the data
# ---> 22     classes = classes[unique_labels(y_true, y_pred)]
#      23     if normalize:
#      24         cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
#
# IndexError: boolean index did not match indexed array along dimension 0; dimension is 2 but corresponding boolean dimension is 1

# %%
# list(zip(cl_names, clf_cluster.classes_))
#for i in clf_cluster.classes_:
#    print(list(le_cluster.classes_)[i])
#clf_cluster.classes_, cl_names, cl_names[13]

# %%
#error_patternfirst[ErrorLog.I2C.name]
#rawtuxdata.query("cid == 96730")

# %%
rawtuxdata[pattern_name][:20]
# Out:
#     BLACKLIGHT  BLACKLIGHT2  CONFIG_NLS_DEFAULT  CRC32_CLUSTER   V4L2  \
# 0        False        False               False          False  False
# 1        False        False               False          False  False
# 2        False        False               False          False  False
# 3        False        False               False          False  False
# 4        False        False               False          False  False
# 5        False        False               False          False  False
# 6        False        False               False          False  False
# 7        False        False               False          False  False
# 8        False        False               False          False  False
# 9        False        False               False          False  False
# 10       False        False               False          False  False
# 11       False        False               False          False  False
# 12       False        False               False          False  False
# 13       False        False               False          False  False
# 14       False        False               False          False  False
# 15       False        False               False          False  False
# 16       False        False               False          False  False
# 17       False        False               False          False  False
# 18       False        False               False          False  False
# 19       False        False               False          False  False
#
#     OVERFLOW2   ULPI    PCM    TTM  AS68K    GEN  AICDB  AIC7XXX  \
# 0       False  False  False  False  False  False  False    False
# 1       False  False  False  False  False  False  False    False
# 2       False  False  False  False  False  False  False    False
# 3       False  False  False  False  False  False  False    False
# 4       False  False  False  False  False  False  False    False
# 5       False  False  False  False  False  False  False    False
# 6       False  False  False  False  False  False  False    False
# 7       False  False  False  False  False  False  False    False
# 8       False  False  False  False  False  False  False    False
# 9       False  False  False  False  False  False  False    False
# 10      False  False  False  False  False  False  False    False
# 11      False  False  False  False  False  False  False    False
# 12      False  False  False  False  False  False  False    False
# 13      False  False  False  False  False  False  False    False
# 14      False  False  False  False  False  False  False    False
# 15      False  False  False  False  False  False  False    False
# 16      False  False  False  False  False  False  False    False
# 17      False  False  False  False  False  False  False    False
# 18      False  False  False  False  False  False  False    False
# 19      False  False  False  False  False  False  False    False
#
#     DRM_BRIDGE_CLUSTER  PINCTRL_CLUSTER  BTBCM  BPFFANCY   DEVM  DEVM2  \
# 0                False            False  False     False  False  False
# 1                False            False  False     False  False  False
# 2                False            False  False     False  False  False
# 3                False            False  False     False  False  False
# 4                False            False  False     False  False  False
# 5                False            False  False     False  False  False
# 6                False            False  False     False  False  False
# 7                False            False  False     False  False  False
# 8                False            False  False     False  False  False
# 9                False            False  False     False  False  False
# 10               False            False  False     False  False  False
# 11               False            False  False     False  False  False
# 12               False            False  False     False  False  False
# 13               False            False  False     False  False  False
# 14               False            False  False     False  False  False
# 15               False            False  False     False  False  False
# 16               False            False  False     False  False  False
# 17               False            False  False     False  False  False
# 18               False            False  False     False  False  False
# 19               False            False  False     False  False  False
#
#     I2C_CLUSTER
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 12        False
# 13        False
# 14        False
# 15        False
# 16        False
# 17        False
# 18        False
# 19        False

# %%
for path in all_paths[::-1]: # all_paths[::-1]:
    configs_path = rawtuxdata.query(path + " & compile_success == False")
    clusters_path = []
    for ind, cfg in configs_path.iterrows():  
        cluster_cfg = []
        for err in ErrorLog:
            if(cfg[err.name]):
                cluster_cfg.append(err.name)                
        assert(len(set(cluster_cfg)) == 1)
        clusters_path.append(cluster_cfg[0])
                
    print(path, "=>", set(clusters_path))
    print()
        
    # configs_path['cid'].values
# Out:
# AIC79XX_BUILD_FIRMWARE > 0.5 => {'AICDB', 'AS68K', 'AIC7XXX', 'OVERFLOW2'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE > 0.5 => {'AICDB', 'AS68K', 'AIC7XXX', 'OVERFLOW2'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE > 0.5 => {'AS68K'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL > 0.5 & INFINIBAND_ADDR_TRANS > 0.5 & FORTIFY_SOURCE > 0.5 & IPV6 > 1.5 & NEW_LEDS <= 0.5 => {'DEVM2'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL > 0.5 & INFINIBAND_ADDR_TRANS > 0.5 & FORTIFY_SOURCE > 0.5 & IPV6 <= 1.5 & IPV6 > 0.5 & UBSAN_NULL > 0.5 => {'OVERFLOW2'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL > 0.5 & INFINIBAND_ADDR_TRANS > 0.5 & FORTIFY_SOURCE > 0.5 & IPV6 <= 1.5 & IPV6 > 0.5 & UBSAN_NULL <= 0.5 & UBSAN_ALIGNMENT > 0.5 => {'OVERFLOW2'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL > 0.5 & INFINIBAND_ADDR_TRANS <= 0.5 & I40EVF > 0.5 & VIDEO_XILINX_TPG <= 0.5 & SCR24X > 1.5 => {'V4L2'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL > 0.5 & INFINIBAND_ADDR_TRANS <= 0.5 & I40EVF <= 0.5 & SND_HDA_EXT_CORE <= 0.5 => {'TTM'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC > 0.5 & REGMAP_MMIO > 0.5 & FUSION_LAN > 0.5 & USB_F_TCM > 0.5 & EDAC_PND2 > 0.5 & NET_ACT_CONNMARK > 1.5 & USB_GSPCA_OV534 > 1.5 & INITRAMFS_COMPRESSION > 21273.5 => {'BLACKLIGHT'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC > 0.5 & REGMAP_MMIO > 0.5 & FUSION_LAN > 0.5 & USB_F_TCM > 0.5 & EDAC_PND2 > 0.5 & NET_ACT_CONNMARK <= 1.5 & I2C_EG20T > 0.5 & INFINIBAND_QEDR > 1.5 & GPIOLIB <= 0.5 & QCOM_HIDMA_MGMT > 1.5 => {'PINCTRL_CLUSTER'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC > 0.5 & REGMAP_MMIO > 0.5 & FUSION_LAN > 0.5 & USB_F_TCM > 0.5 & EDAC_PND2 > 0.5 & NET_ACT_CONNMARK <= 1.5 & I2C_EG20T > 0.5 & INFINIBAND_QEDR <= 1.5 & SND_AT73C213 > 0.5 & VIDEO_SOLO6X10 > 1.5 & MEMCG_SWAP_ENABLED > 0.5 & NFC_NCI_SPI > 1.5 => {'BLACKLIGHT2'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC > 0.5 & REGMAP_MMIO > 0.5 & FUSION_LAN > 0.5 & USB_F_TCM > 0.5 & EDAC_PND2 > 0.5 & NET_ACT_CONNMARK <= 1.5 & I2C_EG20T > 0.5 & INFINIBAND_QEDR <= 1.5 & SND_AT73C213 <= 0.5 & IMA_READ_POLICY > 0.5 & DVB_CX24123 > 1.5 => {'DRM_BRIDGE_CLUSTER'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC > 0.5 & REGMAP_MMIO > 0.5 & FUSION_LAN > 0.5 & USB_F_TCM > 0.5 & EDAC_PND2 > 0.5 & NET_ACT_CONNMARK <= 1.5 & I2C_EG20T <= 0.5 & SND_AT73C213 > 1.5 & VIDEO_CS5345 > 1.5 => {'BLACKLIGHT'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC > 0.5 & REGMAP_MMIO > 0.5 & FUSION_LAN > 0.5 & USB_F_TCM > 0.5 & EDAC_PND2 > 0.5 & NET_ACT_CONNMARK <= 1.5 & I2C_EG20T <= 0.5 & SND_AT73C213 <= 1.5 & USB_SL811_CS > 1.5 & GENERIC_IRQ_CHIP <= 0.5 => {'PINCTRL_CLUSTER'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC > 0.5 & REGMAP_MMIO > 0.5 & FUSION_LAN > 0.5 & USB_F_TCM > 0.5 & EDAC_PND2 > 0.5 & NET_ACT_CONNMARK <= 1.5 & I2C_EG20T <= 0.5 & SND_AT73C213 <= 1.5 & USB_SL811_CS <= 1.5 & CHARGER_AXP20X > 1.5 & SATA_SIL > 1.5 => {'TTM'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC > 0.5 & REGMAP_MMIO > 0.5 & FUSION_LAN > 0.5 & USB_F_TCM > 0.5 & EDAC_PND2 > 0.5 & NET_ACT_CONNMARK <= 1.5 & I2C_EG20T <= 0.5 & SND_AT73C213 <= 1.5 & USB_SL811_CS <= 1.5 & CHARGER_AXP20X <= 1.5 & DVB_BUDGET > 1.5 & COMEDI_AMPLC_PC263_PCI > 1.5 => {'BLACKLIGHT'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC > 0.5 & REGMAP_MMIO > 0.5 & FUSION_LAN > 0.5 & USB_F_TCM > 0.5 & EDAC_PND2 <= 0.5 & USB_MUSB_GADGET > 0.5 & AD2S90 > 1.5 => {'TTM', 'BLACKLIGHT'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC > 0.5 & REGMAP_MMIO > 0.5 & FUSION_LAN > 0.5 & USB_F_TCM > 0.5 & EDAC_PND2 <= 0.5 & USB_MUSB_GADGET <= 0.5 & VIPERBOARD_ADC > 1.5 & MPILIB <= 0.5 => {'BLACKLIGHT'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC > 0.5 & REGMAP_MMIO > 0.5 & FUSION_LAN > 0.5 & USB_F_TCM <= 0.5 & VIDEO_SOLO6X10 > 1.5 & COMPAT_32 > 0.5 => {'BLACKLIGHT'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC > 0.5 & REGMAP_MMIO > 0.5 & FUSION_LAN > 0.5 & USB_F_TCM <= 0.5 & VIDEO_SOLO6X10 <= 1.5 & USB_CHIPIDEA_PCI > 1.5 & BCM_KONA_USB2_PHY > 1.5 => {'PINCTRL_CLUSTER'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC > 0.5 & REGMAP_MMIO > 0.5 & FUSION_LAN > 0.5 & USB_F_TCM <= 0.5 & VIDEO_SOLO6X10 <= 1.5 & USB_CHIPIDEA_PCI <= 1.5 & VIDEO_LM3646 > 1.5 & SND_SOC_ROCKCHIP <= 0.5 => {'DRM_BRIDGE_CLUSTER'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC > 0.5 & REGMAP_MMIO > 0.5 & FUSION_LAN <= 0.5 & SND_SYNTH_EMUX > 1.5 => {'TTM'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC > 0.5 & REGMAP_MMIO <= 0.5 & SND_SOC_GTM601 > 1.5 => {'DEVM'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC > 0.5 & REGMAP_MMIO <= 0.5 & SND_SOC_GTM601 <= 1.5 & PINCTRL_AS3722 > 1.5 & HID_APPLE > 0.5 => {'TTM'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC <= 0.5 & SND_PDAUDIOCF > 1.5 & MOST <= 0.5 => {'DRM_BRIDGE_CLUSTER'}
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC <= 0.5 & SND_PDAUDIOCF <= 1.5 & PTP_1588_CLOCK_GIANFAR > 0.5 & CAN_PEAK_PCIEFD > 1.5 & TCS3414 <= 0.5 => {'BLACKLIGHT'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS > 1.5 & USB_PULSE8_CEC <= 0.5 & SND_PDAUDIOCF <= 1.5 & PTP_1588_CLOCK_GIANFAR <= 0.5 & TCG_VTPM_PROXY > 1.5 => {'BTBCM'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS <= 1.5 & PARIDE_EPIA > 1.5 => {'CONFIG_NLS_DEFAULT'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS <= 1.5 & PARIDE_EPIA <= 1.5 & TCM_USER2 > 1.5 & RANDOMIZE_BASE <= 0.5 => {'CONFIG_NLS_DEFAULT'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS <= 1.5 & PARIDE_EPIA <= 1.5 & TCM_USER2 <= 1.5 & SCSI_AIC94XX > 1.5 => {'CONFIG_NLS_DEFAULT'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 > 0.5 & NLS <= 1.5 & PARIDE_EPIA <= 1.5 & TCM_USER2 <= 1.5 & SCSI_AIC94XX <= 1.5 & BLK_DEV_RBD <= 0.5 & SPI_JCORE <= 0.5 => {'CONFIG_NLS_DEFAULT'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 <= 0.5 & PWRSEQ_SD8787 > 1.5 & CORDIC <= 0.5 => {'TTM'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 <= 0.5 & PWRSEQ_SD8787 <= 1.5 & VIDEO_MUX > 1.5 & DRM_PANEL > 0.5 => {'V4L2'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 <= 0.5 & PWRSEQ_SD8787 <= 1.5 & VIDEO_MUX <= 1.5 & TYPEC_WCOVE > 1.5 & PHY_BRCM_SATA <= 0.5 => {'TTM'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 <= 0.5 & PWRSEQ_SD8787 <= 1.5 & VIDEO_MUX <= 1.5 & TYPEC_WCOVE <= 1.5 & GPIOLIB > 0.5 & SND_SOC_INTEL_KBL_RT5663_RT5514_MAX98927_MACH > 1.5 & HWMON_VID <= 0.5 => {'TTM'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 <= 0.5 & PWRSEQ_SD8787 <= 1.5 & VIDEO_MUX <= 1.5 & TYPEC_WCOVE <= 1.5 & GPIOLIB > 0.5 & SND_SOC_INTEL_KBL_RT5663_RT5514_MAX98927_MACH <= 1.5 & MMC_SDHCI_PXAV2 > 1.5 & CHARGER_TWL4030 > 1.5 => {'TTM'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 <= 0.5 & PWRSEQ_SD8787 <= 1.5 & VIDEO_MUX <= 1.5 & TYPEC_WCOVE <= 1.5 & GPIOLIB > 0.5 & SND_SOC_INTEL_KBL_RT5663_RT5514_MAX98927_MACH <= 1.5 & MMC_SDHCI_PXAV2 <= 1.5 & MTD_SBC_GXX > 1.5 & GPIO_PISOSR <= 0.5 => {'TTM'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 <= 0.5 & PWRSEQ_SD8787 <= 1.5 & VIDEO_MUX <= 1.5 & TYPEC_WCOVE <= 1.5 & GPIOLIB <= 0.5 & DRM_I2C_NXP_TDA998X > 1.5 & EXTRA_FIRMWARE_DIR > 12181.0 => {'TTM', 'BLACKLIGHT'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND > 0.5 & VME_CA91CX42 <= 0.5 & PWRSEQ_SD8787 <= 1.5 & VIDEO_MUX <= 1.5 & TYPEC_WCOVE <= 1.5 & GPIOLIB <= 0.5 & DRM_I2C_NXP_TDA998X <= 1.5 & USB_STORAGE_ONETOUCH > 1.5 & EFI_FAKE_MEMMAP <= 0.5 => {'BLACKLIGHT'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND <= 0.5 & SND_SOC_IMX_WM8962 > 1.5 => {'BLACKLIGHT'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND <= 0.5 & SND_SOC_IMX_WM8962 <= 1.5 & BRIDGE_EBT_ARPREPLY > 1.5 & GPIO_PCI_IDIO_16 <= 0.5 => {'BLACKLIGHT'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND <= 0.5 & SND_SOC_IMX_WM8962 <= 1.5 & BRIDGE_EBT_ARPREPLY <= 1.5 & CAN_PEAK_USB > 1.5 & SERIAL_8250_LPSS <= 0.5 => {'BTBCM'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND <= 0.5 & SND_SOC_IMX_WM8962 <= 1.5 & BRIDGE_EBT_ARPREPLY <= 1.5 & CAN_PEAK_USB <= 1.5 & VIDEO_STI_DELTA_DRIVER > 1.5 & SND_VERBOSE_PRINTK > 0.5 => {'I2C_CLUSTER'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN > 0.5 & XEN_PCIDEV_FRONTEND <= 0.5 & SND_SOC_IMX_WM8962 <= 1.5 & BRIDGE_EBT_ARPREPLY <= 1.5 & CAN_PEAK_USB <= 1.5 & VIDEO_STI_DELTA_DRIVER <= 1.5 & DRM_R128 > 1.5 & BLK_DEV_NULL_BLK <= 0.5 & SND_SEQ_MIDI_EMUL > 0.5 => {'BLACKLIGHT'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN <= 0.5 & USB_STORAGE_SDDR09 > 1.5 => {'V4L2'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS > 0.5 & VIDEO_RCAR_VIN <= 0.5 & USB_STORAGE_SDDR09 <= 1.5 & COMEDI_DAS08_ISA > 1.5 => {'V4L2'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 > 0.5 & VIDEO_S5P_MIPI_CSIS <= 0.5 & DVB_DUMMY_FE > 1.5 => {'V4L2'}
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC > 0.5 & CRC32 <= 0.5 & MAX1363 > 1.5 => {'CRC32_CLUSTER'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC <= 0.5 & VIDEO_MUX > 1.5 & REGMAP_I2C <= 0.5 => {'V4L2'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_VTC <= 0.5 & VIDEO_MUX <= 1.5 & SND_AT91_SOC_SAM9G20_WM8731 > 1.5 => {'PCM'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR <= 0.5 & DRM_VBOXVIDEO > 1.5 => {'GEN', 'TTM'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR <= 0.5 & DRM_VBOXVIDEO <= 1.5 & HFI1_VERBS_31BIT_PSN > 0.5 & TEST_SYSCTL > 0.5 & VIDEO_AD5820 > 1.5 => {'OVERFLOW2'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR <= 0.5 & DRM_VBOXVIDEO <= 1.5 & HFI1_VERBS_31BIT_PSN > 0.5 & TEST_SYSCTL <= 0.5 & NET_IPIP > 1.0 => {'OVERFLOW2'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR <= 0.5 & DRM_VBOXVIDEO <= 1.5 & HFI1_VERBS_31BIT_PSN <= 0.5 & WIL6210_TRACING > 0.5 & NF_CONNTRACK_PPTP > 1.5 => {'OVERFLOW2'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR <= 0.5 & DRM_VBOXVIDEO <= 1.5 & HFI1_VERBS_31BIT_PSN <= 0.5 & WIL6210_TRACING <= 0.5 & ISDN_DRV_AVMB1_T1PCI > 0.5 & INFINIBAND_ISERT > 1.5 & FPGA_MGR_ICE40_SPI > 1.5 => {'OVERFLOW2'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR <= 0.5 & DRM_VBOXVIDEO <= 1.5 & HFI1_VERBS_31BIT_PSN <= 0.5 & WIL6210_TRACING <= 0.5 & ISDN_DRV_AVMB1_T1PCI > 0.5 & INFINIBAND_ISERT <= 1.5 & SPI_SH_MSIOF > 0.5 & RT_MUTEXES <= 0.5 & USB_HACKRF <= 0.5 => {'ULPI'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR <= 0.5 & DRM_VBOXVIDEO <= 1.5 & HFI1_VERBS_31BIT_PSN <= 0.5 & WIL6210_TRACING <= 0.5 & ISDN_DRV_AVMB1_T1PCI > 0.5 & INFINIBAND_ISERT <= 1.5 & SPI_SH_MSIOF <= 0.5 & BACKLIGHT_LP8788 <= 0.5 => {'BLACKLIGHT'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR <= 0.5 & DRM_VBOXVIDEO <= 1.5 & HFI1_VERBS_31BIT_PSN <= 0.5 & WIL6210_TRACING <= 0.5 & ISDN_DRV_AVMB1_T1PCI <= 0.5 & SCLP_ASYNC_ID <= 4360.5 => {'OVERFLOW2'}

# %%
# rawtuxdata['PM_STD_PARTITION']

# %%
cluster_to_paths = []
for cluster in ErrorLog:
    configs_cluster = rawtuxdata.query(cluster.name + " == True " + "& compile_success == False")
    path_clusters = []
    for ind, cfg in configs_cluster.iterrows():  
        cid = cfg['cid']
        # print(cid)
        # path = find_rule_for_configuration_id(cid)       
        path = find_rule_for_configuration(clf, rawtuxdata.drop(columns=pattern_name).drop(columns=["cid"]).drop(columns=size_methods).drop(columns=compilation_status_column_name).columns, rawtuxdata.query("cid == " + str(cid)).iloc[0])        
        path_clusters.append(path)
                
    print(cluster, "=>", set(path_clusters))
    print()
    cluster_to_paths.append({ cluster : set(path_clusters) })
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-73-80758442d0a3> in <module>
#       7         # print(cid)
#       8         # path = find_rule_for_configuration_id(cid)
# ----> 9         path = find_rule_for_configuration(clf, rawtuxdata.drop(columns=pattern_name).drop(columns=["cid"]).drop(columns=size_methods).drop(columns=compilation_status_column_name).columns, rawtuxdata.query("cid == " + str(cid)).iloc[0])
#      10         path_clusters.append(path)
#      11
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# /usr/local/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
#    3110             if labels is not None:
# -> 3111                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3112
#    3113         if inplace:
#
# /usr/local/lib/python3.7/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3141                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3142             else:
# -> 3143                 new_axis = axis.drop(labels, errors=errors)
#    3144             result = self.reindex(**{axis_name: new_axis})
#    3145
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    4402             if errors != 'ignore':
#    4403                 raise KeyError(
# -> 4404                     '{} not found in axis'.format(labels[mask]))
#    4405             indexer = indexer[~mask]
#    4406         return self.delete(indexer)
#
# KeyError: "['vmlinux' 'GZIP-bzImage' 'GZIP-vmlinux' 'GZIP' 'BZIP2-bzImage'\n 'BZIP2-vmlinux' 'BZIP2' 'LZMA-bzImage' 'LZMA-vmlinux' 'LZMA' 'XZ-bzImage'\n 'XZ-vmlinux' 'XZ' 'LZO-bzImage' 'LZO-vmlinux' 'LZO' 'LZ4-bzImage'\n 'LZ4-vmlinux' 'LZ4'] not found in axis"

# %%
#cluster_to_paths

# %%
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR <= 0.5 & DRM_VBOXVIDEO > 1.5
rawtuxdata.query("AIC79XX_BUILD_FIRMWARE > 0.5 & GENERIC_ALLOCATOR <= 0.5 & DRM_VBOXVIDEO > 1.5")[['compile_success', ErrorLog.AICDB.name]]

# %%
# del cluster_errorfirst
