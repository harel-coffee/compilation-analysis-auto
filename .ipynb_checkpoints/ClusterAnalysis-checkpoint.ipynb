# %%
import pandas as pd

errorlogs = pd.read_pickle('errlogs.pkl')
# found thanks to clustering! 
suspicious_cids = [70715, 70716, 74459, 74460, 74461, 74463, 74464]
for cid in suspicious_cids:
    errorlogs = errorlogs[errorlogs.cid != cid]

# %%
len(errorlogs)
# Out:
# 3531

# %%
errorlogs.loc[3]['error_message']
# Out:
# 'make[4]: flex: Command not found\nmake[4]: *** [/TuxML/linux-4.13.3/drivers/scsi/aic7xxx/aicasm//aicasm_scan.c] Error 127\nmake[3]: *** [drivers/scsi/aic7xxx/aicasm/aicasm] Error 2\nmake[2]: *** [drivers/scsi/aic7xxx] Error 2\nmake[1]: *** [drivers/scsi] Error 2\nmake[1]: *** Waiting for unfinished jobs....\nmake: *** [drivers] Error 2\n'

# %%
from enum import Enum, auto
class ErrorLog(Enum):
    BLACKLIGHT = auto(),
    BLACKLIGHT2 = auto(),
    CONFIG_NLS_DEFAULT = auto(),
    CRC32 = auto(),
    V4L2 = auto(), 
    OVERFLOW2 = auto(), 
    ULPI = auto(), 
    PCM = auto(),
    TTM = auto(), 
    AS68K = auto(), 
    GEN = auto(), 
    AICDB = auto(), 
    AIC7XXX = auto(),
    DRM_BRIDGE = auto(),
    PINCTRL = auto(), 
    BTBCM = auto(),
    BPFFANCY = auto(), 
    DEVM = auto(), 
    I2C = auto() 
    


    

patterns = { ErrorLog.BLACKLIGHT : "undefined reference to `backlight_device",
            ErrorLog.BLACKLIGHT2: 'intel_backlight_device_register', # cid 87044 does not match BACKLIGHT 
            ErrorLog.CONFIG_NLS_DEFAULT : "CONFIG_NLS_DEFAULT",
            ErrorLog.CRC32 : 'undefined reference to `crc32', 
            ErrorLog.V4L2 : 'undefined reference to `v4l2',
            ErrorLog.OVERFLOW2 : '__read_overflow2',
            ErrorLog.ULPI : 'undefined reference to `ulpi', # 100-126K dataset
            ErrorLog.PCM : 'undefined reference to `atmel_pcm_dma_platform', # 100-126K dataset
            ErrorLog.TTM : 'undefined reference to `ttm', 
            ErrorLog.AS68K: 'as68k: not found',
            ErrorLog.GEN : 'undefined reference to `gen_pool', 
            ErrorLog.AIC7XXX: 'drivers/scsi/aic7xxx',
            ErrorLog.AICDB : 'aicdb.h: No such file or directory', 
            ErrorLog.DRM_BRIDGE : 'undefined reference to `drm_panel_bridge_add', 
            ErrorLog.PINCTRL : 'pinctrl-mcp23s08', # loosely pattern (too general?)
            ErrorLog.BTBCM : 'undefined reference to `btbcm_set_bdaddr', 
            ErrorLog.BPFFANCY : 'bpf-fancy', # loosely pattern (too general?)
            ErrorLog.DEVM : 'undefined reference to `__devm_regmap',
            ErrorLog.I2C: 'i2c_get_adapter',
            ErrorLog.DEVM2 : 'undefined reference to `devm_of_led'
           }

pattern_name = [name for name, member in ErrorLog.__members__.items()]
error_pattern = pd.DataFrame(columns=pattern_name, index=errorlogs['cid'])
error_pattern.fillna(False, inplace=True)

for i, errorlog in errorlogs.iterrows():
    error = errorlog['error_message']
    cid = errorlog['cid']
    for k, p in patterns.items():
        if (p in error):
            error_pattern.loc[cid][k.name] = True
            #print (k.name, "found in configuration", cid)

# %%
#error_pattern.loc[99949]['BLACKLIGHT'] = True
error_pattern['CONFIG_NLS_DEFAULT'].value_counts()
#error_pattern.hist()
# Out:
# False    3526
# True        5
# Name: CONFIG_NLS_DEFAULT, dtype: int64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline  

def nb_patterns(row):
    return sum(row == True)                    
error_pattern['nb_patterns'] = error_pattern.apply(nb_patterns, axis=1)
pattern_frequencies = error_pattern[pattern_name].apply(nb_patterns, axis=0)
pattern_frequencies.plot(kind='bar')
pattern_frequencies
# Out:
# BLACKLIGHT              10
# CONFIG_NLS_DEFAULT       5
# CRC32                    2
# V4L2                     9
# OVERFLOW2               86
# ULPI                     0
# PCM                      0
# TTM                     11
# AS68K                  550
# GEN                    279
# AICDB                 2514
# AIC7XXX               2693
# DRM_BRIDGE               3
# PINCTRL                150
# BTBCM                    2
# BPFFANCY                 2
# DEVM                     2
# I2C                    417
# dtype: int64

# %%
error_pattern.sort_values(by='nb_patterns', ascending=False)[:20]
# Out:
#        BLACKLIGHT  CONFIG_NLS_DEFAULT  CRC32   V4L2  OVERFLOW2   ULPI    PCM  \
# cid
# 71259       False               False  False  False      False  False  False
# 53111       False               False  False  False      False  False  False
# 45350       False               False  False  False      False  False  False
# 71037       False               False  False  False      False  False  False
# 37984       False               False  False  False      False  False  False
# 83702       False               False  False  False      False  False  False
# 44666       False               False  False  False      False  False  False
# 61453       False               False  False  False      False  False  False
# 79099       False               False  False  False      False  False  False
# 61805       False               False  False  False      False  False  False
# 45454       False               False  False  False      False  False  False
# 45640       False               False  False  False      False  False  False
# 81785       False               False  False  False      False  False  False
# 61029       False               False  False  False      False  False  False
# 62533       False               False  False  False      False  False  False
# 60148       False               False  False  False      False  False  False
# 60009       False               False  False  False      False  False  False
# 46623       False               False  False  False      False  False  False
# 59582       False               False  False  False      False  False  False
# 62268       False               False  False  False      False  False  False
#
#          TTM  AS68K    GEN  AICDB  AIC7XXX  DRM_BRIDGE  PINCTRL  BTBCM  \
# cid
# 71259  False   True  False   True     True       False     True  False
# 53111  False   True  False   True     True       False     True  False
# 45350  False   True  False   True     True       False     True  False
# 71037  False   True  False   True     True       False     True  False
# 37984  False   True  False   True     True       False     True  False
# 83702  False   True  False   True     True       False     True  False
# 44666  False  False  False   True     True       False     True  False
# 61453  False  False  False   True     True       False     True  False
# 79099  False  False  False   True     True       False     True  False
# 61805  False  False  False   True     True       False     True  False
# 45454  False   True  False  False     True       False     True  False
# 45640  False  False  False   True     True       False     True  False
# 81785  False  False  False   True     True       False     True  False
# 61029  False  False  False   True     True       False     True  False
# 62533  False   True  False   True     True       False    False  False
# 60148  False  False  False   True     True       False     True  False
# 60009  False  False  False   True     True       False     True  False
# 46623  False   True  False   True     True       False    False  False
# 59582  False  False   True  False     True       False     True  False
# 62268  False  False  False   True     True       False     True  False
#
#        BPFFANCY   DEVM   I2C  nb_patterns
# cid
# 71259     False  False  True            5
# 53111     False  False  True            5
# 45350     False  False  True            5
# 71037     False  False  True            5
# 37984     False  False  True            5
# 83702     False  False  True            5
# 44666     False  False  True            4
# 61453     False  False  True            4
# 79099     False  False  True            4
# 61805     False  False  True            4
# 45454     False  False  True            4
# 45640     False  False  True            4
# 81785     False  False  True            4
# 61029     False  False  True            4
# 62533     False  False  True            4
# 60148     False  False  True            4
# 60009     False  False  True            4
# 46623     False  False  True            4
# 59582     False  False  True            4
# 62268     False  False  True            4

# %%
#error_pattern['CONFIG_NLS_DEFAULT'].value_counts().plot(kind='bar')
error_pattern.query('nb_patterns == 0')
# Out:
#        BLACKLIGHT  CONFIG_NLS_DEFAULT  CRC32   V4L2  OVERFLOW2   ULPI    PCM  \
# cid
# 68569       False               False  False  False      False  False  False
# 87044       False               False  False  False      False  False  False
#
#          TTM  AS68K    GEN  AICDB  AIC7XXX  DRM_BRIDGE  PINCTRL  BTBCM  \
# cid
# 68569  False  False  False  False    False       False    False  False
# 87044  False  False  False  False    False       False    False  False
#
#        BPFFANCY   DEVM    I2C  nb_patterns
# cid
# 68569     False  False  False            0
# 87044     False  False  False            0

# %%
error_pattern.query('nb_patterns == 0').shape
# Out:
# (2, 19)

# %%
for cid in error_pattern.query('nb_patterns == 0').index:
    print ("configuration cid", cid)
    #if cid in suspicious_cids:
    #    print("false positive failure")
    #    continue
    
    error_message = errorlogs.query("cid == " + str(cid))['error_message'].values
    for err in error_message[0].splitlines():
        if "Cyclomatic" not in err:
            print (err)
    print()
    print()
    print()
    
# 74459, 74460, 74461, 74463, 74464
# Out:
# configuration cid 68569
# warning: (DRM_RADEON && DRM_AMDGPU && DRM_NOUVEAU && DRM_I915 && DRM_GMA500 && DRM_SHMOBILE && DRM_TILCDC && DRM_FSL_DCU && DRM_TINYDRM && DRM_PARADE_PS8622 && FB_BACKLIGHT && FB_ARMCLCD && FB_MX3 && USB_APPLEDISPLAY && FB_OLPC_DCON && ACPI_CMPC && SAMSUNG_Q10) selects BACKLIGHT_CLASS_DEVICE which has unmet direct dependencies (HAS_IOMEM && BACKLIGHT_LCD_SUPPORT)
# warning: (TS5500 && ADB_PMU_LED && ATH5K && ATH9K && ATH9K_HTC && CARL9170_LEDS && BRCMSMAC && IWLEGACY && INPUT_WISTRON_BTNS && SENSORS_APPLESMC && IR_REDRAT3 && IR_WINBOND_CIR && IR_TTUSBIR && BACKLIGHT_ADP8860 && BACKLIGHT_ADP8870 && BACKLIGHT_LM3639 && SND_USB_TONEPORT && HID_LENOVO && HID_WACOM && ACER_WMI && ASUS_LAPTOP && DELL_LAPTOP && FUJITSU_LAPTOP && HP_ACCEL && THINKPAD_ACPI && EEEPC_LAPTOP && ASUS_WMI && ASUS_WIRELESS && ACPI_TOSHIBA && SAMSUNG_LAPTOP) selects LEDS_CLASS which has unmet direct dependencies (NEW_LEDS)
# warning: (DRM_RADEON && DRM_AMDGPU && DRM_NOUVEAU && DRM_I915 && DRM_GMA500 && DRM_SHMOBILE && DRM_TILCDC && DRM_FSL_DCU && DRM_TINYDRM && DRM_PARADE_PS8622 && FB_BACKLIGHT && FB_ARMCLCD && FB_MX3 && USB_APPLEDISPLAY && FB_OLPC_DCON && ACPI_CMPC && SAMSUNG_Q10) selects BACKLIGHT_CLASS_DEVICE which has unmet direct dependencies (HAS_IOMEM && BACKLIGHT_LCD_SUPPORT)
# warning: (TS5500 && ADB_PMU_LED && ATH5K && ATH9K && ATH9K_HTC && CARL9170_LEDS && BRCMSMAC && IWLEGACY && INPUT_WISTRON_BTNS && SENSORS_APPLESMC && IR_REDRAT3 && IR_WINBOND_CIR && IR_TTUSBIR && BACKLIGHT_ADP8860 && BACKLIGHT_ADP8870 && BACKLIGHT_LM3639 && SND_USB_TONEPORT && HID_LENOVO && HID_WACOM && ACER_WMI && ASUS_LAPTOP && DELL_LAPTOP && FUJITSU_LAPTOP && HP_ACCEL && THINKPAD_ACPI && EEEPC_LAPTOP && ASUS_WMI && ASUS_WIRELESS && ACPI_TOSHIBA && SAMSUNG_LAPTOP) selects LEDS_CLASS which has unmet direct dependencies (NEW_LEDS)
# drivers/input/input-leds.o: In function `input_leds_disconnect':
# input-leds.c:(.text+0x66): undefined reference to `led_classdev_unregister'
# drivers/input/input-leds.o: In function `input_leds_connect':
# input-leds.c:(.text+0x4cc): undefined reference to `of_led_classdev_register'
# input-leds.c:(.text+0x568): undefined reference to `led_classdev_unregister'
# drivers/staging/greybus/light.o: In function `gb_lights_light_register':
# light.c:(.text+0x64c): undefined reference to `of_led_classdev_register'
# drivers/staging/greybus/light.o: In function `__gb_lights_led_unregister.constprop.9':
# light.c:(.text+0x730): undefined reference to `led_classdev_unregister'
# drivers/platform/x86/fujitsu-laptop.o: In function `acpi_fujitsu_laptop_add':
# fujitsu-laptop.c:(.text+0x11be): undefined reference to `devm_of_led_classdev_register'
# fujitsu-laptop.c:(.text+0x1246): undefined reference to `devm_of_led_classdev_register'
# fujitsu-laptop.c:(.text+0x12c0): undefined reference to `devm_of_led_classdev_register'
# fujitsu-laptop.c:(.text+0x1334): undefined reference to `devm_of_led_classdev_register'
# make: *** [vmlinux] Error 1
#
#
#
# configuration cid 87044
# In file included from arch/x86/entry/common.c:17:0:
# arch/x86/entry/common.c: In function ‘tracehook_report_syscall_exit’:
# ./include/linux/tracehook.h:126:13: note: userspace variable will be forcibly initialized
#    siginfo_t info;
#              ^~~~
# arch/x86/entry/common.c: In function ‘syscall_slow_exit_work’:
# ./include/linux/tracehook.h:126:13: note: userspace variable will be forcibly initialized
# kernel/sysctl_binary.c: In function ‘SYSC_sysctl’:
# kernel/sysctl_binary.c:1413:23: note: userspace variable will be forcibly initialized
#   struct __sysctl_args tmp;
#                        ^~~
# arch/x86/entry/vsyscall/vsyscall_64.c: In function ‘write_ok_or_segv’:
# arch/x86/entry/vsyscall/vsyscall_64.c:105:13: note: userspace variable will be forcibly initialized
#    siginfo_t info;
#              ^~~~
# arch/x86/kernel/signal.c: In function ‘do_signal’:
# arch/x86/kernel/signal.c:806:17: note: userspace variable will be forcibly initialized
#   struct ksignal ksig;
#                  ^~~~
# kernel/ptrace.c: In function ‘ptrace_peek_siginfo’:
# kernel/ptrace.c:712:13: note: userspace variable will be forcibly initialized
#    siginfo_t info;
#              ^~~~
# kernel/ptrace.c: In function ‘ptrace_request’:
# kernel/ptrace.c:1076:16: note: userspace variable will be forcibly initialized
#    struct iovec kiov;
#                 ^~~~
# kernel/ptrace.c:890:12: note: userspace variable will be forcibly initialized
#   siginfo_t siginfo, *si;
#             ^~~~~~~
# kernel/ptrace.c: In function ‘compat_ptrace_request’:
# kernel/ptrace.c:1242:16: note: userspace variable will be forcibly initialized
#    struct iovec kiov;
#                 ^~~~
# kernel/ptrace.c:1197:12: note: userspace variable will be forcibly initialized
#   siginfo_t siginfo;
#             ^~~~~~~
# arch/x86/kernel/traps.c: In function ‘do_error_trap’:
# arch/x86/kernel/traps.c:303:12: note: userspace variable will be forcibly initialized
#   siginfo_t info;
#             ^~~~
# arch/x86/kernel/traps.c: In function ‘math_error’:
# arch/x86/kernel/traps.c:827:12: note: userspace variable will be forcibly initialized
#   siginfo_t info;
#             ^~~~
# kernel/signal.c: In function ‘SYSC_rt_sigtimedwait’:
# kernel/signal.c:2851:12: note: userspace variable will be forcibly initialized
#   siginfo_t info;
#             ^~~~
# kernel/signal.c: In function ‘C_SYSC_rt_sigtimedwait’:
# kernel/signal.c:2884:12: note: userspace variable will be forcibly initialized
#   siginfo_t info;
#             ^~~~
# kernel/signal.c: In function ‘SYSC_kill’:
# kernel/signal.c:2917:17: note: userspace variable will be forcibly initialized
#   struct siginfo info;
#                  ^~~~
# kernel/signal.c: In function ‘SYSC_rt_sigqueueinfo’:
# kernel/signal.c:3030:12: note: userspace variable will be forcibly initialized
#   siginfo_t info;
#             ^~~~
# kernel/signal.c: In function ‘SYSC_rt_tgsigqueueinfo’:
# kernel/signal.c:3071:12: note: userspace variable will be forcibly initialized
#   siginfo_t info;
#             ^~~~
# kernel/signal.c: In function ‘SYSC_sigaltstack’:
# kernel/signal.c:3209:15: note: userspace variable will be forcibly initialized
#   stack_t new, old;
#                ^~~
# kernel/signal.c:3209:10: note: userspace variable will be forcibly initialized
#   stack_t new, old;
#           ^~~
# kernel/signal.c: In function ‘C_SYSC_sigaltstack’:
# kernel/signal.c:3248:15: note: userspace variable will be forcibly initialized
#   stack_t uss, uoss;
#                ^~~~
# kernel/signal.c:3248:10: note: userspace variable will be forcibly initialized
#   stack_t uss, uoss;
#           ^~~
# kernel/signal.c: In function ‘do_notify_parent_cldstop’:
# kernel/signal.c:1706:17: note: userspace variable will be forcibly initialized
#   struct siginfo info;
#                  ^~~~
# kernel/signal.c: In function ‘ptrace_do_notify’:
# kernel/signal.c:1929:12: note: userspace variable will be forcibly initialized
#   siginfo_t info;
#             ^~~~
# kernel/signal.c: In function ‘do_notify_parent’:
# kernel/signal.c:1602:17: note: userspace variable will be forcibly initialized
#   struct siginfo info;
#                  ^~~~
# kernel/signal.c: In function ‘restore_altstack’:
# kernel/signal.c:3222:10: note: userspace variable will be forcibly initialized
#   stack_t new;
#           ^~~
# arch/x86/mm/fault.c: In function ‘force_sig_info_fault’:
# arch/x86/mm/fault.c:231:12: note: userspace variable will be forcibly initialized
#   siginfo_t info;
#             ^~~~
# In file included from fs/read_write.c:12:0:
# fs/read_write.c: In function ‘iov_iter_iovec’:
# ./include/linux/uio.h:69:9: note: userspace variable will be forcibly initialized
#   return (struct iovec) {
#          ^
# fs/read_write.c: In function ‘new_sync_read’:
# fs/read_write.c:391:15: note: userspace variable will be forcibly initialized
#   struct iovec iov = { .iov_base = buf, .iov_len = len };
#                ^~~
# fs/read_write.c: In function ‘new_sync_write’:
# fs/read_write.c:448:15: note: userspace variable will be forcibly initialized
#   struct iovec iov = { .iov_base = (void __user *)buf, .iov_len = len };
#                ^~~
# In file included from fs/read_write.c:12:0:
# fs/read_write.c: In function ‘do_loop_readv_writev’:
# ./include/linux/uio.h:69:9: note: userspace variable will be forcibly initialized
#   return (struct iovec) {
#          ^
# fs/read_write.c:666:16: note: userspace variable will be forcibly initialized
#    struct iovec iovec = iov_iter_iovec(iter);
#                 ^~~~~
# fs/exec.c: In function ‘compat_do_execve’:
# fs/exec.c:1857:22: note: userspace variable will be forcibly initialized
#   struct user_arg_ptr envp = {
#                       ^~~~
# fs/exec.c:1853:22: note: userspace variable will be forcibly initialized
#   struct user_arg_ptr argv = {
#                       ^~~~
# fs/exec.c: In function ‘compat_do_execveat’:
# fs/exec.c:1873:22: note: userspace variable will be forcibly initialized
#   struct user_arg_ptr envp = {
#                       ^~~~
# fs/exec.c:1869:22: note: userspace variable will be forcibly initialized
#   struct user_arg_ptr argv = {
#                       ^~~~
# fs/fcntl.c: In function ‘send_sigio_to_task’:
# fs/fcntl.c:733:13: note: userspace variable will be forcibly initialized
#    siginfo_t si;
#              ^~
# fs/splice.c: In function ‘vmsplice_to_user’:
# fs/splice.c:1265:21: note: userspace variable will be forcibly initialized
#   struct splice_desc sd;
#                      ^~
# arch/x86/kernel/ptrace.c: In function ‘send_sigtrap’:
# arch/x86/kernel/ptrace.c:1396:17: note: userspace variable will be forcibly initialized
#   struct siginfo info;
#                  ^~~~
# arch/x86/kernel/stacktrace.c: In function ‘__save_stack_trace_user’:
# arch/x86/kernel/stacktrace.c:207:27: note: userspace variable will be forcibly initialized
#    struct stack_frame_user frame;
#                            ^~~~~
# arch/x86/kernel/stacktrace.c: In function ‘save_stack_trace_user’:
# arch/x86/kernel/stacktrace.c:207:27: note: userspace variable will be forcibly initialized
# mm/memory-failure.c: In function ‘kill_proc’:
# mm/memory-failure.c:184:17: note: userspace variable will be forcibly initialized
#   struct siginfo si;
#                  ^~
# ipc/mqueue.c: In function ‘SYSC_mq_notify’:
# ipc/mqueue.c:1345:18: note: userspace variable will be forcibly initialized
#   struct sigevent n, *p = NULL;
#                   ^
# ipc/mqueue.c: In function ‘C_SYSC_mq_notify’:
# ipc/mqueue.c:1520:18: note: userspace variable will be forcibly initialized
#   struct sigevent n, *p = NULL;
#                   ^
# ipc/mqueue.c: In function ‘__do_notify’:
# ipc/mqueue.c:635:18: note: userspace variable will be forcibly initialized
#    struct siginfo sig_i;
#                   ^~~~~
# security/keys/keyring.c: In function ‘keyring_read’:
# security/keys/keyring.c:461:39: note: userspace variable will be forcibly initialized
#   struct keyring_read_iterator_context ctx;
#                                        ^~~
# security/keys/keyctl.c: In function ‘keyctl_instantiate_key’:
# security/keys/keyctl.c:1122:16: note: userspace variable will be forcibly initialized
#    struct iovec iov;
#                 ^~~
# kernel/time/posix-timers.c: In function ‘SYSC_timer_create’:
# kernel/time/posix-timers.c:577:14: note: userspace variable will be forcibly initialized
#    sigevent_t event;
#               ^~~~~
# kernel/time/posix-timers.c: In function ‘C_SYSC_timer_create’:
# kernel/time/posix-timers.c:592:14: note: userspace variable will be forcibly initialized
#    sigevent_t event;
#               ^~~~~
# In file included from block/bio.c:22:0:
# block/bio.c: In function ‘iov_iter_iovec’:
# ./include/linux/uio.h:69:9: note: userspace variable will be forcibly initialized
#   return (struct iovec) {
#          ^
# block/bio.c: In function ‘bio_map_user_iov’:
# ./include/linux/uio.h:69:9: note: userspace variable will be forcibly initialized
# ./include/linux/uio.h:69:9: note: userspace variable will be forcibly initialized
# block/bio.c:1329:15: note: userspace variable will be forcibly initialized
#   struct iovec iov;
#                ^~~
# block/blk-map.c: In function ‘blk_rq_map_user’:
# block/blk-map.c:160:15: note: userspace variable will be forcibly initialized
#   struct iovec iov;
#                ^~~
# block/ioctl.c: In function ‘blkpg_ioctl’:
# block/ioctl.c:18:25: note: userspace variable will be forcibly initialized
#   struct blkpg_ioctl_arg a;
#                          ^
# block/scsi_ioctl.c: In function ‘scsi_cmd_ioctl’:
# block/scsi_ioctl.c:612:21: note: userspace variable will be forcibly initialized
#     struct sg_io_hdr hdr;
#                      ^~~
# block/scsi_ioctl.c:611:33: note: userspace variable will be forcibly initialized
#     struct cdrom_generic_command cgc;
#                                  ^~~
# block/scsi_ioctl.c:597:21: note: userspace variable will be forcibly initialized
#     struct sg_io_hdr hdr;
#                      ^~~
# kernel/seccomp.c: In function ‘seccomp_send_sigsys’:
# kernel/seccomp.c:511:17: note: userspace variable will be forcibly initialized
#   struct siginfo info;
#                  ^~~~
# kernel/seccomp.c: In function ‘__seccomp_filter’:
# kernel/seccomp.c:648:14: note: userspace variable will be forcibly initialized
#     siginfo_t info;
#               ^~~~
# kernel/seccomp.c: In function ‘seccomp_prepare_user_filter’:
# kernel/seccomp.c:395:20: note: userspace variable will be forcibly initialized
#   struct sock_fprog fprog;
#                     ^~~~~
# fs/ncpfs/ioctl.c: In function ‘__ncp_ioctl’:
# fs/ncpfs/ioctl.c:742:33: note: userspace variable will be forcibly initialized
#     struct ncp_privatedata_ioctl user;
#                                  ^~~~
# fs/ncpfs/ioctl.c:693:33: note: userspace variable will be forcibly initialized
#     struct ncp_privatedata_ioctl user;
#                                  ^~~~
# fs/ncpfs/ioctl.c:642:32: note: userspace variable will be forcibly initialized
#     struct ncp_objectname_ioctl user;
#                                 ^~~~
# fs/ncpfs/ioctl.c:613:32: note: userspace variable will be forcibly initialized
#     struct ncp_objectname_ioctl user;
#                                 ^~~~
# fs/ncpfs/ioctl.c:262:27: note: userspace variable will be forcibly initialized
#   struct ncp_ioctl_request request;
#                            ^~~~~~~
# sound/core/control.c: In function ‘snd_ctl_elem_list’:
# sound/core/control.c:750:27: note: userspace variable will be forcibly initialized
#   struct snd_ctl_elem_list list;
#                            ^~~~
# sound/core/hwdep.c: In function ‘snd_hwdep_dsp_load’:
# sound/core/hwdep.c:223:29: note: userspace variable will be forcibly initialized
#   struct snd_hwdep_dsp_image info;
#                              ^~~~
# sound/core/pcm_native.c: In function ‘snd_pcm_capture_ioctl1’:
# sound/core/pcm_native.c:2971:20: note: userspace variable will be forcibly initialized
#    struct snd_xfern xfern;
#                     ^~~~~
# sound/core/pcm_native.c:2955:20: note: userspace variable will be forcibly initialized
#    struct snd_xferi xferi;
#                     ^~~~~
# sound/core/pcm_native.c: In function ‘snd_pcm_playback_ioctl1’:
# sound/core/pcm_native.c:2891:20: note: userspace variable will be forcibly initialized
#    struct snd_xfern xfern;
#                     ^~~~~
# sound/core/pcm_native.c:2875:20: note: userspace variable will be forcibly initialized
#    struct snd_xferi xferi;
#                     ^~~~~
# drivers/block/floppy.c: In function ‘raw_cmd_copyout’:
# drivers/block/floppy.c:3073:25: note: userspace variable will be forcibly initialized
#    struct floppy_raw_cmd cmd = *ptr;
#                          ^~~
# drivers/cdrom/cdrom.c: In function ‘mmc_ioctl_cdrom_read_audio’:
# drivers/cdrom/cdrom.c:3006:26: note: userspace variable will be forcibly initialized
#   struct cdrom_read_audio ra;
#                           ^~
# net/socket.c: In function ‘SYSC_sendto’:
# net/socket.c:1712:15: note: userspace variable will be forcibly initialized
#   struct iovec iov;
#                ^~~
# net/socket.c: In function ‘SYSC_recvfrom’:
# net/socket.c:1765:15: note: userspace variable will be forcibly initialized
#   struct iovec iov;
#                ^~~
# net/socket.c: In function ‘dev_ifconf’:
# net/socket.c:2703:16: note: userspace variable will be forcibly initialized
#   struct ifconf ifc;
#                 ^~~
# net/socket.c: In function ‘compat_sioc_ifmap’:
# net/socket.c:3005:15: note: userspace variable will be forcibly initialized
#   struct ifreq ifr;
#                ^~~
# net/socket.c: In function ‘bond_ioctl’:
# net/socket.c:2915:15: note: userspace variable will be forcibly initialized
#   struct ifreq kifr;
#                ^~~~
# net/socket.c: In function ‘routing_ioctl’:
# net/socket.c:3077:17: note: userspace variable will be forcibly initialized
#   struct rtentry r4;
#                  ^~
# net/socket.c: In function ‘copy_msghdr_from_user’:
# net/socket.c:1913:21: note: userspace variable will be forcibly initialized
#   struct user_msghdr msg;
#                      ^~~
# net/8021q/vlan_dev.c: In function ‘vlan_dev_ioctl’:
# net/8021q/vlan_dev.c:361:15: note: userspace variable will be forcibly initialized
#   struct ifreq ifrr;
#                ^~~~
# net/appletalk/aarp.c: In function ‘aarp_send_probe_phase1’:
# net/appletalk/aarp.c:447:15: note: userspace variable will be forcibly initialized
#   struct ifreq atreq;
#                ^~~~~
# drivers/char/ipmi/ipmi_devintf.c: In function ‘ipmi_ioctl’:
# drivers/char/ipmi/ipmi_devintf.c:375:25: note: userspace variable will be forcibly initialized
#    struct ipmi_recv      rsp;
#                          ^~~
# drivers/char/ipmi/ipmi_devintf.c:358:27: note: userspace variable will be forcibly initialized
#    struct ipmi_req_settime req;
#                            ^~~
# drivers/char/ipmi/ipmi_devintf.c:342:19: note: userspace variable will be forcibly initialized
#    struct ipmi_req req;
#                    ^~~
# drivers/char/ipmi/ipmi_devintf.c: In function ‘compat_ipmi_ioctl’:
# drivers/char/ipmi/ipmi_devintf.c:798:22: note: userspace variable will be forcibly initialized
#    struct ipmi_recv   recv64;
#                       ^~~~~~
# drivers/char/ipmi/ipmi_devintf.c:784:27: note: userspace variable will be forcibly initialized
#    struct ipmi_req_settime sp;
#                            ^~
# drivers/char/ipmi/ipmi_devintf.c:770:19: note: userspace variable will be forcibly initialized
#    struct ipmi_req rp;
#                    ^~
# net/appletalk/ddp.c: In function ‘atrtr_ioctl’:
# net/appletalk/ddp.c:879:17: note: userspace variable will be forcibly initialized
#   struct rtentry rt;
#                  ^~
# net/appletalk/ddp.c: In function ‘atif_ioctl’:
# net/appletalk/ddp.c:671:17: note: userspace variable will be forcibly initialized
#   struct rtentry rtdef;
#                  ^~~~~
# net/appletalk/ddp.c:664:15: note: userspace variable will be forcibly initialized
#   struct ifreq atreq;
#                ^~~~~
# lib/iov_iter.c: In function ‘iov_iter_fault_in_readable’:
# lib/iov_iter.c:418:15: note: userspace variable will be forcibly initialized
#   struct iovec v;
#                ^
# lib/iov_iter.c: In function ‘_copy_to_iter’:
# lib/iov_iter.c:565:32: note: userspace variable will be forcibly initialized
#   iterate_and_advance(i, bytes, v,
#                                 ^
# lib/iov_iter.c:119:17: note: in definition of macro ‘iterate_and_advance’
#     struct iovec v;    \
#                  ^
# lib/iov_iter.c: In function ‘_copy_from_iter’:
# lib/iov_iter.c:585:32: note: userspace variable will be forcibly initialized
#   iterate_and_advance(i, bytes, v,
#                                 ^
# lib/iov_iter.c:119:17: note: in definition of macro ‘iterate_and_advance’
#     struct iovec v;    \
#                  ^
# lib/iov_iter.c: In function ‘_copy_from_iter_nocache’:
# lib/iov_iter.c:630:32: note: userspace variable will be forcibly initialized
#   iterate_and_advance(i, bytes, v,
#                                 ^
# lib/iov_iter.c:119:17: note: in definition of macro ‘iterate_and_advance’
#     struct iovec v;    \
#                  ^
# lib/iov_iter.c: In function ‘_copy_from_iter_flushcache’:
# lib/iov_iter.c:650:32: note: userspace variable will be forcibly initialized
#   iterate_and_advance(i, bytes, v,
#                                 ^
# lib/iov_iter.c:119:17: note: in definition of macro ‘iterate_and_advance’
#     struct iovec v;    \
#                  ^
# lib/iov_iter.c: In function ‘iov_iter_zero’:
# lib/iov_iter.c:761:32: note: userspace variable will be forcibly initialized
#   iterate_and_advance(i, bytes, v,
#                                 ^
# lib/iov_iter.c:119:17: note: in definition of macro ‘iterate_and_advance’
#     struct iovec v;    \
#                  ^
# lib/iov_iter.c: In function ‘iov_iter_copy_from_user_atomic’:
# lib/iov_iter.c:784:30: note: userspace variable will be forcibly initialized
#   iterate_all_kinds(i, bytes, v,
#                               ^
# lib/iov_iter.c:88:17: note: in definition of macro ‘iterate_all_kinds’
#     struct iovec v;    \
#                  ^
# lib/iov_iter.c: In function ‘iov_iter_advance’:
# lib/iov_iter.c:847:31: note: userspace variable will be forcibly initialized
#   iterate_and_advance(i, size, v, 0, 0, 0)
#                                ^
# lib/iov_iter.c:119:17: note: in definition of macro ‘iterate_and_advance’
#     struct iovec v;    \
#                  ^
# lib/iov_iter.c: In function ‘_copy_from_iter_full’:
# lib/iov_iter.c:608:30: note: userspace variable will be forcibly initialized
#   iterate_all_kinds(i, bytes, v, ({
#                               ^
# lib/iov_iter.c:88:17: note: in definition of macro ‘iterate_all_kinds’
#     struct iovec v;    \
#                  ^
# lib/iov_iter.c: In function ‘_copy_from_iter_full_nocache’:
# lib/iov_iter.c:673:30: note: userspace variable will be forcibly initialized
#   iterate_all_kinds(i, bytes, v, ({
#                               ^
# lib/iov_iter.c:88:17: note: in definition of macro ‘iterate_all_kinds’
#     struct iovec v;    \
#                  ^
# lib/iov_iter.c: In function ‘iov_iter_alignment’:
# lib/iov_iter.c:982:29: note: userspace variable will be forcibly initialized
#   iterate_all_kinds(i, size, v,
#                              ^
# lib/iov_iter.c:88:17: note: in definition of macro ‘iterate_all_kinds’
#     struct iovec v;    \
#                  ^
# lib/iov_iter.c: In function ‘iov_iter_gap_alignment’:
# lib/iov_iter.c:1001:29: note: userspace variable will be forcibly initialized
#   iterate_all_kinds(i, size, v,
#                              ^
# lib/iov_iter.c:88:17: note: in definition of macro ‘iterate_all_kinds’
#     struct iovec v;    \
#                  ^
# lib/iov_iter.c: In function ‘iov_iter_get_pages’:
# lib/iov_iter.c:1066:32: note: userspace variable will be forcibly initialized
#   iterate_all_kinds(i, maxsize, v, ({
#                                 ^
# lib/iov_iter.c:88:17: note: in definition of macro ‘iterate_all_kinds’
#     struct iovec v;    \
#                  ^
# lib/iov_iter.c: In function ‘iov_iter_get_pages_alloc’:
# lib/iov_iter.c:1143:32: note: userspace variable will be forcibly initialized
#   iterate_all_kinds(i, maxsize, v, ({
#                                 ^
# lib/iov_iter.c:88:17: note: in definition of macro ‘iterate_all_kinds’
#     struct iovec v;    \
#                  ^
# lib/iov_iter.c: In function ‘csum_and_copy_from_iter’:
# lib/iov_iter.c:1188:32: note: userspace variable will be forcibly initialized
#   iterate_and_advance(i, bytes, v, ({
#                                 ^
# lib/iov_iter.c:119:17: note: in definition of macro ‘iterate_and_advance’
#     struct iovec v;    \
#                  ^
# lib/iov_iter.c: In function ‘csum_and_copy_from_iter_full’:
# lib/iov_iter.c:1232:30: note: userspace variable will be forcibly initialized
#   iterate_all_kinds(i, bytes, v, ({
#                               ^
# lib/iov_iter.c:88:17: note: in definition of macro ‘iterate_all_kinds’
#     struct iovec v;    \
#                  ^
# lib/iov_iter.c: In function ‘csum_and_copy_to_iter’:
# lib/iov_iter.c:1275:32: note: userspace variable will be forcibly initialized
#   iterate_and_advance(i, bytes, v, ({
#                                 ^
# lib/iov_iter.c:119:17: note: in definition of macro ‘iterate_and_advance’
#     struct iovec v;    \
#                  ^
# lib/iov_iter.c: In function ‘iov_iter_npages’:
# lib/iov_iter.c:1327:36: note: userspace variable will be forcibly initialized
#   } else iterate_all_kinds(i, size, v, ({
#                                     ^
# lib/iov_iter.c:88:17: note: in definition of macro ‘iterate_all_kinds’
#     struct iovec v;    \
#                  ^
# net/core/sock.c: In function ‘sock_setsockopt’:
# net/core/sock.c:956:22: note: userspace variable will be forcibly initialized
#     struct sock_fprog fprog;
#                       ^~~~~
# net/core/sock.c:930:22: note: userspace variable will be forcibly initialized
#     struct sock_fprog fprog;
#                       ^~~~~
# net/core/dev_ioctl.c: In function ‘dev_ifconf’:
# net/core/dev_ioctl.c:70:16: note: userspace variable will be forcibly initialized
#   struct ifconf ifc;
#                 ^~~
# net/core/dev_ioctl.c: In function ‘dev_ifname’:
# net/core/dev_ioctl.c:22:15: note: userspace variable will be forcibly initialized
#   struct ifreq ifr;
#                ^~~
# net/core/dev_ioctl.c: In function ‘dev_ioctl’:
# net/core/dev_ioctl.c:425:16: note: userspace variable will be forcibly initialized
#    struct iwreq iwr;
#                 ^~~
# net/core/dev_ioctl.c:399:15: note: userspace variable will be forcibly initialized
#   struct ifreq ifr;
#                ^~~
# fs/eventpoll.c: In function ‘ep_send_events’:
# fs/eventpoll.c:1718:29: note: userspace variable will be forcibly initialized
#   struct ep_send_events_data esed;
#                              ^~~~
# fs/eventpoll.c: In function ‘ep_poll’:
# fs/eventpoll.c:1718:29: note: userspace variable will be forcibly initialized
# net/ieee802154/socket.c: In function ‘ieee802154_dev_ioctl’:
# net/ieee802154/socket.c:135:15: note: userspace variable will be forcibly initialized
#   struct ifreq ifr;
#                ^~~
# In file included from drivers/gpu/drm/i915/i915_trace.h:10:0,
#                  from drivers/gpu/drm/i915/i915_drv.h:3043,
#                  from drivers/gpu/drm/i915/i915_drv.c:49:
# drivers/gpu/drm/i915/intel_drv.h:1727:12: error: ‘intel_backlight_device_register’ defined but not used [-Werror=unused-function]
#  static int intel_backlight_device_register(struct intel_connector *connector)
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cc1: all warnings being treated as errors
# make[4]: *** [drivers/gpu/drm/i915/i915_drv.o] Error 1
# make[4]: *** Waiting for unfinished jobs....
# In file included from drivers/gpu/drm/i915/i915_trace.h:10:0,
#                  from drivers/gpu/drm/i915/i915_drv.h:3043,
#                  from drivers/gpu/drm/i915/i915_irq.c:36:
# drivers/gpu/drm/i915/intel_drv.h:1727:12: error: ‘intel_backlight_device_register’ defined but not used [-Werror=unused-function]
#  static int intel_backlight_device_register(struct intel_connector *connector)
#             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# net/ipx/af_ipx.c: In function ‘ipxitf_ioctl’:
# net/ipx/af_ipx.c:1120:15: note: userspace variable will be forcibly initialized
#   struct ifreq ifr;
#                ^~~
# cc1: all warnings being treated as errors
# make[4]: *** [drivers/gpu/drm/i915/i915_irq.o] Error 1
# make[3]: *** [drivers/gpu/drm/i915] Error 2
# make[3]: *** Waiting for unfinished jobs....
# net/ipx/ipx_route.c: In function ‘ipxrtr_ioctl’:
# net/ipx/ipx_route.c:260:17: note: userspace variable will be forcibly initialized
#   struct rtentry rt; /* Use these to behave like 'other' stacks */
#                  ^~
# make[2]: *** [drivers/gpu/drm] Error 2
# make[1]: *** [drivers/gpu] Error 2
# make: *** [drivers] Error 2
# make: *** Waiting for unfinished jobs....
# fs/compat_ioctl.c: In function ‘do_i2c_smbus_ioctl’:
# fs/compat_ioctl.c:746:4: note: userspace variable will be forcibly initialized
#   } v;
#     ^
# net/packet/af_packet.c: In function ‘fanout_set_data_cbpf’:
# net/packet/af_packet.c:1571:20: note: userspace variable will be forcibly initialized
#   struct sock_fprog fprog;
#                     ^~~~~
# net/compat.c: In function ‘get_compat_bpf_fprog’:
# net/compat.c:317:20: note: userspace variable will be forcibly initialized
#   struct sock_fprog f;
#                     ^
# fs/xfs/xfs_ioctl.c: In function ‘xfs_ioc_bulkstat’:
# fs/xfs/xfs_ioctl.c:750:21: note: userspace variable will be forcibly initialized
#   xfs_fsop_bulkreq_t bulkreq;
#                      ^~~~~~~
# fs/xfs/xfs_ioctl.c: In function ‘xfs_attrlist_by_handle’:
# fs/xfs/xfs_ioctl.c:394:32: note: userspace variable will be forcibly initialized
#   xfs_fsop_attrlist_handlereq_t al_hreq;
#                                 ^~~~~~~
# fs/xfs/xfs_ioctl.c: In function ‘xfs_fssetdm_by_handle’:
# fs/xfs/xfs_ioctl.c:349:29: note: userspace variable will be forcibly initialized
#   xfs_fsop_setdm_handlereq_t dmhreq;
#                              ^~~~~~
# fs/xfs/xfs_ioctl.c: In function ‘xfs_attrmulti_by_handle’:
# fs/xfs/xfs_ioctl.c:520:33: note: userspace variable will be forcibly initialized
#   xfs_fsop_attrmulti_handlereq_t am_hreq;
#                                  ^~~~~~~
# fs/xfs/xfs_ioctl.c: In function ‘xfs_file_ioctl’:
# fs/xfs/xfs_ioctl.c:1908:24: note: userspace variable will be forcibly initialized
#    xfs_fsop_handlereq_t hreq;
#                         ^~~~
# fs/xfs/xfs_ioctl.c:1898:24: note: userspace variable will be forcibly initialized
#    xfs_fsop_handlereq_t hreq;
#                         ^~~~
# fs/xfs/xfs_ioctl.c:1891:24: note: userspace variable will be forcibly initialized
#    xfs_fsop_handlereq_t hreq;
#                         ^~~~
# fs/xfs/xfs_itable.c: In function ‘xfs_bulkstat’:
# fs/xfs/xfs_itable.c:367:31: note: userspace variable will be forcibly initialized
#   struct xfs_bulkstat_agichunk ac;
#                                ^~
False  False  False      False  False  False
#
#          TTM  AS68K    GEN  AICDB  AIC7XXX  DRM_BRIDGE  PINCTRL  BTBCM  \
# cid
# 31459  False   True  False  False    False       False     True  False
# 40197  False   True  False  False    False       False     True  False
# 54887  False   True  False  False    False       False     True  False
# 66532  False   True  False  False    False       False     True  False
# 53352  False   True  False  False    False       False     True  False
# 71787  False   True  False  False    False       False     True  False
# 73349  False   True  False  False    False       False     True  False
# 49111  False   True  False  False    False       False     True  False
# 46934  False   True  False  False    False       False     True  False
# 59966  False   True  False  False    False       False     True  False
# 40525  False   True  False  False    False       False     True  False
# 46178  False   True  False  False    False       False     True  False
# 76001  False   True  False  False    False       False     True  False
# 36983  False   True  False  False    False       False     True  False
# 83767  False   True  False  False    False       False     True  False
# 38853  False   True  False  False    False       False     True  False
# 83185  False   True  False  False    False       False     True  False
# 38689  False   True  False  False    False       False     True  False
# 60469  False   True  False  False    False       False     True  False
# 74602  False   True  False  False    False       False    False  False
# 77227  False   True  False  False    False       False    False  False
# 73375  False   True  False  False    False       False    False  False
# 81346  False   True  False  False    False       False    False  False
# 71136  False   True  False  False    False       False    False  False
# 69167  False   True  False  False    False       False    False  False
# 68816  False   True  False  False    False       False    False  False
# 83227  False   True  False  False    False       False    False  False
# 74853  False   True  False  False    False       False    False  False
# 62720  False   True  False  False    False       False    False  False
# 83941  False   True  False  False    False       False    False  False
# 61253  False   True  False  False    False       False    False  False
# 53378  False   True  False  False    False       False    False  False
# 57747  False   True  False  False    False       False    False  False
# 56188  False   True  False  False    False       False    False  False
# 32474  False   True  False  False    False       False    False  False
# 33200  False   True  False  False    False       False    False  False
# 34416  False   True  False  False    False       False    False  False
# 34578  False   True  False  False    False       False    False  False
# 35163  False   True  False  False    False       False    False  False
# 35239  False   True  False  False    False       False    False  False
# 39245  False   True  False  False    False       False    False  False
# 40563  False   True  False  False    False       False    False  False
# 47557  False   True  False  False    False       False    False  False
# 49982  False   True  False  False    False       False    False  False
# 50036  False   True  False  False    False       False    False  False
# 50525  False   True  False  False    False       False    False  False
# 50720  False   True  False  False    False       False    False  False
# 52467  False   True  False  False    False       False    False  False
# 53234  False   True  False  False    False       False    False  False
# 31492  False   True  False  False    False       False    False  False
# 54865  False   True  False  False    False       False    False  False
# 86030  False   True  False  False    False       False    False  False
#
#        BPFFANCY   DEVM   I2C  nb_patterns
# cid
# 31459     False  False  True            3
# 40197     False  False  True            3
# 54887     False  False  True            3
# 66532     False  False  True            3
# 53352     False  False  True            3
# 71787     False  False  True            3
# 73349     False  False  True            3
# 49111     False  False  True            3
# 46934     False  False  True            3
# 59966     False  False  True            3
# 40525     False  False  True            3
# 46178     False  False  True            3
# 76001     False  False  True            3
# 36983     False  False  True            3
# 83767     False  False  True            3
# 38853     False  False  True            3
# 83185     False  False  True            3
# 38689     False  False  True            3
# 60469     False  False  True            3
# 74602     False  False  True            2
# 77227     False  False  True            2
# 73375     False  False  True            2
# 81346     False  False  True            2
# 71136     False  False  True            2
# 69167     False  False  True            2
# 68816     False  False  True            2
# 83227     False  False  True            2
# 74853     False  False  True            2
# 62720     False  False  True            2
# 83941     False  False  True            2
# 61253     False  False  True            2
# 53378     False  False  True            2
# 57747     False  False  True            2
# 56188     False  False  True            2
# 32474     False  False  True            2
# 33200     False  False  True            2
# 34416     False  False  True            2
# 34578     False  False  True            2
# 35163     False  False  True            2
# 35239     False  False  True            2
# 39245     False  False  True            2
# 40563     False  False  True            2
# 47557     False  False  True            2
# 49982     False  False  True            2
# 50036     False  False  True            2
# 50525     False  False  True            2
# 50720     False  False  True            2
# 52467     False  False  True            2
# 53234     False  False  True            2
# 31492     False  False  True            2
# 54865     False  False  True            2
# 86030     False  False  True            2

# %%
#error_pattern.query('nb_patterns == 2 & (as68k == False & AIC7XXX == True)').sort_values(by='nb_patterns', ascending=False)
error_pattern.query('nb_patterns >= 2 & (AS68K == False & AICDB == False & AIC7XXX == True)').sort_values(by='nb_patterns', ascending=False)
# Out:
#        BLACKLIGHT  CONFIG_NLS_DEFAULT  CRC32   V4L2  OVERFLOW2   ULPI    PCM  \
# cid
#
# 89854  False  False  False  False    False       False     True  False
# 99203  False  False   True  False    False       False    False  False
# 96892  False  False   True  False    False       False    False  False
# 66920  False  False  False  False    False       False    False  False
# ...      ...    ...    ...    ...      ...         ...      ...    ...
# 49050  False  False   True  False    False       False    False  False
# 45759  False  False  False  False    False       False    False  False
# 62070  False  False   True  False    False       False    False  False
# 45156  False  False   True  False    False       False    False  False
# 44020  False  False   True  False    False       False    False  False
# 42696  False  False  False  False    False       False    False  False
# 41663  False  False  False  False    False       False    False  False
# 41619  False  False   True  False    False       False    False  False
# 37227  False  False  False  False    False       False     True  False
# 35459  False  False   True  False    False       False    False  False
# 52421  False  False  False  False    False       False    False  False
# 53458  False  False   True  False    False       False    False  False
# 53651  False  False  False  False    False       False    False  False
# 53836  False  False  False  False    False       False    False  False
# 61649  False  False   True  False    False       False    False  False
# 60939   True  False   True  False    False       False    False  False
# 60593  False  False  False  False    False       False    False  False
# 60230  False  False  False  False    False       False    False  False
# 59440  False  False  False  False    False       False    False  False
# 58323  False  False   True  False    False       False    False  False
# 56433  False  False   True  False    False       False    False  False
# 56432  False  False   True  False    False       False    False  False
# 56072  False  False   True  False    False       False    False  False
# 55385  False  False  False  False    False       False    False  False
# 55110  False  False   True  False    False       False    False  False
# 55001  False  False  False  False    False       False    False  False
# 54129  False  False  False  False    False       False    False  False
# 54126  False  False  False  False    False       False    False  False
# 54125  False  False  False  False    False       False    False  False
# 60609  False  False  False  False    False       False    False  False
#
#        BPFFANCY   DEVM    I2C  nb_patterns
# cid
# 99287     False  False   True            3
# 47369     False  False   True            3
# 61554     False  False   True            3
# 66910     False  False   True            3
# 60735     False  False   True            3
# 31080     False  False   True            3
# 57668     False  False   True            3
# 56341     False  False   True            3
# 75995     False  False   True            3
# 78821     False  False   True            3
# 80885     False  False   True            3
# 50915     False  False   True            3
# 82919     False  False   True            3
# 84163     False  False   True            3
# 49868     False  False   True            3
# 80545     False  False   True            3
# 63879     False  False   True            3
# 87074     False  False   True            3
# 44201     False  False   True            3
# 44678     False  False   True            3
# 32214     False  False   True            3
# 33137     False  False   True            3
# 45222     False  False   True            3
# 45564     False  False   True            3
# 64467     False  False   True            2
# 64163     False  False   True            2
# 89854     False  False   True            2
# 99203     False  False   True            2
# 96892     False  False   True            2
# 66920     False  False   True            2
# ...         ...    ...    ...          ...
# 49050     False  False   True            2
# 45759     False  False   True            2
# 62070     False  False   True            2
# 45156     False  False   True            2
# 44020     False  False   True            2
# 42696     False  False   True            2
# 41663     False  False   True            2
# 41619     False  False   True            2
# 37227     False  False   True            2
# 35459     False  False   True            2
# 52421     False  False   True            2
# 53458     False  False   True            2
# 53651     False  False   True            2
# 53836     False  False   True            2
# 61649     False  False   True            2
# 60939     False  False  False            2
# 60593     False  False   True            2
# 60230     False  False   True            2
# 59440     False  False   True            2
# 58323     False  False   True            2
# 56433     False  False   True            2
# 56432     False  False   True            2
# 56072     False  False   True            2
# 55385     False  False   True            2
# 55110     False  False   True            2
# 55001     False  False   True            2
# 54129     False  False   True            2
# 54126     False  False   True            2
# 54125     False  False   True            2
# 60609     False  False   True            2
#
# [92 rows x 19 columns]

# %%
# masking effect
error_pattern.query('nb_patterns >= 2 & CONFIG_NLS_DEFAULT == True').sort_values(by='nb_patterns', ascending=False)
error_pattern.query('CONFIG_NLS_DEFAULT == True').sort_values(by='nb_patterns', ascending=False)
# Out:
#        BLACKLIGHT  CONFIG_NLS_DEFAULT  CRC32   V4L2  OVERFLOW2   ULPI    PCM  \
# cid
#
EN  AICDB  AIC7XXX  DRM_BRIDGE  PINCTRL  BTBCM  \
# cid
# 59582  False  False  True  False     True       False     True  False
# 67934  False  False  True  False     True       False     True  False
# 68861  False  False  True  False     True       False     True  False
# 59320  False  False  True  False     True       False    False  False
# 31080  False  False  True  False    False       False     True  False
# 75995  False  False  True  False    False       False     True  False
# 50915  False  False  True  False    False       False     True  False
# 80545  False  False  True  False    False       False     True  False
# 49868  False  False  True  False    False       False     True  False
# 84163  False  False  True  False    False       False     True  False
# 87074  False  False  True  False    False       False     True  False
# 44201  False  False  True  False    False       False     True  False
# 63879  False  False  True  False    False       False     True  False
# 44678  False  False  True  False    False       False     True  False
# 61554  False  False  True  False    False       False     True  False
# 47369  False  False  True  False    False       False     True  False
# 45222  False  False  True  False    False       False     True  False
# 60735  False  False  True  False    False       False     True  False
# 66910  False  False  True  False    False       False     True  False
# 78821  False  False  True  False    False       False     True  False
# 99287  False  False  True  False    False       False     True  False
# 53739  False  False  True  False     True       False    False  False
# 80885  False  False  True  False    False       False     True  False
# 68353  False  False  True  False     True       False    False  False
# 56341  False  False  True  False    False       False     True  False
# 58573  False  False  True  False     True       False    False  False
# 33137  False  False  True  False    False       False     True  False
# 82919  False  False  True  False    False       False     True  False
# 58323  False  False  True  False    False       False    False  False
# 47318  False  False  True  False    False       False    False  False
# ...      ...    ...   ...    ...      ...         ...      ...    ...
# 61556  False  False  True  False    False       False    False  False
# 52419  False  False  True  False    False       False    False  False
# 57479  False  False  True  False    False       False    False  False
# 52489  False  False  True  False    False       False    False  False
# 52988  False  False  True  False    False       False    False  False
# 53767  False  False  True  False    False       False    False  False
# 54464  False  False  True  False    False       False    False  False
# 54708  False  False  True  False    False       False    False  False
# 55077  False  False  True  False    False       False    False  False
# 55168  False  False  True  False    False       False    False  False
# 55726  False  False  True  False    False       False    False  False
# 56558  False  False  True  False    False       False    False  False
# 56559  False  False  True  False    False       False    False  False
# 57008  False  False  True  False    False       False    False  False
# 57388  False  False  True  False    False       False    False  False
# 57837  False  False  True  False    False       False    False  False
# 61238  False  False  True  False    False       False    False  False
# 57953  False  False  True  False    False       False    False  False
# 58039  False  False  True  False    False       False    False  False
# 58382  False  False  True  False    False       False    False  False
# 58727  False  False  True  False    False       False    False  False
# 58942  False  False  True  False    False       False    False  False
# 59486  False  False  True  False    False       False    False  False
# 59638  False  False  True  False    False       False    False  False
# 59854  False  False  True  False    False       False    False  False
# 60397  False  False  True  False    False       False    False  False
# 60643  False  False  True  False    False       False    False  False
# 60730  False  False  True  False    False       False    False  False
# 61146  False  False  True  False    False       False    False  False
# 99909  False  False  True  False    False       False    False  False
#
#        BPFFANCY   DEVM    I2C  nb_patterns
# cid
# 59582     False  False   True            4
# 67934     False  False   True            4
# 68861     False  False   True            4
# 59320     False  False   True            3
# 31080     False  False   True            3
# 75995     False  False   True            3
# 50915     False  False   True            3
# 80545     False  False   True            3
# 49868     False  False   True            3
# 84163     False  False   True            3
# 87074     False  False   True            3
# 44201     False  False   True            3
# 63879     False  False   True            3
# 49868       False               False  False  False      False  False  False
# 47369       False               False  False  False      False  False  False
# 45564       False               False  False  False      False  False  False
# 45222       False               False  False  False      False  False  False
# 44678       False               False  False  False      False  False  False
# 44201       False               False  False  False      False  False  False
# 33137       False               False  False  False      False  False  False
# 99287       False               False  False  False      False  False  False
# 37227       False               False  False  False      False  False  False
# 89854       False               False  False  False      False  False  False
# 98605       False               False  False  False      False  False  False
#
#          TTM  AS68K    GEN  AICDB  AIC7XXX  DRM_BRIDGE  PINCTRL  BTBCM  \
# cid
# 31080  False  False   True  False    False       False     True  False
# 32214  False  False  False  False    False       False     True  False
# 87074  False  False   True  False    False       False     True  False
# 84163  False  False   True  False    False       False     True  False
# 82919  False  False   True  False    False       False     True  False
# 80885  False  False   True  False    False       False     True  False
# 80545  False  False   True  False    False       False     True  False
# 78821  False  False   True  False    False       False     True  False
# 75995  False  False   True  False    False       False     True  False
# 66910  False  False   True  False    False       False     True  False
# 63879  False  False   True  False    False       False     True  False
# 61554  False  False   True  False    False       False     True  False
# 60735  False  False   True  False    False       False     True  False
# 57668  False  False  False  False    False       False     True  False
# 56341  False  False   True  False    False       False     True  False
# 50915  False  False   True  False    False       False     True  False
# 49868  False  False   True  False    False       False     True  False
# 47369  False  False   True  False    False       False     True  False
# 45564   True  False  False  False    False       False     True  False
# 45222  False  False   True  False    False       False     True  False
# 44678  False  False   True  False    False       False     True  False
# 44201  False  False   True  False    False       False     True  False
# 33137  False  False   True  False    False       False     True  False
# 99287  False  False   True  False    False       False     True  False
# 37227  False  False  False  False    False       False     True  False
# 89854  False  False  False  False    False       False     True  False
# 98605  False  False  False  False    False       False     True  False
#
#        BPFFANCY   DEVM    I2C  nb_patterns
# cid
# 31080     False  False   True            3
# 32214     False  False   True            3
# 87074     False  False   True            3
# 84163     False  False   True            3
# 82919     False  False   True            3
# 80885     False  False   True            3
# 80545     False  False   True            3
# 78821     False  False   True            3
# 75995     False  False   True            3
# 66910     False  False   True            3
# 63879     False  False   True            3
# 61554     False  False   True            3
# 60735     False  False   True            3
# 57668     False  False   True            3
# 56341     False  False   True            3
# 50915     False  False   True            3
# 49868     False  False   True            3
# 47369     False  False   True            3
# 45564     False  False   True            3
# 45222     False  False   True            3
# 44678     False  False   True            3
# 44201     False  False   True            3
# 33137     False  False   True            3
# 99287     False  False   True            3
# 37227     False  False   True            2
# 89854     False  False   True            2
# 98605     False  False  False            1

# %%
# nice masking effect!
error_pattern.query('I2C == True & (PINCTRL == False & AS68K == False & AIC7XXX == False)').sort_values(by='nb_patterns', ascending=False)
# Out:
#        BLACKLIGHT  CONFIG_NLS_DEFAULT  CRC32   V4L2  OVERFLOW2   ULPI    PCM  \
# cid
# 30730       False               False  False  False       True  False  False
# 35459       False               False  False  False      False  False  False
# 61649       False               False  False  False      False  False  False
# 62070       False               False  False  False      False  False  False
# 62326       False               False  False  False       True  False  False
# 63355       False               False  False  False       True  False  False
# 64163       False               False  False   True      False  False  False
# 64467       False               False  False  False       True  False  False
# 66920       False               False  False  False       True  False  False
# 66938        True               False  False  False      False  False  False
# 66968       False               False  False  False      False  False  False
# 68645       False               False  False  False       True  False  False
# 71360       False               False  False  False      False  False  False
# 93416  False  False   True  False    False       False    False  False
# 96223  False  False   True  False    False       False    False  False
# ...      ...    ...    ...    ...      ...         ...      ...    ...
# 41619  False  False   True  False    False       False    False  False
# 41663  False  False  False  False    False       False    False  False
# 42696  False  False  False  False    False       False    False  False
# 44020  False  False   True  False    False       False    False  False
# 45156  False  False   True  False    False       False    False  False
# 45759  False  False  False  False    False       False    False  False
# 47318  False  False   True  False    False       False    False  False
# 49050  False  False   True  False    False       False    False  False
# 49463  False  False  False  False    False       False    False  False
# 49900  False  False  False  False    False       False    False  False
# 50153  False  False  False  False    False       False    False  False
# 50863  False  False   True  False    False       False    False  False
# 50936  False  False  False  False    False       False    False  False
# 51876  False  False   True  False    False       False    False  False
# 52421  False  False  False  False    False       False    False  False
# 53458  False  False   True  False    False       False    False  False
# 53651  False  False  False  False    False       False    False  False
# 53836  False  False  False  False    False       False    False  False
# 54125  False  False  False  False    False       False    False  False
# 54126  False  False  False  False    False       False    False  False
# 54129  False  False  False  False    False       False    False  False
# 55001  False  False  False  False    False       False    False  False
# 55110  False  False   True  False    False       False    False  False
# 55385  False  False  False  False    False       False    False  False
# 56072  False  False   True  False    False       False    False  False
# 56432  False  False   True  False    False       False    False  False
# 56433  False  False   True  False    False       False    False  False
# 58323  False  False   True  False    False       False    False  False
# 99203  False  False   True  False    False       False    False  False
# 96730  False  False  False  False    False       False    False  False
#
#        BPFFANCY   DEVM   I2C  nb_patterns
# cid
# 30730     False  False  True            2
# 35459     False  False  True            2
# 61649     False  False  True            2
# 62070     False  False  True            2
# 62326     False  False  True            2
# 63355     False  False  True            2
# 64163     False  False  True            2
# 64467     False  False  True            2
# 66920     False  False  True            2
# 66938     False  False  True            2
# 66968     False  False  True            2
# 68645     False  False  True            2
# 71360     False  False  True            2
# 74184     False  False  True            2
# 76319     False  False  True            2
# 77090     False  False  True            2
# 77279     False  False  True            2
# 78428     False  False  True            2
# 78680     False  False  True            2
# 78740     False  False  True            2
# 79995     False  False  True            2
# 80298     False  False  True            2
# 81448     False  False  True            2
# 84244     False  False  True            2
# 85136     False  False  True            2
# 85751     False  False  True            2
# 85917     False  False  True            2
# 89701     False  False  True            2
# 93416     False  False  True            2
# 96223     False  False  True            2
# ...         ...    ...   ...          ...
# 41619     False  False  True            2
# 41663     False  False  True            2
# 42696     False  False  True            2
# 44020     False  False  True            2
# 45156     False  False  True            2
# 45759     False  False  True            2
# 47318     False  False  True            2
# 49050     False  False  True            2
# 49463     False  False  True            2
# 49900     False  False  True            2
# 50153     False  False  True            2
# 50863     False  False  True            2
# 50936     False  False  True            2
# 51876     False  False  True            2
# 52421     False  False  True            2
# 53458     False  False  True            2
# 53651     False  False  True            2
# 53836     False  False  True            2
# 54125     False  False  True            2
# 54126     False  False  True            2
# 54129     False  False  True            2
# 55001     False  False  True            2
# 55110     False  False  True            2
# 55385     False  False  True            2
# 56072     False  False  True            2
# 56432     False  False  True            2
# 56433     False  False  True            2
# 58323     False  False  True            2
# 99203     False  False  True            2
# 96730     False  False  True            1
#
# [65 rows x 19 columns]
