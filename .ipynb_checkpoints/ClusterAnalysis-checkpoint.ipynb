# %%
import pandas as pd

errorlogs = pd.read_pickle('errlogs.pkl')
# found thanks to clustering! 
suspicious_cids = [70715, 70716, 74459, 74460, 74461, 74463, 74464]
for cid in suspicious_cids:
    errorlogs = errorlogs[errorlogs.cid != cid]

# %%
len(errorlogs)
# Out:
# 3531

# %%
errorlogs.loc[3]['error_message']
# Out:
# 'make[4]: flex: Command not found\nmake[4]: *** [/TuxML/linux-4.13.3/drivers/scsi/aic7xxx/aicasm//aicasm_scan.c] Error 127\nmake[3]: *** [drivers/scsi/aic7xxx/aicasm/aicasm] Error 2\nmake[2]: *** [drivers/scsi/aic7xxx] Error 2\nmake[1]: *** [drivers/scsi] Error 2\nmake[1]: *** Waiting for unfinished jobs....\nmake: *** [drivers] Error 2\n'

# %%
from enum import Enum, auto
class ErrorLog(Enum):
    BLACKLIGHT = auto(),
    BLACKLIGHT2 = auto(),
    CONFIG_NLS_DEFAULT = auto(),
    CRC32_CLUSTER = auto(),
    V4L2 = auto(), 
    OVERFLOW2 = auto(), 
    ULPI = auto(), 
    PCM = auto(),
    TTM = auto(), 
    AS68K = auto(), 
    GEN = auto(), 
    AICDB = auto(), 
    AIC7XXX = auto(),
    DRM_BRIDGE_CLUSTER = auto(),
    PINCTRL_CLUSTER = auto(), 
    BTBCM = auto(),
    BPFFANCY = auto(), 
    DEVM = auto(), 
    DEVM2 = auto(), 
    I2C_CLUSTER = auto() 
    


    

patterns = { ErrorLog.BLACKLIGHT : "undefined reference to `backlight_device",
            ErrorLog.BLACKLIGHT2: 'error: ‘intel_backlight_device_register’', # 'intel_backlight_device_register', # cid 87044 does not match BACKLIGHT 
            ErrorLog.CONFIG_NLS_DEFAULT : "CONFIG_NLS_DEFAULT",
            ErrorLog.CRC32_CLUSTER : 'undefined reference to `crc32', 
            ErrorLog.V4L2 : 'undefined reference to `v4l2',
            ErrorLog.OVERFLOW2 : '__read_overflow2',
            ErrorLog.ULPI : 'undefined reference to `ulpi', # 100-126K dataset
            ErrorLog.PCM : 'undefined reference to `atmel_pcm_dma_platform', # 100-126K dataset
            ErrorLog.TTM : 'undefined reference to `ttm', 
            ErrorLog.AS68K: 'as68k: not found',
            ErrorLog.GEN : 'undefined reference to `gen_pool', 
            ErrorLog.AIC7XXX: '[drivers/scsi/aic7xxx/aicasm/aicasm] Error 2', #'drivers/scsi/aic7xxx',
            ErrorLog.AICDB : 'aicdb.h: No such file or directory', 
            ErrorLog.DRM_BRIDGE_CLUSTER : 'undefined reference to `drm_panel_bridge_add', 
            ErrorLog.PINCTRL_CLUSTER : '[drivers/pinctrl/pinctrl-mcp23s08.o] Error', #'pinctrl-mcp23s08', # loosely pattern (too general?)
            ErrorLog.BTBCM : 'undefined reference to `btbcm_set_bdaddr', 
            ErrorLog.BPFFANCY : 'bpf-fancy', # loosely pattern (too general?)
            ErrorLog.DEVM : 'undefined reference to `__devm_regmap',
            ErrorLog.I2C_CLUSTER: 'error: implicit declaration of function ‘i2c_get_adapter’', #'i2c_get_adapter',
            ErrorLog.DEVM2 : 'undefined reference to `devm_of_led'
           }

pattern_name = [name for name, member in ErrorLog.__members__.items()]
# TODO: instead of having True/False values for each pattern column name, 
# let's have a single column with cluster(s) values
error_pattern = pd.DataFrame(columns=pattern_name, index=errorlogs['cid'])
error_pattern.fillna(False, inplace=True)

for i, errorlog in errorlogs.iterrows():
    error = errorlog['error_message']
    cid = errorlog['cid']
    for k, p in patterns.items():
        if (p in error):
            error_pattern.loc[cid][k.name] = True
            # TODO: error_pattern.loc[cid]['cluster_error'] = k.name
            #print (k.name, "found in configuration", cid)

# %%
# same, except we use the first error message (and only it)
# it mimics basic Linux build process
# see discussion here: https://github.com/TuxML/compilation-analysis/issues/1#issuecomment-488711237

pattern_name = [name for name, member in ErrorLog.__members__.items()]
error_patternfirst = pd.DataFrame(columns=pattern_name, index=errorlogs['cid'])
error_patternfirst.fillna(False, inplace=True)

for i, errorlog in errorlogs.iterrows():
    error = errorlog['error_message']
    cid = errorlog['cid']
    #print(cid)
    for err in error.splitlines():
        found = False
        for k, p in patterns.items():
            if found:
                break
            if (p in err):
                error_patternfirst.loc[cid][k.name] = True
                found = True
                #print (k, "found")
        if found:
            break
    #for k, p in patterns.items():
    #    if (p in error):
    #        error_patternfirst.loc[cid][k.name] = True
            #print (k.name, "found in configuration", cid)

# %%
error_patternfirst
# Out:
#        BLACKLIGHT  BLACKLIGHT2  CONFIG_NLS_DEFAULT  CRC32_CLUSTER   V4L2  \
# cid
# 30699       False        False               False          False  False
# 30700       False        False               False          False  False
# 30704       False        False               False          False  False
# 30717       False        False               False          False  False
# 30718       False        False               False          False  False
# 30722       False        False               False          False  False
# 30726       False        False               False          False  False
# 30730       False        False               False          False  False
# 30731       False        False               False          False  False
# 30737       False        False               False          False  False
# 30806       False        False               False          False  False
# 30811       False        False               False          False  False
# 30821       False        False               False          False  False
# 30837       False        False               False          False  False
# 30849       False        False               False          False  False
# 30879       False        False               False          False  False
# 30886       False        False               False          False  False
# 30891       False        False               False          False  False
# 30901       False        False               False          False  False
# 30904       False        False               False          False  False
# 30917       False        False               False          False  False
# 30927       False        False               False          False  False
# 30959       False        False               False          False  False
# 30961       False        False               False          False  False
# 30962       False        False               False          False  False
# 30964       False        False               False          False  False
# 30971       False        False               False          False  False
# 30989       False        False               False          False  False
# 31012       False        False               False          False  False
# 31025       False        False               False          False  False
# ...           ...          ...                 ...            ...    ...
# 94536       False        False               False          False  False
# 94539       False        False               False          False  False
# 95092       False        False               False          False  False
# 95173       False        False               False          False  False
# 95288       False        False               False          False  False
# 95447       False        False               False          False  False
# 95777       False        False               False          False  False
# 95951       False        False               False          False  False
# 96223       False        False               False          False  False
# 96730       False        False               False          False  False
# 96814       False        False               False          False  False
# 96892       False        False               False          False  False
# 96958       False        False               False          False  False
# 97161       False        False               False          False  False
# 97234       False        False               False          False  False
# 97330       False        False               False          False   True
# 97876       False        False               False          False  False
# 98147       False        False               False          False  False
# 98161       False        False               False          False  False
# 98215        True        False               False          False  False
# 98314       False        False               False          False  False
# 98510       False        False               False          False  False
# 98511       False        False               False          False  False
# 98605       False        False               False          False  False
# 98902       False        False               False          False  False
# 98920       False        False               False          False  False
# 99203       False        False               False          False  False
# 99287       False        False               False          False  False
# 99909       False        False               False          False  False
# 99949       False        False                True          False  False
#
#        OVERFLOW2   ULPI    PCM    TTM  AS68K    GEN  AICDB  AIC7XXX  \
# cid
# 30699      False  False  False  False   True  False  False    False
# 30700      False  False  False  False   True  False  False    False
# 30704      False  False  False  False  False  False  False     True
# 30717      False  False  False  False  False  False  False     True
# 30718      False  False  False  False  False  False  False     True
# 30722      False  False  False  False  False  False  False     True
# 30726      False  False  False  False  False  False  False     True
# 30730       True  False  False  False  False  False  False    False
# 30731      False  False  False  False  False  False  False     True
# 30737      False  False  False  False  False  False  False     True
# 30806      False  False  False  False  False  False  False     True
# 30811      False  False  False  False  False  False  False     True
# 30821      False  False  False  False  False   True  False    False
# 30837       True  False  False  False  False  False  False    False
# 30849      False  False  False  False  False  False  False     True
# 30879      False  False  False  False  False  False  False     True
# 30886      False  False  False  False  False  False  False     True
# 30891      False  False  False  False  False  False  False     True
# 30901      False  False  False  False  False  False  False     True
# 30904      False  False  False  False  False  False  False     True
# 30917      False  False  False  False  False  False  False     True
# 30927      False  False  False  False  False  False  False     True
# 30959      False  False  False  False  False  False  False     True
# 30961      False  False  False  False   True  False  False    False
# 30962      False  False  False  False   True  False  False    False
# 30964      False  False  False  False  False  False  False     True
# 30971      False  False  False  False  False  False  False     True
# 30989      False  False  False  False   True  False  False    False
# 31012      False  False  False  False  False  False  False     True
# 31025      False  False  False  False   True  False  False    False
# ...          ...    ...    ...    ...    ...    ...    ...      ...
# 94536      False  False  False  False  False   True  False    False
# 94539      False  False  False   True  False  False  False    False
# 95092      False  False  False  False  False   True  False    False
# 95173      False  False  False  False  False   True  False    False
# 95288      False  False  False  False  False   True  False    False
# 95447      False  False  False   True  False  False  False    False
# 95777      False  False  False  False  False   True  False    False
# 95951      False  False  False  False  False   True  False    False
# 96223      False  False  False  False  False   True  False    False
# 96730      False  False  False  False  False  False  False    False
# 96814      False  False  False  False  False   True  False    False
# 96892      False  False  False  False  False   True  False    False
# 96958      False  False  False  False  False   True  False    False
# 97161      False  False  False  False  False   True  False    False
# 97234      False  False  False  False  False   True  False    False
# 97330      False  False  False  False  False  False  False    False
# 97876      False  False  False  False  False   True  False    False
# 98147      False  False  False  False  False   True  False    False
# 98161      False  False  False  False  False   True  False    False
# 98215      False  False  False  False  False  False  False    False
# 98314      False  False  False  False  False   True  False    False
# 98510      False  False  False  False  False   True  False    False
# 98511      False  False  False  False  False   True  False    False
# 98605      False  False  False  False  False  False  False    False
# 98902      False  False  False  False  False   True  False    False
# 98920      False  False  False  False  False   True  False    False
# 99203      False  False  False  False  False   True  False    False
# 99287      False  False  False  False  False   True  False    False
# 99909      False  False  False  False  False   True  False    False
# 99949      False  False  False  False  False  False  False    False
#
#        DRM_BRIDGE_CLUSTER  PINCTRL_CLUSTER  BTBCM  BPFFANCY   DEVM  DEVM2  \
# cid
# 30699               False            False  False     False  False  False
# 30700               False            False  False     False  False  False
# 30704               False            False  False     False  False  False
# 30717               False            False  False     False  False  False
# 30718               False            False  False     False  False  False
# 30722               False            False  False     False  False  False
# 30726               False            False  False     False  False  False
# 30730               False            False  False     False  False  False
# 30731               False            False  False     False  False  False
# 30737               False            False  False     False  False  False
# 30806               False            False  False     False  False  False
# 30811               False            False  False     False  False  False
# 30821               False            False  False     False  False  False
# 30837               False            False  False     False  False  False
# 30849               False            False  False     False  False  False
# 30879               False            False  False     False  False  False
# 30886               False            False  False     False  False  False
# 30891               False            False  False     False  False  False
# 30901               False            False  False     False  False  False
# 30904               False            False  False     False  False  False
# 30917               False            False  False     False  False  False
# 30927               False            False  False     False  False  False
# 30959               False            False  False     False  False  False
# 30961               False            False  False     False  False  False
# 30962               False            False  False     False  False  False
# 30964               False            False  False     False  False  False
# 30971               False            False  False     False  False  False
# 30989               False            False  False     False  False  False
# 31012               False            False  False     False  False  False
# 31025               False            False  False     False  False  False
# ...                   ...              ...    ...       ...    ...    ...
# 94536               False            False  False     False  False  False
# 94539               False            False  False     False  False  False
# 95092               False            False  False     False  False  False
# 95173               False            False  False     False  False  False
# 95288               False            False  False     False  False  False
# 95447               False            False  False     False  False  False
# 95777               False            False  False     False  False  False
# 95951               False            False  False     False  False  False
# 96223               False            False  False     False  False  False
# 96730               False            False  False     False  False  False
# 96814               False            False  False     False  False  False
# 96892               False            False  False     False  False  False
# 96958               False            False  False     False  False  False
# 97161               False            False  False     False  False  False
# 97234               False            False  False     False  False  False
# 97330               False            False  False     False  False  False
# 97876               False            False  False     False  False  False
# 98147               False            False  False     False  False  False
# 98161               False            False  False     False  False  False
# 98215               False            False  False     False  False  False
# 98314               False            False  False     False  False  False
# 98510               False            False  False     False  False  False
# 98511               False            False  False     False  False  False
# 98605               False             True  False     False  False  False
# 98902               False            False  False     False  False  False
# 98920               False            False  False     False  False  False
# 99203               False            False  False     False  False  False
# 99287               False            False  False     False  False  False
# 99909               False            False  False     False  False  False
# 99949               False            False  False     False  False  False
#
#        I2C_CLUSTER
# cid
# 30699        False
# 30700        False
# 30704        False
# 30717        False
# 30718        False
# 30722        False
# 30726        False
# 30730        False
# 30731        False
# 30737        False
# 30806        False
# 30811        False
# 30821        False
# 30837        False
# 30849        False
# 30879        False
# 30886        False
# 30891        False
# 30901        False
# 30904        False
# 30917        False
# 30927        False
# 30959        False
# 30961        False
# 30962        False
# 30964        False
# 30971        False
# 30989        False
# 31012        False
# 31025        False
# ...            ...
# 94536        False
# 94539        False
# 95092        False
# 95173        False
# 95288        False
# 95447        False
# 95777        False
# 95951        False
# 96223        False
# 96730         True
# 96814        False
# 96892        False
# 96958        False
# 97161        False
# 97234        False
# 97330        False
# 97876        False
# 98147        False
# 98161        False
# 98215        False
# 98314        False
# 98510        False
# 98511        False
# 98605        False
# 98902        False
# 98920        False
# 99203        False
# 99287        False
# 99909        False
# 99949        False
#
# [3531 rows x 20 columns]

# %%
#error_pattern.loc[99949]['BLACKLIGHT'] = True
error_pattern['CONFIG_NLS_DEFAULT'].value_counts()
#error_pattern.hist()
# Out:
# False    3526
# True        5
# Name: CONFIG_NLS_DEFAULT, dtype: int64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline  

def nb_patterns(row):
    return sum(row == True)                    
error_pattern['nb_patterns'] = error_pattern.apply(nb_patterns, axis=1)
pattern_frequencies = error_pattern[pattern_name].apply(nb_patterns, axis=0)
pattern_frequencies.plot(kind='bar')
pattern_frequencies
# Out:
# BLACKLIGHT              10
# BLACKLIGHT2              1
# CONFIG_NLS_DEFAULT       5
# CRC32_CLUSTER            2
# V4L2                     9
# OVERFLOW2               86
# ULPI                     0
# PCM                      0
# TTM                     11
# AS68K                  550
# GEN                    279
# AICDB                 2514
# AIC7XXX               2681
# DRM_BRIDGE_CLUSTER       3
# PINCTRL_CLUSTER          3
# BTBCM                    2
# BPFFANCY                 2
# DEVM                     2
# DEVM2                    1
# I2C_CLUSTER              1
# dtype: int64

# %%
import numpy as np 
# error_patternfirst['nb_patterns'] = error_patternfirst.apply(nb_patterns, axis=1)
patternfirst_frequencies = error_patternfirst[pattern_name].apply(nb_patterns, axis=0)
patternfirst_frequencies.plot(kind='bar')
patternfirst_frequencies
# np.unique(error_patternfirst['nb_patterns'].values)
# Out:
# BLACKLIGHT              10
# BLACKLIGHT2              1
# CONFIG_NLS_DEFAULT       5
# CRC32_CLUSTER            2
# V4L2                     9
# OVERFLOW2               86
# ULPI                     0
# PCM                      0
# TTM                     11
# AS68K                  478
# GEN                    277
# AICDB                 2476
# AIC7XXX                162
# DRM_BRIDGE_CLUSTER       3
# PINCTRL_CLUSTER          3
# BTBCM                    2
# BPFFANCY                 2
# DEVM                     2
# DEVM2                    1
# I2C_CLUSTER              1
# dtype: int64

# %%
error_pattern['nb_patterns'].hist()
error_pattern.query("AIC7XXX == False")['nb_patterns'].hist()

# %%
error_pattern.sort_values(by='nb_patterns', ascending=False)[:20]
# Out:
#        BLACKLIGHT  BLACKLIGHT2  CONFIG_NLS_DEFAULT  CRC32_CLUSTER   V4L2  \
# cid
# 68566       False        False               False          False  False
# 59360       False        False               False          False  False
# 57646       False        False               False          False  False
# 51532       False        False               False          False  False
# 79222       False        False               False          False  False
# 46328       False        False               False          False  False
# 37984       False        False               False          False  False
# 44012       False        False               False          False  False
# 72724       False        False               False          False  False
# 73037       False        False               False          False  False
# 82426       False        False               False          False  False
# 40657       False        False               False          False  False
# 82427       False        False               False          False  False
# 72676       False        False               False          False  False
# 46217       False        False               False          False  False
# 44158       False        False               False          False  False
# 43935       False        False               False          False  False
# 82382       False        False               False          False  False
# 59414       False        False               False          False  False
# 41365       False        False               False          False  False
#
#        OVERFLOW2   ULPI    PCM    TTM  AS68K     ...       AICDB  AIC7XXX  \
# cid                                              ...
# 68566      False  False  False  False   True     ...        True     True
# 59360      False  False  False  False   True     ...        True     True
# 57646      False  False  False  False   True     ...        True     True
# 51532      False  False  False  False   True     ...        True     True
# 79222      False  False  False  False   True     ...        True     True
# 46328      False  False  False  False   True     ...        True     True
# 37984      False  False  False  False   True     ...        True     True
# 44012      False  False  False  False   True     ...        True     True
# 72724      False  False  False  False   True     ...        True     True
# 73037      False  False  False  False   True     ...        True     True
# 82426      False  False  False  False   True     ...        True     True
# 40657      False  False  False  False   True     ...        True     True
# 82427      False  False  False  False   True     ...        True     True
# 72676      False  False  False  False   True     ...        True     True
# 46217      False  False  False  False   True     ...        True     True
# 44158      False  False  False  False   True     ...        True     True
# 43935      False  False  False  False   True     ...        True     True
# 82382      False  False  False  False   True     ...        True     True
# 59414      False  False  False  False   True     ...        True     True
# 41365      False  False  False  False   True     ...        True     True
#
#        DRM_BRIDGE_CLUSTER  PINCTRL_CLUSTER  BTBCM  BPFFANCY   DEVM  DEVM2  \
# cid
# 68566               False            False  False     False  False  False
# 59360               False            False  False     False  False  False
# 57646               False            False  False     False  False  False
# 51532               False            False  False     False  False  False
# 79222               False            False  False     False  False  False
# 46328               False            False  False     False  False  False
# 37984               False            False  False     False  False  False
# 44012               False            False  False     False  False  False
# 72724               False            False  False     False  False  False
# 73037               False            False  False     False  False  False
# 82426               False            False  False     False  False  False
# 40657               False            False  False     False  False  False
# 82427               False            False  False     False  False  False
# 72676               False            False  False     False  False  False
# 46217               False            False  False     False  False  False
# 44158               False            False  False     False  False  False
# 43935               False            False  False     False  False  False
# 82382               False            False  False     False  False  False
# 59414               False            False  False     False  False  False
# 41365               False            False  False     False  False  False
#
#        I2C_CLUSTER  nb_patterns
# cid
# 68566        False            3
# 59360        False            3
# 57646        False            3
# 51532        False            3
# 79222        False            3
# 46328        False            3
# 37984        False            3
# 44012        False            3
# 72724        False            3
# 73037        False            3
# 82426        False            3
# 40657        False            3
# 82427        False            3
# 72676        False            3
# 46217        False            3
# 44158        False            3
# 43935        False            3
# 82382        False            3
# 59414        False            3
# 41365        False            3
#
# [20 rows x 21 columns]

# %%
#error_pattern['CONFIG_NLS_DEFAULT'].value_counts().plot(kind='bar')
error_pattern.query('nb_patterns == 0')
# Out:
# Empty DataFrame
# Columns: [BLACKLIGHT, BLACKLIGHT2, CONFIG_NLS_DEFAULT, CRC32_CLUSTER, V4L2, OVERFLOW2, ULPI, PCM, TTM, AS68K, GEN, AICDB, AIC7XXX, DRM_BRIDGE_CLUSTER, PINCTRL_CLUSTER, BTBCM, BPFFANCY, DEVM, DEVM2, I2C_CLUSTER, nb_patterns]
# Index: []
#
# [0 rows x 21 columns]

# %%
error_pattern.query('nb_patterns == 0').shape
# Out:
# (0, 21)

# %%
for cid in error_pattern.query('nb_patterns == 0').index:
    print ("configuration cid", cid)
    #if cid in suspicious_cids:
    #    print("false positive failure")
    #    continue
    
    error_message = errorlogs.query("cid == " + str(cid))['error_message'].values
    for err in error_message[0].splitlines():
        if "Cyclomatic" not in err:
            print (err)
    print()
    print()
    print()
    
# 74459, 74460, 74461, 74463, 74464

# %%
error_pattern.query('nb_patterns >= 2 & (AS68K == True & AIC7XXX == False)').sort_values(by='nb_patterns', ascending=False)
# Out:
# Empty DataFrame
# Columns: [BLACKLIGHT, BLACKLIGHT2, CONFIG_NLS_DEFAULT, CRC32_CLUSTER, V4L2, OVERFLOW2, ULPI, PCM, TTM, AS68K, GEN, AICDB, AIC7XXX, DRM_BRIDGE_CLUSTER, PINCTRL_CLUSTER, BTBCM, BPFFANCY, DEVM, DEVM2, I2C_CLUSTER, nb_patterns]
# Index: []
#
# [0 rows x 21 columns]

# %%
error_pattern.query('nb_patterns >= 2 & (AS68K == False & AIC7XXX == False & AICDB == True)').sort_values(by='nb_patterns', ascending=False)
# Out:
# Empty DataFrame
# Columns: [BLACKLIGHT, BLACKLIGHT2, CONFIG_NLS_DEFAULT, CRC32_CLUSTER, V4L2, OVERFLOW2, ULPI, PCM, TTM, AS68K, GEN, AICDB, AIC7XXX, DRM_BRIDGE_CLUSTER, PINCTRL_CLUSTER, BTBCM, BPFFANCY, DEVM, DEVM2, I2C_CLUSTER, nb_patterns]
# Index: []
#
# [0 rows x 21 columns]

# %%
#error_pattern.query('nb_patterns == 2 & (as68k == False & AIC7XXX == True)').sort_values(by='nb_patterns', ascending=False)
error_pattern.query('nb_patterns >= 2 & (AS68K == False & AICDB == False & AIC7XXX == True)').sort_values(by='nb_patterns', ascending=False)
# Out:
# Empty DataFrame
# Columns: [BLACKLIGHT, BLACKLIGHT2, CONFIG_NLS_DEFAULT, CRC32_CLUSTER, V4L2, OVERFLOW2, ULPI, PCM, TTM, AS68K, GEN, AICDB, AIC7XXX, DRM_BRIDGE_CLUSTER, PINCTRL_CLUSTER, BTBCM, BPFFANCY, DEVM, DEVM2, I2C_CLUSTER, nb_patterns]
# Index: []
#
# [0 rows x 21 columns]

# %%
error_pattern.query('nb_patterns >= 2 & (AS68K == False & AIC7XXX == False)').sort_values(by='nb_patterns', ascending=False)
# Out:
#        BLACKLIGHT  BLACKLIGHT2  CONFIG_NLS_DEFAULT  CRC32_CLUSTER   V4L2  \
# cid
# 60939       False        False               False          False  False
# 78770       False        False               False          False  False
#
#        OVERFLOW2   ULPI    PCM   TTM  AS68K     ...       AICDB  AIC7XXX  \
# cid                                             ...
# 60939      False  False  False  True  False     ...       False    False
# 78770      False  False  False  True  False     ...       False    False
#
#        DRM_BRIDGE_CLUSTER  PINCTRL_CLUSTER  BTBCM  BPFFANCY   DEVM  DEVM2  \
# cid
# 60939               False            False  False     False  False  False
# 78770               False            False  False     False  False  False
#
#        I2C_CLUSTER  nb_patterns
# cid
# 60939        False            2
# 78770        False            2
#
# [2 rows x 21 columns]

# %%
# masking effect
error_pattern.query('nb_patterns >= 2 & CONFIG_NLS_DEFAULT == True').sort_values(by='nb_patterns', ascending=False)
error_pattern.query('CONFIG_NLS_DEFAULT == True').sort_values(by='nb_patterns', ascending=False)
# Out:
#        BLACKLIGHT  BLACKLIGHT2  CONFIG_NLS_DEFAULT  CRC32_CLUSTER   V4L2  \
# cid
# 44596       False        False                True          False  False
# 52277       False        False                True          False  False
# 60391       False        False                True          False  False
# 62743       False        False                True          False  False
# 99949       False        False                True          False  False
#
#        OVERFLOW2   ULPI    PCM    TTM  AS68K     ...       AICDB  AIC7XXX  \
# cid                                              ...
# 44596      False  False  False  False  False     ...       False    False
# 52277      False  False  False  False  False     ...       False    False
# 60391      False  False  False  False  False     ...       False    False
# 62743      False  False  False  False  False     ...       False    False
# 99949      False  False  False  False  False     ...       False    False
#
#        DRM_BRIDGE_CLUSTER  PINCTRL_CLUSTER  BTBCM  BPFFANCY   DEVM  DEVM2  \
# cid
# 44596               False            False  False     False  False  False
# 52277               False            False  False     False  False  False
# 60391               False            False  False     False  False  False
# 62743               False            False  False     False  False  False
# 99949               False            False  False     False  False  False
#
#        I2C_CLUSTER  nb_patterns
# cid
# 44596        False            1
# 52277        False            1
# 60391        False            1
# 62743        False            1
# 99949        False            1
#
# [5 rows x 21 columns]

# %%
# masking effect
error_pattern.query('GEN == True').sort_values(by='nb_patterns', ascending=False)
# Out:
#        BLACKLIGHT  BLACKLIGHT2  CONFIG_NLS_DEFAULT  CRC32_CLUSTER   V4L2  \
# cid
# 78770       False        False               False          False  False
# 60939       False        False               False          False  False
# 30821       False        False               False          False  False
# 79950       False        False               False          False  False
# 79434       False        False               False          False  False
# 79281       False        False               False          False  False
# 78932       False        False               False          False  False
# 78821       False        False               False          False  False
# 78740       False        False               False          False  False
# 80204       False        False               False          False  False
# 78428       False        False               False          False  False
# 78396       False        False               False          False  False
# 78132       False        False               False          False  False
# 77994       False        False               False          False  False
# 77090       False        False               False          False  False
# 76890       False        False               False          False  False
# 79995       False        False               False          False  False
# 80225       False        False               False          False  False
# 76319       False        False               False          False  False
# 81188       False        False               False          False  False
# 81902       False        False               False          False  False
# 81883       False        False               False          False  False
# 81448       False        False               False          False  False
# 81295       False        False               False          False  False
# 81273       False        False               False          False  False
# 81217       False        False               False          False  False
# 81087       False        False               False          False  False
# 80298       False        False               False          False  False
# 80969       False        False               False          False  False
# 80885       False        False               False          False  False
# ...           ...          ...                 ...            ...    ...
# 51876       False        False               False          False  False
# 52134       False        False               False          False  False
# 52373       False        False               False          False  False
# 52390       False        False               False          False  False
# 52419       False        False               False          False  False
# 52489       False        False               False          False  False
# 52988       False        False               False          False  False
# 53458       False        False               False          False  False
# 53739       False        False               False          False  False
# 53767       False        False               False          False  False
# 54464       False        False               False          False  False
# 54708       False        False               False          False  False
# 55077       False        False               False          False  False
# 55168       False        False               False          False  False
# 58382       False        False               False          False  False
# 55726       False        False               False          False  False
# 56072       False        False               False          False  False
# 56341       False        False               False          False  False
# 56432       False        False               False          False  False
# 56433       False        False               False          False  False
# 56558       False        False               False          False  False
# 56559       False        False               False          False  False
# 57008       False        False               False          False  False
# 57388       False        False               False          False  False
# 57479       False        False               False          False  False
# 57837       False        False               False          False  False
# 57953       False        False               False          False  False
# 58039       False        False               False          False  False
# 58323       False        False               False          False  False
# 99909       False        False               False          False  False
#
#        OVERFLOW2   ULPI    PCM    TTM  AS68K     ...       AICDB  AIC7XXX  \
# cid                                              ...
# 78770      False  False  False   True  False     ...       False    False
# 60939      False  False  False   True  False     ...       False    False
# 30821      False  False  False  False  False     ...       False    False
# 79950      False  False  False  False  False     ...       False    False
# 79434      False  False  False  False  False     ...       False    False
# 79281      False  False  False  False  False     ...       False    False
# 78932      False  False  False  False  False     ...       False    False
# 78821      False  False  False  False  False     ...       False    False
# 78740      False  False  False  False  False     ...       False    False
# 80204      False  False  False  False  False     ...       False    False
# 78428      False  False  False  False  False     ...       False    False
# 78396      False  False  False  False  False     ...       False    False
# 78132      False  False  False  False  False     ...       False    False
# 77994      False  False  False  False  False     ...       False    False
# 77090      False  False  False  False  False     ...       False    False
# 76890      False  False  False  False  False     ...       False    False
# 79995      False  False  False  False  False     ...       False    False
# 80225      False  False  False  False  False     ...       False    False
# 76319      False  False  False  False  False     ...       False    False
# 81188      False  False  False  False  False     ...       False    False
# 81902      False  False  False  False  False     ...       False    False
# 81883      False  False  False  False  False     ...       False    False
# 81448      False  False  False  False  False     ...       False    False
# 81295      False  False  False  False  False     ...       False    False
# 81273      False  False  False  False  False     ...       False    False
# 81217      False  False  False  False  False     ...       False    False
# 81087      False  False  False  False  False     ...       False    False
# 80298      False  False  False  False  False     ...       False    False
# 80969      False  False  False  False  False     ...       False    False
# 80885      False  False  False  False  False     ...       False    False
# ...          ...    ...    ...    ...    ...     ...         ...      ...
# 51876      False  False  False  False  False     ...       False    False
# 52134      False  False  False  False  False     ...       False    False
# 52373      False  False  False  False  False     ...       False    False
# 52390      False  False  False  False  False     ...       False    False
# 52419      False  False  False  False  False     ...       False    False
# 52489      False  False  False  False  False     ...       False    False
# 52988      False  False  False  False  False     ...       False    False
# 53458      False  False  False  False  False     ...       False    False
# 53739      False  False  False  False  False     ...       False    False
# 53767      False  False  False  False  False     ...       False    False
# 54464      False  False  False  False  False     ...       False    False
# 54708      False  False  False  False  False     ...       False    False
# 55077      False  False  False  False  False     ...       False    False
# 55168      False  False  False  False  False     ...       False    False
# 58382      False  False  False  False  False     ...       False    False
# 55726      False  False  False  False  False     ...       False    False
# 56072      False  False  False  False  False     ...       False    False
# 56341      False  False  False  False  False     ...       False    False
# 56432      False  False  False  False  False     ...       False    False
# 56433      False  False  False  False  False     ...       False    False
# 56558      False  False  False  False  False     ...       False    False
# 56559      False  False  False  False  False     ...       False    False
# 57008      False  False  False  False  False     ...       False    False
# 57388      False  False  False  False  False     ...       False    False
# 57479      False  False  False  False  False     ...       False    False
# 57837      False  False  False  False  False     ...       False    False
# 57953      False  False  False  False  False     ...       False    False
# 58039      False  False  False  False  False     ...       False    False
# 58323      False  False  False  False  False     ...       False    False
# 99909      False  False  False  False  False     ...       False    False
#
#        DRM_BRIDGE_CLUSTER  PINCTRL_CLUSTER  BTBCM  BPFFANCY   DEVM  DEVM2  \
# cid
# 78770               False            False  False     False  False  False
# 60939               False            False  False     False  False  False
# 30821               False            False  False     False  False  False
# 79950               False            False  False     False  False  False
# 79434               False            False  False     False  False  False
# 79281               False            False  False     False  False  False
# 78932               False            False  False     False  False  False
# 78821               False            False  False     False  False  False
# 78740               False            False  False     False  False  False
# 80204               False            False  False     False  False  False
# 78428               False            False  False     False  False  False
# 78396               False            False  False     False  False  False
# 78132               False            False  False     False  False  False
# 77994               False            False  False     False  False  False
# 77090               False            False  False     False  False  False
# 76890               False            False  False     False  False  False
# 79995               False            False  False     False  False  False
# 80225               False            False  False     False  False  False
# 76319               False            False  False     False  False  False
# 81188               False            False  False     False  False  False
# 81902               False            False  False     False  False  False
# 81883               False            False  False     False  False  False
# 81448               False            False  False     False  False  False
# 81295               False            False  False     False  False  False
# 81273               False            False  False     False  False  False
# 81217               False            False  False     False  False  False
# 81087               False            False  False     False  False  False
# 80298               False            False  False     False  False  False
# 80969               False            False  False     False  False  False
# 80885               False            False  False     False  False  False
# ...                   ...              ...    ...       ...    ...    ...
# 51876               False            False  False     False  False  False
# 52134               False            False  False     False  False  False
# 52373               False            False  False     False  False  False
# 52390               False            False  False     False  False  False
# 52419               False            False  False     False  False  False
# 52489               False            False  False     False  False  False
# 52988               False            False  False     False  False  False
# 53458               False            False  False     False  False  False
# 53739               False            False  False     False  False  False
# 53767               False            False  False     False  False  False
# 54464               False            False  False     False  False  False
# 54708               False            False  False     False  False  False
# 55077               False            False  False     False  False  False
# 55168               False            False  False     False  False  False
# 58382               False            False  False     False  False  False
# 55726               False            False  False     False  False  False
# 56072               False            False  False     False  False  False
# 56341               False            False  False     False  False  False
# 56432               False            False  False     False  False  False
# 56433               False            False  False     False  False  False
# 56558               False            False  False     False  False  False
# 56559               False            False  False     False  False  False
# 57008               False            False  False     False  False  False
# 57388               False            False  False     False  False  False
# 57479               False            False  False     False  False  False
# 57837               False            False  False     False  False  False
# 57953               False            False  False     False  False  False
# 58039               False            False  False     False  False  False
# 58323               False            False  False     False  False  False
# 99909               False            False  False     False  False  False
#
#        I2C_CLUSTER  nb_patterns
# cid
# 78770        False            2
# 60939        False            2
# 30821        False            1
# 79950        False            1
# 79434        False            1
# 79281        False            1
# 78932        False            1
# 78821        False            1
# 78740        False            1
# 80204        False            1
# 78428        False            1
# 78396        False            1
# 78132        False            1
# 77994        False            1
# 77090        False            1
# 76890        False            1
# 79995        False            1
# 80225        False            1
# 76319        False            1
# 81188        False            1
# 81902        False            1
# 81883        False            1
# 81448        False            1
# 81295        False            1
# 81273        False            1
# 81217        False            1
# 81087        False            1
# 80298        False            1
# 80969        False            1
# 80885        False            1
# ...            ...          ...
# 51876        False            1
# 52134        False            1
# 52373        False            1
# 52390        False            1
# 52419        False            1
# 52489        False            1
# 52988        False            1
# 53458        False            1
# 53739        False            1
# 53767        False            1
# 54464        False            1
# 54708        False            1
# 55077        False            1
# 55168        False            1
# 58382        False            1
# 55726        False            1
# 56072        False            1
# 56341        False            1
# 56432        False            1
# 56433        False            1
# 56558        False            1
# 56559        False            1
# 57008        False            1
# 57388        False            1
# 57479        False            1
# 57837        False            1
# 57953        False            1
# 58039        False            1
# 58323        False            1
# 99909        False            1
#
# [279 rows x 21 columns]

# %%
error_pattern.query('BLACKLIGHT == True').sort_values(by='nb_patterns', ascending=False)
# Out:
#        BLACKLIGHT  BLACKLIGHT2  CONFIG_NLS_DEFAULT  CRC32_CLUSTER   V4L2  \
# cid
# 59503        True        False               False          False  False
# 64086        True        False               False          False  False
# 65670        True        False               False          False  False
# 66938        True        False               False          False  False
# 67750        True        False               False          False  False
# 75145        True        False               False          False  False
# 81720        True        False               False          False  False
# 89618        True        False               False          False  False
# 93674        True        False               False          False  False
# 98215        True        False               False          False  False
#
#        OVERFLOW2   ULPI    PCM    TTM  AS68K     ...       AICDB  AIC7XXX  \
# cid                                              ...
# 59503      False  False  False  False  False     ...       False    False
# 64086      False  False  False  False  False     ...       False    False
# 65670      False  False  False  False  False     ...       False    False
# 66938      False  False  False  False  False     ...       False    False
# 67750      False  False  False  False  False     ...       False    False
# 75145      False  False  False  False  False     ...       False    False
# 81720      False  False  False  False  False     ...       False    False
# 89618      False  False  False  False  False     ...       False    False
# 93674      False  False  False  False  False     ...       False    False
# 98215      False  False  False  False  False     ...       False    False
#
#        DRM_BRIDGE_CLUSTER  PINCTRL_CLUSTER  BTBCM  BPFFANCY   DEVM  DEVM2  \
# cid
# 59503               False            False  False     False  False  False
# 64086               False            False  False     False  False  False
# 65670               False            False  False     False  False  False
# 66938               False            False  False     False  False  False
# 67750               False            False  False     False  False  False
# 75145               False            False  False     False  False  False
# 81720               False            False  False     False  False  False
# 89618               False            False  False     False  False  False
# 93674               False            False  False     False  False  False
# 98215               False            False  False     False  False  False
#
#        I2C_CLUSTER  nb_patterns
# cid
# 59503        False            1
# 64086        False            1
# 65670        False            1
# 66938        False            1
# 67750        False            1
# 75145        False            1
# 81720        False            1
# 89618        False            1
# 93674        False            1
# 98215        False            1
#
# [10 rows x 21 columns]

# %%
# nice masking effect!
error_pattern.query('PINCTRL_CLUSTER == True & (AS68K == False & AIC7XXX == False)').sort_values(by='nb_patterns', ascending=False)
# Out:
#        BLACKLIGHT  BLACKLIGHT2  CONFIG_NLS_DEFAULT  CRC32_CLUSTER   V4L2  \
# cid
# 37227       False        False               False          False  False
# 89854       False        False               False          False  False
# 98605       False        False               False          False  False
#
#        OVERFLOW2   ULPI    PCM    TTM  AS68K     ...       AICDB  AIC7XXX  \
# cid                                              ...
# 37227      False  False  False  False  False     ...       False    False
# 89854      False  False  False  False  False     ...       False    False
# 98605      False  False  False  False  False     ...       False    False
#
#        DRM_BRIDGE_CLUSTER  PINCTRL_CLUSTER  BTBCM  BPFFANCY   DEVM  DEVM2  \
# cid
# 37227               False             True  False     False  False  False
# 89854               False             True  False     False  False  False
# 98605               False             True  False     False  False  False
#
#        I2C_CLUSTER  nb_patterns
# cid
# 37227        False            1
# 89854        False            1
# 98605        False            1
#
# [3 rows x 21 columns]

# %%
# nice masking effect!
error_pattern.query('I2C_CLUSTER == True & (PINCTRL_CLUSTER == False & AS68K == False & AIC7XXX == False)').sort_values(by='nb_patterns', ascending=False)
# Out:
#        BLACKLIGHT  BLACKLIGHT2  CONFIG_NLS_DEFAULT  CRC32_CLUSTER   V4L2  \
# cid
# 96730       False        False               False          False  False
#
#        OVERFLOW2   ULPI    PCM    TTM  AS68K     ...       AICDB  AIC7XXX  \
# cid                                              ...
# 96730      False  False  False  False  False     ...       False    False
#
#        DRM_BRIDGE_CLUSTER  PINCTRL_CLUSTER  BTBCM  BPFFANCY   DEVM  DEVM2  \
# cid
# 96730               False            False  False     False  False  False
#
#        I2C_CLUSTER  nb_patterns
# cid
# 96730         True            1
#
# [1 rows x 21 columns]

# %%
import json
# see Hugo notebook here!
with open("option_columns.json","r") as f:
    option_columns = json.load(f)

# %%
rawtuxdata = pd.read_csv("dataset_after_encoding.csv", dtype={k:"int8" for k in option_columns})
rawtuxdata.info(memory_usage='deep')
rawtuxdata.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69362 entries, 0 to 69361
# Columns: 12654 entries, X86_LOCAL_APIC to cid
# dtypes: float64(6), int64(37), int8(12611)
# memory usage: 857.0 MB
# (69362, 12654)

# %%
set(errorlogs['cid']) - set(rawtuxdata['cid'])
# Out:
# {30699,
#  33833,
#  33836,
#  33837,
#  54125,
#  54126,
#  54127,
#  54128,
#  54129,
#  56432,
#  56558,
#  57249,
#  70614,
#  70665,
#  70709,
#  70710,
#  74227,
#  74233,
#  78892,
#  79033,
#  79141,
#  88152,
#  88817,
#  88909}

# %%
basic_head = ["cid", "time", "date"] # "compile"
compilation_status_column_name = 'compile_success'
size_methods = ["vmlinux", "GZIP-bzImage", "GZIP-vmlinux", "GZIP", "BZIP2-bzImage", 
              "BZIP2-vmlinux", "BZIP2", "LZMA-bzImage", "LZMA-vmlinux", "LZMA", "XZ-bzImage", "XZ-vmlinux", "XZ", 
              "LZO-bzImage", "LZO-vmlinux", "LZO", "LZ4-bzImage", "LZ4-vmlinux", "LZ4"]

# %%
print(str(len(rawtuxdata)) + " before the removal of some entries (those with same configurations)")
# tuxdata.drop_duplicates(subset=tuxdata.columns.difference(['vmlinux']), inplace=True)
rawtuxdata.drop_duplicates(subset=rawtuxdata.columns.difference(size_methods).difference(basic_head), inplace=True)
print(str(len(rawtuxdata)) + " after the removal of some entries (those with same configurations)")
# Out:
# 69362 before the removal of some entries (those with same configurations)
# 69362 after the removal of some entries (those with same configurations)

# %%
cid_errors_not_in_configdata = set(errorlogs['cid']) - set(rawtuxdata['cid'])
for cid in cid_errors_not_in_configdata:
    error_message = errorlogs.query("cid == " + str(cid))['error_message'].values
    for err in error_message[0].splitlines():
        if "Cyclomatic" not in err:
            print (err)
# Out:
# aicasm_symbol.c:48:19: fatal error: aicdb.h: No such file or directory
#  #include "aicdb.h"
#                    ^
# compilation terminated.
# aicasm_gram.tab.c: In function 'yyparse':
# aicasm_gram.tab.c:1628:16: warning: implicit declaration of function 'yylex' [-Wimplicit-function-declaration]
# aicasm_macro_gram.tab.c: In function 'mmparse':
# /TuxML/linux-4.13.3/drivers/scsi/aic7xxx/aicasm//aicasm_macro_gram.c:64:25: warning: implicit declaration of function 'mmlex' [-Wimplicit-function-declaration]
#  #define yylex           mmlex
#                          ^
# aicasm_macro_gram.tab.c:1199:16: note: in expansion of macro 'yylex'
# aicasm_scan.l: In function 'yylex':
# aicasm_scan.l:420:6: warning: implicit declaration of function 'mm_switch_to_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(temp_state);
#       ^~~~~~~~~~~~~~~~~~~
# aicasm_scan.l:421:6: warning: implicit declaration of function 'mmparse' [-Wimplicit-function-declaration]
#       mm_switch_to_buffer(old_state);
#       ^~~~~~~
# aicasm_scan.l:424:6: warning: implicit declaration of function 'mm_delete_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(old_state);
#       ^~~~~~~~~~~~~~~~
# make[4]: *** [aicasm] Error 1
# make[3]: *** [drivers/scsi/aic7xxx/aicasm/aicasm] Error 2
# make[2]: *** [drivers/scsi/aic7xxx] Error 2
# make[2]: *** Waiting for unfinished jobs....
# make[1]: *** [drivers/scsi] Error 2
# make[1]: *** Waiting for unfinished jobs....
# make: *** [drivers] Error 2
# aicasm_symbol.c:48:19: fatal error: aicdb.h: No such file or directory
#  #include "aicdb.h"
#                    ^
# compilation terminated.
# aicasm_gram.tab.c: In function 'yyparse':
# aicasm_gram.tab.c:1628:16: warning: implicit declaration of function 'yylex' [-Wimplicit-function-declaration]
# aicasm_macro_gram.tab.c: In function 'mmparse':
# /TuxML/linux-4.13.3/drivers/scsi/aic7xxx/aicasm//aicasm_macro_gram.c:64:25: warning: implicit declaration of function 'mmlex' [-Wimplicit-function-declaration]
#  #define yylex           mmlex
#                          ^
# aicasm_macro_gram.tab.c:1199:16: note: in expansion of macro 'yylex'
# aicasm_scan.l: In function 'yylex':
# aicasm_scan.l:420:6: warning: implicit declaration of function 'mm_switch_to_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(temp_state);
#       ^~~~~~~~~~~~~~~~~~~
# aicasm_scan.l:421:6: warning: implicit declaration of function 'mmparse' [-Wimplicit-function-declaration]
#       mm_switch_to_buffer(old_state);
#       ^~~~~~~
# aicasm_scan.l:424:6: warning: implicit declaration of function 'mm_delete_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(old_state);
#       ^~~~~~~~~~~~~~~~
# make[4]: *** [aicasm] Error 1
# make[3]: *** [drivers/scsi/aic7xxx/aicasm/aicasm] Error 2
# make[2]: *** [drivers/scsi/aic7xxx] Error 2
# make[1]: *** [drivers/scsi] Error 2
# make[1]: *** Waiting for unfinished jobs....
# make: *** [drivers] Error 2
# warning: (X86_INTEL_LPSS && INTEL_SOC_DTS_IOSF_CORE && SND_SST_IPC_ACPI && MMC_SDHCI_ACPI) selects IOSF_MBI which has unmet direct dependencies (PCI)
# warning: (X86_INTEL_LPSS && INTEL_SOC_DTS_IOSF_CORE && SND_SST_IPC_ACPI && MMC_SDHCI_ACPI) selects IOSF_MBI which has unmet direct dependencies (PCI)
# aicasm_symbol.c:48:19: fatal error: aicdb.h: No such file or directory
#  #include "aicdb.h"
#                    ^
# compilation terminated.
# aicasm_gram.tab.c: In function ‘yyparse’:
# aicasm_gram.tab.c:1628:16: warning: implicit declaration of function ‘yylex’ [-Wimplicit-function-declaration]
# aicasm_macro_gram.tab.c: In function ‘mmparse’:
# /TuxML/linux-4.13.3/drivers/scsi/aic7xxx/aicasm//aicasm_macro_gram.c:64:25: warning: implicit declaration of function ‘mmlex’ [-Wimplicit-function-declaration]
#  #define yylex           mmlex
#                          ^
# aicasm_macro_gram.tab.c:1199:16: note: in expansion of macro ‘yylex’
# aicasm_scan.l: In function ‘yylex’:
# aicasm_scan.l:420:6: warning: implicit declaration of function ‘mm_switch_to_buffer’ [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(temp_state);
#       ^~~~~~~~~~~~~~~~~~~
# aicasm_scan.l:421:6: warning: implicit declaration of function ‘mmparse’ [-Wimplicit-function-declaration]
#       mm_switch_to_buffer(old_state);
#       ^~~~~~~
# aicasm_scan.l:424:6: warning: implicit declaration of function ‘mm_delete_buffer’ [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(old_state);
#       ^~~~~~~~~~~~~~~~
# make[4]: *** [aicasm] Error 1
# make[3]: *** [drivers/scsi/aic7xxx/aicasm/aicasm] Error 2
# make[2]: *** [drivers/scsi/aic7xxx] Error 2
# make[1]: *** [drivers/scsi] Error 2
# make[1]: *** Waiting for unfinished jobs....
# make: *** [drivers] Error 2
# make[4]: flex: Command not found
# make[4]: *** [/TuxML/linux-4.13.3/drivers/scsi/aic7xxx/aicasm//aicasm_scan.c] Error 127
# make[3]: *** [drivers/scsi/aic7xxx/aicasm/aicasm] Error 2
# make[2]: *** [drivers/scsi/aic7xxx] Error 2
# make[1]: *** [drivers/scsi] Error 2
# make[1]: *** Waiting for unfinished jobs....
# In file included from ./include/linux/mtd/spi-nor.h:14:0,
#                  from drivers/spi/spi-bcm-qspi.c:28:
# ./include/linux/mtd/cfi.h:76:2: warning: #warning No CONFIG_MTD_CFI_Ix selected. No NOR chip support can work. [-Wcpp]
#  #warning No CONFIG_MTD_CFI_Ix selected. No NOR chip support can work.
#   ^~~~~~~
# In file included from ./include/linux/mtd/spi-nor.h:14:0,
#                  from drivers/spi/spi-bcm-qspi.c:28:
# ./include/linux/mtd/cfi.h:76:2: warning: #warning No CONFIG_MTD_CFI_Ix selected. No NOR chip support can work. [-Wcpp]
#  #warning No CONFIG_MTD_CFI_Ix selected. No NOR chip support can work.
#   ^~~~~~~
# make: *** [drivers] Error 2
# aicasm_symbol.c:48:19: fatal error: aicdb.h: No such file or directory
#  #include "aicdb.h"
#                    ^
# compilation terminated.
# aicasm_gram.tab.c: In function 'yyparse':
# aicasm_gram.tab.c:1628:16: warning: implicit declaration of function 'yylex' [-Wimplicit-function-declaration]
# aicasm_macro_gram.tab.c: In function 'mmparse':
# /TuxML/linux-4.13.3/drivers/scsi/aic7xxx/aicasm//aicasm_macro_gram.c:64:25: warning: implicit declaration of function 'mmlex' [-Wimplicit-function-declaration]
#  #define yylex           mmlex
#                          ^
# aicasm_macro_gram.tab.c:1199:16: note: in expansion of macro 'yylex'
# aicasm_scan.l: In function 'yylex':
# aicasm_scan.l:420:6: warning: implicit declaration of function 'mm_switch_to_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(temp_state);
#       ^~~~~~~~~~~~~~~~~~~
# aicasm_scan.l:421:6: warning: implicit declaration of function 'mmparse' [-Wimplicit-function-declaration]
#       mm_switch_to_buffer(old_state);
#       ^~~~~~~
# aicasm_scan.l:424:6: warning: implicit declaration of function 'mm_delete_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(old_state);
#       ^~~~~~~~~~~~~~~~
# make[4]: *** [aicasm] Error 1
# make[3]: *** [drivers/scsi/aic7xxx/aicasm/aicasm] Error 2
# make[2]: *** [drivers/scsi/aic7xxx] Error 2
# make[1]: *** [drivers/scsi] Error 2
# make[1]: *** Waiting for unfinished jobs....
# make: *** [drivers] Error 2
# aicasm_symbol.c:48:19: fatal error: aicdb.h: No such file or directory
#  #include "aicdb.h"
#                    ^
# compilation terminated.
# aicasm_gram.tab.c: In function 'yyparse':
# aicasm_gram.tab.c:1628:16: warning: implicit declaration of function 'yylex' [-Wimplicit-function-declaration]
# aicasm_macro_gram.tab.c: In function 'mmparse':
# /TuxML/linux-4.13.3/drivers/scsi/aic7xxx/aicasm//aicasm_macro_gram.c:64:25: warning: implicit declaration of function 'mmlex' [-Wimplicit-function-declaration]
#  #define yylex           mmlex
#                          ^
# aicasm_macro_gram.tab.c:1199:16: note: in expansion of macro 'yylex'
# aicasm_scan.l: In function 'yylex':
# aicasm_scan.l:420:6: warning: implicit declaration of function 'mm_switch_to_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(temp_state);
#       ^~~~~~~~~~~~~~~~~~~
# aicasm_scan.l:421:6: warning: implicit declaration of function 'mmparse' [-Wimplicit-function-declaration]
#       mm_switch_to_buffer(old_state);
#       ^~~~~~~
# aicasm_scan.l:424:6: warning: implicit declaration of function 'mm_delete_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(old_state);
#       ^~~~~~~~~~~~~~~~
# make[4]: *** [aicasm] Error 1
# make[3]: *** [drivers/scsi/aic7xxx/aicasm/aicasm] Error 2
# make[2]: *** [drivers/scsi/aic7xxx] Error 2
# make[1]: *** [drivers/scsi] Error 2
# make[1]: *** Waiting for unfinished jobs....
# make: *** [drivers] Error 2
# In file included from /usr/include/linux/filter.h:9:0,
#                  from samples/seccomp/bpf-fancy.c:12:
# /usr/include/linux/types.h:4:23: fatal error: asm/types.h: No such file or directory
#  #include <asm/types.h>
#                        ^
# compilation terminated.
# make[2]: *** [samples/seccomp/bpf-fancy.o] Error 1
# make[1]: *** [samples/seccomp] Error 2
# make: *** [samples] Error 2
# make: *** Waiting for unfinished jobs....
# aicasm_symbol.c:48:19: fatal error: aicdb.h: No such file or directory
#  #include "aicdb.h"
#                    ^
# compilation terminated.
# aicasm_gram.tab.c: In function 'yyparse':
# aicasm_gram.tab.c:1628:16: warning: implicit declaration of function 'yylex' [-Wimplicit-function-declaration]
# aicasm_macro_gram.tab.c: In function 'mmparse':
# /TuxML/linux-4.13.3/drivers/scsi/aic7xxx/aicasm//aicasm_macro_gram.c:64:25: warning: implicit declaration of function 'mmlex' [-Wimplicit-function-declaration]
#  #define yylex           mmlex
#                          ^
# aicasm_macro_gram.tab.c:1199:16: note: in expansion of macro 'yylex'
# aicasm_scan.l: In function 'yylex':
# aicasm_scan.l:420:6: warning: implicit declaration of function 'mm_switch_to_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(temp_state);
#       ^~~~~~~~~~~~~~~~~~~
# aicasm_scan.l:421:6: warning: implicit declaration of function 'mmparse' [-Wimplicit-function-declaration]
#       mm_switch_to_buffer(old_state);
#       ^~~~~~~
# aicasm_scan.l:424:6: warning: implicit declaration of function 'mm_delete_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(old_state);
#       ^~~~~~~~~~~~~~~~
# make[4]: *** [aicasm] Error 1
# make[3]: *** [drivers/scsi/aic7xxx/aicasm/aicasm] Error 2
# make[2]: *** [drivers/scsi/aic7xxx] Error 2
# make[2]: *** Waiting for unfinished jobs....
# make[1]: *** [drivers/scsi] Error 2
# make[1]: *** Waiting for unfinished jobs....
# make: *** [drivers] Error 2
# aicasm_symbol.c:48:19: fatal error: aicdb.h: No such file or directory
#  #include "aicdb.h"
#                    ^
# compilation terminated.
# aicasm_gram.tab.c: In function 'yyparse':
# aicasm_gram.tab.c:1628:16: warning: implicit declaration of function 'yylex' [-Wimplicit-function-declaration]
# aicasm_macro_gram.tab.c: In function 'mmparse':
# /TuxML/linux-4.13.3/drivers/scsi/aic7xxx/aicasm//aicasm_macro_gram.c:64:25: warning: implicit declaration of function 'mmlex' [-Wimplicit-function-declaration]
#  #define yylex           mmlex
#                          ^
# aicasm_macro_gram.tab.c:1199:16: note: in expansion of macro 'yylex'
# aicasm_scan.l: In function 'yylex':
# aicasm_scan.l:420:6: warning: implicit declaration of function 'mm_switch_to_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(temp_state);
#       ^~~~~~~~~~~~~~~~~~~
# aicasm_scan.l:421:6: warning: implicit declaration of function 'mmparse' [-Wimplicit-function-declaration]
#       mm_switch_to_buffer(old_state);
#       ^~~~~~~
# aicasm_scan.l:424:6: warning: implicit declaration of function 'mm_delete_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(old_state);
#       ^~~~~~~~~~~~~~~~
# make[4]: *** [aicasm] Error 1
# make[3]: *** [drivers/scsi/aic7xxx/aicasm/aicasm] Error 2
# make[2]: *** [drivers/scsi/aic7xxx] Error 2
# make[2]: *** Waiting for unfinished jobs....
# make[1]: *** [drivers/scsi] Error 2
# make[1]: *** Waiting for unfinished jobs....
# make: *** [drivers] Error 2
# In file included from /usr/include/stdio.h:27:0,
#                  from samples/seccomp/bpf-fancy.c:15:
# /usr/include/features.h:364:25: fatal error: sys/cdefs.h: No such file or directory
#  #  include <sys/cdefs.h>
#                          ^
# compilation terminated.
# make[2]: *** [samples/seccomp/bpf-fancy.o] Error 1
# make[1]: *** [samples/seccomp] Error 2
# make: *** [samples] Error 2
# make: *** Waiting for unfinished jobs....
# lib/ubsan.o: warning: objtool: val_to_string.constprop.4()+0xaf: leave instruction with modified stack frame
# /bin/sh: 1: as68k: not found
# make[3]: *** [drivers/net/wan/wanxlfw.inc] Error 127
# make[2]: *** [drivers/net/wan] Error 2
# make[2]: *** Waiting for unfinished jobs....
# make[1]: *** [drivers/net] Error 2
# make[1]: *** Waiting for unfinished jobs....
# make: *** [drivers] Error 2
# aicasm_symbol.c:48:19: fatal error: aicdb.h: No such file or directory
#  #include "aicdb.h"
#                    ^
# compilation terminated.
# aicasm_gram.tab.c: In function 'yyparse':
# aicasm_gram.tab.c:1628:16: warning: implicit declaration of function 'yylex' [-Wimplicit-function-declaration]
# aicasm_macro_gram.tab.c: In function 'mmparse':
# /TuxML/linux-4.13.3/drivers/scsi/aic7xxx/aicasm//aicasm_macro_gram.c:64:25: warning: implicit declaration of function 'mmlex' [-Wimplicit-function-declaration]
#  #define yylex           mmlex
#                          ^
# aicasm_macro_gram.tab.c:1199:16: note: in expansion of macro 'yylex'
# aicasm_scan.l: In function 'yylex':
# aicasm_scan.l:420:6: warning: implicit declaration of function 'mm_switch_to_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(temp_state);
#       ^~~~~~~~~~~~~~~~~~~
# aicasm_scan.l:421:6: warning: implicit declaration of function 'mmparse' [-Wimplicit-function-declaration]
#       mm_switch_to_buffer(old_state);
#       ^~~~~~~
# aicasm_scan.l:424:6: warning: implicit declaration of function 'mm_delete_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(old_state);
#       ^~~~~~~~~~~~~~~~
# make[4]: *** [aicasm] Error 1
# make[3]: *** [drivers/scsi/aic7xxx/aicasm/aicasm] Error 2
# make[2]: *** [drivers/scsi/aic7xxx] Error 2
# make[2]: *** Waiting for unfinished jobs....
# make[1]: *** [drivers/scsi] Error 2
# make[1]: *** Waiting for unfinished jobs....
# make: *** [drivers] Error 2
# crypto/twofish_common.c: In function '__twofish_setkey':
# crypto/twofish_common.c:700:1: warning: the frame size of 4992 bytes is larger than 2048 bytes [-Wframe-larger-than=]
#  }
#  ^
# aicasm_symbol.c:48:19: fatal error: aicdb.h: No such file or directory
#  #include "aicdb.h"
#                    ^
# compilation terminated.
# aicasm_gram.tab.c: In function 'yyparse':
# aicasm_gram.tab.c:1628:16: warning: implicit declaration of function 'yylex' [-Wimplicit-function-declaration]
# aicasm_macro_gram.tab.c: In function 'mmparse':
# /TuxML/linux-4.13.3/drivers/scsi/aic7xxx/aicasm//aicasm_macro_gram.c:64:25: warning: implicit declaration of function 'mmlex' [-Wimplicit-function-declaration]
#  #define yylex           mmlex
#                          ^
# aicasm_macro_gram.tab.c:1199:16: note: in expansion of macro 'yylex'
# aicasm_scan.l: In function 'yylex':
# aicasm_scan.l:420:6: warning: implicit declaration of function 'mm_switch_to_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(temp_state);
#       ^~~~~~~~~~~~~~~~~~~
# aicasm_scan.l:421:6: warning: implicit declaration of function 'mmparse' [-Wimplicit-function-declaration]
#       mm_switch_to_buffer(old_state);
#       ^~~~~~~
# aicasm_scan.l:424:6: warning: implicit declaration of function 'mm_delete_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(old_state);
#       ^~~~~~~~~~~~~~~~
# make[4]: *** [aicasm] Error 1
# make[3]: *** [drivers/scsi/aic7xxx/aicasm/aicasm] Error 2
# make[2]: *** [drivers/scsi/aic7xxx] Error 2
# make[2]: *** Waiting for unfinished jobs....
# make[1]: *** [drivers/scsi] Error 2
# make[1]: *** Waiting for unfinished jobs....
# make: *** [drivers] Error 2
# /bin/sh: 1: as68k: not found
# make[3]: *** [drivers/net/wan/wanxlfw.inc] Error 127
# make[2]: *** [drivers/net/wan] Error 2
# make[2]: *** Waiting for unfinished jobs....
# make[1]: *** [drivers/net] Error 2
# make[1]: *** Waiting for unfinished jobs....
# make: *** [drivers] Error 2
# In file included from ./include/linux/bitmap.h:8:0,
#                  from ./include/linux/cpumask.h:11,
#                  from ./arch/x86/include/asm/cpumask.h:4,
#                  from ./arch/x86/include/asm/msr.h:10,
#                  from ./arch/x86/include/asm/processor.h:20,
#                  from ./arch/x86/include/asm/cpufeature.h:4,
#                  from ./arch/x86/include/asm/thread_info.h:52,
#                  from ./include/linux/thread_info.h:37,
#                  from ./arch/x86/include/asm/preempt.h:6,
#                  from ./include/linux/preempt.h:80,
#                  from ./include/linux/spinlock.h:50,
#                  from drivers/infiniband/core/core_priv.h:37,
#                  from drivers/infiniband/core/roce_gid_mgmt.c:33:
# In function 'memcpy',
#     inlined from 'rdma_ip2gid' at ./include/rdma/ib_addr.h:175:3,
#     inlined from 'addr_event.isra.0.constprop' at drivers/infiniband/core/roce_gid_mgmt.c:691:2,
#     inlined from 'inetaddr_event' at drivers/infiniband/core/roce_gid_mgmt.c:714:9:
# ./include/linux/string.h:305:4: error: call to '__read_overflow2' declared with attribute error: detected read beyond size of object passed as 2nd parameter
#     __read_overflow2();
#     ^~~~~~~~~~~~~~~~~~
# make[3]: *** [drivers/infiniband/core/roce_gid_mgmt.o] Error 1
# make[2]: *** [drivers/infiniband/core] Error 2
# make[1]: *** [drivers/infiniband] Error 2
# make[1]: *** Waiting for unfinished jobs....
# make: *** [drivers] Error 2
# In file included from ./include/linux/bitmap.h:8:0,
#                  from ./include/linux/cpumask.h:11,
#                  from ./arch/x86/include/asm/cpumask.h:4,
#                  from ./arch/x86/include/asm/msr.h:10,
#                  from ./arch/x86/include/asm/processor.h:20,
#                  from ./arch/x86/include/asm/cpufeature.h:4,
#                  from ./arch/x86/include/asm/thread_info.h:52,
#                  from ./include/linux/thread_info.h:37,
#                  from ./arch/x86/include/asm/preempt.h:6,
#                  from ./include/linux/preempt.h:80,
#                  from ./include/linux/spinlock.h:50,
#                  from drivers/infiniband/core/core_priv.h:37,
#                  from drivers/infiniband/core/roce_gid_mgmt.c:33:
# In function 'memcpy',
#     inlined from 'rdma_ip2gid' at ./include/rdma/ib_addr.h:175:3,
#     inlined from 'addr_event.isra.0.constprop' at drivers/infiniband/core/roce_gid_mgmt.c:691:2,
#     inlined from 'inetaddr_event' at drivers/infiniband/core/roce_gid_mgmt.c:714:9:
# ./include/linux/string.h:305:4: error: call to '__read_overflow2' declared with attribute error: detected read beyond size of object passed as 2nd parameter
#     __read_overflow2();
#     ^~~~~~~~~~~~~~~~~~
# make[3]: *** [drivers/infiniband/core/roce_gid_mgmt.o] Error 1
# make[2]: *** [drivers/infiniband/core] Error 2
# make[1]: *** [drivers/infiniband] Error 2
# make[1]: *** Waiting for unfinished jobs....
# make: *** [drivers] Error 2
# In file included from ./include/linux/uaccess.h:13:0,
#                  from ./include/linux/highmem.h:8,
#                  from fs/binfmt_elf.c:28:
# fs/binfmt_elf.c: In function 'create_elf_tables':
# ./arch/x86/include/asm/uaccess_64.h:143:20: warning: array subscript is above array bounds [-Warray-bounds]
#     __put_user_asm(4[(u16 *)src], 4 + (u16 __user *)dst,
#                     ^
# ./arch/x86/include/asm/uaccess.h:468:16: note: in definition of macro '__put_user_asm'
#         : ltype(x), "m" (__m(addr)), "i" (errret), "0" (err))
#                 ^
# ./arch/x86/include/asm/uaccess_64.h:143:20: warning: array subscript is above array bounds [-Warray-bounds]
#     __put_user_asm(4[(u16 *)src], 4 + (u16 __user *)dst,
#                     ^
# ./arch/x86/include/asm/uaccess.h:468:16: note: in definition of macro '__put_user_asm'
#         : ltype(x), "m" (__m(addr)), "i" (errret), "0" (err))
#                 ^
# ./arch/x86/include/asm/uaccess_64.h:154:20: warning: array subscript is above array bounds [-Warray-bounds]
#     __put_user_asm(1[(u64 *)src], 1 + (u64 __user *)dst,
#                     ^
# ./arch/x86/include/asm/uaccess.h:468:16: note: in definition of macro '__put_user_asm'
#         : ltype(x), "m" (__m(addr)), "i" (errret), "0" (err))
#                 ^
# ./arch/x86/include/asm/uaccess_64.h:154:20: warning: array subscript is above array bounds [-Warray-bounds]
#     __put_user_asm(1[(u64 *)src], 1 + (u64 __user *)dst,
#                     ^
# ./arch/x86/include/asm/uaccess.h:468:16: note: in definition of macro '__put_user_asm'
#         : ltype(x), "m" (__m(addr)), "i" (errret), "0" (err))
#                 ^
# In file included from ./include/linux/uaccess.h:13:0,
#                  from ./include/linux/highmem.h:8,
#                  from fs/binfmt_elf.c:28,
#                  from fs/compat_binfmt_elf.c:131:
# fs/binfmt_elf.c: In function 'create_elf_tables':
# ./arch/x86/include/asm/uaccess_64.h:143:20: warning: array subscript is above array bounds [-Warray-bounds]
#     __put_user_asm(4[(u16 *)src], 4 + (u16 __user *)dst,
#                     ^
# ./arch/x86/include/asm/uaccess.h:468:16: note: in definition of macro '__put_user_asm'
#         : ltype(x), "m" (__m(addr)), "i" (errret), "0" (err))
#                 ^
# ./arch/x86/include/asm/uaccess_64.h:143:20: warning: array subscript is above array bounds [-Warray-bounds]
#     __put_user_asm(4[(u16 *)src], 4 + (u16 __user *)dst,
#                     ^
# ./arch/x86/include/asm/uaccess.h:468:16: note: in definition of macro '__put_user_asm'
#         : ltype(x), "m" (__m(addr)), "i" (errret), "0" (err))
#                 ^
# ./arch/x86/include/asm/uaccess_64.h:154:20: warning: array subscript is above array bounds [-Warray-bounds]
#     __put_user_asm(1[(u64 *)src], 1 + (u64 __user *)dst,
#                     ^
# ./arch/x86/include/asm/uaccess.h:468:16: note: in definition of macro '__put_user_asm'
#         : ltype(x), "m" (__m(addr)), "i" (errret), "0" (err))
#                 ^
# ./arch/x86/include/asm/uaccess_64.h:154:20: warning: array subscript is above array bounds [-Warray-bounds]
#     __put_user_asm(1[(u64 *)src], 1 + (u64 __user *)dst,
#                     ^
# ./arch/x86/include/asm/uaccess.h:468:16: note: in definition of macro '__put_user_asm'
#         : ltype(x), "m" (__m(addr)), "i" (errret), "0" (err))
#                 ^
# aicasm_symbol.c:48:19: fatal error: aicdb.h: No such file or directory
#  #include "aicdb.h"
#                    ^
# compilation terminated.
# aicasm_gram.tab.c: In function 'yyparse':
# aicasm_gram.tab.c:1628:16: warning: implicit declaration of function 'yylex' [-Wimplicit-function-declaration]
# aicasm_macro_gram.tab.c: In function 'mmparse':
# /TuxML/linux-4.13.3/drivers/scsi/aic7xxx/aicasm//aicasm_macro_gram.c:64:25: warning: implicit declaration of function 'mmlex' [-Wimplicit-function-declaration]
#  #define yylex           mmlex
#                          ^
# aicasm_macro_gram.tab.c:1199:16: note: in expansion of macro 'yylex'
# aicasm_scan.l: In function 'yylex':
# aicasm_scan.l:420:6: warning: implicit declaration of function 'mm_switch_to_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(temp_state);
#       ^~~~~~~~~~~~~~~~~~~
# aicasm_scan.l:421:6: warning: implicit declaration of function 'mmparse' [-Wimplicit-function-declaration]
#       mm_switch_to_buffer(old_state);
#       ^~~~~~~
# aicasm_scan.l:424:6: warning: implicit declaration of function 'mm_delete_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(old_state);
#       ^~~~~~~~~~~~~~~~
# make[4]: *** [aicasm] Error 1
# make[3]: *** [drivers/scsi/aic7xxx/aicasm/aicasm] Error 2
# make[2]: *** [drivers/scsi/aic7xxx] Error 2
# make[1]: *** [drivers/scsi] Error 2
# make[1]: *** Waiting for unfinished jobs....
# make: *** [drivers] Error 2
# /bin/sh: 1: as68k: not found
# make[3]: *** [drivers/net/wan/wanxlfw.inc] Error 127
# make[2]: *** [drivers/net/wan] Error 2
# make[1]: *** [drivers/net] Error 2
# make[1]: *** Waiting for unfinished jobs....
# make: *** [drivers] Error 2
# In file included from ./include/linux/bitmap.h:8:0,
#                  from ./include/linux/cpumask.h:11,
#                  from ./arch/x86/include/asm/cpumask.h:4,
#                  from ./arch/x86/include/asm/msr.h:10,
#                  from ./arch/x86/include/asm/processor.h:20,
#                  from ./arch/x86/include/asm/cpufeature.h:4,
#                  from ./arch/x86/include/asm/thread_info.h:52,
#                  from ./include/linux/thread_info.h:37,
#                  from ./arch/x86/include/asm/preempt.h:6,
#                  from ./include/linux/preempt.h:80,
#                  from ./include/linux/spinlock.h:50,
#                  from drivers/infiniband/core/core_priv.h:37,
#                  from drivers/infiniband/core/roce_gid_mgmt.c:33:
# In function 'memcpy',
#     inlined from 'rdma_ip2gid' at ./include/rdma/ib_addr.h:175:3,
#     inlined from 'addr_event.isra.0.constprop' at drivers/infiniband/core/roce_gid_mgmt.c:691:2,
#     inlined from 'inetaddr_event' at drivers/infiniband/core/roce_gid_mgmt.c:714:9:
# ./include/linux/string.h:305:4: error: call to '__read_overflow2' declared with attribute error: detected read beyond size of object passed as 2nd parameter
#     __read_overflow2();
#     ^~~~~~~~~~~~~~~~~~
# make[3]: *** [drivers/infiniband/core/roce_gid_mgmt.o] Error 1
# make[2]: *** [drivers/infiniband/core] Error 2
# make[1]: *** [drivers/infiniband] Error 2
# make[1]: *** Waiting for unfinished jobs....
# make: *** [drivers] Error 2
# lib/ubsan.o: warning: objtool: val_to_string.constprop.4()+0xaf: leave instruction with modified stack frame
# /bin/sh: 1: as68k: not found
# make[3]: *** [drivers/net/wan/wanxlfw.inc] Error 127
# make[3]: *** Waiting for unfinished jobs....
# make[2]: *** [drivers/net/wan] Error 2
# make[2]: *** Waiting for unfinished jobs....
# aicasm_symbol.c: In function 'aic_print_reg_dump_end':
# aicasm_symbol.c:397:13: warning: implicit declaration of function 'tolower' [-Wimplicit-function-declaration]
#    *letter = tolower(*letter);
#              ^~~~~~~
# aicasm_gram.tab.c: In function 'yyparse':
# aicasm_gram.tab.c:1628:16: warning: implicit declaration of function 'yylex' [-Wimplicit-function-declaration]
# aicasm_macro_gram.tab.c: In function 'mmparse':
# /TuxML/linux-4.13.3/drivers/scsi/aic7xxx/aicasm//aicasm_macro_gram.c:64:25: warning: implicit declaration of function 'mmlex' [-Wimplicit-function-declaration]
#  #define yylex           mmlex
#                          ^
# aicasm_macro_gram.tab.c:1199:16: note: in expansion of macro 'yylex'
# aicasm_scan.l: In function 'yylex':
# aicasm_scan.l:420:6: warning: implicit declaration of function 'mm_switch_to_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(temp_state);
#       ^~~~~~~~~~~~~~~~~~~
# aicasm_scan.l:421:6: warning: implicit declaration of function 'mmparse' [-Wimplicit-function-declaration]
#       mm_switch_to_buffer(old_state);
#       ^~~~~~~
# aicasm_scan.l:424:6: warning: implicit declaration of function 'mm_delete_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(old_state);
#       ^~~~~~~~~~~~~~~~
# drivers/scsi/aic7xxx/aicasm/aicasm: 880 instructions used
# drivers/scsi/aic7xxx/aicasm/aicasm: 25 of 37 register definitions used
# make[1]: *** [drivers/net] Error 2
# make[1]: *** Waiting for unfinished jobs....
# make: *** [drivers] Error 2
# drivers/gpu/drm/radeon/radeon_object.c: In function 'radeon_bo_create':
# drivers/gpu/drm/radeon/radeon_object.c:242:2: warning: #warning Please enable CONFIG_MTRR and CONFIG_X86_PAT for better performance thanks to write-combining [-Wcpp]
#  #warning Please enable CONFIG_MTRR and CONFIG_X86_PAT for better performance \
#   ^~~~~~~
# aicasm_symbol.c:48:19: fatal error: aicdb.h: No such file or directory
#  #include "aicdb.h"
#                    ^
# compilation terminated.
# aicasm_gram.tab.c: In function 'yyparse':
# aicasm_gram.tab.c:1628:16: warning: implicit declaration of function 'yylex' [-Wimplicit-function-declaration]
# aicasm_macro_gram.tab.c: In function 'mmparse':
# /TuxML/linux-4.13.3/drivers/scsi/aic7xxx/aicasm//aicasm_macro_gram.c:64:25: warning: implicit declaration of function 'mmlex' [-Wimplicit-function-declaration]
#  #define yylex           mmlex
#                          ^
# aicasm_macro_gram.tab.c:1199:16: note: in expansion of macro 'yylex'
# aicasm_scan.l: In function 'yylex':
# aicasm_scan.l:420:6: warning: implicit declaration of function 'mm_switch_to_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(temp_state);
#       ^~~~~~~~~~~~~~~~~~~
# aicasm_scan.l:421:6: warning: implicit declaration of function 'mmparse' [-Wimplicit-function-declaration]
#       mm_switch_to_buffer(old_state);
#       ^~~~~~~
# aicasm_scan.l:424:6: warning: implicit declaration of function 'mm_delete_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(old_state);
#       ^~~~~~~~~~~~~~~~
# make[4]: *** [aicasm] Error 1
# make[3]: *** [drivers/scsi/aic7xxx/aicasm/aicasm] Error 2
# make[2]: *** [drivers/scsi/aic7xxx] Error 2
# make[1]: *** [drivers/scsi] Error 2
# make[1]: *** Waiting for unfinished jobs....
# make: *** [drivers] Error 2
# drivers/gpu/drm/amd/amdgpu/amdgpu_object.c: In function 'amdgpu_bo_create_restricted':
# drivers/gpu/drm/amd/amdgpu/amdgpu_object.c:378:2: warning: #warning Please enable CONFIG_MTRR and CONFIG_X86_PAT for better performance thanks to write-combining [-Wcpp]
#  #warning Please enable CONFIG_MTRR and CONFIG_X86_PAT for better performance \
#   ^~~~~~~
# drivers/staging/vboxvideo/vbox_hgsmi.o: In function `hgsmi_buffer_alloc':
# /TuxML/linux-4.13.3/drivers/staging/vboxvideo/vbox_hgsmi.c:76: undefined reference to `gen_pool_dma_alloc'
# drivers/staging/vboxvideo/vbox_hgsmi.o: In function `hgsmi_buffer_free':
# /TuxML/linux-4.13.3/drivers/staging/vboxvideo/vbox_hgsmi.c:101: undefined reference to `gen_pool_free'
# drivers/staging/vboxvideo/vbox_hgsmi.o: In function `hgsmi_buffer_submit':
# /TuxML/linux-4.13.3/drivers/staging/vboxvideo/vbox_hgsmi.c:108: undefined reference to `gen_pool_virt_to_phys'
# drivers/staging/vboxvideo/vbox_main.o: In function `vbox_hw_fini':
# /TuxML/linux-4.13.3/drivers/staging/vboxvideo/vbox_main.c:348: undefined reference to `gen_pool_destroy'
# drivers/staging/vboxvideo/vbox_main.o: In function `vbox_driver_load':
# /TuxML/linux-4.13.3/drivers/staging/vboxvideo/vbox_main.c:295: undefined reference to `gen_pool_create'
# /TuxML/linux-4.13.3/drivers/staging/vboxvideo/vbox_main.c:299: undefined reference to `gen_pool_add_virt'
# /TuxML/linux-4.13.3/drivers/staging/vboxvideo/vbox_main.c:339: undefined reference to `gen_pool_destroy'
# make: *** [vmlinux] Error 1
# drivers/gpu/drm/radeon/radeon_object.c: In function 'radeon_bo_create':
# drivers/gpu/drm/radeon/radeon_object.c:242:2: warning: #warning Please enable CONFIG_MTRR and CONFIG_X86_PAT for better performance thanks to write-combining [-Wcpp]
#  #warning Please enable CONFIG_MTRR and CONFIG_X86_PAT for better performance \
#   ^~~~~~~
# drivers/staging/vboxvideo/vbox_hgsmi.o: In function `hgsmi_buffer_alloc':
# /TuxML/linux-4.13.3/drivers/staging/vboxvideo/vbox_hgsmi.c:76: undefined reference to `gen_pool_dma_alloc'
# drivers/staging/vboxvideo/vbox_hgsmi.o: In function `hgsmi_buffer_free':
# /TuxML/linux-4.13.3/drivers/staging/vboxvideo/vbox_hgsmi.c:101: undefined reference to `gen_pool_free'
# drivers/staging/vboxvideo/vbox_hgsmi.o: In function `hgsmi_buffer_submit':
# /TuxML/linux-4.13.3/drivers/staging/vboxvideo/vbox_hgsmi.c:108: undefined reference to `gen_pool_virt_to_phys'
# drivers/staging/vboxvideo/vbox_main.o: In function `vbox_hw_fini':
# /TuxML/linux-4.13.3/drivers/staging/vboxvideo/vbox_main.c:348: undefined reference to `gen_pool_destroy'
# drivers/staging/vboxvideo/vbox_main.o: In function `vbox_driver_load':
# /TuxML/linux-4.13.3/drivers/staging/vboxvideo/vbox_main.c:295: undefined reference to `gen_pool_create'
# /TuxML/linux-4.13.3/drivers/staging/vboxvideo/vbox_main.c:299: undefined reference to `gen_pool_add_virt'
# /TuxML/linux-4.13.3/drivers/staging/vboxvideo/vbox_main.c:339: undefined reference to `gen_pool_destroy'
# make: *** [vmlinux] Error 1
# drivers/gpu/drm/radeon/radeon_object.c: In function 'radeon_bo_create':
# drivers/gpu/drm/radeon/radeon_object.c:242:2: warning: #warning Please enable CONFIG_MTRR and CONFIG_X86_PAT for better performance thanks to write-combining [-Wcpp]
#  #warning Please enable CONFIG_MTRR and CONFIG_X86_PAT for better performance \
#   ^~~~~~~
# aicasm_symbol.c:48:19: fatal error: aicdb.h: No such file or directory
#  #include "aicdb.h"
#                    ^
# compilation terminated.
# aicasm_gram.tab.c: In function 'yyparse':
# aicasm_gram.tab.c:1628:16: warning: implicit declaration of function 'yylex' [-Wimplicit-function-declaration]
# aicasm_macro_gram.tab.c: In function 'mmparse':
# /TuxML/linux-4.13.3/drivers/scsi/aic7xxx/aicasm//aicasm_macro_gram.c:64:25: warning: implicit declaration of function 'mmlex' [-Wimplicit-function-declaration]
#  #define yylex           mmlex
#                          ^
# aicasm_macro_gram.tab.c:1199:16: note: in expansion of macro 'yylex'
# aicasm_scan.l: In function 'yylex':
# aicasm_scan.l:420:6: warning: implicit declaration of function 'mm_switch_to_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(temp_state);
#       ^~~~~~~~~~~~~~~~~~~
# aicasm_scan.l:421:6: warning: implicit declaration of function 'mmparse' [-Wimplicit-function-declaration]
#       mm_switch_to_buffer(old_state);
#       ^~~~~~~
# aicasm_scan.l:424:6: warning: implicit declaration of function 'mm_delete_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(old_state);
#       ^~~~~~~~~~~~~~~~
# make[4]: *** [aicasm] Error 1
# make[3]: *** [drivers/scsi/aic7xxx/aicasm/aicasm] Error 2
# make[2]: *** [drivers/scsi/aic7xxx] Error 2
# make[2]: *** Waiting for unfinished jobs....
# make[1]: *** [drivers/scsi] Error 2
# make[1]: *** Waiting for unfinished jobs....
# make: *** [drivers] Error 2

# %%
# TODO: workaround 
# see issue here: https://github.com/TuxML/compilation-analysis/issues/7
for cid in cid_errors_not_in_configdata:
    errorlogs = errorlogs[errorlogs.cid != cid]
    error_patternfirst = error_patternfirst[error_patternfirst.index != cid]
    error_pattern = error_pattern[error_pattern.index != cid]

errorlogs.shape, error_patternfirst.shape, error_pattern.shape
# Out:
# ((3507, 2), (3507, 20), (3507, 21))

# %%
patternfirst_frequencies = error_patternfirst[pattern_name].apply(nb_patterns, axis=0)
patternfirst_frequencies.plot(kind='bar')
patternfirst_frequencies
# Out:
# BLACKLIGHT              10
# BLACKLIGHT2              1
# CONFIG_NLS_DEFAULT       5
# CRC32_CLUSTER            2
# V4L2                     9
# OVERFLOW2               83
# ULPI                     0
# PCM                      0
# TTM                     11
# AS68K                  474
# GEN                    275
# AICDB                 2464
# AIC7XXX                161
# DRM_BRIDGE_CLUSTER       3
# PINCTRL_CLUSTER          3
# BTBCM                    2
# BPFFANCY                 0
# DEVM                     2
# DEVM2                    1
# I2C_CLUSTER              1
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn import tree


TESTING_SIZE= 0.001 #0.99 # 0.001 # 0.9
X_train, X_test, y_train, y_test = train_test_split(
    rawtuxdata
    .drop(columns=["cid"])
    .drop(columns=size_methods)
    .drop(columns=compilation_status_column_name), 
    rawtuxdata[compilation_status_column_name], test_size=TESTING_SIZE, random_state=0)  
clf = tree.DecisionTreeClassifier() #GradientBoostingClassifier(n_estimators=100) #RandomForestRegressor(n_estimators=100) #   #GradientBoostingRegressor(n_estimators=100)  
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, balanced_accuracy_score

y_pred = clf.predict(X_test)

acc = accuracy_score (y_test, y_pred)
prec = precision_score (y_test, y_pred)
reca = recall_score (y_test, y_pred)
f1 = f1_score (y_test, y_pred)
balance_acc = balanced_accuracy_score (y_test, y_pred)
print("Accuracy score:", acc)
print("Precision score:", prec)
print("Recall score:", reca)
print("F1 score:", f1)
print("Balance accuracy score:", balance_acc)
# Out:
# Accuracy score: 1.0
# Precision score: 1.0
# Recall score: 1.0
# F1 score: 1.0
# Balance accuracy score: 1.0

# %%
del X_train
del X_test 
del y_train 
del y_test

# %%
import graphviz 

def printTree(clf, feature_names):
    dot_data = tree.export_graphviz(clf, out_file=None, 
                         feature_names=feature_names,  
                         filled=True, rounded=True,
                         special_characters=True)  
    graph = graphviz.Source(dot_data)  
    graph.render("TUXML_compilation_failures")
    
printTree(clf, rawtuxdata.drop(columns=["cid"]).drop(columns=size_methods).drop(columns=compilation_status_column_name).columns)

# %%
from sklearn.tree import _tree

def tree_to_rules(tree, feature_names):
    tree_ = tree.tree_
    feature_name = [
        feature_names[i] if i != _tree.TREE_UNDEFINED else "undefined!"
        for i in tree_.feature
    ]
    #print ("def tree({}):".format(", ".join(feature_names)))

    def recurse(node, previous_rules):
        if tree_.feature[node] != _tree.TREE_UNDEFINED:
            name = feature_name[node]
            threshold = tree_.threshold[node]
            #print ("{}if {} <= {}:".format(indent, name, threshold))
            recurse(tree_.children_left[node], previous_rules+[name + " <= " + str(threshold)])
            #print ("{}else:  # if {} > {}".format(indent, name, threshold))
            recurse(tree_.children_right[node], previous_rules+[name + " > " + str(threshold)])
        else:
            print(" & ".join(previous_rules) + " ---> " + str(tree_.value[node]))

    recurse(0, [])
    
tree_to_rules(clf, rawtuxdata.drop(columns=["cid"]).drop(columns=size_methods).drop(columns=compilation_status_column_name).columns)
# Out:
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR <= 0.5 & DRM_VBOXVIDEO <= 1.5 & MLX5_INFINIBAND <= 0.5 & XEN_FBDEV_FRONTEND <= 0.5 ---> [[0. 1.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR <= 0.5 & DRM_VBOXVIDEO <= 1.5 & MLX5_INFINIBAND <= 0.5 & XEN_FBDEV_FRONTEND > 0.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR <= 0.5 & DRM_VBOXVIDEO <= 1.5 & MLX5_INFINIBAND > 0.5 & ISDN_DIVAS_USERIDI <= 0.5 & MICROCHIP_KSZ <= 0.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR <= 0.5 & DRM_VBOXVIDEO <= 1.5 & MLX5_INFINIBAND > 0.5 & ISDN_DIVAS_USERIDI <= 0.5 & MICROCHIP_KSZ > 0.5 ---> [[0. 3.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR <= 0.5 & DRM_VBOXVIDEO <= 1.5 & MLX5_INFINIBAND > 0.5 & ISDN_DIVAS_USERIDI > 0.5 & INFINIBAND_SRPT <= 1.5 & WIL6210_TRACING <= 0.5 & XEN_PCIDEV_BACKEND <= 1.5 & FB_GEODE_GX <= 0.5 & TI_ADC128S052 <= 1.5 ---> [[ 0. 20.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR <= 0.5 & DRM_VBOXVIDEO <= 1.5 & MLX5_INFINIBAND > 0.5 & ISDN_DIVAS_USERIDI > 0.5 & INFINIBAND_SRPT <= 1.5 & WIL6210_TRACING <= 0.5 & XEN_PCIDEV_BACKEND <= 1.5 & FB_GEODE_GX <= 0.5 & TI_ADC128S052 > 1.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR <= 0.5 & DRM_VBOXVIDEO <= 1.5 & MLX5_INFINIBAND > 0.5 & ISDN_DIVAS_USERIDI > 0.5 & INFINIBAND_SRPT <= 1.5 & WIL6210_TRACING <= 0.5 & XEN_PCIDEV_BACKEND <= 1.5 & FB_GEODE_GX > 0.5 ---> [[   0. 3426.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR <= 0.5 & DRM_VBOXVIDEO <= 1.5 & MLX5_INFINIBAND > 0.5 & ISDN_DIVAS_USERIDI > 0.5 & INFINIBAND_SRPT <= 1.5 & WIL6210_TRACING <= 0.5 & XEN_PCIDEV_BACKEND > 1.5 & DVB_DIB7000M <= 1.5 ---> [[0. 8.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR <= 0.5 & DRM_VBOXVIDEO <= 1.5 & MLX5_INFINIBAND > 0.5 & ISDN_DIVAS_USERIDI > 0.5 & INFINIBAND_SRPT <= 1.5 & WIL6210_TRACING <= 0.5 & XEN_PCIDEV_BACKEND > 1.5 & DVB_DIB7000M > 1.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR <= 0.5 & DRM_VBOXVIDEO <= 1.5 & MLX5_INFINIBAND > 0.5 & ISDN_DIVAS_USERIDI > 0.5 & INFINIBAND_SRPT <= 1.5 & WIL6210_TRACING > 0.5 & VIDEO_BT856 <= 1.5 ---> [[0. 6.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR <= 0.5 & DRM_VBOXVIDEO <= 1.5 & MLX5_INFINIBAND > 0.5 & ISDN_DIVAS_USERIDI > 0.5 & INFINIBAND_SRPT <= 1.5 & WIL6210_TRACING > 0.5 & VIDEO_BT856 > 1.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR <= 0.5 & DRM_VBOXVIDEO <= 1.5 & MLX5_INFINIBAND > 0.5 & ISDN_DIVAS_USERIDI > 0.5 & INFINIBAND_SRPT > 1.5 & SCSI_SRP_ATTRS <= 1.5 ---> [[2. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR <= 0.5 & DRM_VBOXVIDEO <= 1.5 & MLX5_INFINIBAND > 0.5 & ISDN_DIVAS_USERIDI > 0.5 & INFINIBAND_SRPT > 1.5 & SCSI_SRP_ATTRS > 1.5 ---> [[ 0. 17.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR <= 0.5 & DRM_VBOXVIDEO > 1.5 ---> [[277.   0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG <= 0.5 & FW_LOADER <= 1.0 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG <= 0.5 & FW_LOADER > 1.0 & IR_SPI <= 1.5 & NFS_V3_ACL <= 0.5 & CHARGER_CPCAP <= 1.5 & CFAG12864B <= 1.5 & MAC80211_MPL_DEBUG <= 0.5 ---> [[  0. 224.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG <= 0.5 & FW_LOADER > 1.0 & IR_SPI <= 1.5 & NFS_V3_ACL <= 0.5 & CHARGER_CPCAP <= 1.5 & CFAG12864B <= 1.5 & MAC80211_MPL_DEBUG > 0.5 & TEST_PRINTF <= 1.5 ---> [[0. 2.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG <= 0.5 & FW_LOADER > 1.0 & IR_SPI <= 1.5 & NFS_V3_ACL <= 0.5 & CHARGER_CPCAP <= 1.5 & CFAG12864B <= 1.5 & MAC80211_MPL_DEBUG > 0.5 & TEST_PRINTF > 1.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG <= 0.5 & FW_LOADER > 1.0 & IR_SPI <= 1.5 & NFS_V3_ACL <= 0.5 & CHARGER_CPCAP <= 1.5 & CFAG12864B > 1.5 & DVB_EC100 <= 0.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG <= 0.5 & FW_LOADER > 1.0 & IR_SPI <= 1.5 & NFS_V3_ACL <= 0.5 & CHARGER_CPCAP <= 1.5 & CFAG12864B > 1.5 & DVB_EC100 > 0.5 ---> [[0. 2.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG <= 0.5 & FW_LOADER > 1.0 & IR_SPI <= 1.5 & NFS_V3_ACL <= 0.5 & CHARGER_CPCAP > 1.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG <= 0.5 & FW_LOADER > 1.0 & IR_SPI <= 1.5 & NFS_V3_ACL > 0.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG <= 0.5 & FW_LOADER > 1.0 & IR_SPI > 1.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 <= 1.0 & MAX1363 <= 1.5 ---> [[ 0. 27.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 <= 1.0 & MAX1363 > 1.5 ---> [[2. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP <= 0.5 & FPGA_MGR_SOCFPGA <= 1.5 ---> [[ 0. 60.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP <= 0.5 & FPGA_MGR_SOCFPGA > 1.5 ---> [[2. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE <= 0.5 & PWRSEQ_SD8787 <= 1.5 & CAN_C_CAN_PCI <= 1.5 & VIDEO_MUX <= 1.5 & GPIOLIB_IRQCHIP <= 0.5 & TTY_PRINTK <= 1.5 ---> [[ 0. 30.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE <= 0.5 & PWRSEQ_SD8787 <= 1.5 & CAN_C_CAN_PCI <= 1.5 & VIDEO_MUX <= 1.5 & GPIOLIB_IRQCHIP <= 0.5 & TTY_PRINTK > 1.5 ---> [[3. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE <= 0.5 & PWRSEQ_SD8787 <= 1.5 & CAN_C_CAN_PCI <= 1.5 & VIDEO_MUX <= 1.5 & GPIOLIB_IRQCHIP > 0.5 ---> [[  0. 915.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE <= 0.5 & PWRSEQ_SD8787 <= 1.5 & CAN_C_CAN_PCI <= 1.5 & VIDEO_MUX > 1.5 & CRYPTO_RMD256 <= 1.0 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE <= 0.5 & PWRSEQ_SD8787 <= 1.5 & CAN_C_CAN_PCI <= 1.5 & VIDEO_MUX > 1.5 & CRYPTO_RMD256 > 1.0 ---> [[0. 1.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE <= 0.5 & PWRSEQ_SD8787 <= 1.5 & CAN_C_CAN_PCI > 1.5 & HVC_DRIVER <= 0.5 ---> [[0. 1.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE <= 0.5 & PWRSEQ_SD8787 <= 1.5 & CAN_C_CAN_PCI > 1.5 & HVC_DRIVER > 0.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE <= 0.5 & PWRSEQ_SD8787 > 1.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO <= 0.5 & BRIDGE_EBT_LOG <= 1.5 & SND_SOC_CS42L51_I2C <= 1.5 ---> [[  0. 207.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO <= 0.5 & BRIDGE_EBT_LOG <= 1.5 & SND_SOC_CS42L51_I2C > 1.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO <= 0.5 & BRIDGE_EBT_LOG > 1.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS <= 0.5 & SND_SOC_INTEL_BYT_CHT_ES8316_MACH <= 1.5 & SND_PDAUDIOCF <= 1.5 & TYPEC_WCOVE <= 1.5 & CAN_GS_USB <= 1.5 & SND_ATMEL_SOC <= 1.5 & IIO_CROS_EC_LIGHT_PROX <= 1.5 ---> [[   0. 1837.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS <= 0.5 & SND_SOC_INTEL_BYT_CHT_ES8316_MACH <= 1.5 & SND_PDAUDIOCF <= 1.5 & TYPEC_WCOVE <= 1.5 & CAN_GS_USB <= 1.5 & SND_ATMEL_SOC <= 1.5 & IIO_CROS_EC_LIGHT_PROX > 1.5 & RTC_DRV_88PM80X <= 1.5 ---> [[ 0. 19.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS <= 0.5 & SND_SOC_INTEL_BYT_CHT_ES8316_MACH <= 1.5 & SND_PDAUDIOCF <= 1.5 & TYPEC_WCOVE <= 1.5 & CAN_GS_USB <= 1.5 & SND_ATMEL_SOC <= 1.5 & IIO_CROS_EC_LIGHT_PROX > 1.5 & RTC_DRV_88PM80X > 1.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS <= 0.5 & SND_SOC_INTEL_BYT_CHT_ES8316_MACH <= 1.5 & SND_PDAUDIOCF <= 1.5 & TYPEC_WCOVE <= 1.5 & CAN_GS_USB <= 1.5 & SND_ATMEL_SOC > 1.5 & DMA_VIRTUAL_CHANNELS <= 0.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS <= 0.5 & SND_SOC_INTEL_BYT_CHT_ES8316_MACH <= 1.5 & SND_PDAUDIOCF <= 1.5 & TYPEC_WCOVE <= 1.5 & CAN_GS_USB <= 1.5 & SND_ATMEL_SOC > 1.5 & DMA_VIRTUAL_CHANNELS > 0.5 ---> [[ 0. 13.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS <= 0.5 & SND_SOC_INTEL_BYT_CHT_ES8316_MACH <= 1.5 & SND_PDAUDIOCF <= 1.5 & TYPEC_WCOVE <= 1.5 & CAN_GS_USB > 1.5 & JOYSTICK_XPAD <= 1.5 ---> [[ 0. 11.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS <= 0.5 & SND_SOC_INTEL_BYT_CHT_ES8316_MACH <= 1.5 & SND_PDAUDIOCF <= 1.5 & TYPEC_WCOVE <= 1.5 & CAN_GS_USB > 1.5 & JOYSTICK_XPAD > 1.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS <= 0.5 & SND_SOC_INTEL_BYT_CHT_ES8316_MACH <= 1.5 & SND_PDAUDIOCF <= 1.5 & TYPEC_WCOVE > 1.5 & FSL_FTM_TIMER <= 0.5 ---> [[0. 4.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS <= 0.5 & SND_SOC_INTEL_BYT_CHT_ES8316_MACH <= 1.5 & SND_PDAUDIOCF <= 1.5 & TYPEC_WCOVE > 1.5 & FSL_FTM_TIMER > 0.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS <= 0.5 & SND_SOC_INTEL_BYT_CHT_ES8316_MACH <= 1.5 & SND_PDAUDIOCF > 1.5 & RESET_TI_SYSCON <= 1.5 ---> [[0. 4.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS <= 0.5 & SND_SOC_INTEL_BYT_CHT_ES8316_MACH <= 1.5 & SND_PDAUDIOCF > 1.5 & RESET_TI_SYSCON > 1.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS <= 0.5 & SND_SOC_INTEL_BYT_CHT_ES8316_MACH > 1.5 & CRYPTO_WP512 <= 0.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS <= 0.5 & SND_SOC_INTEL_BYT_CHT_ES8316_MACH > 1.5 & CRYPTO_WP512 > 0.5 ---> [[0. 2.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS > 0.5 & PATA_SCH <= 0.5 & CAN_EMS_PCI <= 1.5 & INTEL_SOC_PMIC_BXTWC <= 1.5 ---> [[  0. 674.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS > 0.5 & PATA_SCH <= 0.5 & CAN_EMS_PCI <= 1.5 & INTEL_SOC_PMIC_BXTWC > 1.5 & PATA_RZ1000 <= 1.5 ---> [[ 0. 27.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS > 0.5 & PATA_SCH <= 0.5 & CAN_EMS_PCI <= 1.5 & INTEL_SOC_PMIC_BXTWC > 1.5 & PATA_RZ1000 > 1.5 ---> [[2. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS > 0.5 & PATA_SCH <= 0.5 & CAN_EMS_PCI > 1.5 & COMEDI_MITE <= 0.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS > 0.5 & PATA_SCH <= 0.5 & CAN_EMS_PCI > 1.5 & COMEDI_MITE > 0.5 ---> [[0. 2.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS > 0.5 & PATA_SCH > 0.5 & NLS <= 1.5 & BLK_DEV_SIIMAGE <= 1.5 & PARIDE_EPIA <= 1.5 & TCM_USER2 <= 1.5 ---> [[   0. 1817.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS > 0.5 & PATA_SCH > 0.5 & NLS <= 1.5 & BLK_DEV_SIIMAGE <= 1.5 & PARIDE_EPIA <= 1.5 & TCM_USER2 > 1.5 & AXP20X_POWER <= 1.0 ---> [[0. 1.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS > 0.5 & PATA_SCH > 0.5 & NLS <= 1.5 & BLK_DEV_SIIMAGE <= 1.5 & PARIDE_EPIA <= 1.5 & TCM_USER2 > 1.5 & AXP20X_POWER > 1.0 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS > 0.5 & PATA_SCH > 0.5 & NLS <= 1.5 & BLK_DEV_SIIMAGE <= 1.5 & PARIDE_EPIA > 1.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS > 0.5 & PATA_SCH > 0.5 & NLS <= 1.5 & BLK_DEV_SIIMAGE > 1.5 & FB_VIA <= 0.5 ---> [[0. 1.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS > 0.5 & PATA_SCH > 0.5 & NLS <= 1.5 & BLK_DEV_SIIMAGE > 1.5 & FB_VIA > 0.5 ---> [[3. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS > 0.5 & PATA_SCH > 0.5 & NLS > 1.5 & USB_F_TCM <= 0.5 & VIDEO_CX88_ENABLE_VP3054 <= 0.5 & ACPI_CUSTOM_DSDT_FILE <= 4063.5 & BLK_MQ_VIRTIO <= 0.5 ---> [[2. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS > 0.5 & PATA_SCH > 0.5 & NLS > 1.5 & USB_F_TCM <= 0.5 & VIDEO_CX88_ENABLE_VP3054 <= 0.5 & ACPI_CUSTOM_DSDT_FILE <= 4063.5 & BLK_MQ_VIRTIO > 0.5 ---> [[ 0. 39.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS > 0.5 & PATA_SCH > 0.5 & NLS > 1.5 & USB_F_TCM <= 0.5 & VIDEO_CX88_ENABLE_VP3054 <= 0.5 & ACPI_CUSTOM_DSDT_FILE > 4063.5 ---> [[  0. 768.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS > 0.5 & PATA_SCH > 0.5 & NLS > 1.5 & USB_F_TCM <= 0.5 & VIDEO_CX88_ENABLE_VP3054 > 0.5 & MFD_MAX14577 <= 1.5 ---> [[0. 6.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS > 0.5 & PATA_SCH > 0.5 & NLS > 1.5 & USB_F_TCM <= 0.5 & VIDEO_CX88_ENABLE_VP3054 > 0.5 & MFD_MAX14577 > 1.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS > 0.5 & PATA_SCH > 0.5 & NLS > 1.5 & USB_F_TCM > 0.5 & XENFS <= 0.5 & SND_AT73C213 <= 1.5 & BLK_DEV_THROTTLING_LOW <= 0.5 ---> [[   0. 1017.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS > 0.5 & PATA_SCH > 0.5 & NLS > 1.5 & USB_F_TCM > 0.5 & XENFS <= 0.5 & SND_AT73C213 <= 1.5 & BLK_DEV_THROTTLING_LOW > 0.5 & LCD_L4F00242T03 <= 1.5 & X86_PKG_TEMP_THERMAL <= 1.5 ---> [[ 0. 49.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS > 0.5 & PATA_SCH > 0.5 & NLS > 1.5 & USB_F_TCM > 0.5 & XENFS <= 0.5 & SND_AT73C213 <= 1.5 & BLK_DEV_THROTTLING_LOW > 0.5 & LCD_L4F00242T03 <= 1.5 & X86_PKG_TEMP_THERMAL > 1.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS > 0.5 & PATA_SCH > 0.5 & NLS > 1.5 & USB_F_TCM > 0.5 & XENFS <= 0.5 & SND_AT73C213 <= 1.5 & BLK_DEV_THROTTLING_LOW > 0.5 & LCD_L4F00242T03 > 1.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS > 0.5 & PATA_SCH > 0.5 & NLS > 1.5 & USB_F_TCM > 0.5 & XENFS <= 0.5 & SND_AT73C213 > 1.5 & SND_DMAENGINE_PCM <= 0.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS > 0.5 & PATA_SCH > 0.5 & NLS > 1.5 & USB_F_TCM > 0.5 & XENFS <= 0.5 & SND_AT73C213 > 1.5 & SND_DMAENGINE_PCM > 0.5 ---> [[0. 2.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS > 0.5 & PATA_SCH > 0.5 & NLS > 1.5 & USB_F_TCM > 0.5 & XENFS > 0.5 & PTP_1588_CLOCK_GIANFAR <= 0.5 & BT_HCIUART_NOKIA <= 1.5 ---> [[  0. 127.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS > 0.5 & PATA_SCH > 0.5 & NLS > 1.5 & USB_F_TCM > 0.5 & XENFS > 0.5 & PTP_1588_CLOCK_GIANFAR <= 0.5 & BT_HCIUART_NOKIA > 1.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS > 0.5 & PATA_SCH > 0.5 & NLS > 1.5 & USB_F_TCM > 0.5 & XENFS > 0.5 & PTP_1588_CLOCK_GIANFAR > 0.5 & INFINIBAND_QEDR <= 1.5 & BCM_VIDEOCORE <= 0.5 & NFC_PN544_I2C <= 1.5 & DVB_BUDGET <= 1.5 ---> [[  0. 850.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS > 0.5 & PATA_SCH > 0.5 & NLS > 1.5 & USB_F_TCM > 0.5 & XENFS > 0.5 & PTP_1588_CLOCK_GIANFAR > 0.5 & INFINIBAND_QEDR <= 1.5 & BCM_VIDEOCORE <= 0.5 & NFC_PN544_I2C <= 1.5 & DVB_BUDGET > 1.5 & GPIO_TWL6040 <= 0.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS > 0.5 & PATA_SCH > 0.5 & NLS > 1.5 & USB_F_TCM > 0.5 & XENFS > 0.5 & PTP_1588_CLOCK_GIANFAR > 0.5 & INFINIBAND_QEDR <= 1.5 & BCM_VIDEOCORE <= 0.5 & NFC_PN544_I2C <= 1.5 & DVB_BUDGET > 1.5 & GPIO_TWL6040 > 0.5 ---> [[0. 6.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS > 0.5 & PATA_SCH > 0.5 & NLS > 1.5 & USB_F_TCM > 0.5 & XENFS > 0.5 & PTP_1588_CLOCK_GIANFAR > 0.5 & INFINIBAND_QEDR <= 1.5 & BCM_VIDEOCORE <= 0.5 & NFC_PN544_I2C > 1.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS > 0.5 & PATA_SCH > 0.5 & NLS > 1.5 & USB_F_TCM > 0.5 & XENFS > 0.5 & PTP_1588_CLOCK_GIANFAR > 0.5 & INFINIBAND_QEDR <= 1.5 & BCM_VIDEOCORE > 0.5 & CRYPTO_CRYPTD <= 0.5 & USB_SL811_CS <= 1.5 ---> [[  0. 342.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS > 0.5 & PATA_SCH > 0.5 & NLS > 1.5 & USB_F_TCM > 0.5 & XENFS > 0.5 & PTP_1588_CLOCK_GIANFAR > 0.5 & INFINIBAND_QEDR <= 1.5 & BCM_VIDEOCORE > 0.5 & CRYPTO_CRYPTD <= 0.5 & USB_SL811_CS > 1.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS > 0.5 & PATA_SCH > 0.5 & NLS > 1.5 & USB_F_TCM > 0.5 & XENFS > 0.5 & PTP_1588_CLOCK_GIANFAR > 0.5 & INFINIBAND_QEDR <= 1.5 & BCM_VIDEOCORE > 0.5 & CRYPTO_CRYPTD > 0.5 & VIDEO_SOLO6X10 <= 1.5 ---> [[    0. 47193.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS > 0.5 & PATA_SCH > 0.5 & NLS > 1.5 & USB_F_TCM > 0.5 & XENFS > 0.5 & PTP_1588_CLOCK_GIANFAR > 0.5 & INFINIBAND_QEDR <= 1.5 & BCM_VIDEOCORE > 0.5 & CRYPTO_CRYPTD > 0.5 & VIDEO_SOLO6X10 > 1.5 & MEMCG_SWAP_ENABLED <= 0.5 ---> [[  0. 817.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS > 0.5 & PATA_SCH > 0.5 & NLS > 1.5 & USB_F_TCM > 0.5 & XENFS > 0.5 & PTP_1588_CLOCK_GIANFAR > 0.5 & INFINIBAND_QEDR <= 1.5 & BCM_VIDEOCORE > 0.5 & CRYPTO_CRYPTD > 0.5 & VIDEO_SOLO6X10 > 1.5 & MEMCG_SWAP_ENABLED > 0.5 & NFC_TRF7970A <= 1.5 ---> [[ 0. 21.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS > 0.5 & PATA_SCH > 0.5 & NLS > 1.5 & USB_F_TCM > 0.5 & XENFS > 0.5 & PTP_1588_CLOCK_GIANFAR > 0.5 & INFINIBAND_QEDR <= 1.5 & BCM_VIDEOCORE > 0.5 & CRYPTO_CRYPTD > 0.5 & VIDEO_SOLO6X10 > 1.5 & MEMCG_SWAP_ENABLED > 0.5 & NFC_TRF7970A > 1.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS > 0.5 & PATA_SCH > 0.5 & NLS > 1.5 & USB_F_TCM > 0.5 & XENFS > 0.5 & PTP_1588_CLOCK_GIANFAR > 0.5 & INFINIBAND_QEDR > 1.5 & GPIOLIB <= 0.5 & MAX77620_THERMAL <= 1.5 ---> [[0. 2.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS > 0.5 & PATA_SCH > 0.5 & NLS > 1.5 & USB_F_TCM > 0.5 & XENFS > 0.5 & PTP_1588_CLOCK_GIANFAR > 0.5 & INFINIBAND_QEDR > 1.5 & GPIOLIB <= 0.5 & MAX77620_THERMAL > 1.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS > 0.5 & PATA_SCH > 0.5 & NLS > 1.5 & USB_F_TCM > 0.5 & XENFS > 0.5 & PTP_1588_CLOCK_GIANFAR > 0.5 & INFINIBAND_QEDR > 1.5 & GPIOLIB > 0.5 ---> [[  0. 174.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL > 0.5 & INFINIBAND_ADDR_TRANS <= 0.5 & I40EVF <= 0.5 & HID_LOGITECH <= 1.5 ---> [[0. 9.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL > 0.5 & INFINIBAND_ADDR_TRANS <= 0.5 & I40EVF <= 0.5 & HID_LOGITECH > 1.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL > 0.5 & INFINIBAND_ADDR_TRANS <= 0.5 & I40EVF > 0.5 & VIDEO_XILINX_TPG <= 0.5 & SCR24X <= 1.5 ---> [[ 0. 16.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL > 0.5 & INFINIBAND_ADDR_TRANS <= 0.5 & I40EVF > 0.5 & VIDEO_XILINX_TPG <= 0.5 & SCR24X > 1.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL > 0.5 & INFINIBAND_ADDR_TRANS <= 0.5 & I40EVF > 0.5 & VIDEO_XILINX_TPG > 0.5 ---> [[   0. 4581.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL > 0.5 & INFINIBAND_ADDR_TRANS > 0.5 & FORTIFY_SOURCE <= 0.5 ---> [[  0. 230.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL > 0.5 & INFINIBAND_ADDR_TRANS > 0.5 & FORTIFY_SOURCE > 0.5 & IPV6 <= 1.5 & IPV6 <= 0.5 ---> [[ 0. 36.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL > 0.5 & INFINIBAND_ADDR_TRANS > 0.5 & FORTIFY_SOURCE > 0.5 & IPV6 <= 1.5 & IPV6 > 0.5 & UBSAN_NULL <= 0.5 & UBSAN_ALIGNMENT <= 0.5 ---> [[ 0. 22.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL > 0.5 & INFINIBAND_ADDR_TRANS > 0.5 & FORTIFY_SOURCE > 0.5 & IPV6 <= 1.5 & IPV6 > 0.5 & UBSAN_NULL <= 0.5 & UBSAN_ALIGNMENT > 0.5 ---> [[24.  0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL > 0.5 & INFINIBAND_ADDR_TRANS > 0.5 & FORTIFY_SOURCE > 0.5 & IPV6 <= 1.5 & IPV6 > 0.5 & UBSAN_NULL > 0.5 ---> [[46.  0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL > 0.5 & INFINIBAND_ADDR_TRANS > 0.5 & FORTIFY_SOURCE > 0.5 & IPV6 > 1.5 & NEW_LEDS <= 0.5 ---> [[1. 0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL > 0.5 & INFINIBAND_ADDR_TRANS > 0.5 & FORTIFY_SOURCE > 0.5 & IPV6 > 1.5 & NEW_LEDS > 0.5 ---> [[  0. 118.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE > 0.5 ---> [[419.   0.]]
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE > 0.5 ---> [[1072.    0.]]
# AIC79XX_BUILD_FIRMWARE > 0.5 ---> [[1613.    0.]]

# %%
def tree_to_failure_rules(tree, feature_names):
    tree_ = tree.tree_
    feature_name = [
        feature_names[i] if i != _tree.TREE_UNDEFINED else "undefined!"
        for i in tree_.feature
    ]
    #print ("def tree({}):".format(", ".join(feature_names)))

    def recurse(node, previous_rules, acc):
        if tree_.feature[node] != _tree.TREE_UNDEFINED:
            name = feature_name[node]
            threshold = tree_.threshold[node]
            #print ("{}if {} <= {}:".format(indent, name, threshold))
            recurse(tree_.children_left[node], previous_rules+[name + " <= " + str(threshold)], acc)
            #print ("{}else:  # if {} > {}".format(indent, name, threshold))
            recurse(tree_.children_right[node], previous_rules+[name + " > " + str(threshold)], acc)
        else:
            if tree_.value[node][0][0] > tree_.value[node][0][1]:
                #print(" & ".join(previous_rules) + " ---> " + str(tree_.value[node]))
                acc.append(" & ".join(previous_rules))

    acc = []
    recurse(0, [], acc)
    return acc
    
all_paths = tree_to_failure_rules(clf, rawtuxdata.drop(columns=["cid"]).drop(columns=size_methods).drop(columns=compilation_status_column_name).columns)

# %%
    
def find_rule_for_configuration(tree, feature_names, configuration):
    tree_ = tree.tree_
    feature_name = [
        feature_names[i] if i != _tree.TREE_UNDEFINED else "undefined!"
        for i in tree_.feature
    ]
    
    def recurse(node, previous_rules, configuration):
        if tree_.feature[node] != _tree.TREE_UNDEFINED:
            name = feature_name[node]
            threshold = tree_.threshold[node]
            #print ("{}if {} <= {}:".format(indent, name, threshold))
            if configuration[name] <= threshold:
                return recurse(tree_.children_left[node], previous_rules+[name + " <= " + str(threshold)], configuration)
            #print ("{}else:  # if {} > {}".format(indent, name, threshold))
            else:
                return recurse(tree_.children_right[node], previous_rules+[name + " > " + str(threshold)], configuration)
        else:
            #if tree_.value[node][0][0] > tree_.value[node][0][1]:
            #print(" & ".join(previous_rules))
            return " & ".join(previous_rules)
       
    return recurse(0, [], configuration)
    
def find_rule_for_configuration_id(cid):
    return find_rule_for_configuration(clf, rawtuxdata.drop(columns=["cid"]).drop(columns=size_methods).drop(columns=compilation_status_column_name).columns, rawtuxdata.query("cid == " + str(cid)).iloc[0]) 

find_rule_for_configuration_id(92072)
# Out:
# 'AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS <= 0.5 & SND_SOC_INTEL_BYT_CHT_ES8316_MACH <= 1.5 & SND_PDAUDIOCF <= 1.5 & TYPEC_WCOVE <= 1.5 & CAN_GS_USB <= 1.5 & SND_ATMEL_SOC > 1.5 & DMA_VIRTUAL_CHANNELS <= 0.5'

# %%
rawtuxdata.query("AIC7XXX_BUILD_FIRMWARE == 1 | AIC79XX_BUILD_FIRMWARE == 1 | WANXL_BUILD_FIRMWARE == 1").shape
# Out:
# (3106, 12654)

# %%
rawtuxdata.query("(AIC7XXX_BUILD_FIRMWARE == 0 & AIC79XX_BUILD_FIRMWARE == 0) & WANXL_BUILD_FIRMWARE == 1")['compile_success'].unique()
# Out:
# array([0])

# %%
rawtuxdata.query("AIC7XXX_BUILD_FIRMWARE == 0 & AIC79XX_BUILD_FIRMWARE == 0 & WANXL_BUILD_FIRMWARE == 0 & compile_success == False").shape
# Out:
# (401, 12654)

# %%
'''
basic conclusion: bug GENERIC_ALLOCATOR + DRM_VBOXVIDEO is always masked by firmwares-like failures
'''
generic_allocator_mask_firmwares = rawtuxdata.query("GENERIC_ALLOCATOR == 0 & DRM_VBOXVIDEO == 2 & (AIC7XXX_BUILD_FIRMWARE == 1 | AIC79XX_BUILD_FIRMWARE == 1 | WANXL_BUILD_FIRMWARE == 1)  & compile_success == False")
print("generic allocator bug with firmwares' failures", generic_allocator_mask_firmwares.shape)
print()
print()
for cid in generic_allocator_mask_firmwares['cid']:
    print ("###### configuration id", cid)
    err_pattern = error_pattern.query("cid == " + str(cid)).iloc[0]
    for err in ErrorLog:
        if (err_pattern[err.name]):
            print(err)
    error_messages = errorlogs.query("cid == " + str(cid)).iloc[0]['error_message'].splitlines()
    for error in error_messages:
        if "Cyclomatic " not in error:
            print(error)
    print()
    print()
# Out:
# generic allocator bug with firmwares' failures (13, 12654)
#
#
# ###### configuration id 30901
# ErrorLog.AIC7XXX
# make[4]: flex: Command not found
# make[4]: *** [/TuxML/linux-4.13.3/drivers/scsi/aic7xxx/aicasm//aicasm_scan.c] Error 127
# make[3]: *** [drivers/scsi/aic7xxx/aicasm/aicasm] Error 2
# make[2]: *** [drivers/scsi/aic7xxx] Error 2
# make[1]: *** [drivers/scsi] Error 2
# make[1]: *** Waiting for unfinished jobs....
# make: *** [drivers] Error 2
#
#
# ###### configuration id 36364
# ErrorLog.AS68K
# In file included from ./include/linux/uaccess.h:13:0,
#                  from ./include/linux/highmem.h:8,
#                  from fs/binfmt_elf.c:28:
# fs/binfmt_elf.c: In function 'create_elf_tables':
# ./arch/x86/include/asm/uaccess_64.h:143:20: warning: array subscript is above array bounds [-Warray-bounds]
#     __put_user_asm(4[(u16 *)src], 4 + (u16 __user *)dst,
#                     ^
# ./arch/x86/include/asm/uaccess.h:468:16: note: in definition of macro '__put_user_asm'
#         : ltype(x), "m" (__m(addr)), "i" (errret), "0" (err))
#                 ^
# ./arch/x86/include/asm/uaccess_64.h:143:20: warning: array subscript is above array bounds [-Warray-bounds]
#     __put_user_asm(4[(u16 *)src], 4 + (u16 __user *)dst,
#                     ^
# ./arch/x86/include/asm/uaccess.h:468:16: note: in definition of macro '__put_user_asm'
#         : ltype(x), "m" (__m(addr)), "i" (errret), "0" (err))
#                 ^
# ./arch/x86/include/asm/uaccess_64.h:154:20: warning: array subscript is above array bounds [-Warray-bounds]
#     __put_user_asm(1[(u64 *)src], 1 + (u64 __user *)dst,
#                     ^
# ./arch/x86/include/asm/uaccess.h:468:16: note: in definition of macro '__put_user_asm'
#         : ltype(x), "m" (__m(addr)), "i" (errret), "0" (err))
#                 ^
# ./arch/x86/include/asm/uaccess_64.h:154:20: warning: array subscript is above array bounds [-Warray-bounds]
#     __put_user_asm(1[(u64 *)src], 1 + (u64 __user *)dst,
#                     ^
# ./arch/x86/include/asm/uaccess.h:468:16: note: in definition of macro '__put_user_asm'
#         : ltype(x), "m" (__m(addr)), "i" (errret), "0" (err))
#                 ^
# drivers/gpu/drm/radeon/radeon_object.c: In function 'radeon_bo_create':
# drivers/gpu/drm/radeon/radeon_object.c:242:2: warning: #warning Please enable CONFIG_MTRR and CONFIG_X86_PAT for better performance thanks to write-combining [-Wcpp]
#  #warning Please enable CONFIG_MTRR and CONFIG_X86_PAT for better performance \
#   ^~~~~~~
# /bin/sh: 1: as68k: not found
# make[3]: *** [drivers/net/wan/wanxlfw.inc] Error 127
# make[2]: *** [drivers/net/wan] Error 2
# make[2]: *** Waiting for unfinished jobs....
# make[1]: *** [drivers/net] Error 2
# make[1]: *** Waiting for unfinished jobs....
# make: *** [drivers] Error 2
#
#
# ###### configuration id 37341
# ErrorLog.AICDB
# ErrorLog.AIC7XXX
# aicasm_symbol.c:48:19: fatal error: aicdb.h: No such file or directory
#  #include "aicdb.h"
#                    ^
# compilation terminated.
# aicasm_gram.tab.c: In function 'yyparse':
# aicasm_gram.tab.c:1628:16: warning: implicit declaration of function 'yylex' [-Wimplicit-function-declaration]
# aicasm_macro_gram.tab.c: In function 'mmparse':
# /TuxML/linux-4.13.3/drivers/scsi/aic7xxx/aicasm//aicasm_macro_gram.c:64:25: warning: implicit declaration of function 'mmlex' [-Wimplicit-function-declaration]
#  #define yylex           mmlex
#                          ^
# aicasm_macro_gram.tab.c:1199:16: note: in expansion of macro 'yylex'
# aicasm_scan.l: In function 'yylex':
# aicasm_scan.l:420:6: warning: implicit declaration of function 'mm_switch_to_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(temp_state);
#       ^~~~~~~~~~~~~~~~~~~
# aicasm_scan.l:421:6: warning: implicit declaration of function 'mmparse' [-Wimplicit-function-declaration]
#       mm_switch_to_buffer(old_state);
#       ^~~~~~~
# aicasm_scan.l:424:6: warning: implicit declaration of function 'mm_delete_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(old_state);
#       ^~~~~~~~~~~~~~~~
# make[4]: *** [aicasm] Error 1
# make[3]: *** [drivers/scsi/aic7xxx/aicasm/aicasm] Error 2
# make[2]: *** [drivers/scsi/aic7xxx] Error 2
# make[1]: *** [drivers/scsi] Error 2
# make[1]: *** Waiting for unfinished jobs....
# make: *** [drivers] Error 2
#
#
# ###### configuration id 40757
# ErrorLog.AICDB
# ErrorLog.AIC7XXX
# drivers/gpu/drm/radeon/radeon_object.c: In function 'radeon_bo_create':
# drivers/gpu/drm/radeon/radeon_object.c:242:2: warning: #warning Please enable CONFIG_MTRR and CONFIG_X86_PAT for better performance thanks to write-combining [-Wcpp]
#  #warning Please enable CONFIG_MTRR and CONFIG_X86_PAT for better performance \
#   ^~~~~~~
# drivers/gpu/drm/radeon/radeon_object.c:242:2: warning: #warning Please enable CONFIG_MTRR and CONFIG_X86_PAT for better performance thanks to write-combining [-Wcpp]
#  #warning Please enable CONFIG_MTRR and CONFIG_X86_PAT for better performance \
#   ^~~~~~~
# aicasm_symbol.c:48:19: fatal error: aicdb.h: No such file or directory
#  #include "aicdb.h"
#                    ^
# compilation terminated.
# aicasm_gram.tab.c: In function 'yyparse':
# aicasm_gram.tab.c:1628:16: warning: implicit declaration of function 'yylex' [-Wimplicit-function-declaration]
# aicasm_macro_gram.tab.c: In function 'mmparse':
# /TuxML/linux-4.13.3/drivers/scsi/aic7xxx/aicasm//aicasm_macro_gram.c:64:25: warning: implicit declaration of function 'mmlex' [-Wimplicit-function-declaration]
#  #define yylex           mmlex
#                          ^
# aicasm_macro_gram.tab.c:1199:16: note: in expansion of macro 'yylex'
# aicasm_scan.l: In function 'yylex':
# aicasm_scan.l:420:6: warning: implicit declaration of function 'mm_switch_to_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(temp_state);
#       ^~~~~~~~~~~~~~~~~~~
# aicasm_scan.l:421:6: warning: implicit declaration of function 'mmparse' [-Wimplicit-function-declaration]
#       mm_switch_to_buffer(old_state);
#       ^~~~~~~
# aicasm_scan.l:424:6: warning: implicit declaration of function 'mm_delete_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(old_state);
#       ^~~~~~~~~~~~~~~~
# make[4]: *** [aicasm] Error 1
# make[3]: *** [drivers/scsi/aic7xxx/aicasm/aicasm] Error 2
# make[2]: *** [drivers/scsi/aic7xxx] Error 2
# make[2]: *** Waiting for unfinished jobs....
# make[1]: *** [drivers/scsi] Error 2
# make[1]: *** Waiting for unfinished jobs....
# make: *** [drivers] Error 2
#
#
# ###### configuration id 48193
# ErrorLog.AICDB
# ErrorLog.AIC7XXX
# kernel/sysctl_binary.c: In function 'SYSC_sysctl':
# kernel/sysctl_binary.c:1413:23: note: userspace variable will be forcibly initialized
#   struct __sysctl_args tmp;
#                        ^~~
# kernel/ptrace.c: In function 'ptrace_peek_siginfo':
# kernel/ptrace.c:712:13: note: userspace variable will be forcibly initialized
#    siginfo_t info;
#              ^~~~
# kernel/ptrace.c: In function 'ptrace_request':
# kernel/ptrace.c:1076:16: note: userspace variable will be forcibly initialized
#    struct iovec kiov;
#                 ^~~~
# kernel/ptrace.c:890:12: note: userspace variable will be forcibly initialized
#   siginfo_t siginfo, *si;
#             ^~~~~~~
# kernel/signal.c: In function 'SYSC_sigaltstack':
# kernel/signal.c:3209:15: note: userspace variable will be forcibly initialized
#   stack_t new, old;
#                ^~~
# kernel/signal.c:3209:10: note: userspace variable will be forcibly initialized
#   stack_t new, old;
#           ^~~
# kernel/signal.c: In function 'do_notify_parent_cldstop':
# kernel/signal.c:1706:17: note: userspace variable will be forcibly initialized
#   struct siginfo info;
#                  ^~~~
# kernel/signal.c: In function 'ptrace_do_notify':
# kernel/signal.c:1929:12: note: userspace variable will be forcibly initialized
#   siginfo_t info;
#             ^~~~
# kernel/signal.c: In function 'SYSC_rt_tgsigqueueinfo':
# kernel/signal.c:3071:12: note: userspace variable will be forcibly initialized
#   siginfo_t info;
#             ^~~~
# kernel/signal.c: In function 'SYSC_kill':
# kernel/signal.c:2917:17: note: userspace variable will be forcibly initialized
#   struct siginfo info;
#                  ^~~~
# kernel/signal.c: In function 'SYSC_rt_sigqueueinfo':
# kernel/signal.c:3030:12: note: userspace variable will be forcibly initialized
#   siginfo_t info;
#             ^~~~
# kernel/signal.c: In function 'do_notify_parent':
# kernel/signal.c:1602:17: note: userspace variable will be forcibly initialized
#   struct siginfo info;
#                  ^~~~
# In file included from arch/x86/entry/common.c:17:0:
# arch/x86/entry/common.c: In function 'tracehook_report_syscall_exit':
# ./include/linux/tracehook.h:126:13: note: userspace variable will be forcibly initialized
#    siginfo_t info;
#              ^~~~
# kernel/signal.c: In function 'SYSC_rt_sigtimedwait':
# kernel/signal.c:2851:12: note: userspace variable will be forcibly initialized
#   siginfo_t info;
#             ^~~~
# kernel/signal.c: In function 'restore_altstack':
# kernel/signal.c:3222:10: note: userspace variable will be forcibly initialized
#   stack_t new;
#           ^~~
# arch/x86/entry/vsyscall/vsyscall_64.c: In function 'write_ok_or_segv':
# arch/x86/entry/vsyscall/vsyscall_64.c:105:13: note: userspace variable will be forcibly initialized
#    siginfo_t info;
#              ^~~~
# arch/x86/kernel/signal.c: In function 'do_signal':
# arch/x86/kernel/signal.c:806:17: note: userspace variable will be forcibly initialized
#   struct ksignal ksig;
#                  ^~~~
# arch/x86/kernel/traps.c: In function 'math_error':
# arch/x86/kernel/traps.c:827:12: note: userspace variable will be forcibly initialized
#   siginfo_t info;
#             ^~~~
# arch/x86/kernel/traps.c: In function 'do_error_trap':
# arch/x86/kernel/traps.c:303:12: note: userspace variable will be forcibly initialized
#   siginfo_t info;
#             ^~~~
# arch/x86/mm/fault.c: In function 'force_sig_info_fault':
# arch/x86/mm/fault.c:231:12: note: userspace variable will be forcibly initialized
#   siginfo_t info;
#             ^~~~
# In file included from fs/read_write.c:12:0:
# fs/read_write.c: In function 'iov_iter_iovec':
# ./include/linux/uio.h:69:9: note: userspace variable will be forcibly initialized
#   return (struct iovec) {
#          ^
# fs/read_write.c: In function 'new_sync_read':
# fs/read_write.c:391:15: note: userspace variable will be forcibly initialized
#   struct iovec iov = { .iov_base = buf, .iov_len = len };
#                ^~~
# fs/read_write.c: In function 'new_sync_write':
# fs/read_write.c:448:15: note: userspace variable will be forcibly initialized
#   struct iovec iov = { .iov_base = (void __user *)buf, .iov_len = len };
#                ^~~
# In file included from fs/read_write.c:12:0:
# fs/read_write.c: In function 'do_loop_readv_writev':
# ./include/linux/uio.h:69:9: note: userspace variable will be forcibly initialized
#   return (struct iovec) {
#          ^
# fs/read_write.c:666:16: note: userspace variable will be forcibly initialized
#    struct iovec iovec = iov_iter_iovec(iter);
#                 ^~~~~
# fs/exec.c: In function 'count':
# fs/exec.c:465:12: note: userspace variable will be forcibly initialized
#  static int count(struct user_arg_ptr argv, int max)
#             ^~~~~
# fs/exec.c: In function 'copy_strings':
# fs/exec.c:496:12: note: userspace variable will be forcibly initialized
#  static int copy_strings(int argc, struct user_arg_ptr argv,
#             ^~~~~~~~~~~~
# fs/exec.c: In function 'copy_strings_kernel':
# fs/exec.c:592:22: note: userspace variable will be forcibly initialized
#   struct user_arg_ptr argv = {
#                       ^~~~
# fs/exec.c: In function 'do_execveat_common':
# fs/exec.c:592:22: note: userspace variable will be forcibly initialized
# fs/exec.c: In function 'do_execve':
# fs/exec.c:1833:22: note: userspace variable will be forcibly initialized
#   struct user_arg_ptr envp = { .ptr.native = __envp };
#                       ^~~~
# fs/exec.c:1832:22: note: userspace variable will be forcibly initialized
#   struct user_arg_ptr argv = { .ptr.native = __argv };
#                       ^~~~
# fs/exec.c: In function 'SYSC_execve':
# fs/exec.c:1832:22: note: userspace variable will be forcibly initialized
# fs/exec.c:1833:22: note: userspace variable will be forcibly initialized
#   struct user_arg_ptr envp = { .ptr.native = __envp };
#                       ^~~~
# fs/exec.c: In function 'do_execveat':
# fs/exec.c:1843:22: note: userspace variable will be forcibly initialized
#   struct user_arg_ptr envp = { .ptr.native = __envp };
#                       ^~~~
# fs/exec.c:1842:22: note: userspace variable will be forcibly initialized
#   struct user_arg_ptr argv = { .ptr.native = __argv };
#                       ^~~~
# fs/exec.c: In function 'SYSC_execveat':
# fs/exec.c:1842:22: note: userspace variable will be forcibly initialized
# fs/exec.c:1843:22: note: userspace variable will be forcibly initialized
#   struct user_arg_ptr envp = { .ptr.native = __envp };
#                       ^~~~
# fs/fcntl.c: In function 'send_sigio_to_task':
# fs/fcntl.c:733:13: note: userspace variable will be forcibly initialized
#    siginfo_t si;
#              ^~
# fs/splice.c: In function 'vmsplice_to_user':
# fs/splice.c:1265:21: note: userspace variable will be forcibly initialized
#   struct splice_desc sd;
#                      ^~
# arch/x86/kernel/ptrace.c: In function 'send_sigtrap':
# arch/x86/kernel/ptrace.c:1396:17: note: userspace variable will be forcibly initialized
#   struct siginfo info;
#                  ^~~~
# arch/x86/kernel/stacktrace.c: In function '__save_stack_trace_user':
# arch/x86/kernel/stacktrace.c:207:27: note: userspace variable will be forcibly initialized
#    struct stack_frame_user frame;
#                            ^~~~~
# kernel/time/posix-timers.c: In function 'SYSC_timer_create':
# kernel/time/posix-timers.c:577:14: note: userspace variable will be forcibly initialized
#    sigevent_t event;
#               ^~~~~
# security/keys/keyring.c: In function 'keyring_read':
# security/keys/keyring.c:461:39: note: userspace variable will be forcibly initialized
#   struct keyring_read_iterator_context ctx;
#                                        ^~~
# security/keys/keyctl.c: In function 'keyctl_instantiate_key':
# security/keys/keyctl.c:1122:16: note: userspace variable will be forcibly initialized
#    struct iovec iov;
#                 ^~~
# In file included from block/bio.c:22:0:
# block/bio.c: In function 'iov_iter_iovec':
# ./include/linux/uio.h:69:9: note: userspace variable will be forcibly initialized
#   return (struct iovec) {
#          ^
# block/bio.c: In function 'bio_map_user_iov':
# ./include/linux/uio.h:69:9: note: userspace variable will be forcibly initialized
# ./include/linux/uio.h:69:9: note: userspace variable will be forcibly initialized
# block/bio.c:1329:15: note: userspace variable will be forcibly initialized
#   struct iovec iov;
#                ^~~
# block/blk-map.c: In function 'blk_rq_map_user':
# block/blk-map.c:160:15: note: userspace variable will be forcibly initialized
#   struct iovec iov;
#                ^~~
# block/ioctl.c: In function 'blkpg_ioctl':
# block/ioctl.c:18:25: note: userspace variable will be forcibly initialized
#   struct blkpg_ioctl_arg a;
#                          ^
# block/scsi_ioctl.c: In function 'scsi_cmd_ioctl':
# block/scsi_ioctl.c:612:21: note: userspace variable will be forcibly initialized
#     struct sg_io_hdr hdr;
#                      ^~~
# block/scsi_ioctl.c:611:33: note: userspace variable will be forcibly initialized
#     struct cdrom_generic_command cgc;
#                                  ^~~
# block/scsi_ioctl.c:597:21: note: userspace variable will be forcibly initialized
#     struct sg_io_hdr hdr;
#                      ^~~
# sound/core/control.c: In function 'snd_ctl_elem_list':
# sound/core/control.c:750:27: note: userspace variable will be forcibly initialized
#   struct snd_ctl_elem_list list;
#                            ^~~~
# sound/core/hwdep.c: In function 'snd_hwdep_dsp_load':
# sound/core/hwdep.c:223:29: note: userspace variable will be forcibly initialized
#   struct snd_hwdep_dsp_image info;
#                              ^~~~
# sound/core/pcm_native.c: In function 'snd_pcm_capture_ioctl1':
# sound/core/pcm_native.c:2971:20: note: userspace variable will be forcibly initialized
#    struct snd_xfern xfern;
#                     ^~~~~
# sound/core/pcm_native.c:2955:20: note: userspace variable will be forcibly initialized
#    struct snd_xferi xferi;
#                     ^~~~~
# sound/core/pcm_native.c: In function 'snd_pcm_playback_ioctl1':
# sound/core/pcm_native.c:2891:20: note: userspace variable will be forcibly initialized
#    struct snd_xfern xfern;
#                     ^~~~~
# sound/core/pcm_native.c:2875:20: note: userspace variable will be forcibly initialized
#    struct snd_xferi xferi;
#                     ^~~~~
# lib/iov_iter.c: In function 'iov_iter_fault_in_readable':
# lib/iov_iter.c:418:15: note: userspace variable will be forcibly initialized
#   struct iovec v;
#                ^
# lib/iov_iter.c: In function '_copy_to_iter':
# lib/iov_iter.c:565:32: note: userspace variable will be forcibly initialized
#   iterate_and_advance(i, bytes, v,
#                                 ^
# lib/iov_iter.c:119:17: note: in definition of macro 'iterate_and_advance'
#     struct iovec v;    \
#                  ^
# lib/iov_iter.c: In function '_copy_from_iter':
# lib/iov_iter.c:585:32: note: userspace variable will be forcibly initialized
#   iterate_and_advance(i, bytes, v,
#                                 ^
# lib/iov_iter.c:119:17: note: in definition of macro 'iterate_and_advance'
#     struct iovec v;    \
#                  ^
# lib/iov_iter.c: In function '_copy_from_iter_nocache':
# lib/iov_iter.c:630:32: note: userspace variable will be forcibly initialized
#   iterate_and_advance(i, bytes, v,
#                                 ^
# lib/iov_iter.c:119:17: note: in definition of macro 'iterate_and_advance'
#     struct iovec v;    \
#                  ^
# lib/iov_iter.c: In function '_copy_from_iter_flushcache':
# lib/iov_iter.c:650:32: note: userspace variable will be forcibly initialized
#   iterate_and_advance(i, bytes, v,
#                                 ^
# lib/iov_iter.c:119:17: note: in definition of macro 'iterate_and_advance'
#     struct iovec v;    \
#                  ^
# lib/iov_iter.c: In function 'iov_iter_zero':
# lib/iov_iter.c:761:32: note: userspace variable will be forcibly initialized
#   iterate_and_advance(i, bytes, v,
#                                 ^
# lib/iov_iter.c:119:17: note: in definition of macro 'iterate_and_advance'
#     struct iovec v;    \
#                  ^
# lib/iov_iter.c: In function 'iov_iter_copy_from_user_atomic':
# lib/iov_iter.c:784:30: note: userspace variable will be forcibly initialized
#   iterate_all_kinds(i, bytes, v,
#                               ^
# lib/iov_iter.c:88:17: note: in definition of macro 'iterate_all_kinds'
#     struct iovec v;    \
#                  ^
# lib/iov_iter.c: In function 'iov_iter_advance':
# lib/iov_iter.c:847:31: note: userspace variable will be forcibly initialized
#   iterate_and_advance(i, size, v, 0, 0, 0)
#                                ^
# lib/iov_iter.c:119:17: note: in definition of macro 'iterate_and_advance'
#     struct iovec v;    \
#                  ^
# lib/iov_iter.c: In function '_copy_from_iter_full':
# lib/iov_iter.c:608:30: note: userspace variable will be forcibly initialized
#   iterate_all_kinds(i, bytes, v, ({
#                               ^
# lib/iov_iter.c:88:17: note: in definition of macro 'iterate_all_kinds'
#     struct iovec v;    \
#                  ^
# lib/iov_iter.c: In function '_copy_from_iter_full_nocache':
# lib/iov_iter.c:673:30: note: userspace variable will be forcibly initialized
#   iterate_all_kinds(i, bytes, v, ({
#                               ^
# lib/iov_iter.c:88:17: note: in definition of macro 'iterate_all_kinds'
#     struct iovec v;    \
#                  ^
# lib/iov_iter.c: In function 'iov_iter_alignment':
# lib/iov_iter.c:982:29: note: userspace variable will be forcibly initialized
#   iterate_all_kinds(i, size, v,
#                              ^
# lib/iov_iter.c:88:17: note: in definition of macro 'iterate_all_kinds'
#     struct iovec v;    \
#                  ^
# lib/iov_iter.c: In function 'iov_iter_gap_alignment':
# lib/iov_iter.c:1001:29: note: userspace variable will be forcibly initialized
#   iterate_all_kinds(i, size, v,
#                              ^
# lib/iov_iter.c:88:17: note: in definition of macro 'iterate_all_kinds'
#     struct iovec v;    \
#                  ^
# lib/iov_iter.c: In function 'iov_iter_get_pages':
# lib/iov_iter.c:1066:32: note: userspace variable will be forcibly initialized
#   iterate_all_kinds(i, maxsize, v, ({
#                                 ^
# lib/iov_iter.c:88:17: note: in definition of macro 'iterate_all_kinds'
#     struct iovec v;    \
#                  ^
# lib/iov_iter.c: In function 'iov_iter_get_pages_alloc':
# lib/iov_iter.c:1143:32: note: userspace variable will be forcibly initialized
#   iterate_all_kinds(i, maxsize, v, ({
#                                 ^
# lib/iov_iter.c:88:17: note: in definition of macro 'iterate_all_kinds'
#     struct iovec v;    \
#                  ^
# lib/iov_iter.c: In function 'csum_and_copy_from_iter':
# lib/iov_iter.c:1188:32: note: userspace variable will be forcibly initialized
#   iterate_and_advance(i, bytes, v, ({
#                                 ^
# lib/iov_iter.c:119:17: note: in definition of macro 'iterate_and_advance'
#     struct iovec v;    \
#                  ^
# lib/iov_iter.c: In function 'csum_and_copy_from_iter_full':
# lib/iov_iter.c:1232:30: note: userspace variable will be forcibly initialized
#   iterate_all_kinds(i, bytes, v, ({
#                               ^
# lib/iov_iter.c:88:17: note: in definition of macro 'iterate_all_kinds'
#     struct iovec v;    \
#                  ^
# lib/iov_iter.c: In function 'csum_and_copy_to_iter':
# lib/iov_iter.c:1275:32: note: userspace variable will be forcibly initialized
#   iterate_and_advance(i, bytes, v, ({
#                                 ^
# lib/iov_iter.c:119:17: note: in definition of macro 'iterate_and_advance'
#     struct iovec v;    \
#                  ^
# lib/iov_iter.c: In function 'iov_iter_npages':
# lib/iov_iter.c:1327:36: note: userspace variable will be forcibly initialized
#   } else iterate_all_kinds(i, size, v, ({
#                                     ^
# lib/iov_iter.c:88:17: note: in definition of macro 'iterate_all_kinds'
#     struct iovec v;    \
#                  ^
# drivers/block/floppy.c: In function 'raw_cmd_copyout':
# drivers/block/floppy.c:3073:25: note: userspace variable will be forcibly initialized
#    struct floppy_raw_cmd cmd = *ptr;
#                          ^~~
# drivers/block/DAC960.c: In function 'DAC960_gam_ioctl':
# drivers/block/DAC960.c:7007:30: note: userspace variable will be forcibly initialized
#   DAC960_V2_GetHealthStatus_T GetHealthStatus;
#                               ^~~~~~~~~~~~~~~
# drivers/block/DAC960.c:6843:26: note: userspace variable will be forcibly initialized
#   DAC960_V2_UserCommand_T UserCommand;
#                           ^~~~~~~~~~~
# drivers/block/DAC960.c:6676:26: note: userspace variable will be forcibly initialized
#   DAC960_V1_UserCommand_T UserCommand;
#                           ^~~~~~~~~~~
# drivers/block/skd_main.c: In function 'skd_sg_io_copy_buffer':
# drivers/block/skd_main.c:1595:18: note: userspace variable will be forcibly initialized
#   struct sg_iovec curiov;
#                   ^~~~~~
# drivers/block/skd_main.c: In function 'skd_ioctl_sg_io':
# drivers/block/skd_main.c:1247:19: note: userspace variable will be forcibly initialized
#   struct skd_sg_io sksgio;
#                    ^~~~~~
# In file included from fs/jffs2/background.c:19:0:
# fs/jffs2/background.c: In function 'kernel_dequeue_signal':
# ./include/linux/sched/signal.h:268:12: note: userspace variable will be forcibly initialized
#   siginfo_t __info;
#             ^~~~~~
# drivers/cdrom/cdrom.c: In function 'mmc_ioctl_cdrom_read_audio':
# drivers/cdrom/cdrom.c:3006:26: note: userspace variable will be forcibly initialized
#   struct cdrom_read_audio ra;
#                           ^~
# drivers/char/mwave/mwavedd.c: In function 'mwave_ioctl':
# drivers/char/mwave/mwavedd.c:259:17: note: userspace variable will be forcibly initialized
#     MW_READWRITE rWriteData;
#                  ^~~~~~~~~~
# drivers/char/mwave/mwavedd.c:236:17: note: userspace variable will be forcibly initialized
#     MW_READWRITE rWriteData;
#                  ^~~~~~~~~~
# drivers/char/mwave/mwavedd.c:213:17: note: userspace variable will be forcibly initialized
#     MW_READWRITE rReadData;
#                  ^~~~~~~~~
# drivers/char/mwave/mwavedd.c:190:17: note: userspace variable will be forcibly initialized
#     MW_READWRITE rReadData;
#                  ^~~~~~~~~
# fs/eventpoll.c: In function 'ep_send_events':
# fs/eventpoll.c:1718:29: note: userspace variable will be forcibly initialized
#   struct ep_send_events_data esed;
#                              ^~~~
# fs/eventpoll.c: In function 'ep_poll':
# fs/eventpoll.c:1718:29: note: userspace variable will be forcibly initialized
# fs/signalfd.c: In function 'signalfd_read':
# fs/signalfd.c:211:12: note: userspace variable will be forcibly initialized
#   siginfo_t info;
#             ^~~~
# drivers/hid/uhid.c: In function 'uhid_dev_create':
# drivers/hid/uhid.c:535:25: note: userspace variable will be forcibly initialized
#   struct uhid_create_req orig;
#                          ^~~~
# drivers/i2c/i2c-dev.c: In function 'i2cdev_ioctl_rdwr':
# drivers/i2c/i2c-dev.c:243:29: note: userspace variable will be forcibly initialized
#   struct i2c_rdwr_ioctl_data rdwr_arg;
#                              ^~~~~~~~
# drivers/i2c/i2c-dev.c: In function 'i2cdev_ioctl_smbus':
# drivers/i2c/i2c-dev.c:333:30: note: userspace variable will be forcibly initialized
#   struct i2c_smbus_ioctl_data data_arg;
#                               ^~~~~~~~
# drivers/input/ff-memless.c: In function 'ml_play_effects':
# drivers/input/ff-memless.c:404:19: note: userspace variable will be forcibly initialized
#   struct ff_effect effect;
#                    ^~~~~~
# drivers/input/evdev.c: In function 'evdev_do_ioctl':
# drivers/input/evdev.c:1067:19: note: userspace variable will be forcibly initialized
#   struct ff_effect effect;
#                    ^~~~~~
# drivers/input/misc/uinput.c: In function 'uinput_ioctl_handler':
# drivers/input/misc/uinput.c:792:26: note: userspace variable will be forcibly initialized
#   struct uinput_ff_upload ff_up;
#                           ^~~~~
# drivers/mtd/mtdchar.c: In function 'mtdchar_ioctl':
# drivers/mtd/mtdchar.c:1035:26: note: userspace variable will be forcibly initialized
#    struct blkpg_ioctl_arg a;
#                           ^
# drivers/mtd/mtdchar.c:806:22: note: userspace variable will be forcibly initialized
#    struct mtd_oob_buf buf;
#                       ^~~
# drivers/mtd/mtdchar.c:792:22: note: userspace variable will be forcibly initialized
#    struct mtd_oob_buf buf;
#                       ^~~
# drivers/gpu/drm/qxl/qxl_ioctl.c: In function 'qxl_execbuffer_ioctl':
# drivers/gpu/drm/qxl/qxl_ioctl.c:279:25: note: userspace variable will be forcibly initialized
#   struct drm_qxl_command user_cmd;
#                          ^~~~~~~~
# aicasm_symbol.c:48:19: fatal error: aicdb.h: No such file or directory
#  #include "aicdb.h"
#                    ^
# compilation terminated.
# aicasm_gram.tab.c: In function 'yyparse':
# aicasm_gram.tab.c:1628:16: warning: implicit declaration of function 'yylex' [-Wimplicit-function-declaration]
# aicasm_macro_gram.tab.c: In function 'mmparse':
# /TuxML/linux-4.13.3/drivers/scsi/aic7xxx/aicasm//aicasm_macro_gram.c:64:25: warning: implicit declaration of function 'mmlex' [-Wimplicit-function-declaration]
#  #define yylex           mmlex
#                          ^
# aicasm_macro_gram.tab.c:1199:16: note: in expansion of macro 'yylex'
# aicasm_scan.l: In function 'yylex':
# aicasm_scan.l:420:6: warning: implicit declaration of function 'mm_switch_to_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(temp_state);
#       ^~~~~~~~~~~~~~~~~~~
# aicasm_scan.l:421:6: warning: implicit declaration of function 'mmparse' [-Wimplicit-function-declaration]
#       mm_switch_to_buffer(old_state);
#       ^~~~~~~
# aicasm_scan.l:424:6: warning: implicit declaration of function 'mm_delete_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(old_state);
#       ^~~~~~~~~~~~~~~~
# make[4]: *** [aicasm] Error 1
# make[3]: *** [drivers/scsi/aic7xxx/aicasm/aicasm] Error 2
# make[2]: *** [drivers/scsi/aic7xxx] Error 2
# make[1]: *** [drivers/scsi] Error 2
# make[1]: *** Waiting for unfinished jobs....
# make: *** [drivers] Error 2
#
#
# ###### configuration id 50359
# ErrorLog.AICDB
# ErrorLog.AIC7XXX
# aicasm_symbol.c:48:19: fatal error: aicdb.h: No such file or directory
#  #include "aicdb.h"
#                    ^
# compilation terminated.
# aicasm_gram.tab.c: In function 'yyparse':
# aicasm_gram.tab.c:1628:16: warning: implicit declaration of function 'yylex' [-Wimplicit-function-declaration]
# aicasm_macro_gram.tab.c: In function 'mmparse':
# /TuxML/linux-4.13.3/drivers/scsi/aic7xxx/aicasm//aicasm_macro_gram.c:64:25: warning: implicit declaration of function 'mmlex' [-Wimplicit-function-declaration]
#  #define yylex           mmlex
#                          ^
# aicasm_macro_gram.tab.c:1199:16: note: in expansion of macro 'yylex'
# aicasm_scan.l: In function 'yylex':
# aicasm_scan.l:420:6: warning: implicit declaration of function 'mm_switch_to_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(temp_state);
#       ^~~~~~~~~~~~~~~~~~~
# aicasm_scan.l:421:6: warning: implicit declaration of function 'mmparse' [-Wimplicit-function-declaration]
#       mm_switch_to_buffer(old_state);
#       ^~~~~~~
# aicasm_scan.l:424:6: warning: implicit declaration of function 'mm_delete_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(old_state);
#       ^~~~~~~~~~~~~~~~
# make[4]: *** [aicasm] Error 1
# make[3]: *** [drivers/scsi/aic7xxx/aicasm/aicasm] Error 2
# make[2]: *** [drivers/scsi/aic7xxx] Error 2
# make[1]: *** [drivers/scsi] Error 2
# make[1]: *** Waiting for unfinished jobs....
# make: *** [drivers] Error 2
#
#
# ###### configuration id 53234
# ErrorLog.AS68K
# /bin/sh: 1: as68k: not found
# make[3]: *** [drivers/net/wan/wanxlfw.inc] Error 127
# make[3]: *** Waiting for unfinished jobs....
# make[2]: *** [drivers/net/wan] Error 2
# make[2]: *** Waiting for unfinished jobs....
# make[1]: *** [drivers/net] Error 2
# make: *** [drivers] Error 2
#
#
# ###### configuration id 55986
# ErrorLog.AICDB
# ErrorLog.AIC7XXX
# aicasm_symbol.c:48:19: fatal error: aicdb.h: No such file or directory
#  #include "aicdb.h"
#                    ^
# compilation terminated.
# aicasm_gram.tab.c: In function 'yyparse':
# aicasm_gram.tab.c:1628:16: warning: implicit declaration of function 'yylex' [-Wimplicit-function-declaration]
# aicasm_macro_gram.tab.c: In function 'mmparse':
# /TuxML/linux-4.13.3/drivers/scsi/aic7xxx/aicasm//aicasm_macro_gram.c:64:25: warning: implicit declaration of function 'mmlex' [-Wimplicit-function-declaration]
#  #define yylex           mmlex
#                          ^
# aicasm_macro_gram.tab.c:1199:16: note: in expansion of macro 'yylex'
# aicasm_scan.l: In function 'yylex':
# aicasm_scan.l:420:6: warning: implicit declaration of function 'mm_switch_to_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(temp_state);
#       ^~~~~~~~~~~~~~~~~~~
# aicasm_scan.l:421:6: warning: implicit declaration of function 'mmparse' [-Wimplicit-function-declaration]
#       mm_switch_to_buffer(old_state);
#       ^~~~~~~
# aicasm_scan.l:424:6: warning: implicit declaration of function 'mm_delete_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(old_state);
#       ^~~~~~~~~~~~~~~~
# make[4]: *** [aicasm] Error 1
# make[3]: *** [drivers/scsi/aic7xxx/aicasm/aicasm] Error 2
# make[2]: *** [drivers/scsi/aic7xxx] Error 2
# make[1]: *** [drivers/scsi] Error 2
# make[1]: *** Waiting for unfinished jobs....
# make: *** [drivers] Error 2
#
#
# ###### configuration id 59253
# ErrorLog.AICDB
# ErrorLog.AIC7XXX
# aicasm_symbol.c:48:19: fatal error: aicdb.h: No such file or directory
#  #include "aicdb.h"
#                    ^
# compilation terminated.
# aicasm_gram.tab.c: In function 'yyparse':
# aicasm_gram.tab.c:1628:16: warning: implicit declaration of function 'yylex' [-Wimplicit-function-declaration]
# aicasm_macro_gram.tab.c: In function 'mmparse':
# /TuxML/linux-4.13.3/drivers/scsi/aic7xxx/aicasm//aicasm_macro_gram.c:64:25: warning: implicit declaration of function 'mmlex' [-Wimplicit-function-declaration]
#  #define yylex           mmlex
#                          ^
# aicasm_macro_gram.tab.c:1199:16: note: in expansion of macro 'yylex'
# aicasm_scan.l: In function 'yylex':
# aicasm_scan.l:420:6: warning: implicit declaration of function 'mm_switch_to_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(temp_state);
#       ^~~~~~~~~~~~~~~~~~~
# aicasm_scan.l:421:6: warning: implicit declaration of function 'mmparse' [-Wimplicit-function-declaration]
#       mm_switch_to_buffer(old_state);
#       ^~~~~~~
# aicasm_scan.l:424:6: warning: implicit declaration of function 'mm_delete_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(old_state);
#       ^~~~~~~~~~~~~~~~
# make[4]: *** [aicasm] Error 1
# make[3]: *** [drivers/scsi/aic7xxx/aicasm/aicasm] Error 2
# make[2]: *** [drivers/scsi/aic7xxx] Error 2
# make[1]: *** [drivers/scsi] Error 2
# make[1]: *** Waiting for unfinished jobs....
# make: *** [drivers] Error 2
#
#
# ###### configuration id 61758
# ErrorLog.AICDB
# ErrorLog.AIC7XXX
# drivers/gpu/drm/radeon/radeon_object.c: In function 'radeon_bo_create':
# drivers/gpu/drm/radeon/radeon_object.c:242:2: warning: #warning Please enable CONFIG_MTRR and CONFIG_X86_PAT for better performance thanks to write-combining [-Wcpp]
#  #warning Please enable CONFIG_MTRR and CONFIG_X86_PAT for better performance \
#   ^~~~~~~
# aicasm_symbol.c:48:19: fatal error: aicdb.h: No such file or directory
#  #include "aicdb.h"
#                    ^
# compilation terminated.
# aicasm_gram.tab.c: In function 'yyparse':
# aicasm_gram.tab.c:1628:16: warning: implicit declaration of function 'yylex' [-Wimplicit-function-declaration]
# aicasm_macro_gram.tab.c: In function 'mmparse':
# /TuxML/linux-4.13.3/drivers/scsi/aic7xxx/aicasm//aicasm_macro_gram.c:64:25: warning: implicit declaration of function 'mmlex' [-Wimplicit-function-declaration]
#  #define yylex           mmlex
#                          ^
# aicasm_macro_gram.tab.c:1199:16: note: in expansion of macro 'yylex'
# aicasm_scan.l: In function 'yylex':
# aicasm_scan.l:420:6: warning: implicit declaration of function 'mm_switch_to_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(temp_state);
#       ^~~~~~~~~~~~~~~~~~~
# aicasm_scan.l:421:6: warning: implicit declaration of function 'mmparse' [-Wimplicit-function-declaration]
#       mm_switch_to_buffer(old_state);
#       ^~~~~~~
# aicasm_scan.l:424:6: warning: implicit declaration of function 'mm_delete_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(old_state);
#       ^~~~~~~~~~~~~~~~
# make[4]: *** [aicasm] Error 1
# make[3]: *** [drivers/scsi/aic7xxx/aicasm/aicasm] Error 2
# make[2]: *** [drivers/scsi/aic7xxx] Error 2
# make[1]: *** [drivers/scsi] Error 2
# make[1]: *** Waiting for unfinished jobs....
# make: *** [drivers] Error 2
#
#
# ###### configuration id 67576
# ErrorLog.AICDB
# ErrorLog.AIC7XXX
# aicasm_symbol.c:48:19: fatal error: aicdb.h: No such file or directory
#  #include "aicdb.h"
#                    ^
# compilation terminated.
# aicasm_gram.tab.c: In function 'yyparse':
# aicasm_gram.tab.c:1628:16: warning: implicit declaration of function 'yylex' [-Wimplicit-function-declaration]
# aicasm_macro_gram.tab.c: In function 'mmparse':
# /TuxML/linux-4.13.3/drivers/scsi/aic7xxx/aicasm//aicasm_macro_gram.c:64:25: warning: implicit declaration of function 'mmlex' [-Wimplicit-function-declaration]
#  #define yylex           mmlex
#                          ^
# aicasm_macro_gram.tab.c:1199:16: note: in expansion of macro 'yylex'
# aicasm_scan.l: In function 'yylex':
# aicasm_scan.l:420:6: warning: implicit declaration of function 'mm_switch_to_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(temp_state);
#       ^~~~~~~~~~~~~~~~~~~
# aicasm_scan.l:421:6: warning: implicit declaration of function 'mmparse' [-Wimplicit-function-declaration]
#       mm_switch_to_buffer(old_state);
#       ^~~~~~~
# aicasm_scan.l:424:6: warning: implicit declaration of function 'mm_delete_buffer' [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(old_state);
#       ^~~~~~~~~~~~~~~~
# make[4]: *** [aicasm] Error 1
# make[3]: *** [drivers/scsi/aic7xxx/aicasm/aicasm] Error 2
# make[2]: *** [drivers/scsi/aic7xxx] Error 2
# make[1]: *** [drivers/scsi] Error 2
# make[1]: *** Waiting for unfinished jobs....
# drivers/gpu/drm/radeon/radeon_object.c: In function 'radeon_bo_create':
# drivers/gpu/drm/radeon/radeon_object.c:242:2: warning: #warning Please enable CONFIG_MTRR and CONFIG_X86_PAT for better performance thanks to write-combining [-Wcpp]
#  #warning Please enable CONFIG_MTRR and CONFIG_X86_PAT for better performance \
#   ^~~~~~~
# make: *** [drivers] Error 2
#
#
# ###### configuration id 79099
# ErrorLog.AICDB
# ErrorLog.AIC7XXX
# aicasm_symbol.c:48:19: fatal error: aicdb.h: No such file or directory
#  #include "aicdb.h"
#                    ^
# compilation terminated.
# aicasm_gram.tab.c: In function ‘yyparse’:
# aicasm_gram.tab.c:1628:16: warning: implicit declaration of function ‘yylex’ [-Wimplicit-function-declaration]
# aicasm_macro_gram.tab.c: In function ‘mmparse’:
# /TuxML/linux-4.13.3/drivers/scsi/aic7xxx/aicasm//aicasm_macro_gram.c:64:25: warning: implicit declaration of function ‘mmlex’ [-Wimplicit-function-declaration]
#  #define yylex           mmlex
#                          ^
# aicasm_macro_gram.tab.c:1199:16: note: in expansion of macro ‘yylex’
# aicasm_scan.l: In function ‘yylex’:
# aicasm_scan.l:420:6: warning: implicit declaration of function ‘mm_switch_to_buffer’ [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(temp_state);
#       ^~~~~~~~~~~~~~~~~~~
# aicasm_scan.l:421:6: warning: implicit declaration of function ‘mmparse’ [-Wimplicit-function-declaration]
#       mm_switch_to_buffer(old_state);
#       ^~~~~~~
# aicasm_scan.l:424:6: warning: implicit declaration of function ‘mm_delete_buffer’ [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(old_state);
#       ^~~~~~~~~~~~~~~~
# make[4]: *** [aicasm] Error 1
# make[3]: *** [drivers/scsi/aic7xxx/aicasm/aicasm] Error 2
# make[2]: *** [drivers/scsi/aic7xxx] Error 2
# make[2]: *** Waiting for unfinished jobs....
# make[1]: *** [drivers/scsi] Error 2
# make[1]: *** Waiting for unfinished jobs....
# make: *** [drivers] Error 2
#
#
# ###### configuration id 84168
# ErrorLog.AICDB
# ErrorLog.AIC7XXX
# drivers/gpu/drm/amd/amdgpu/amdgpu_object.c: In function ‘amdgpu_bo_create_restricted’:
# drivers/gpu/drm/amd/amdgpu/amdgpu_object.c:378:2: warning: #warning Please enable CONFIG_MTRR and CONFIG_X86_PAT for better performance thanks to write-combining [-Wcpp]
#  #warning Please enable CONFIG_MTRR and CONFIG_X86_PAT for better performance \
#   ^~~~~~~
# aicasm_symbol.c:48:19: fatal error: aicdb.h: No such file or directory
#  #include "aicdb.h"
#                    ^
# compilation terminated.
# aicasm_gram.tab.c: In function ‘yyparse’:
# aicasm_gram.tab.c:1628:16: warning: implicit declaration of function ‘yylex’ [-Wimplicit-function-declaration]
# aicasm_macro_gram.tab.c: In function ‘mmparse’:
# /TuxML/linux-4.13.3/drivers/scsi/aic7xxx/aicasm//aicasm_macro_gram.c:64:25: warning: implicit declaration of function ‘mmlex’ [-Wimplicit-function-declaration]
#  #define yylex           mmlex
#                          ^
# aicasm_macro_gram.tab.c:1199:16: note: in expansion of macro ‘yylex’
# aicasm_scan.l: In function ‘yylex’:
# aicasm_scan.l:420:6: warning: implicit declaration of function ‘mm_switch_to_buffer’ [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(temp_state);
#       ^~~~~~~~~~~~~~~~~~~
# aicasm_scan.l:421:6: warning: implicit declaration of function ‘mmparse’ [-Wimplicit-function-declaration]
#       mm_switch_to_buffer(old_state);
#       ^~~~~~~
# aicasm_scan.l:424:6: warning: implicit declaration of function ‘mm_delete_buffer’ [-Wimplicit-function-declaration]
#       yy_switch_to_buffer(old_state);
#       ^~~~~~~~~~~~~~~~
# make[4]: *** [aicasm] Error 1
# make[3]: *** [drivers/scsi/aic7xxx/aicasm/aicasm] Error 2
# make[2]: *** [drivers/scsi/aic7xxx] Error 2
# make[1]: *** [drivers/scsi] Error 2
# make[1]: *** Waiting for unfinished jobs....
# make: *** [drivers] Error 2

# %%
'''
basic conclusion: bug GENERIC_ALLOCATOR + DRM_VBOXVIDEO is not masked by other failures
but may mask other failures 
'''

generic_allocator_mask_notfirmware = rawtuxdata.query("GENERIC_ALLOCATOR == 0 & DRM_VBOXVIDEO == 2 & ~(AIC7XXX_BUILD_FIRMWARE == 1 | AIC79XX_BUILD_FIRMWARE == 1 | WANXL_BUILD_FIRMWARE == 1)  & compile_success == False")


print("generic allocator bug *without* firmwares' failures", generic_allocator_mask_notfirmware.shape)
print()
print()
for cid in generic_allocator_mask_notfirmware['cid']:
    err_pattern = error_pattern.query("cid == " + str(cid)).iloc[0]
    if not (err_pattern[ErrorLog.GEN.name]):
        print ("###### configuration id", cid)
        print("GENERIC allocator NOT found")
    #else:
    #    for err in ErrorLog:
    #        if (err_pattern[err.name]):
    #            print(err)
# Out:
# generic allocator bug *without* firmwares' failures (277, 12654)

# %%
# ~(AIC7XXX_BUILD_FIRMWARE == 1 | AIC79XX_BUILD_FIRMWARE == 1 | WANXL_BUILD_FIRMWARE == 1)  &
# Mathieu: I'm deactivating it, it's time-consuming and error-prone 
if False:
    for path1 in all_paths[::-1]:
        # collect all cids related to a path
        path_cids = rawtuxdata.query(path1 + " & compile_success == False")['cid'].values
        spath_cids = set(path_cids)
        print (path1)
        for path2 in all_paths[::-1]:
            if (path1 != path2):                
                for cid in path_cids:
                    # report whether an alternate path/rule can match the cid 
                    #print (cid)
                    overlap = rawtuxdata.query(path2 + " & compile_success == False & cid == " + str(cid)) #['cid'].values
                    #overlap = list(spath_cids & set(path_cids2)) 
                    if len(overlap) > 0:
                        print(path1, "also hold with\n", path2, "=> #", overlap)
                        print()
    
       
#    for path2 in all_paths:
#        if (path1 != path2):
#            overlap = len(rawtuxdata.query(path1 + " | ~(" + path2 + ") & compile_success == False").index)
#            if  overlap > 0:
#                print(path1, "also hold with\n", path2, "=> #", overlap)
#                print()
        
        
#

# %%
# TODO: classification on clusters!
rawtuxdata = pd.merge(rawtuxdata, error_patternfirst, on='cid', how='outer')

# %%
rawtuxdata.shape, error_patternfirst.shape
# Out:
# ((69362, 12674), (3507, 20))

# %%
rawtuxdata.query(ErrorLog.AICDB.name + " == True").shape
# rawtuxdata['cid']
# configwithclusters['cid']
# Out:
# (2464, 12674)

# %%
for err in ErrorLog:
    rawtuxdata[err.name] = rawtuxdata[err.name].fillna(False)

# %%
'''
create a column with the first kind/cluster of error message that pops out
it will be a label
allows multi-class classification (instead of simply binary classification)
TODO: applies to error_patternfirst and error_pattern
'''

from sklearn.preprocessing import LabelEncoder
# FIXE: enum auto() does not work
def which_pattern(row):
    for err in ErrorLog:
        if (row[err.name]):
            return err.name
    return "NO_FAILURE"
cluster_errorfirst = rawtuxdata.apply(which_pattern, axis=1)
cluster_errorfirst.unique()

# encoding strings as labels
le_cluster = LabelEncoder()
rawtuxdata['cluster_errorfirst'] = le_cluster.fit_transform(cluster_errorfirst)

# %%
from sklearn.model_selection import train_test_split
from sklearn import tree

TESTING_SIZE_CLUSTER= 0.1 #0.99 # 0.001 # 0.9
X_train_cluster, X_test_cluster, y_train_cluster, y_test_cluster = train_test_split(
    rawtuxdata
    .drop(columns=["cid"])
    .drop(columns=['cluster_errorfirst'])
   # .drop(columns=["nb_patterns"])
    .drop(columns=pattern_name)
    .drop(columns=size_methods)
    .drop(columns=compilation_status_column_name), 
    rawtuxdata['cluster_errorfirst'], test_size=TESTING_SIZE_CLUSTER, random_state=0)  

# rawtuxdata[[ErrorLog.AS68K.name, ErrorLog.AICDB.name]] # multi-output
# rawtuxdata[pattern_name]

clf_cluster = tree.DecisionTreeClassifier() #GradientBoostingClassifier(n_estimators=100) #RandomForestRegressor(n_estimators=100) #   #GradientBoostingRegressor(n_estimators=100)  
clf_cluster.fit(X_train_cluster, y_train_cluster)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
y_pred_cluster = clf_cluster.predict(X_test_cluster)

average_method_cl = 'micro'

acc_cl = accuracy_score (y_test_cluster, y_pred_cluster)
prec_cl = precision_score (y_test_cluster, y_pred_cluster, average=average_method_cl)
reca_cl = recall_score (y_test_cluster, y_pred_cluster, average=average_method_cl)
f1_cl = f1_score (y_test_cluster, y_pred_cluster, average=average_method_cl)
balance_acc_cl = balanced_accuracy_score (y_test_cluster, y_pred_cluster)
print("Accuracy score:", acc_cl)
print("Precision score:", prec_cl)
print("Recall score:", reca_cl)
print("F1 score:", f1_cl)
print("Balance accuracy score:", balance_acc_cl)
# Out:
# Accuracy score: 0.9866169596178771
# Precision score: 0.9866169596178771
# Recall score: 0.9866169596178771
# F1 score: 0.9866169596178771
# Balance accuracy score: 0.15902546528953823

# %%
import graphviz 
ft_names =  rawtuxdata.drop(columns=["cid", 'cluster_errorfirst']).drop(columns=pattern_name).drop(columns=size_methods).drop(columns=compilation_status_column_name).columns
# TODO: 
cl_names = list(le_cluster.classes_)
dot_data = tree.export_graphviz(clf_cluster, out_file=None, 
                         feature_names=ft_names,
                         class_names = cl_names,
                         filled=True, rounded=True,
                         special_characters=True)  
graph = graphviz.Source(dot_data)  
graph.render("TUXML_compilation_failures_clusters")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-90-0f04c2692dc7> in <module>
#       2 ft_names =  rawtuxdata.drop(columns=["cid", 'cluster_errorfirst']).drop(columns=pattern_name).drop(columns=size_methods).drop(columns=compilation_status_column_name).columns
#       3 # TODO:
# ----> 4 cl_names = list(le_cluster.classes_)
#       5 dot_data = tree.export_graphviz(clf_cluster, out_file=None,
#       6                          feature_names=ft_names,
#
# NameError: name 'le_cluster' is not defined

# %%
from sklearn.metrics import confusion_matrix
from sklearn.utils.multiclass import unique_labels


def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if not title:
        if normalize:
            title = 'Normalized confusion matrix'
        else:
            title = 'Confusion matrix, without normalization'

    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    # Only use the labels that appear in the data
    classes = classes[unique_labels(y_true, y_pred)]
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        #print("Normalized confusion matrix")
    else:
        #print('Confusion matrix, without normalization')
        pass

    #print(cm)

    fig, ax = plt.subplots(figsize=(15, 15))
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=classes, yticklabels=classes,
           title=title,
           ylabel='True label',
           xlabel='Predicted label')

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return ax


#np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plot_confusion_matrix(y_test_cluster, y_pred_cluster, classes=np.array(cl_names),
                      title='Confusion matrix, without normalization')

# Plot normalized confusion matrix
plot_confusion_matrix(y_test_cluster, y_pred_cluster, classes=np.array(cl_names), normalize=True,
                      title='Normalized confusion matrix')

plt.show()

# %%
np.array(cl_names)

# %%
#error_patternfirst[ErrorLog.I2C.name]
#rawtuxdata.query("cid == 96730")

# %%
rawtuxdata[pattern_name]
# Out:
#        BLACKLIGHT  BLACKLIGHT2  CONFIG_NLS_DEFAULT  CRC32_CLUSTER   V4L2  \
# 0           False        False               False          False  False
# 1           False        False               False          False  False
# 2           False        False               False          False  False
# 3           False        False               False          False  False
# 4           False        False               False          False  False
# 5           False        False               False          False  False
# 6           False        False               False          False  False
# 7           False        False               False          False  False
# 8           False        False               False          False  False
# 9           False        False               False          False  False
# 10          False        False               False          False  False
# 11          False        False               False          False  False
# 12          False        False               False          False  False
# 13          False        False               False          False  False
# 14          False        False               False          False  False
# 15          False        False               False          False  False
# 16          False        False               False          False  False
# 17          False        False               False          False  False
# 18          False        False               False          False  False
# 19          False        False               False          False  False
# 20          False        False               False          False  False
# 21          False        False               False          False  False
# 22          False        False               False          False  False
# 23          False        False               False          False  False
# 24          False        False               False          False  False
# 25          False        False               False          False  False
# 26          False        False               False          False  False
# 27          False        False               False          False  False
# 28          False        False               False          False  False
# 29          False        False               False          False  False
# ...           ...          ...                 ...            ...    ...
# 69332       False        False               False          False  False
# 69333       False        False               False          False  False
# 69334       False        False               False          False  False
# 69335       False        False               False          False  False
# 69336       False        False               False          False  False
# 69337       False        False               False          False  False
# 69338       False        False               False          False  False
# 69339       False        False               False          False  False
# 69340       False        False               False          False  False
# 69341       False        False               False          False  False
# 69342       False        False               False          False  False
# 69343       False        False               False          False  False
# 69344       False        False               False          False  False
# 69345       False        False               False          False  False
# 69346       False        False               False          False  False
# 69347       False        False               False          False  False
# 69348       False        False               False          False  False
# 69349       False        False               False          False  False
# 69350       False        False               False          False  False
# 69351       False        False               False          False  False
# 69352       False        False               False          False  False
# 69353       False        False               False          False  False
# 69354       False        False               False          False  False
# 69355       False        False               False          False  False
# 69356       False        False               False          False  False
# 69357       False        False               False          False  False
# 69358       False        False               False          False  False
# 69359       False        False               False          False  False
# 69360       False        False               False          False  False
# 69361       False        False               False          False  False
#
#        OVERFLOW2   ULPI    PCM    TTM  AS68K    GEN  AICDB  AIC7XXX  \
# 0          False  False  False  False  False  False  False    False
# 1          False  False  False  False  False  False  False    False
# 2          False  False  False  False  False  False  False    False
# 3          False  False  False  False  False  False  False    False
# 4          False  False  False  False  False  False  False    False
# 5          False  False  False  False  False  False  False    False
# 6          False  False  False  False  False  False  False    False
# 7          False  False  False  False  False  False  False    False
# 8          False  False  False  False  False  False  False    False
# 9          False  False  False  False  False  False  False    False
# 10         False  False  False  False  False  False  False    False
# 11         False  False  False  False  False  False  False    False
# 12         False  False  False  False  False  False  False    False
# 13         False  False  False  False  False  False  False    False
# 14         False  False  False  False  False  False  False    False
# 15         False  False  False  False  False  False  False    False
# 16         False  False  False  False  False  False  False    False
# 17         False  False  False  False  False  False  False    False
# 18         False  False  False  False  False  False  False    False
# 19         False  False  False  False  False  False  False    False
# 20         False  False  False  False  False  False  False    False
# 21         False  False  False  False  False  False  False    False
# 22         False  False  False  False  False  False  False    False
# 23         False  False  False  False  False  False  False    False
# 24         False  False  False  False  False  False  False    False
# 25         False  False  False  False  False  False  False    False
# 26         False  False  False  False  False  False  False    False
# 27         False  False  False  False  False  False  False    False
# 28         False  False  False  False  False  False  False    False
# 29         False  False  False  False  False  False  False    False
# ...          ...    ...    ...    ...    ...    ...    ...      ...
# 69332      False  False  False  False  False  False  False    False
# 69333      False  False  False  False  False  False  False    False
# 69334      False  False  False  False  False  False  False    False
# 69335      False  False  False  False  False  False  False    False
# 69336      False  False  False  False  False  False  False    False
# 69337      False  False  False  False  False  False  False    False
# 69338      False  False  False  False  False  False  False    False
# 69339      False  False  False  False  False  False  False    False
# 69340      False  False  False  False  False  False  False    False
# 69341      False  False  False  False  False  False  False    False
# 69342      False  False  False  False  False  False  False    False
# 69343      False  False  False  False  False  False  False    False
# 69344      False  False  False  False  False  False  False    False
# 69345      False  False  False  False  False  False  False    False
# 69346      False  False  False  False  False  False  False    False
# 69347      False  False  False  False  False  False  False    False
# 69348      False  False  False  False  False  False  False    False
# 69349      False  False  False  False  False  False  False    False
# 69350      False  False  False  False  False  False  False    False
# 69351      False  False  False  False  False  False  False    False
# 69352      False  False  False  False  False  False  False    False
# 69353      False  False  False  False  False  False  False    False
# 69354      False  False  False  False  False  False  False    False
# 69355      False  False  False  False  False  False  False    False
# 69356      False  False  False  False  False  False  False    False
# 69357      False  False  False  False  False  False  False    False
# 69358      False  False  False  False  False  False  False    False
# 69359      False  False  False  False  False  False  False    False
# 69360      False  False  False  False  False  False  False    False
# 69361      False  False  False  False  False  False  False    False
#
#        DRM_BRIDGE_CLUSTER  PINCTRL_CLUSTER  BTBCM  BPFFANCY   DEVM  DEVM2  \
# 0                   False            False  False     False  False  False
# 1                   False            False  False     False  False  False
# 2                   False            False  False     False  False  False
# 3                   False            False  False     False  False  False
# 4                   False            False  False     False  False  False
# 5                   False            False  False     False  False  False
# 6                   False            False  False     False  False  False
# 7                   False            False  False     False  False  False
# 8                   False            False  False     False  False  False
# 9                   False            False  False     False  False  False
# 10                  False            False  False     False  False  False
# 11                  False            False  False     False  False  False
# 12                  False            False  False     False  False  False
# 13                  False            False  False     False  False  False
# 14                  False            False  False     False  False  False
# 15                  False            False  False     False  False  False
# 16                  False            False  False     False  False  False
# 17                  False            False  False     False  False  False
# 18                  False            False  False     False  False  False
# 19                  False            False  False     False  False  False
# 20                  False            False  False     False  False  False
# 21                  False            False  False     False  False  False
# 22                  False            False  False     False  False  False
# 23                  False            False  False     False  False  False
# 24                  False            False  False     False  False  False
# 25                  False            False  False     False  False  False
# 26                  False            False  False     False  False  False
# 27                  False            False  False     False  False  False
# 28                  False            False  False     False  False  False
# 29                  False            False  False     False  False  False
# ...                   ...              ...    ...       ...    ...    ...
# 69332               False            False  False     False  False  False
# 69333               False            False  False     False  False  False
# 69334               False            False  False     False  False  False
# 69335               False            False  False     False  False  False
# 69336               False            False  False     False  False  False
# 69337               False            False  False     False  False  False
# 69338               False            False  False     False  False  False
# 69339               False            False  False     False  False  False
# 69340               False            False  False     False  False  False
# 69341               False            False  False     False  False  False
# 69342               False            False  False     False  False  False
# 69343               False            False  False     False  False  False
# 69344               False            False  False     False  False  False
# 69345               False            False  False     False  False  False
# 69346               False            False  False     False  False  False
# 69347               False            False  False     False  False  False
# 69348               False            False  False     False  False  False
# 69349               False            False  False     False  False  False
# 69350               False            False  False     False  False  False
# 69351               False            False  False     False  False  False
# 69352               False            False  False     False  False  False
# 69353               False            False  False     False  False  False
# 69354               False            False  False     False  False  False
# 69355               False            False  False     False  False  False
# 69356               False            False  False     False  False  False
# 69357               False            False  False     False  False  False
# 69358               False            False  False     False  False  False
# 69359               False            False  False     False  False  False
# 69360               False            False  False     False  False  False
# 69361               False            False  False     False  False  False
#
#        I2C_CLUSTER
# 0            False
# 1            False
# 2            False
# 3            False
# 4            False
# 5            False
# 6            False
# 7            False
# 8            False
# 9            False
# 10           False
# 11           False
# 12           False
# 13           False
# 14           False
# 15           False
# 16           False
# 17           False
# 18           False
# 19           False
# 20           False
# 21           False
# 22           False
# 23           False
# 24           False
# 25           False
# 26           False
# 27           False
# 28           False
# 29           False
# ...            ...
# 69332        False
# 69333        False
# 69334        False
# 69335        False
# 69336        False
# 69337        False
# 69338        False
# 69339        False
# 69340        False
# 69341        False
# 69342        False
# 69343        False
# 69344        False
# 69345        False
# 69346        False
# 69347        False
# 69348        False
# 69349        False
# 69350        False
# 69351        False
# 69352        False
# 69353        False
# 69354        False
# 69355        False
# 69356        False
# 69357        False
# 69358        False
# 69359        False
# 69360        False
# 69361        False
#
# [69362 rows x 20 columns]

# %%
for path in all_paths[::-1]: # all_paths[::-1]:
    configs_path = rawtuxdata.query(path + " & compile_success == False")
    clusters_path = []
    for ind, cfg in configs_path.iterrows():  
        cluster_cfg = []
        for err in ErrorLog:
            if(cfg[err.name]):
                cluster_cfg.append(err.name)                
        assert(len(set(cluster_cfg)) == 1)
        clusters_path.append(cluster_cfg[0])
                
    print(path, "=>", set(clusters_path))
    print()
        
    # configs_path['cid'].values
# Out:
# AIC79XX_BUILD_FIRMWARE > 0.5 => {'AS68K', 'OVERFLOW2', 'AIC7XXX', 'AICDB'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE > 0.5 => {'AS68K', 'OVERFLOW2', 'AIC7XXX', 'AICDB'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE > 0.5 => {'AS68K'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL > 0.5 & INFINIBAND_ADDR_TRANS > 0.5 & FORTIFY_SOURCE > 0.5 & IPV6 > 1.5 & NEW_LEDS <= 0.5 => {'DEVM2'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL > 0.5 & INFINIBAND_ADDR_TRANS > 0.5 & FORTIFY_SOURCE > 0.5 & IPV6 <= 1.5 & IPV6 > 0.5 & UBSAN_NULL > 0.5 => {'OVERFLOW2'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL > 0.5 & INFINIBAND_ADDR_TRANS > 0.5 & FORTIFY_SOURCE > 0.5 & IPV6 <= 1.5 & IPV6 > 0.5 & UBSAN_NULL <= 0.5 & UBSAN_ALIGNMENT > 0.5 => {'OVERFLOW2'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL > 0.5 & INFINIBAND_ADDR_TRANS <= 0.5 & I40EVF > 0.5 & VIDEO_XILINX_TPG <= 0.5 & SCR24X > 1.5 => {'V4L2'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL > 0.5 & INFINIBAND_ADDR_TRANS <= 0.5 & I40EVF <= 0.5 & HID_LOGITECH > 1.5 => {'TTM'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS > 0.5 & PATA_SCH > 0.5 & NLS > 1.5 & USB_F_TCM > 0.5 & XENFS > 0.5 & PTP_1588_CLOCK_GIANFAR > 0.5 & INFINIBAND_QEDR > 1.5 & GPIOLIB <= 0.5 & MAX77620_THERMAL > 1.5 => {'PINCTRL_CLUSTER'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS > 0.5 & PATA_SCH > 0.5 & NLS > 1.5 & USB_F_TCM > 0.5 & XENFS > 0.5 & PTP_1588_CLOCK_GIANFAR > 0.5 & INFINIBAND_QEDR <= 1.5 & BCM_VIDEOCORE > 0.5 & CRYPTO_CRYPTD > 0.5 & VIDEO_SOLO6X10 > 1.5 & MEMCG_SWAP_ENABLED > 0.5 & NFC_TRF7970A > 1.5 => {'BLACKLIGHT2'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS > 0.5 & PATA_SCH > 0.5 & NLS > 1.5 & USB_F_TCM > 0.5 & XENFS > 0.5 & PTP_1588_CLOCK_GIANFAR > 0.5 & INFINIBAND_QEDR <= 1.5 & BCM_VIDEOCORE > 0.5 & CRYPTO_CRYPTD <= 0.5 & USB_SL811_CS > 1.5 => {'PINCTRL_CLUSTER'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS > 0.5 & PATA_SCH > 0.5 & NLS > 1.5 & USB_F_TCM > 0.5 & XENFS > 0.5 & PTP_1588_CLOCK_GIANFAR > 0.5 & INFINIBAND_QEDR <= 1.5 & BCM_VIDEOCORE <= 0.5 & NFC_PN544_I2C > 1.5 => {'TTM'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS > 0.5 & PATA_SCH > 0.5 & NLS > 1.5 & USB_F_TCM > 0.5 & XENFS > 0.5 & PTP_1588_CLOCK_GIANFAR > 0.5 & INFINIBAND_QEDR <= 1.5 & BCM_VIDEOCORE <= 0.5 & NFC_PN544_I2C <= 1.5 & DVB_BUDGET > 1.5 & GPIO_TWL6040 <= 0.5 => {'BLACKLIGHT'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS > 0.5 & PATA_SCH > 0.5 & NLS > 1.5 & USB_F_TCM > 0.5 & XENFS > 0.5 & PTP_1588_CLOCK_GIANFAR <= 0.5 & BT_HCIUART_NOKIA > 1.5 => {'BTBCM'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS > 0.5 & PATA_SCH > 0.5 & NLS > 1.5 & USB_F_TCM > 0.5 & XENFS <= 0.5 & SND_AT73C213 > 1.5 & SND_DMAENGINE_PCM <= 0.5 => {'BLACKLIGHT'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS > 0.5 & PATA_SCH > 0.5 & NLS > 1.5 & USB_F_TCM > 0.5 & XENFS <= 0.5 & SND_AT73C213 <= 1.5 & BLK_DEV_THROTTLING_LOW > 0.5 & LCD_L4F00242T03 > 1.5 => {'DRM_BRIDGE_CLUSTER'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS > 0.5 & PATA_SCH > 0.5 & NLS > 1.5 & USB_F_TCM > 0.5 & XENFS <= 0.5 & SND_AT73C213 <= 1.5 & BLK_DEV_THROTTLING_LOW > 0.5 & LCD_L4F00242T03 <= 1.5 & X86_PKG_TEMP_THERMAL > 1.5 => {'BLACKLIGHT'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS > 0.5 & PATA_SCH > 0.5 & NLS > 1.5 & USB_F_TCM <= 0.5 & VIDEO_CX88_ENABLE_VP3054 > 0.5 & MFD_MAX14577 > 1.5 => {'PINCTRL_CLUSTER'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS > 0.5 & PATA_SCH > 0.5 & NLS > 1.5 & USB_F_TCM <= 0.5 & VIDEO_CX88_ENABLE_VP3054 <= 0.5 & ACPI_CUSTOM_DSDT_FILE <= 4063.5 & BLK_MQ_VIRTIO <= 0.5 => {'DRM_BRIDGE_CLUSTER', 'BLACKLIGHT'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS > 0.5 & PATA_SCH > 0.5 & NLS <= 1.5 & BLK_DEV_SIIMAGE > 1.5 & FB_VIA > 0.5 => {'CONFIG_NLS_DEFAULT'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS > 0.5 & PATA_SCH > 0.5 & NLS <= 1.5 & BLK_DEV_SIIMAGE <= 1.5 & PARIDE_EPIA > 1.5 => {'CONFIG_NLS_DEFAULT'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS > 0.5 & PATA_SCH > 0.5 & NLS <= 1.5 & BLK_DEV_SIIMAGE <= 1.5 & PARIDE_EPIA <= 1.5 & TCM_USER2 > 1.5 & AXP20X_POWER > 1.0 => {'CONFIG_NLS_DEFAULT'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS > 0.5 & PATA_SCH <= 0.5 & CAN_EMS_PCI > 1.5 & COMEDI_MITE <= 0.5 => {'TTM'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS > 0.5 & PATA_SCH <= 0.5 & CAN_EMS_PCI <= 1.5 & INTEL_SOC_PMIC_BXTWC > 1.5 & PATA_RZ1000 > 1.5 => {'TTM'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS <= 0.5 & SND_SOC_INTEL_BYT_CHT_ES8316_MACH > 1.5 & CRYPTO_WP512 <= 0.5 => {'TTM'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS <= 0.5 & SND_SOC_INTEL_BYT_CHT_ES8316_MACH <= 1.5 & SND_PDAUDIOCF > 1.5 & RESET_TI_SYSCON > 1.5 => {'DRM_BRIDGE_CLUSTER'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS <= 0.5 & SND_SOC_INTEL_BYT_CHT_ES8316_MACH <= 1.5 & SND_PDAUDIOCF <= 1.5 & TYPEC_WCOVE > 1.5 & FSL_FTM_TIMER > 0.5 => {'TTM'}
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS <= 0.5 & SND_SOC_INTEL_BYT_CHT_ES8316_MACH <= 1.5 & SND_PDAUDIOCF <= 1.5 & TYPEC_WCOVE <= 1.5 & CAN_GS_USB > 1.5 & JOYSTICK_XPAD > 1.5 => {'BLACKLIGHT'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS <= 0.5 & SND_SOC_INTEL_BYT_CHT_ES8316_MACH <= 1.5 & SND_PDAUDIOCF <= 1.5 & TYPEC_WCOVE <= 1.5 & CAN_GS_USB <= 1.5 & SND_ATMEL_SOC > 1.5 & DMA_VIRTUAL_CHANNELS <= 0.5 => {'DEVM'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS <= 0.5 & SND_SOC_INTEL_BYT_CHT_ES8316_MACH <= 1.5 & SND_PDAUDIOCF <= 1.5 & TYPEC_WCOVE <= 1.5 & CAN_GS_USB <= 1.5 & SND_ATMEL_SOC <= 1.5 & IIO_CROS_EC_LIGHT_PROX > 1.5 & RTC_DRV_88PM80X > 1.5 => {'TTM'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO <= 0.5 & BRIDGE_EBT_LOG > 1.5 => {'BLACKLIGHT'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO <= 0.5 & BRIDGE_EBT_LOG <= 1.5 & SND_SOC_CS42L51_I2C > 1.5 => {'DEVM'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE <= 0.5 & PWRSEQ_SD8787 > 1.5 => {'TTM'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE <= 0.5 & PWRSEQ_SD8787 <= 1.5 & CAN_C_CAN_PCI > 1.5 & HVC_DRIVER > 0.5 => {'BTBCM'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE <= 0.5 & PWRSEQ_SD8787 <= 1.5 & CAN_C_CAN_PCI <= 1.5 & VIDEO_MUX > 1.5 & CRYPTO_RMD256 <= 1.0 => {'V4L2'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE <= 0.5 & PWRSEQ_SD8787 <= 1.5 & CAN_C_CAN_PCI <= 1.5 & VIDEO_MUX <= 1.5 & GPIOLIB_IRQCHIP <= 0.5 & TTY_PRINTK > 1.5 => {'BLACKLIGHT'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP <= 0.5 & FPGA_MGR_SOCFPGA > 1.5 => {'I2C_CLUSTER', 'V4L2'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 <= 1.0 & MAX1363 > 1.5 => {'CRC32_CLUSTER'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG <= 0.5 & FW_LOADER > 1.0 & IR_SPI > 1.5 => {'V4L2'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG <= 0.5 & FW_LOADER > 1.0 & IR_SPI <= 1.5 & NFS_V3_ACL > 0.5 => {'V4L2'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG <= 0.5 & FW_LOADER > 1.0 & IR_SPI <= 1.5 & NFS_V3_ACL <= 0.5 & CHARGER_CPCAP > 1.5 => {'V4L2'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG <= 0.5 & FW_LOADER > 1.0 & IR_SPI <= 1.5 & NFS_V3_ACL <= 0.5 & CHARGER_CPCAP <= 1.5 & CFAG12864B > 1.5 & DVB_EC100 <= 0.5 => {'V4L2'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG <= 0.5 & FW_LOADER > 1.0 & IR_SPI <= 1.5 & NFS_V3_ACL <= 0.5 & CHARGER_CPCAP <= 1.5 & CFAG12864B <= 1.5 & MAC80211_MPL_DEBUG > 0.5 & TEST_PRINTF > 1.5 => {'V4L2'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG <= 0.5 & FW_LOADER <= 1.0 => {'V4L2'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR <= 0.5 & DRM_VBOXVIDEO > 1.5 => {'TTM', 'GEN'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR <= 0.5 & DRM_VBOXVIDEO <= 1.5 & MLX5_INFINIBAND > 0.5 & ISDN_DIVAS_USERIDI > 0.5 & INFINIBAND_SRPT > 1.5 & SCSI_SRP_ATTRS <= 1.5 => {'OVERFLOW2'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR <= 0.5 & DRM_VBOXVIDEO <= 1.5 & MLX5_INFINIBAND > 0.5 & ISDN_DIVAS_USERIDI > 0.5 & INFINIBAND_SRPT <= 1.5 & WIL6210_TRACING > 0.5 & VIDEO_BT856 > 1.5 => {'OVERFLOW2'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR <= 0.5 & DRM_VBOXVIDEO <= 1.5 & MLX5_INFINIBAND > 0.5 & ISDN_DIVAS_USERIDI > 0.5 & INFINIBAND_SRPT <= 1.5 & WIL6210_TRACING <= 0.5 & XEN_PCIDEV_BACKEND > 1.5 & DVB_DIB7000M > 1.5 => {'OVERFLOW2'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR <= 0.5 & DRM_VBOXVIDEO <= 1.5 & MLX5_INFINIBAND > 0.5 & ISDN_DIVAS_USERIDI > 0.5 & INFINIBAND_SRPT <= 1.5 & WIL6210_TRACING <= 0.5 & XEN_PCIDEV_BACKEND <= 1.5 & FB_GEODE_GX <= 0.5 & TI_ADC128S052 > 1.5 => {'BLACKLIGHT'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR <= 0.5 & DRM_VBOXVIDEO <= 1.5 & MLX5_INFINIBAND > 0.5 & ISDN_DIVAS_USERIDI <= 0.5 & MICROCHIP_KSZ <= 0.5 => {'OVERFLOW2'}
#
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR <= 0.5 & DRM_VBOXVIDEO <= 1.5 & MLX5_INFINIBAND <= 0.5 & XEN_FBDEV_FRONTEND > 0.5 => {'OVERFLOW2'}

# %%
# rawtuxdata['PM_STD_PARTITION']

# %%
cluster_to_paths = []
for cluster in ErrorLog:
    configs_cluster = rawtuxdata.query(cluster.name + " == True " + "& compile_success == False")
    path_clusters = []
    for ind, cfg in configs_cluster.iterrows():  
        cid = cfg['cid']
        # print(cid)
        # path = find_rule_for_configuration_id(cid)       
        path = find_rule_for_configuration(clf, rawtuxdata.drop(columns=pattern_name).drop(columns=["cid"]).drop(columns=size_methods).drop(columns=compilation_status_column_name).columns, rawtuxdata.query("cid == " + str(cid)).iloc[0])        
        path_clusters.append(path)
                
    print(cluster, "=>", set(path_clusters))
    print()
    cluster_to_paths.append({ cluster : set(path_clusters) })
# Out:
# ErrorLog.BLACKLIGHT => {'AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS <= 0.5 & SND_SOC_INTEL_BYT_CHT_ES8316_MACH <= 1.5 & SND_PDAUDIOCF <= 1.5 & TYPEC_WCOVE <= 1.5 & CAN_GS_USB > 1.5 & JOYSTICK_XPAD > 1.5', 'AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS > 0.5 & PATA_SCH > 0.5 & NLS > 1.5 & USB_F_TCM > 0.5 & XENFS <= 0.5 & SND_AT73C213 > 1.5 & SND_DMAENGINE_PCM <= 0.5', 'AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO <= 0.5 & BRIDGE_EBT_LOG > 1.5', 'AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR <= 0.5 & DRM_VBOXVIDEO <= 1.5 & MLX5_INFINIBAND > 0.5 & ISDN_DIVAS_USERIDI > 0.5 & INFINIBAND_SRPT <= 1.5 & WIL6210_TRACING <= 0.5 & XEN_PCIDEV_BACKEND <= 1.5 & FB_GEODE_GX <= 0.5 & TI_ADC128S052 > 1.5', 'AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS > 0.5 & PATA_SCH > 0.5 & NLS > 1.5 & USB_F_TCM > 0.5 & XENFS > 0.5 & PTP_1588_CLOCK_GIANFAR > 0.5 & INFINIBAND_QEDR <= 1.5 & BCM_VIDEOCORE <= 0.5 & NFC_PN544_I2C <= 1.5 & DVB_BUDGET > 1.5 & GPIO_TWL6040 <= 0.5', 'AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS > 0.5 & PATA_SCH > 0.5 & NLS > 1.5 & USB_F_TCM <= 0.5 & VIDEO_CX88_ENABLE_VP3054 <= 0.5 & ACPI_CUSTOM_DSDT_FILE <= 4063.5 & BLK_MQ_VIRTIO <= 0.5', 'AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE <= 0.5 & PWRSEQ_SD8787 <= 1.5 & CAN_C_CAN_PCI <= 1.5 & VIDEO_MUX <= 1.5 & GPIOLIB_IRQCHIP <= 0.5 & TTY_PRINTK > 1.5', 'AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS > 0.5 & PATA_SCH > 0.5 & NLS > 1.5 & USB_F_TCM > 0.5 & XENFS <= 0.5 & SND_AT73C213 <= 1.5 & BLK_DEV_THROTTLING_LOW > 0.5 & LCD_L4F00242T03 <= 1.5 & X86_PKG_TEMP_THERMAL > 1.5'}
#
# ErrorLog.BLACKLIGHT2 => {'AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS > 0.5 & PATA_SCH > 0.5 & NLS > 1.5 & USB_F_TCM > 0.5 & XENFS > 0.5 & PTP_1588_CLOCK_GIANFAR > 0.5 & INFINIBAND_QEDR <= 1.5 & BCM_VIDEOCORE > 0.5 & CRYPTO_CRYPTD > 0.5 & VIDEO_SOLO6X10 > 1.5 & MEMCG_SWAP_ENABLED > 0.5 & NFC_TRF7970A > 1.5'}
#
# ErrorLog.CONFIG_NLS_DEFAULT => {'AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS > 0.5 & PATA_SCH > 0.5 & NLS <= 1.5 & BLK_DEV_SIIMAGE <= 1.5 & PARIDE_EPIA > 1.5', 'AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS > 0.5 & PATA_SCH > 0.5 & NLS <= 1.5 & BLK_DEV_SIIMAGE > 1.5 & FB_VIA > 0.5', 'AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS > 0.5 & PATA_SCH > 0.5 & NLS <= 1.5 & BLK_DEV_SIIMAGE <= 1.5 & PARIDE_EPIA <= 1.5 & TCM_USER2 > 1.5 & AXP20X_POWER > 1.0'}
#
# ErrorLog.CRC32_CLUSTER => {'AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 <= 1.0 & MAX1363 > 1.5'}
#
# ErrorLog.V4L2 => {'AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG <= 0.5 & FW_LOADER > 1.0 & IR_SPI > 1.5', 'AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP <= 0.5 & FPGA_MGR_SOCFPGA > 1.5', 'AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE <= 0.5 & PWRSEQ_SD8787 <= 1.5 & CAN_C_CAN_PCI <= 1.5 & VIDEO_MUX > 1.5 & CRYPTO_RMD256 <= 1.0', 'AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG <= 0.5 & FW_LOADER > 1.0 & IR_SPI <= 1.5 & NFS_V3_ACL <= 0.5 & CHARGER_CPCAP > 1.5', 'AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL > 0.5 & INFINIBAND_ADDR_TRANS <= 0.5 & I40EVF > 0.5 & VIDEO_XILINX_TPG <= 0.5 & SCR24X > 1.5', 'AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG <= 0.5 & FW_LOADER > 1.0 & IR_SPI <= 1.5 & NFS_V3_ACL <= 0.5 & CHARGER_CPCAP <= 1.5 & CFAG12864B <= 1.5 & MAC80211_MPL_DEBUG > 0.5 & TEST_PRINTF > 1.5', 'AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG <= 0.5 & FW_LOADER > 1.0 & IR_SPI <= 1.5 & NFS_V3_ACL <= 0.5 & CHARGER_CPCAP <= 1.5 & CFAG12864B > 1.5 & DVB_EC100 <= 0.5', 'AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG <= 0.5 & FW_LOADER <= 1.0', 'AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG <= 0.5 & FW_LOADER > 1.0 & IR_SPI <= 1.5 & NFS_V3_ACL > 0.5'}
#
# ErrorLog.OVERFLOW2 => {'AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR <= 0.5 & DRM_VBOXVIDEO <= 1.5 & MLX5_INFINIBAND > 0.5 & ISDN_DIVAS_USERIDI > 0.5 & INFINIBAND_SRPT <= 1.5 & WIL6210_TRACING <= 0.5 & XEN_PCIDEV_BACKEND > 1.5 & DVB_DIB7000M > 1.5', 'AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE > 0.5', 'AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR <= 0.5 & DRM_VBOXVIDEO <= 1.5 & MLX5_INFINIBAND > 0.5 & ISDN_DIVAS_USERIDI > 0.5 & INFINIBAND_SRPT <= 1.5 & WIL6210_TRACING > 0.5 & VIDEO_BT856 > 1.5', 'AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR <= 0.5 & DRM_VBOXVIDEO <= 1.5 & MLX5_INFINIBAND > 0.5 & ISDN_DIVAS_USERIDI <= 0.5 & MICROCHIP_KSZ <= 0.5', 'AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL > 0.5 & INFINIBAND_ADDR_TRANS > 0.5 & FORTIFY_SOURCE > 0.5 & IPV6 <= 1.5 & IPV6 > 0.5 & UBSAN_NULL > 0.5', 'AIC79XX_BUILD_FIRMWARE > 0.5', 'AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL > 0.5 & INFINIBAND_ADDR_TRANS > 0.5 & FORTIFY_SOURCE > 0.5 & IPV6 <= 1.5 & IPV6 > 0.5 & UBSAN_NULL <= 0.5 & UBSAN_ALIGNMENT > 0.5', 'AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR <= 0.5 & DRM_VBOXVIDEO <= 1.5 & MLX5_INFINIBAND > 0.5 & ISDN_DIVAS_USERIDI > 0.5 & INFINIBAND_SRPT > 1.5 & SCSI_SRP_ATTRS <= 1.5', 'AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR <= 0.5 & DRM_VBOXVIDEO <= 1.5 & MLX5_INFINIBAND <= 0.5 & XEN_FBDEV_FRONTEND > 0.5'}
#
# ErrorLog.ULPI => set()
#
# ErrorLog.PCM => set()
# ErrorLog.TTM => {'AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS > 0.5 & PATA_SCH <= 0.5 & CAN_EMS_PCI > 1.5 & COMEDI_MITE <= 0.5', 'AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR <= 0.5 & DRM_VBOXVIDEO > 1.5', 'AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL > 0.5 & INFINIBAND_ADDR_TRANS <= 0.5 & I40EVF <= 0.5 & HID_LOGITECH > 1.5', 'AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS <= 0.5 & SND_SOC_INTEL_BYT_CHT_ES8316_MACH > 1.5 & CRYPTO_WP512 <= 0.5', 'AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS <= 0.5 & SND_SOC_INTEL_BYT_CHT_ES8316_MACH <= 1.5 & SND_PDAUDIOCF <= 1.5 & TYPEC_WCOVE <= 1.5 & CAN_GS_USB <= 1.5 & SND_ATMEL_SOC <= 1.5 & IIO_CROS_EC_LIGHT_PROX > 1.5 & RTC_DRV_88PM80X > 1.5', 'AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE <= 0.5 & PWRSEQ_SD8787 > 1.5', 'AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS > 0.5 & PATA_SCH > 0.5 & NLS > 1.5 & USB_F_TCM > 0.5 & XENFS > 0.5 & PTP_1588_CLOCK_GIANFAR > 0.5 & INFINIBAND_QEDR <= 1.5 & BCM_VIDEOCORE <= 0.5 & NFC_PN544_I2C > 1.5', 'AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS <= 0.5 & SND_SOC_INTEL_BYT_CHT_ES8316_MACH <= 1.5 & SND_PDAUDIOCF <= 1.5 & TYPEC_WCOVE > 1.5 & FSL_FTM_TIMER > 0.5', 'AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR > 0.5 & UBSAN_SANITIZE_ALL <= 0.5 & VIDEO_XILINX_TPG > 0.5 & CRC32 > 1.0 & VIDEO_ATOMISP > 0.5 & EDAC_DECODE_MCE > 0.5 & RSI_SDIO > 0.5 & SPEAKUP_SYNTH_BNS > 0.5 & PATA_SCH <= 0.5 & CAN_EMS_PCI <= 1.5 & INTEL_SOC_PMIC_BXTWC > 1.5 & PATA_RZ1000 > 1.5'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-57-80758442d0a3> in <module>
#       7         # print(cid)
#       8         # path = find_rule_for_configuration_id(cid)
# ----> 9         path = find_rule_for_configuration(clf, rawtuxdata.drop(columns=pattern_name).drop(columns=["cid"]).drop(columns=size_methods).drop(columns=compilation_status_column_name).columns, rawtuxdata.query("cid == " + str(cid)).iloc[0])
#      10         path_clusters.append(path)
#      11
#
# KeyboardInterrupt:

# %%
#cluster_to_paths

# %%
# AIC79XX_BUILD_FIRMWARE <= 0.5 & AIC7XXX_BUILD_FIRMWARE <= 0.5 & WANXL_BUILD_FIRMWARE <= 0.5 & GENERIC_ALLOCATOR <= 0.5 & DRM_VBOXVIDEO > 1.5
rawtuxdata.query("AIC79XX_BUILD_FIRMWARE > 0.5 & GENERIC_ALLOCATOR <= 0.5 & DRM_VBOXVIDEO > 1.5")[['compile_success', ErrorLog.AICDB.name]]

# %%
# del cluster_errorfirst
